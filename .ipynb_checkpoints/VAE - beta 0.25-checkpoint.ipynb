# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

#Build the encoder
encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Build the decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + 0.25 * kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + 0.25 * kl_loss

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d_5 (Conv1D)              (None, 88, 8)        32          ['input_3[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 44, 8)       0           ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_6[0][0]']
#
#  flatten_1 (Flatten)            (None, 352)          0           ['max_pooling1d_3[0][0]']
#
#  dense_3 (Dense)                (None, 128)          45184       ['flatten_1[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_3[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_3[0][0]']
#
#  sampling_1 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 128)               384
#
#  dense_5 (Dense)             (None, 704)               90816
#
#  reshape_1 (Reshape)         (None, 88, 8)             0
#
#  conv1d_7 (Conv1D)           (None, 88, 16)            400
#
#  up_sampling1d_2 (UpSampling  (None, 176, 16)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 176, 8)            392
#
#  up_sampling1d_3 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 352, 1)            25
#
#  cropping1d_1 (Cropping1D)   (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(
                                    features, labels, test_size=0.2, random_state=42)

x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]

x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
learn_rate = [0.001, 0.005, 0.008, 0.01]
batch_size = [32, 64, 128, 256]

param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

for lr in learn_rate:
    for bs in batch_size:
        print("Learning rate: ", lr)
        print("Batch size: ", bs)
        
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))
        
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
        early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
        
        vae.fit(x_train, batch_size=bs, epochs=30, validation_split = 0.2, 
                callbacks=[reduce_lr, early_stop])

        score = vae.evaluate(x_test)
        print(score)

        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Learning rate:  0.001
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 8ms/step - loss: 1.4312 - reconstruction_loss: 1.2240 - kl_loss: 0.0109 - val_total_loss: 1.0510 - val_reconstruction_loss: 1.0450 - val_kl_loss: 0.0239 - lr: 0.0010
# Epoch 2/30
# 210/210 [==============================] - 1s 7ms/step - loss: 1.0019 - reconstruction_loss: 0.9827 - kl_loss: 0.0284 - val_total_loss: 1.0541 - val_reconstruction_loss: 1.0411 - val_kl_loss: 0.0520 - lr: 0.0010
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9569 - reconstruction_loss: 0.9204 - kl_loss: 0.1296 - val_total_loss: 1.0187 - val_reconstruction_loss: 0.9514 - val_kl_loss: 0.2696 - lr: 0.0010
# Epoch 4/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9357 - reconstruction_loss: 0.8423 - kl_loss: 0.3142 - val_total_loss: 0.8944 - val_reconstruction_loss: 0.7831 - val_kl_loss: 0.4453 - lr: 0.0010
# Epoch 5/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9083 - reconstruction_loss: 0.8139 - kl_loss: 0.3815 - val_total_loss: 0.8765 - val_reconstruction_loss: 0.7506 - val_kl_loss: 0.5036 - lr: 0.0010
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9167 - reconstruction_loss: 0.7976 - kl_loss: 0.4216 - val_total_loss: 1.0432 - val_reconstruction_loss: 0.9307 - val_kl_loss: 0.4499 - lr: 0.0010
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8754 - reconstruction_loss: 0.7827 - kl_loss: 0.4511 - val_total_loss: 0.8954 - val_reconstruction_loss: 0.7367 - val_kl_loss: 0.6347 - lr: 0.0010
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8970 - reconstruction_loss: 0.7713 - kl_loss: 0.4727 - val_total_loss: 0.8685 - val_reconstruction_loss: 0.7046 - val_kl_loss: 0.6555 - lr: 0.0010
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8968 - reconstruction_loss: 0.7663 - kl_loss: 0.4852 - val_total_loss: 1.0282 - val_reconstruction_loss: 0.8563 - val_kl_loss: 0.6875 - lr: 0.0010
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8870 - reconstruction_loss: 0.7541 - kl_loss: 0.5004 - val_total_loss: 0.9060 - val_reconstruction_loss: 0.7297 - val_kl_loss: 0.7051 - lr: 0.0010
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8786 - reconstruction_loss: 0.7476 - kl_loss: 0.5353 - val_total_loss: 0.9706 - val_reconstruction_loss: 0.7876 - val_kl_loss: 0.7320 - lr: 0.0010
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8623 - reconstruction_loss: 0.7260 - kl_loss: 0.5687 - val_total_loss: 1.0306 - val_reconstruction_loss: 0.8569 - val_kl_loss: 0.6945 - lr: 0.0010
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8913 - reconstruction_loss: 0.7232 - kl_loss: 0.6104 - val_total_loss: 0.9421 - val_reconstruction_loss: 0.7854 - val_kl_loss: 0.6265 - lr: 0.0010
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8733 - reconstruction_loss: 0.7142 - kl_loss: 0.6203 - val_total_loss: 0.8080 - val_reconstruction_loss: 0.6130 - val_kl_loss: 0.7800 - lr: 0.0010
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8651 - reconstruction_loss: 0.7084 - kl_loss: 0.6341 - val_total_loss: 0.8140 - val_reconstruction_loss: 0.6395 - val_kl_loss: 0.6983 - lr: 0.0010
# Epoch 16/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8621 - reconstruction_loss: 0.7006 - kl_loss: 0.6623 - val_total_loss: 0.8740 - val_reconstruction_loss: 0.6773 - val_kl_loss: 0.7868 - lr: 0.0010
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8638 - reconstruction_loss: 0.7008 - kl_loss: 0.6537 - val_total_loss: 0.8602 - val_reconstruction_loss: 0.6411 - val_kl_loss: 0.8763 - lr: 0.0010
# Epoch 18/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8657 - reconstruction_loss: 0.7006 - kl_loss: 0.6670 - val_total_loss: 0.8707 - val_reconstruction_loss: 0.6564 - val_kl_loss: 0.8571 - lr: 0.0010
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8568 - reconstruction_loss: 0.6917 - kl_loss: 0.6789 - val_total_loss: 0.7932 - val_reconstruction_loss: 0.5968 - val_kl_loss: 0.7856 - lr: 0.0010
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8688 - reconstruction_loss: 0.6937 - kl_loss: 0.6821 - val_total_loss: 0.9142 - val_reconstruction_loss: 0.7122 - val_kl_loss: 0.8083 - lr: 0.0010
# Epoch 21/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8642 - reconstruction_loss: 0.6903 - kl_loss: 0.6799 - val_total_loss: 0.9253 - val_reconstruction_loss: 0.7219 - val_kl_loss: 0.8133 - lr: 0.0010
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8789 - reconstruction_loss: 0.6876 - kl_loss: 0.6978 - val_total_loss: 0.8709 - val_reconstruction_loss: 0.6806 - val_kl_loss: 0.7609 - lr: 0.0010
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8515 - reconstruction_loss: 0.6866 - kl_loss: 0.7012 - val_total_loss: 0.7955 - val_reconstruction_loss: 0.5755 - val_kl_loss: 0.8801 - lr: 0.0010
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8642 - reconstruction_loss: 0.6882 - kl_loss: 0.6969 - val_total_loss: 0.7654 - val_reconstruction_loss: 0.5768 - val_kl_loss: 0.7544 - lr: 0.0010
# Epoch 25/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8549 - reconstruction_loss: 0.6798 - kl_loss: 0.7141 - val_total_loss: 0.8523 - val_reconstruction_loss: 0.6326 - val_kl_loss: 0.8787 - lr: 0.0010
# Epoch 26/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8578 - reconstruction_loss: 0.6815 - kl_loss: 0.7168 - val_total_loss: 0.7860 - val_reconstruction_loss: 0.5831 - val_kl_loss: 0.8115 - lr: 0.0010
# Epoch 27/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8675 - reconstruction_loss: 0.6843 - kl_loss: 0.7248 - val_total_loss: 0.7068 - val_reconstruction_loss: 0.4920 - val_kl_loss: 0.8594 - lr: 0.0010
# Epoch 28/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8619 - reconstruction_loss: 0.6793 - kl_loss: 0.7028 - val_total_loss: 0.8354 - val_reconstruction_loss: 0.6235 - val_kl_loss: 0.8475 - lr: 0.0010
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8579 - reconstruction_loss: 0.6747 - kl_loss: 0.7232 - val_total_loss: 0.8974 - val_reconstruction_loss: 0.6880 - val_kl_loss: 0.8374 - lr: 0.0010
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8638 - reconstruction_loss: 0.6739 - kl_loss: 0.7250 - val_total_loss: 0.8641 - val_reconstruction_loss: 0.6523 - val_kl_loss: 0.8471 - lr: 0.0010
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.8765 - reconstruction_loss: 0.6794 - kl_loss: 0.7884
# [0.8764734268188477, 0.6793788075447083, 0.7883785367012024]
# Learning rate:  0.001
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8625 - reconstruction_loss: 0.6671 - kl_loss: 0.7446 - val_total_loss: 0.6908 - val_reconstruction_loss: 0.4878 - val_kl_loss: 0.8120 - lr: 0.0010
# Epoch 2/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8528 - reconstruction_loss: 0.6678 - kl_loss: 0.7559 - val_total_loss: 0.8378 - val_reconstruction_loss: 0.6478 - val_kl_loss: 0.7600 - lr: 0.0010
# Epoch 3/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8381 - reconstruction_loss: 0.6739 - kl_loss: 0.7244 - val_total_loss: 0.7967 - val_reconstruction_loss: 0.5779 - val_kl_loss: 0.8751 - lr: 0.0010
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8499 - reconstruction_loss: 0.6651 - kl_loss: 0.7321 - val_total_loss: 0.9249 - val_reconstruction_loss: 0.7216 - val_kl_loss: 0.8134 - lr: 0.0010
# Epoch 5/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8605 - reconstruction_loss: 0.6639 - kl_loss: 0.7412 - val_total_loss: 0.8255 - val_reconstruction_loss: 0.6181 - val_kl_loss: 0.8294 - lr: 0.0010
# Epoch 6/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8562 - reconstruction_loss: 0.6630 - kl_loss: 0.7547 - val_total_loss: 0.9777 - val_reconstruction_loss: 0.7381 - val_kl_loss: 0.9585 - lr: 0.0010
# Epoch 7/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8482 - reconstruction_loss: 0.6604 - kl_loss: 0.7493 - val_total_loss: 0.7874 - val_reconstruction_loss: 0.5760 - val_kl_loss: 0.8458 - lr: 0.0010
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8614 - reconstruction_loss: 0.6598 - kl_loss: 0.7490 - val_total_loss: 0.8556 - val_reconstruction_loss: 0.6472 - val_kl_loss: 0.8335 - lr: 0.0010
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8395 - reconstruction_loss: 0.6626 - kl_loss: 0.7615 - val_total_loss: 1.0124 - val_reconstruction_loss: 0.7932 - val_kl_loss: 0.8767 - lr: 0.0010
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8353 - reconstruction_loss: 0.6565 - kl_loss: 0.7541 - val_total_loss: 0.8612 - val_reconstruction_loss: 0.6332 - val_kl_loss: 0.9119 - lr: 0.0010
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8500 - reconstruction_loss: 0.6601 - kl_loss: 0.7608 - val_total_loss: 0.9023 - val_reconstruction_loss: 0.6896 - val_kl_loss: 0.8506 - lr: 0.0010
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8619 - reconstruction_loss: 0.6570 - kl_loss: 0.7667 - val_total_loss: 0.7579 - val_reconstruction_loss: 0.5188 - val_kl_loss: 0.9561 - lr: 0.0010
# Epoch 13/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8689 - reconstruction_loss: 0.6657 - kl_loss: 0.7600 - val_total_loss: 0.8789 - val_reconstruction_loss: 0.6304 - val_kl_loss: 0.9941 - lr: 0.0010
# Epoch 14/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8547 - reconstruction_loss: 0.6572 - kl_loss: 0.7686 - val_total_loss: 0.8344 - val_reconstruction_loss: 0.5714 - val_kl_loss: 1.0519 - lr: 0.0010
# Epoch 15/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8409 - reconstruction_loss: 0.6536 - kl_loss: 0.7477 - val_total_loss: 0.7832 - val_reconstruction_loss: 0.5655 - val_kl_loss: 0.8706 - lr: 0.0010
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8680 - reconstruction_loss: 0.6606 - kl_loss: 0.7537 - val_total_loss: 0.8757 - val_reconstruction_loss: 0.6530 - val_kl_loss: 0.8907 - lr: 0.0010
# Epoch 17/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8398 - reconstruction_loss: 0.6584 - kl_loss: 0.7543 - val_total_loss: 0.7103 - val_reconstruction_loss: 0.4732 - val_kl_loss: 0.9484 - lr: 0.0010
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8415 - reconstruction_loss: 0.6556 - kl_loss: 0.7633 - val_total_loss: 0.9513 - val_reconstruction_loss: 0.7232 - val_kl_loss: 0.9123 - lr: 0.0010
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8414 - reconstruction_loss: 0.6583 - kl_loss: 0.7771 - val_total_loss: 0.8953 - val_reconstruction_loss: 0.6592 - val_kl_loss: 0.9445 - lr: 0.0010
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8361 - reconstruction_loss: 0.6544 - kl_loss: 0.7609 - val_total_loss: 0.7994 - val_reconstruction_loss: 0.5755 - val_kl_loss: 0.8957 - lr: 0.0010
# Epoch 21/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8450 - reconstruction_loss: 0.6549 - kl_loss: 0.7561 - val_total_loss: 0.8008 - val_reconstruction_loss: 0.5447 - val_kl_loss: 1.0244 - lr: 0.0010
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8568 - reconstruction_loss: 0.6486 - kl_loss: 0.7953 - val_total_loss: 1.1907 - val_reconstruction_loss: 0.9759 - val_kl_loss: 0.8592 - lr: 0.0010
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8521 - reconstruction_loss: 0.6537 - kl_loss: 0.7866 - val_total_loss: 0.9187 - val_reconstruction_loss: 0.6660 - val_kl_loss: 1.0109 - lr: 0.0010
# Epoch 24/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8411 - reconstruction_loss: 0.6514 - kl_loss: 0.7627 - val_total_loss: 0.8219 - val_reconstruction_loss: 0.6049 - val_kl_loss: 0.8681 - lr: 0.0010
# Epoch 25/30
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8535 - reconstruction_loss: 0.6530 - kl_loss: 0.7784
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8532 - reconstruction_loss: 0.6537 - kl_loss: 0.7745 - val_total_loss: 0.9389 - val_reconstruction_loss: 0.7235 - val_kl_loss: 0.8615 - lr: 0.0010
# Epoch 26/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8504 - reconstruction_loss: 0.6495 - kl_loss: 0.7848 - val_total_loss: 0.8969 - val_reconstruction_loss: 0.6796 - val_kl_loss: 0.8689 - lr: 5.0000e-04
# Epoch 27/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8460 - reconstruction_loss: 0.6465 - kl_loss: 0.8120 - val_total_loss: 0.8884 - val_reconstruction_loss: 0.6507 - val_kl_loss: 0.9509 - lr: 5.0000e-04
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8451 - reconstruction_loss: 0.6443 - kl_loss: 0.8082 - val_total_loss: 0.8319 - val_reconstruction_loss: 0.6024 - val_kl_loss: 0.9178 - lr: 5.0000e-04
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8326 - reconstruction_loss: 0.6460 - kl_loss: 0.7821 - val_total_loss: 0.8350 - val_reconstruction_loss: 0.6086 - val_kl_loss: 0.9053 - lr: 5.0000e-04
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8506 - reconstruction_loss: 0.6460 - kl_loss: 0.7812 - val_total_loss: 0.8979 - val_reconstruction_loss: 0.6745 - val_kl_loss: 0.8934 - lr: 5.0000e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8315 - reconstruction_loss: 0.6397 - kl_loss: 0.7674
# [0.83152836561203, 0.6396743059158325, 0.7674162983894348]
# Learning rate:  0.001
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 20ms/step - loss: 0.8544 - reconstruction_loss: 0.6470 - kl_loss: 0.7718 - val_total_loss: 0.7815 - val_reconstruction_loss: 0.5645 - val_kl_loss: 0.8680 - lr: 0.0010
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8495 - reconstruction_loss: 0.6461 - kl_loss: 0.7982 - val_total_loss: 0.8015 - val_reconstruction_loss: 0.5825 - val_kl_loss: 0.8760 - lr: 0.0010
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8622 - reconstruction_loss: 0.6446 - kl_loss: 0.7979 - val_total_loss: 0.8232 - val_reconstruction_loss: 0.6025 - val_kl_loss: 0.8827 - lr: 0.0010
# Epoch 4/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8501 - reconstruction_loss: 0.6517 - kl_loss: 0.8043 - val_total_loss: 0.9225 - val_reconstruction_loss: 0.6950 - val_kl_loss: 0.9101 - lr: 0.0010
# Epoch 5/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8407 - reconstruction_loss: 0.6456 - kl_loss: 0.8021 - val_total_loss: 0.7377 - val_reconstruction_loss: 0.5090 - val_kl_loss: 0.9149 - lr: 0.0010
# Epoch 6/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8441 - reconstruction_loss: 0.6449 - kl_loss: 0.7700 - val_total_loss: 0.9316 - val_reconstruction_loss: 0.7037 - val_kl_loss: 0.9117 - lr: 0.0010
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8295 - reconstruction_loss: 0.6450 - kl_loss: 0.8031 - val_total_loss: 0.7966 - val_reconstruction_loss: 0.5574 - val_kl_loss: 0.9568 - lr: 0.0010
# Epoch 8/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8364 - reconstruction_loss: 0.6486 - kl_loss: 0.7784 - val_total_loss: 0.7552 - val_reconstruction_loss: 0.5320 - val_kl_loss: 0.8929 - lr: 0.0010
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8355 - reconstruction_loss: 0.6452 - kl_loss: 0.7826 - val_total_loss: 0.7952 - val_reconstruction_loss: 0.5623 - val_kl_loss: 0.9318 - lr: 0.0010
# Epoch 10/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8511 - reconstruction_loss: 0.6435 - kl_loss: 0.7877 - val_total_loss: 0.8038 - val_reconstruction_loss: 0.5678 - val_kl_loss: 0.9441 - lr: 0.0010
# Epoch 11/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8523 - reconstruction_loss: 0.6451 - kl_loss: 0.7942 - val_total_loss: 0.8260 - val_reconstruction_loss: 0.5641 - val_kl_loss: 1.0477 - lr: 0.0010
# Epoch 12/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8537 - reconstruction_loss: 0.6461 - kl_loss: 0.8088 - val_total_loss: 0.6916 - val_reconstruction_loss: 0.4534 - val_kl_loss: 0.9528 - lr: 0.0010
# Epoch 13/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8552 - reconstruction_loss: 0.6458 - kl_loss: 0.7917 - val_total_loss: 0.7659 - val_reconstruction_loss: 0.5354 - val_kl_loss: 0.9217 - lr: 0.0010
# Epoch 14/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8394 - reconstruction_loss: 0.6429 - kl_loss: 0.7967 - val_total_loss: 0.8193 - val_reconstruction_loss: 0.5885 - val_kl_loss: 0.9233 - lr: 0.0010
# Epoch 15/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8388 - reconstruction_loss: 0.6371 - kl_loss: 0.8019 - val_total_loss: 0.8403 - val_reconstruction_loss: 0.6200 - val_kl_loss: 0.8812 - lr: 0.0010
# Epoch 16/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8355 - reconstruction_loss: 0.6431 - kl_loss: 0.7891
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8357 - reconstruction_loss: 0.6424 - kl_loss: 0.7915 - val_total_loss: 0.8135 - val_reconstruction_loss: 0.5794 - val_kl_loss: 0.9362 - lr: 0.0010
# Epoch 17/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8512 - reconstruction_loss: 0.6388 - kl_loss: 0.8091 - val_total_loss: 0.8315 - val_reconstruction_loss: 0.5953 - val_kl_loss: 0.9448 - lr: 5.0000e-04
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8428 - reconstruction_loss: 0.6391 - kl_loss: 0.7978 - val_total_loss: 0.9579 - val_reconstruction_loss: 0.7227 - val_kl_loss: 0.9408 - lr: 5.0000e-04
# Epoch 19/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8436 - reconstruction_loss: 0.6403 - kl_loss: 0.8076 - val_total_loss: 0.8573 - val_reconstruction_loss: 0.6311 - val_kl_loss: 0.9049 - lr: 5.0000e-04
# Epoch 20/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8320 - reconstruction_loss: 0.6405 - kl_loss: 0.8030 - val_total_loss: 0.7636 - val_reconstruction_loss: 0.5239 - val_kl_loss: 0.9589 - lr: 5.0000e-04
# Epoch 21/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8359 - reconstruction_loss: 0.6392 - kl_loss: 0.8058 - val_total_loss: 0.9248 - val_reconstruction_loss: 0.6963 - val_kl_loss: 0.9139 - lr: 5.0000e-04
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8442 - reconstruction_loss: 0.6381 - kl_loss: 0.8179 - val_total_loss: 0.7994 - val_reconstruction_loss: 0.5579 - val_kl_loss: 0.9659 - lr: 5.0000e-04
# Epoch 23/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8385 - reconstruction_loss: 0.6404 - kl_loss: 0.7958 - val_total_loss: 0.9857 - val_reconstruction_loss: 0.7478 - val_kl_loss: 0.9515 - lr: 5.0000e-04
# Epoch 24/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8300 - reconstruction_loss: 0.6383 - kl_loss: 0.8037 - val_total_loss: 0.7716 - val_reconstruction_loss: 0.5287 - val_kl_loss: 0.9715 - lr: 5.0000e-04
# Epoch 25/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8369 - reconstruction_loss: 0.6375 - kl_loss: 0.8115 - val_total_loss: 0.7380 - val_reconstruction_loss: 0.4998 - val_kl_loss: 0.9529 - lr: 5.0000e-04
# Epoch 26/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8350 - reconstruction_loss: 0.6345 - kl_loss: 0.8031 - val_total_loss: 0.7452 - val_reconstruction_loss: 0.5049 - val_kl_loss: 0.9612 - lr: 5.0000e-04
# Epoch 27/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8300 - reconstruction_loss: 0.6377 - kl_loss: 0.7863 - val_total_loss: 0.8156 - val_reconstruction_loss: 0.5849 - val_kl_loss: 0.9225 - lr: 5.0000e-04
# Epoch 28/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8530 - reconstruction_loss: 0.6378 - kl_loss: 0.8089 - val_total_loss: 0.7957 - val_reconstruction_loss: 0.5613 - val_kl_loss: 0.9376 - lr: 5.0000e-04
# Epoch 29/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8331 - reconstruction_loss: 0.6405 - kl_loss: 0.7966 - val_total_loss: 0.8702 - val_reconstruction_loss: 0.6342 - val_kl_loss: 0.9438 - lr: 5.0000e-04
# Epoch 30/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8277 - reconstruction_loss: 0.6376 - kl_loss: 0.8005 - val_total_loss: 0.9490 - val_reconstruction_loss: 0.7124 - val_kl_loss: 0.9467 - lr: 5.0000e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8021 - reconstruction_loss: 0.6002 - kl_loss: 0.8076
# [0.8021397590637207, 0.6002289652824402, 0.8076431751251221]
# Learning rate:  0.001
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 37ms/step - loss: 0.8393 - reconstruction_loss: 0.6408 - kl_loss: 0.7885 - val_total_loss: 0.8091 - val_reconstruction_loss: 0.5954 - val_kl_loss: 0.8547 - lr: 0.0010
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8379 - reconstruction_loss: 0.6382 - kl_loss: 0.7784 - val_total_loss: 0.8784 - val_reconstruction_loss: 0.6667 - val_kl_loss: 0.8469 - lr: 0.0010
# Epoch 3/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8366 - reconstruction_loss: 0.6408 - kl_loss: 0.7829 - val_total_loss: 0.8542 - val_reconstruction_loss: 0.6403 - val_kl_loss: 0.8555 - lr: 0.0010
# Epoch 4/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8368 - reconstruction_loss: 0.6391 - kl_loss: 0.8144 - val_total_loss: 0.8330 - val_reconstruction_loss: 0.6093 - val_kl_loss: 0.8950 - lr: 0.0010
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8353 - reconstruction_loss: 0.6373 - kl_loss: 0.8036 - val_total_loss: 0.8376 - val_reconstruction_loss: 0.6206 - val_kl_loss: 0.8681 - lr: 0.0010
# Epoch 6/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8449 - reconstruction_loss: 0.6345 - kl_loss: 0.7996 - val_total_loss: 0.8822 - val_reconstruction_loss: 0.6551 - val_kl_loss: 0.9083 - lr: 0.0010
# Epoch 7/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8506 - reconstruction_loss: 0.6357 - kl_loss: 0.8004 - val_total_loss: 0.8570 - val_reconstruction_loss: 0.6434 - val_kl_loss: 0.8543 - lr: 0.0010
# Epoch 8/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8360 - reconstruction_loss: 0.6392 - kl_loss: 0.8069 - val_total_loss: 0.9069 - val_reconstruction_loss: 0.6716 - val_kl_loss: 0.9412 - lr: 0.0010
# Epoch 9/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8252 - reconstruction_loss: 0.6396 - kl_loss: 0.8145 - val_total_loss: 0.8441 - val_reconstruction_loss: 0.6290 - val_kl_loss: 0.8605 - lr: 0.0010
# Epoch 10/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8330 - reconstruction_loss: 0.6459 - kl_loss: 0.8030 - val_total_loss: 0.8673 - val_reconstruction_loss: 0.6554 - val_kl_loss: 0.8477 - lr: 0.0010
# Epoch 11/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8486 - reconstruction_loss: 0.6408 - kl_loss: 0.7974 - val_total_loss: 0.8206 - val_reconstruction_loss: 0.6061 - val_kl_loss: 0.8577 - lr: 0.0010
# Epoch 12/30
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8348 - reconstruction_loss: 0.6382 - kl_loss: 0.8043
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8348 - reconstruction_loss: 0.6353 - kl_loss: 0.7995 - val_total_loss: 0.8511 - val_reconstruction_loss: 0.6351 - val_kl_loss: 0.8640 - lr: 0.0010
# Epoch 13/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8392 - reconstruction_loss: 0.6325 - kl_loss: 0.8080 - val_total_loss: 0.8492 - val_reconstruction_loss: 0.6274 - val_kl_loss: 0.8875 - lr: 5.0000e-04
# Epoch 14/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8326 - reconstruction_loss: 0.6371 - kl_loss: 0.7849 - val_total_loss: 0.8564 - val_reconstruction_loss: 0.6401 - val_kl_loss: 0.8652 - lr: 5.0000e-04
# Epoch 15/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8293 - reconstruction_loss: 0.6391 - kl_loss: 0.8003 - val_total_loss: 0.8648 - val_reconstruction_loss: 0.6426 - val_kl_loss: 0.8890 - lr: 5.0000e-04
# Epoch 16/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8300 - reconstruction_loss: 0.6379 - kl_loss: 0.7909 - val_total_loss: 0.8244 - val_reconstruction_loss: 0.5957 - val_kl_loss: 0.9150 - lr: 5.0000e-04
# Epoch 17/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8440 - reconstruction_loss: 0.6316 - kl_loss: 0.8148 - val_total_loss: 0.8736 - val_reconstruction_loss: 0.6531 - val_kl_loss: 0.8821 - lr: 5.0000e-04
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8331 - reconstruction_loss: 0.6363 - kl_loss: 0.8080 - val_total_loss: 0.8533 - val_reconstruction_loss: 0.6334 - val_kl_loss: 0.8797 - lr: 5.0000e-04
# Epoch 19/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8344 - reconstruction_loss: 0.6384 - kl_loss: 0.8077 - val_total_loss: 0.8332 - val_reconstruction_loss: 0.6093 - val_kl_loss: 0.8955 - lr: 5.0000e-04
# Epoch 20/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8333 - reconstruction_loss: 0.6328 - kl_loss: 0.8126 - val_total_loss: 0.8292 - val_reconstruction_loss: 0.6063 - val_kl_loss: 0.8918 - lr: 5.0000e-04
# Epoch 21/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8362 - reconstruction_loss: 0.6339 - kl_loss: 0.8004 - val_total_loss: 0.8407 - val_reconstruction_loss: 0.6220 - val_kl_loss: 0.8747 - lr: 5.0000e-04
# Epoch 22/30
# 24/27 [=========================>....] - ETA: 0s - loss: 0.8347 - reconstruction_loss: 0.6342 - kl_loss: 0.8107
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 2.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8349 - reconstruction_loss: 0.6343 - kl_loss: 0.8020 - val_total_loss: 0.8467 - val_reconstruction_loss: 0.6283 - val_kl_loss: 0.8736 - lr: 5.0000e-04
# Epoch 22: early stopping
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9145 - reconstruction_loss: 0.7179 - kl_loss: 0.7862
# [0.9144822359085083, 0.717924177646637, 0.7862321734428406]
# Learning rate:  0.005
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 7ms/step - loss: 0.8911 - reconstruction_loss: 0.6995 - kl_loss: 0.7008 - val_total_loss: 0.8056 - val_reconstruction_loss: 0.6217 - val_kl_loss: 0.7359 - lr: 0.0050
# Epoch 2/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8762 - reconstruction_loss: 0.6904 - kl_loss: 0.7301 - val_total_loss: 0.8837 - val_reconstruction_loss: 0.6816 - val_kl_loss: 0.8084 - lr: 0.0050
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8730 - reconstruction_loss: 0.6859 - kl_loss: 0.7433 - val_total_loss: 0.9274 - val_reconstruction_loss: 0.7534 - val_kl_loss: 0.6959 - lr: 0.0050
# Epoch 4/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8764 - reconstruction_loss: 0.6902 - kl_loss: 0.7174 - val_total_loss: 0.9393 - val_reconstruction_loss: 0.7857 - val_kl_loss: 0.6144 - lr: 0.0050
# Epoch 5/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8789 - reconstruction_loss: 0.6832 - kl_loss: 0.7412 - val_total_loss: 0.8459 - val_reconstruction_loss: 0.6521 - val_kl_loss: 0.7750 - lr: 0.0050
# Epoch 6/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8566 - reconstruction_loss: 0.6803 - kl_loss: 0.7461 - val_total_loss: 0.9353 - val_reconstruction_loss: 0.7201 - val_kl_loss: 0.8611 - lr: 0.0050
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8646 - reconstruction_loss: 0.6763 - kl_loss: 0.7372 - val_total_loss: 0.9072 - val_reconstruction_loss: 0.6672 - val_kl_loss: 0.9602 - lr: 0.0050
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8643 - reconstruction_loss: 0.6808 - kl_loss: 0.7410 - val_total_loss: 0.9049 - val_reconstruction_loss: 0.6733 - val_kl_loss: 0.9267 - lr: 0.0050
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8602 - reconstruction_loss: 0.6769 - kl_loss: 0.7334 - val_total_loss: 0.9001 - val_reconstruction_loss: 0.6997 - val_kl_loss: 0.8015 - lr: 0.0050
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8591 - reconstruction_loss: 0.6854 - kl_loss: 0.7213 - val_total_loss: 0.9193 - val_reconstruction_loss: 0.7013 - val_kl_loss: 0.8722 - lr: 0.0050
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8686 - reconstruction_loss: 0.6689 - kl_loss: 0.7659 - val_total_loss: 0.8209 - val_reconstruction_loss: 0.6153 - val_kl_loss: 0.8223 - lr: 0.0050
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8418 - reconstruction_loss: 0.6742 - kl_loss: 0.7256 - val_total_loss: 0.9802 - val_reconstruction_loss: 0.8028 - val_kl_loss: 0.7095 - lr: 0.0050
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8495 - reconstruction_loss: 0.6718 - kl_loss: 0.7398 - val_total_loss: 0.8263 - val_reconstruction_loss: 0.6099 - val_kl_loss: 0.8655 - lr: 0.0050
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8572 - reconstruction_loss: 0.6725 - kl_loss: 0.7591 - val_total_loss: 0.7777 - val_reconstruction_loss: 0.5588 - val_kl_loss: 0.8754 - lr: 0.0050
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8710 - reconstruction_loss: 0.6709 - kl_loss: 0.7558 - val_total_loss: 1.0098 - val_reconstruction_loss: 0.8312 - val_kl_loss: 0.7142 - lr: 0.0050
# Epoch 16/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8629 - reconstruction_loss: 0.6757 - kl_loss: 0.7471 - val_total_loss: 0.7622 - val_reconstruction_loss: 0.5718 - val_kl_loss: 0.7613 - lr: 0.0050
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8664 - reconstruction_loss: 0.6683 - kl_loss: 0.7725 - val_total_loss: 0.7070 - val_reconstruction_loss: 0.5109 - val_kl_loss: 0.7843 - lr: 0.0050
# Epoch 18/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8537 - reconstruction_loss: 0.6642 - kl_loss: 0.7451 - val_total_loss: 0.7762 - val_reconstruction_loss: 0.5560 - val_kl_loss: 0.8808 - lr: 0.0050
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8588 - reconstruction_loss: 0.6675 - kl_loss: 0.7610 - val_total_loss: 0.8106 - val_reconstruction_loss: 0.6188 - val_kl_loss: 0.7672 - lr: 0.0050
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8605 - reconstruction_loss: 0.6719 - kl_loss: 0.7566 - val_total_loss: 0.8130 - val_reconstruction_loss: 0.5925 - val_kl_loss: 0.8818 - lr: 0.0050
# Epoch 21/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8630 - reconstruction_loss: 0.6688 - kl_loss: 0.7615 - val_total_loss: 0.8692 - val_reconstruction_loss: 0.6610 - val_kl_loss: 0.8329 - lr: 0.0050
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8558 - reconstruction_loss: 0.6645 - kl_loss: 0.7635 - val_total_loss: 0.9496 - val_reconstruction_loss: 0.7507 - val_kl_loss: 0.7955 - lr: 0.0050
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8628 - reconstruction_loss: 0.6668 - kl_loss: 0.7712 - val_total_loss: 0.6891 - val_reconstruction_loss: 0.4910 - val_kl_loss: 0.7924 - lr: 0.0050
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8580 - reconstruction_loss: 0.6686 - kl_loss: 0.7633 - val_total_loss: 0.7608 - val_reconstruction_loss: 0.5531 - val_kl_loss: 0.8309 - lr: 0.0050
# Epoch 25/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8593 - reconstruction_loss: 0.6585 - kl_loss: 0.7680 - val_total_loss: 0.9872 - val_reconstruction_loss: 0.7273 - val_kl_loss: 1.0396 - lr: 0.0050
# Epoch 26/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8746 - reconstruction_loss: 0.6666 - kl_loss: 0.7616 - val_total_loss: 0.8673 - val_reconstruction_loss: 0.6290 - val_kl_loss: 0.9529 - lr: 0.0050
# Epoch 27/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8711 - reconstruction_loss: 0.6670 - kl_loss: 0.7648 - val_total_loss: 0.8943 - val_reconstruction_loss: 0.6660 - val_kl_loss: 0.9130 - lr: 0.0050
# Epoch 28/30
# 207/210 [============================>.] - ETA: 0s - loss: 0.8683 - reconstruction_loss: 0.6647 - kl_loss: 0.7666
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8681 - reconstruction_loss: 0.6626 - kl_loss: 0.7659 - val_total_loss: 0.8286 - val_reconstruction_loss: 0.6086 - val_kl_loss: 0.8799 - lr: 0.0050
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8389 - reconstruction_loss: 0.6431 - kl_loss: 0.7669 - val_total_loss: 0.7665 - val_reconstruction_loss: 0.5590 - val_kl_loss: 0.8301 - lr: 0.0025
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8422 - reconstruction_loss: 0.6467 - kl_loss: 0.7800 - val_total_loss: 0.8274 - val_reconstruction_loss: 0.5952 - val_kl_loss: 0.9287 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7987 - reconstruction_loss: 0.6023 - kl_loss: 0.7853
# [0.7986544966697693, 0.6023350358009338, 0.7852778434753418]
# Learning rate:  0.005
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 13ms/step - loss: 0.8617 - reconstruction_loss: 0.6573 - kl_loss: 0.7918 - val_total_loss: 0.8572 - val_reconstruction_loss: 0.6144 - val_kl_loss: 0.9712 - lr: 0.0050
# Epoch 2/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8506 - reconstruction_loss: 0.6525 - kl_loss: 0.7684 - val_total_loss: 0.8806 - val_reconstruction_loss: 0.6585 - val_kl_loss: 0.8886 - lr: 0.0050
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8515 - reconstruction_loss: 0.6491 - kl_loss: 0.7849 - val_total_loss: 0.9907 - val_reconstruction_loss: 0.7614 - val_kl_loss: 0.9173 - lr: 0.0050
# Epoch 4/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8278 - reconstruction_loss: 0.6511 - kl_loss: 0.7876 - val_total_loss: 0.9007 - val_reconstruction_loss: 0.6384 - val_kl_loss: 1.0492 - lr: 0.0050
# Epoch 5/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8452 - reconstruction_loss: 0.6475 - kl_loss: 0.8220 - val_total_loss: 0.8942 - val_reconstruction_loss: 0.6445 - val_kl_loss: 0.9989 - lr: 0.0050
# Epoch 6/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8370 - reconstruction_loss: 0.6528 - kl_loss: 0.7687 - val_total_loss: 0.7805 - val_reconstruction_loss: 0.5341 - val_kl_loss: 0.9858 - lr: 0.0050
# Epoch 7/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8628 - reconstruction_loss: 0.6517 - kl_loss: 0.7893 - val_total_loss: 0.6927 - val_reconstruction_loss: 0.4653 - val_kl_loss: 0.9097 - lr: 0.0050
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8471 - reconstruction_loss: 0.6516 - kl_loss: 0.7964 - val_total_loss: 0.8842 - val_reconstruction_loss: 0.6703 - val_kl_loss: 0.8555 - lr: 0.0050
# Epoch 9/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8587 - reconstruction_loss: 0.6549 - kl_loss: 0.7605 - val_total_loss: 0.9294 - val_reconstruction_loss: 0.7146 - val_kl_loss: 0.8590 - lr: 0.0050
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8514 - reconstruction_loss: 0.6493 - kl_loss: 0.7945 - val_total_loss: 0.8737 - val_reconstruction_loss: 0.6549 - val_kl_loss: 0.8754 - lr: 0.0050
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8393 - reconstruction_loss: 0.6493 - kl_loss: 0.7888 - val_total_loss: 0.9295 - val_reconstruction_loss: 0.6647 - val_kl_loss: 1.0595 - lr: 0.0050
# Epoch 12/30
# 102/105 [============================>.] - ETA: 0s - loss: 0.8425 - reconstruction_loss: 0.6475 - kl_loss: 0.7894
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8426 - reconstruction_loss: 0.6490 - kl_loss: 0.7878 - val_total_loss: 0.9318 - val_reconstruction_loss: 0.7204 - val_kl_loss: 0.8455 - lr: 0.0050
# Epoch 13/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8323 - reconstruction_loss: 0.6388 - kl_loss: 0.8155 - val_total_loss: 0.8862 - val_reconstruction_loss: 0.6609 - val_kl_loss: 0.9010 - lr: 0.0025
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8494 - reconstruction_loss: 0.6381 - kl_loss: 0.8182 - val_total_loss: 0.8888 - val_reconstruction_loss: 0.6754 - val_kl_loss: 0.8539 - lr: 0.0025
# Epoch 15/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8481 - reconstruction_loss: 0.6378 - kl_loss: 0.8100 - val_total_loss: 0.8295 - val_reconstruction_loss: 0.5853 - val_kl_loss: 0.9768 - lr: 0.0025
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8381 - reconstruction_loss: 0.6421 - kl_loss: 0.7942 - val_total_loss: 0.7676 - val_reconstruction_loss: 0.5199 - val_kl_loss: 0.9910 - lr: 0.0025
# Epoch 17/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8387 - reconstruction_loss: 0.6401 - kl_loss: 0.8063 - val_total_loss: 0.9335 - val_reconstruction_loss: 0.6863 - val_kl_loss: 0.9889 - lr: 0.0025
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8357 - reconstruction_loss: 0.6374 - kl_loss: 0.7954 - val_total_loss: 0.8455 - val_reconstruction_loss: 0.6370 - val_kl_loss: 0.8340 - lr: 0.0025
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8447 - reconstruction_loss: 0.6356 - kl_loss: 0.8169 - val_total_loss: 0.7938 - val_reconstruction_loss: 0.5613 - val_kl_loss: 0.9298 - lr: 0.0025
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8360 - reconstruction_loss: 0.6375 - kl_loss: 0.7973 - val_total_loss: 0.9347 - val_reconstruction_loss: 0.7001 - val_kl_loss: 0.9384 - lr: 0.0025
# Epoch 21/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8388 - reconstruction_loss: 0.6381 - kl_loss: 0.7958 - val_total_loss: 0.8913 - val_reconstruction_loss: 0.6527 - val_kl_loss: 0.9543 - lr: 0.0025
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8552 - reconstruction_loss: 0.6407 - kl_loss: 0.8180 - val_total_loss: 0.8170 - val_reconstruction_loss: 0.5767 - val_kl_loss: 0.9611 - lr: 0.0025
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8445 - reconstruction_loss: 0.6386 - kl_loss: 0.8066 - val_total_loss: 0.8764 - val_reconstruction_loss: 0.6428 - val_kl_loss: 0.9345 - lr: 0.0025
# Epoch 24/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8383 - reconstruction_loss: 0.6373 - kl_loss: 0.7986 - val_total_loss: 0.8922 - val_reconstruction_loss: 0.6424 - val_kl_loss: 0.9991 - lr: 0.0025
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8312 - reconstruction_loss: 0.6352 - kl_loss: 0.8159 - val_total_loss: 0.8162 - val_reconstruction_loss: 0.5718 - val_kl_loss: 0.9776 - lr: 0.0025
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8288 - reconstruction_loss: 0.6351 - kl_loss: 0.8005 - val_total_loss: 0.7928 - val_reconstruction_loss: 0.5729 - val_kl_loss: 0.8796 - lr: 0.0025
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8374 - reconstruction_loss: 0.6342 - kl_loss: 0.8064 - val_total_loss: 0.7570 - val_reconstruction_loss: 0.5155 - val_kl_loss: 0.9661 - lr: 0.0025
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8402 - reconstruction_loss: 0.6364 - kl_loss: 0.8186 - val_total_loss: 1.0253 - val_reconstruction_loss: 0.7902 - val_kl_loss: 0.9403 - lr: 0.0025
# Epoch 29/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8437 - reconstruction_loss: 0.6375 - kl_loss: 0.8071 - val_total_loss: 0.8450 - val_reconstruction_loss: 0.5949 - val_kl_loss: 1.0004 - lr: 0.0025
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8302 - reconstruction_loss: 0.6377 - kl_loss: 0.8145 - val_total_loss: 0.8679 - val_reconstruction_loss: 0.6543 - val_kl_loss: 0.8546 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7434 - reconstruction_loss: 0.5496 - kl_loss: 0.7751
# [0.7433740496635437, 0.5495913028717041, 0.7751309871673584]
# Learning rate:  0.005
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 19ms/step - loss: 0.8686 - reconstruction_loss: 0.6569 - kl_loss: 0.7646 - val_total_loss: 0.8019 - val_reconstruction_loss: 0.5115 - val_kl_loss: 1.1614 - lr: 0.0050
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8438 - reconstruction_loss: 0.6348 - kl_loss: 0.8130 - val_total_loss: 0.8725 - val_reconstruction_loss: 0.5972 - val_kl_loss: 1.1013 - lr: 0.0050
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8536 - reconstruction_loss: 0.6369 - kl_loss: 0.8196 - val_total_loss: 0.8776 - val_reconstruction_loss: 0.6648 - val_kl_loss: 0.8511 - lr: 0.0050
# Epoch 4/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8570 - reconstruction_loss: 0.6368 - kl_loss: 0.8102 - val_total_loss: 0.8456 - val_reconstruction_loss: 0.6076 - val_kl_loss: 0.9521 - lr: 0.0050
# Epoch 5/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8430 - reconstruction_loss: 0.6407 - kl_loss: 0.8175 - val_total_loss: 0.8434 - val_reconstruction_loss: 0.6144 - val_kl_loss: 0.9159 - lr: 0.0050
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8460 - reconstruction_loss: 0.6416 - kl_loss: 0.8077 - val_total_loss: 0.9525 - val_reconstruction_loss: 0.7418 - val_kl_loss: 0.8427 - lr: 0.0050
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8584 - reconstruction_loss: 0.6413 - kl_loss: 0.7954 - val_total_loss: 0.9600 - val_reconstruction_loss: 0.7432 - val_kl_loss: 0.8674 - lr: 0.0050
# Epoch 8/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8481 - reconstruction_loss: 0.6428 - kl_loss: 0.7916 - val_total_loss: 0.7263 - val_reconstruction_loss: 0.4656 - val_kl_loss: 1.0428 - lr: 0.0050
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8431 - reconstruction_loss: 0.6401 - kl_loss: 0.8212 - val_total_loss: 0.8543 - val_reconstruction_loss: 0.6095 - val_kl_loss: 0.9790 - lr: 0.0050
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8402 - reconstruction_loss: 0.6356 - kl_loss: 0.8092 - val_total_loss: 0.8567 - val_reconstruction_loss: 0.6084 - val_kl_loss: 0.9932 - lr: 0.0050
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8431 - reconstruction_loss: 0.6388 - kl_loss: 0.8159 - val_total_loss: 0.8463 - val_reconstruction_loss: 0.5752 - val_kl_loss: 1.0844 - lr: 0.0050
# Epoch 12/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8346 - reconstruction_loss: 0.6350 - kl_loss: 0.8185 - val_total_loss: 0.8880 - val_reconstruction_loss: 0.6088 - val_kl_loss: 1.1166 - lr: 0.0050
# Epoch 13/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8454 - reconstruction_loss: 0.6340 - kl_loss: 0.8216 - val_total_loss: 0.9661 - val_reconstruction_loss: 0.7386 - val_kl_loss: 0.9102 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8467 - reconstruction_loss: 0.6392 - kl_loss: 0.8061 - val_total_loss: 0.8244 - val_reconstruction_loss: 0.6024 - val_kl_loss: 0.8882 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8279 - reconstruction_loss: 0.6404 - kl_loss: 0.7971 - val_total_loss: 0.8361 - val_reconstruction_loss: 0.6215 - val_kl_loss: 0.8583 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8408 - reconstruction_loss: 0.6391 - kl_loss: 0.8084 - val_total_loss: 0.8658 - val_reconstruction_loss: 0.6304 - val_kl_loss: 0.9416 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8259 - reconstruction_loss: 0.6362 - kl_loss: 0.8100 - val_total_loss: 0.8328 - val_reconstruction_loss: 0.5787 - val_kl_loss: 1.0165 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8407 - reconstruction_loss: 0.6348 - kl_loss: 0.8007 - val_total_loss: 0.7746 - val_reconstruction_loss: 0.5526 - val_kl_loss: 0.8880 - lr: 0.0050
# Epoch 19/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8457 - reconstruction_loss: 0.6382 - kl_loss: 0.8196 - val_total_loss: 1.0003 - val_reconstruction_loss: 0.7772 - val_kl_loss: 0.8922 - lr: 0.0050
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8415 - reconstruction_loss: 0.6404 - kl_loss: 0.8060 - val_total_loss: 0.9280 - val_reconstruction_loss: 0.7002 - val_kl_loss: 0.9115 - lr: 0.0050
# Epoch 21/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8472 - reconstruction_loss: 0.6409 - kl_loss: 0.7836 - val_total_loss: 0.8860 - val_reconstruction_loss: 0.6335 - val_kl_loss: 1.0102 - lr: 0.0050
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8404 - reconstruction_loss: 0.6319 - kl_loss: 0.8124 - val_total_loss: 0.9512 - val_reconstruction_loss: 0.7162 - val_kl_loss: 0.9400 - lr: 0.0050
# Epoch 23/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8488 - reconstruction_loss: 0.6373 - kl_loss: 0.8043 - val_total_loss: 1.1183 - val_reconstruction_loss: 0.8683 - val_kl_loss: 1.0000 - lr: 0.0050
# Epoch 24/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8367 - reconstruction_loss: 0.6418 - kl_loss: 0.7940 - val_total_loss: 0.7628 - val_reconstruction_loss: 0.5293 - val_kl_loss: 0.9341 - lr: 0.0050
# Epoch 25/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8352 - reconstruction_loss: 0.6414 - kl_loss: 0.8148 - val_total_loss: 0.8737 - val_reconstruction_loss: 0.6328 - val_kl_loss: 0.9638 - lr: 0.0050
# Epoch 26/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8461 - reconstruction_loss: 0.6396 - kl_loss: 0.8003 - val_total_loss: 0.8063 - val_reconstruction_loss: 0.5595 - val_kl_loss: 0.9871 - lr: 0.0050
# Epoch 27/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8339 - reconstruction_loss: 0.6352 - kl_loss: 0.8322 - val_total_loss: 0.9149 - val_reconstruction_loss: 0.6976 - val_kl_loss: 0.8693 - lr: 0.0050
# Epoch 28/30
# 51/53 [===========================>..] - ETA: 0s - loss: 0.8497 - reconstruction_loss: 0.6394 - kl_loss: 0.8104
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8492 - reconstruction_loss: 0.6367 - kl_loss: 0.8104 - val_total_loss: 0.7948 - val_reconstruction_loss: 0.5707 - val_kl_loss: 0.8965 - lr: 0.0050
# Epoch 29/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8326 - reconstruction_loss: 0.6321 - kl_loss: 0.8154 - val_total_loss: 0.6728 - val_reconstruction_loss: 0.4412 - val_kl_loss: 0.9263 - lr: 0.0025
# Epoch 30/30
# ...
# Epoch 25/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8462 - reconstruction_loss: 0.6484 - kl_loss: 0.7794 - val_total_loss: 0.9254 - val_reconstruction_loss: 0.6798 - val_kl_loss: 0.9827 - lr: 0.0050
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8289 - reconstruction_loss: 0.6421 - kl_loss: 0.7928 - val_total_loss: 1.0108 - val_reconstruction_loss: 0.7845 - val_kl_loss: 0.9050 - lr: 0.0050
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8448 - reconstruction_loss: 0.6435 - kl_loss: 0.8091 - val_total_loss: 0.8013 - val_reconstruction_loss: 0.5596 - val_kl_loss: 0.9669 - lr: 0.0050
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8391 - reconstruction_loss: 0.6434 - kl_loss: 0.8012 - val_total_loss: 0.8696 - val_reconstruction_loss: 0.6085 - val_kl_loss: 1.0445 - lr: 0.0050
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8353 - reconstruction_loss: 0.6429 - kl_loss: 0.7984 - val_total_loss: 0.9136 - val_reconstruction_loss: 0.6713 - val_kl_loss: 0.9694 - lr: 0.0050
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8365 - reconstruction_loss: 0.6402 - kl_loss: 0.7894 - val_total_loss: 0.8994 - val_reconstruction_loss: 0.6779 - val_kl_loss: 0.8860 - lr: 0.0050
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8035 - reconstruction_loss: 0.6098 - kl_loss: 0.7751
# [0.8035491704940796, 0.6097670197486877, 0.7751285433769226]
# Learning rate:  0.01
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 20ms/step - loss: 0.8886 - reconstruction_loss: 0.6777 - kl_loss: 0.7633 - val_total_loss: 1.0960 - val_reconstruction_loss: 0.8581 - val_kl_loss: 0.9517 - lr: 0.0100
# Epoch 2/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8480 - reconstruction_loss: 0.6487 - kl_loss: 0.7758 - val_total_loss: 0.8835 - val_reconstruction_loss: 0.6611 - val_kl_loss: 0.8899 - lr: 0.0100
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8390 - reconstruction_loss: 0.6436 - kl_loss: 0.7821 - val_total_loss: 0.8700 - val_reconstruction_loss: 0.6418 - val_kl_loss: 0.9128 - lr: 0.0100
# Epoch 4/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8480 - reconstruction_loss: 0.6450 - kl_loss: 0.8049 - val_total_loss: 0.8982 - val_reconstruction_loss: 0.6567 - val_kl_loss: 0.9663 - lr: 0.0100
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8452 - reconstruction_loss: 0.6554 - kl_loss: 0.7744 - val_total_loss: 0.8733 - val_reconstruction_loss: 0.6383 - val_kl_loss: 0.9400 - lr: 0.0100
# Epoch 6/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8504 - reconstruction_loss: 0.6508 - kl_loss: 0.8026 - val_total_loss: 0.7755 - val_reconstruction_loss: 0.5277 - val_kl_loss: 0.9914 - lr: 0.0100
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8518 - reconstruction_loss: 0.6517 - kl_loss: 0.7924 - val_total_loss: 1.1089 - val_reconstruction_loss: 0.8610 - val_kl_loss: 0.9917 - lr: 0.0100
# Epoch 8/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8355 - reconstruction_loss: 0.6435 - kl_loss: 0.8052 - val_total_loss: 0.8393 - val_reconstruction_loss: 0.5745 - val_kl_loss: 1.0591 - lr: 0.0100
# Epoch 9/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8591 - reconstruction_loss: 0.6451 - kl_loss: 0.7909 - val_total_loss: 0.9748 - val_reconstruction_loss: 0.7470 - val_kl_loss: 0.9112 - lr: 0.0100
# Epoch 10/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.8373 - reconstruction_loss: 0.6445 - kl_loss: 0.7960 - val_total_loss: 0.8182 - val_reconstruction_loss: 0.5863 - val_kl_loss: 0.9277 - lr: 0.0100
# Epoch 11/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.8431 - reconstruction_loss: 0.6565 - kl_loss: 0.7702 - val_total_loss: 0.8934 - val_reconstruction_loss: 0.6638 - val_kl_loss: 0.9182 - lr: 0.0100
# Epoch 12/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.8433 - reconstruction_loss: 0.6468 - kl_loss: 0.7845 - val_total_loss: 0.8962 - val_reconstruction_loss: 0.6507 - val_kl_loss: 0.9820 - lr: 0.0100
# Epoch 13/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8520 - reconstruction_loss: 0.6539 - kl_loss: 0.7767
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8518 - reconstruction_loss: 0.6536 - kl_loss: 0.7767 - val_total_loss: 0.7809 - val_reconstruction_loss: 0.5677 - val_kl_loss: 0.8528 - lr: 0.0100
# Epoch 14/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8387 - reconstruction_loss: 0.6478 - kl_loss: 0.7725 - val_total_loss: 0.8857 - val_reconstruction_loss: 0.6639 - val_kl_loss: 0.8871 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8396 - reconstruction_loss: 0.6355 - kl_loss: 0.8016 - val_total_loss: 0.8220 - val_reconstruction_loss: 0.5852 - val_kl_loss: 0.9473 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.8490 - reconstruction_loss: 0.6376 - kl_loss: 0.8044 - val_total_loss: 0.8013 - val_reconstruction_loss: 0.5671 - val_kl_loss: 0.9365 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 19ms/step - loss: 0.8359 - reconstruction_loss: 0.6402 - kl_loss: 0.7913 - val_total_loss: 0.9741 - val_reconstruction_loss: 0.7468 - val_kl_loss: 0.9092 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8352 - reconstruction_loss: 0.6386 - kl_loss: 0.7977 - val_total_loss: 0.8707 - val_reconstruction_loss: 0.6250 - val_kl_loss: 0.9829 - lr: 0.0050
# Epoch 19/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8454 - reconstruction_loss: 0.6402 - kl_loss: 0.8212 - val_total_loss: 0.9409 - val_reconstruction_loss: 0.6963 - val_kl_loss: 0.9781 - lr: 0.0050
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8374 - reconstruction_loss: 0.6378 - kl_loss: 0.8073 - val_total_loss: 0.8759 - val_reconstruction_loss: 0.6075 - val_kl_loss: 1.0739 - lr: 0.0050
# Epoch 21/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8460 - reconstruction_loss: 0.6416 - kl_loss: 0.8042 - val_total_loss: 0.7316 - val_reconstruction_loss: 0.5109 - val_kl_loss: 0.8827 - lr: 0.0050
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8273 - reconstruction_loss: 0.6412 - kl_loss: 0.7893 - val_total_loss: 0.7996 - val_reconstruction_loss: 0.5494 - val_kl_loss: 1.0005 - lr: 0.0050
# Epoch 23/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8391 - reconstruction_loss: 0.6358 - kl_loss: 0.8110 - val_total_loss: 0.7935 - val_reconstruction_loss: 0.5314 - val_kl_loss: 1.0481 - lr: 0.0050
# Epoch 24/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8366 - reconstruction_loss: 0.6395 - kl_loss: 0.7985 - val_total_loss: 0.7621 - val_reconstruction_loss: 0.5279 - val_kl_loss: 0.9371 - lr: 0.0050
# Epoch 25/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8288 - reconstruction_loss: 0.6398 - kl_loss: 0.7785 - val_total_loss: 0.8685 - val_reconstruction_loss: 0.6461 - val_kl_loss: 0.8895 - lr: 0.0050
# Epoch 26/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8346 - reconstruction_loss: 0.6359 - kl_loss: 0.8095 - val_total_loss: 0.9048 - val_reconstruction_loss: 0.6609 - val_kl_loss: 0.9754 - lr: 0.0050
# Epoch 27/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8336 - reconstruction_loss: 0.6402 - kl_loss: 0.8083 - val_total_loss: 0.8155 - val_reconstruction_loss: 0.5844 - val_kl_loss: 0.9247 - lr: 0.0050
# Epoch 28/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8433 - reconstruction_loss: 0.6394 - kl_loss: 0.8113 - val_total_loss: 0.9585 - val_reconstruction_loss: 0.7255 - val_kl_loss: 0.9318 - lr: 0.0050
# Epoch 29/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8440 - reconstruction_loss: 0.6362 - kl_loss: 0.7993 - val_total_loss: 0.8735 - val_reconstruction_loss: 0.6259 - val_kl_loss: 0.9905 - lr: 0.0050
# Epoch 30/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8411 - reconstruction_loss: 0.6405 - kl_loss: 0.8128 - val_total_loss: 0.8407 - val_reconstruction_loss: 0.5930 - val_kl_loss: 0.9908 - lr: 0.0050
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.9671 - reconstruction_loss: 0.7581 - kl_loss: 0.8363
# [0.9671319127082825, 0.7580676674842834, 0.8362569808959961]
# Learning rate:  0.01
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 45ms/step - loss: 0.9163 - reconstruction_loss: 0.7111 - kl_loss: 0.7388 - val_total_loss: 0.8332 - val_reconstruction_loss: 0.6408 - val_kl_loss: 0.7693 - lr: 0.0100
# Epoch 2/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8354 - reconstruction_loss: 0.6475 - kl_loss: 0.7501 - val_total_loss: 0.8349 - val_reconstruction_loss: 0.6162 - val_kl_loss: 0.8746 - lr: 0.0100
# Epoch 3/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8393 - reconstruction_loss: 0.6338 - kl_loss: 0.8185 - val_total_loss: 0.8695 - val_reconstruction_loss: 0.6549 - val_kl_loss: 0.8583 - lr: 0.0100
# Epoch 4/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8333 - reconstruction_loss: 0.6410 - kl_loss: 0.8042 - val_total_loss: 0.8536 - val_reconstruction_loss: 0.6362 - val_kl_loss: 0.8696 - lr: 0.0100
# Epoch 5/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8503 - reconstruction_loss: 0.6418 - kl_loss: 0.8475 - val_total_loss: 0.8268 - val_reconstruction_loss: 0.6050 - val_kl_loss: 0.8874 - lr: 0.0100
# Epoch 6/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8361 - reconstruction_loss: 0.6394 - kl_loss: 0.7998 - val_total_loss: 0.8187 - val_reconstruction_loss: 0.6038 - val_kl_loss: 0.8598 - lr: 0.0100
# Epoch 7/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8470 - reconstruction_loss: 0.6387 - kl_loss: 0.7856 - val_total_loss: 0.8757 - val_reconstruction_loss: 0.6731 - val_kl_loss: 0.8102 - lr: 0.0100
# Epoch 8/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8354 - reconstruction_loss: 0.6432 - kl_loss: 0.7844 - val_total_loss: 0.8431 - val_reconstruction_loss: 0.6019 - val_kl_loss: 0.9645 - lr: 0.0100
# Epoch 9/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8322 - reconstruction_loss: 0.6341 - kl_loss: 0.8268 - val_total_loss: 0.8133 - val_reconstruction_loss: 0.5896 - val_kl_loss: 0.8946 - lr: 0.0100
# Epoch 10/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8454 - reconstruction_loss: 0.6404 - kl_loss: 0.8089 - val_total_loss: 0.8195 - val_reconstruction_loss: 0.6068 - val_kl_loss: 0.8508 - lr: 0.0100
# Epoch 11/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8529 - reconstruction_loss: 0.6432 - kl_loss: 0.7995 - val_total_loss: 0.8552 - val_reconstruction_loss: 0.6267 - val_kl_loss: 0.9140 - lr: 0.0100
# Epoch 12/30
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8551 - reconstruction_loss: 0.6450 - kl_loss: 0.7924
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8545 - reconstruction_loss: 0.6498 - kl_loss: 0.7894 - val_total_loss: 0.8625 - val_reconstruction_loss: 0.6381 - val_kl_loss: 0.8977 - lr: 0.0100
# Epoch 13/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8333 - reconstruction_loss: 0.6317 - kl_loss: 0.7903 - val_total_loss: 0.8385 - val_reconstruction_loss: 0.6316 - val_kl_loss: 0.8277 - lr: 0.0050
# Epoch 14/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8372 - reconstruction_loss: 0.6426 - kl_loss: 0.7761 - val_total_loss: 0.8097 - val_reconstruction_loss: 0.5884 - val_kl_loss: 0.8850 - lr: 0.0050
# Epoch 15/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8270 - reconstruction_loss: 0.6418 - kl_loss: 0.8038 - val_total_loss: 0.8650 - val_reconstruction_loss: 0.6322 - val_kl_loss: 0.9311 - lr: 0.0050
# Epoch 16/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8405 - reconstruction_loss: 0.6335 - kl_loss: 0.8166 - val_total_loss: 0.8384 - val_reconstruction_loss: 0.6281 - val_kl_loss: 0.8412 - lr: 0.0050
# Epoch 17/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8356 - reconstruction_loss: 0.6364 - kl_loss: 0.7818 - val_total_loss: 0.8812 - val_reconstruction_loss: 0.6633 - val_kl_loss: 0.8714 - lr: 0.0050
# Epoch 18/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8487 - reconstruction_loss: 0.6365 - kl_loss: 0.8074 - val_total_loss: 0.8210 - val_reconstruction_loss: 0.6079 - val_kl_loss: 0.8527 - lr: 0.0050
# Epoch 19/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8381 - reconstruction_loss: 0.6410 - kl_loss: 0.8070 - val_total_loss: 0.8263 - val_reconstruction_loss: 0.5999 - val_kl_loss: 0.9055 - lr: 0.0050
# Epoch 20/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8410 - reconstruction_loss: 0.6340 - kl_loss: 0.8100 - val_total_loss: 0.8381 - val_reconstruction_loss: 0.6163 - val_kl_loss: 0.8873 - lr: 0.0050
# Epoch 21/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8332 - reconstruction_loss: 0.6347 - kl_loss: 0.8119 - val_total_loss: 0.8602 - val_reconstruction_loss: 0.6318 - val_kl_loss: 0.9134 - lr: 0.0050
# Epoch 22/30
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8331 - reconstruction_loss: 0.6233 - kl_loss: 0.8195 - val_total_loss: 0.8256 - val_reconstruction_loss: 0.6160 - val_kl_loss: 0.8384 - lr: 0.0050
# Epoch 23/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8282 - reconstruction_loss: 0.6329 - kl_loss: 0.7869 - val_total_loss: 0.8458 - val_reconstruction_loss: 0.6315 - val_kl_loss: 0.8573 - lr: 0.0050
# Epoch 24/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8334 - reconstruction_loss: 0.6308 - kl_loss: 0.8184 - val_total_loss: 0.8555 - val_reconstruction_loss: 0.6469 - val_kl_loss: 0.8342 - lr: 0.0050
# Epoch 25/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8444 - reconstruction_loss: 0.6383 - kl_loss: 0.8019 - val_total_loss: 0.8207 - val_reconstruction_loss: 0.5940 - val_kl_loss: 0.9067 - lr: 0.0050
# Epoch 26/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8336 - reconstruction_loss: 0.6366 - kl_loss: 0.8023 - val_total_loss: 0.8294 - val_reconstruction_loss: 0.6186 - val_kl_loss: 0.8433 - lr: 0.0050
# Epoch 27/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8295 - reconstruction_loss: 0.6301 - kl_loss: 0.8202 - val_total_loss: 0.8364 - val_reconstruction_loss: 0.6153 - val_kl_loss: 0.8842 - lr: 0.0050
# Epoch 28/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8327 - reconstruction_loss: 0.6364 - kl_loss: 0.8192 - val_total_loss: 0.8559 - val_reconstruction_loss: 0.6401 - val_kl_loss: 0.8631 - lr: 0.0050
# Epoch 29/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8286 - reconstruction_loss: 0.6339 - kl_loss: 0.7950 - val_total_loss: 0.8230 - val_reconstruction_loss: 0.6140 - val_kl_loss: 0.8359 - lr: 0.0050
# Epoch 30/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8231 - reconstruction_loss: 0.6315 - kl_loss: 0.7886 - val_total_loss: 0.8517 - val_reconstruction_loss: 0.6411 - val_kl_loss: 0.8423 - lr: 0.0050
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7916 - reconstruction_loss: 0.5883 - kl_loss: 0.8132
# [0.791597843170166, 0.5882993340492249, 0.8131939768791199]
# Best Hyperparameters: {'learn_rate': 0.01, 'batch_size': 32}
# Best Score: [0.6992576718330383, 0.5095996260643005, 0.7586321830749512]

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)

vae.fit(x_train, batch_size=bs, epochs=100, validation_split = 0.2,
        callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 210/210 [==============================] - 3s 8ms/step - loss: 0.8745 - reconstruction_loss: 0.6782 - kl_loss: 0.7555 - val_total_loss: 0.9033 - val_reconstruction_loss: 0.6841 - val_kl_loss: 0.8767 - lr: 0.0100
# Epoch 2/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8476 - reconstruction_loss: 0.6669 - kl_loss: 0.7768 - val_total_loss: 0.9981 - val_reconstruction_loss: 0.7801 - val_kl_loss: 0.8718 - lr: 0.0100
# Epoch 3/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8820 - reconstruction_loss: 0.6817 - kl_loss: 0.7556 - val_total_loss: 0.8846 - val_reconstruction_loss: 0.6905 - val_kl_loss: 0.7764 - lr: 0.0100
# Epoch 4/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8890 - reconstruction_loss: 0.6770 - kl_loss: 0.7571 - val_total_loss: 0.8627 - val_reconstruction_loss: 0.6115 - val_kl_loss: 1.0047 - lr: 0.0100
# Epoch 5/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8794 - reconstruction_loss: 0.6727 - kl_loss: 0.7647 - val_total_loss: 0.9024 - val_reconstruction_loss: 0.6859 - val_kl_loss: 0.8661 - lr: 0.0100
# Epoch 6/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8534 - reconstruction_loss: 0.6727 - kl_loss: 0.7686 - val_total_loss: 1.0302 - val_reconstruction_loss: 0.8279 - val_kl_loss: 0.8092 - lr: 0.0100
# Epoch 7/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8535 - reconstruction_loss: 0.6727 - kl_loss: 0.7588 - val_total_loss: 0.8436 - val_reconstruction_loss: 0.6382 - val_kl_loss: 0.8216 - lr: 0.0100
# Epoch 8/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8472 - reconstruction_loss: 0.6788 - kl_loss: 0.7303 - val_total_loss: 0.8907 - val_reconstruction_loss: 0.6477 - val_kl_loss: 0.9719 - lr: 0.0100
# Epoch 9/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8518 - reconstruction_loss: 0.6712 - kl_loss: 0.7579 - val_total_loss: 0.7986 - val_reconstruction_loss: 0.5322 - val_kl_loss: 1.0652 - lr: 0.0100
# Epoch 10/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8672 - reconstruction_loss: 0.6786 - kl_loss: 0.7421 - val_total_loss: 0.7723 - val_reconstruction_loss: 0.5586 - val_kl_loss: 0.8545 - lr: 0.0100
# Epoch 11/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8628 - reconstruction_loss: 0.6712 - kl_loss: 0.7565 - val_total_loss: 0.9404 - val_reconstruction_loss: 0.7256 - val_kl_loss: 0.8591 - lr: 0.0100
# Epoch 12/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8650 - reconstruction_loss: 0.6739 - kl_loss: 0.7572 - val_total_loss: 0.9533 - val_reconstruction_loss: 0.7493 - val_kl_loss: 0.8159 - lr: 0.0100
# Epoch 13/100
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8507 - reconstruction_loss: 0.6736 - kl_loss: 0.7541 - val_total_loss: 0.8372 - val_reconstruction_loss: 0.6215 - val_kl_loss: 0.8629 - lr: 0.0100
# Epoch 14/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8723 - reconstruction_loss: 0.6675 - kl_loss: 0.7753 - val_total_loss: 0.7662 - val_reconstruction_loss: 0.5414 - val_kl_loss: 0.8993 - lr: 0.0100
# Epoch 15/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8665 - reconstruction_loss: 0.6836 - kl_loss: 0.7409 - val_total_loss: 0.8241 - val_reconstruction_loss: 0.6174 - val_kl_loss: 0.8267 - lr: 0.0100
# Epoch 16/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8696 - reconstruction_loss: 0.6791 - kl_loss: 0.7410 - val_total_loss: 0.8380 - val_reconstruction_loss: 0.6362 - val_kl_loss: 0.8075 - lr: 0.0100
# Epoch 17/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8668 - reconstruction_loss: 0.6879 - kl_loss: 0.7241 - val_total_loss: 0.9891 - val_reconstruction_loss: 0.7974 - val_kl_loss: 0.7670 - lr: 0.0100
# Epoch 18/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8636 - reconstruction_loss: 0.6838 - kl_loss: 0.7323 - val_total_loss: 0.8097 - val_reconstruction_loss: 0.5652 - val_kl_loss: 0.9777 - lr: 0.0100
# Epoch 19/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8502 - reconstruction_loss: 0.6792 - kl_loss: 0.7358 - val_total_loss: 0.8998 - val_reconstruction_loss: 0.7309 - val_kl_loss: 0.6755 - lr: 0.0100
# Epoch 20/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8604 - reconstruction_loss: 0.6767 - kl_loss: 0.7418 - val_total_loss: 0.8815 - val_reconstruction_loss: 0.6138 - val_kl_loss: 1.0710 - lr: 0.0100
# Epoch 21/100
# 207/210 [============================>.] - ETA: 0s - loss: 0.8609 - reconstruction_loss: 0.6832 - kl_loss: 0.7183
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8610 - reconstruction_loss: 0.6843 - kl_loss: 0.7214 - val_total_loss: 0.8803 - val_reconstruction_loss: 0.6690 - val_kl_loss: 0.8452 - lr: 0.0100
# Epoch 22/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8577 - reconstruction_loss: 0.6582 - kl_loss: 0.7794 - val_total_loss: 0.8374 - val_reconstruction_loss: 0.6292 - val_kl_loss: 0.8328 - lr: 0.0050
# Epoch 23/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8602 - reconstruction_loss: 0.6617 - kl_loss: 0.7514 - val_total_loss: 0.8154 - val_reconstruction_loss: 0.6094 - val_kl_loss: 0.8240 - lr: 0.0050
# Epoch 24/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8385 - reconstruction_loss: 0.6615 - kl_loss: 0.7497 - val_total_loss: 0.8634 - val_reconstruction_loss: 0.6139 - val_kl_loss: 0.9979 - lr: 0.0050
# Epoch 25/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8612 - reconstruction_loss: 0.6586 - kl_loss: 0.7693 - val_total_loss: 0.8388 - val_reconstruction_loss: 0.6218 - val_kl_loss: 0.8679 - lr: 0.0050
# Epoch 26/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8427 - reconstruction_loss: 0.6513 - kl_loss: 0.7764 - val_total_loss: 0.9364 - val_reconstruction_loss: 0.6922 - val_kl_loss: 0.9768 - lr: 0.0050
# Epoch 27/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8536 - reconstruction_loss: 0.6571 - kl_loss: 0.7833 - val_total_loss: 0.8617 - val_reconstruction_loss: 0.6405 - val_kl_loss: 0.8847 - lr: 0.0050
# Epoch 28/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8446 - reconstruction_loss: 0.6553 - kl_loss: 0.7666 - val_total_loss: 0.8537 - val_reconstruction_loss: 0.6120 - val_kl_loss: 0.9666 - lr: 0.0050
# Epoch 29/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8467 - reconstruction_loss: 0.6577 - kl_loss: 0.7751 - val_total_loss: 0.7847 - val_reconstruction_loss: 0.5642 - val_kl_loss: 0.8820 - lr: 0.0050
# Epoch 30/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8442 - reconstruction_loss: 0.6561 - kl_loss: 0.7746 - val_total_loss: 0.7643 - val_reconstruction_loss: 0.4954 - val_kl_loss: 1.0758 - lr: 0.0050
# Epoch 31/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8408 - reconstruction_loss: 0.6538 - kl_loss: 0.7683 - val_total_loss: 0.9270 - val_reconstruction_loss: 0.7011 - val_kl_loss: 0.9036 - lr: 0.0050
# Epoch 32/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8397 - reconstruction_loss: 0.6555 - kl_loss: 0.7619 - val_total_loss: 0.9126 - val_reconstruction_loss: 0.7000 - val_kl_loss: 0.8505 - lr: 0.0050
# Epoch 33/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8452 - reconstruction_loss: 0.6561 - kl_loss: 0.7861 - val_total_loss: 0.8431 - val_reconstruction_loss: 0.6338 - val_kl_loss: 0.8368 - lr: 0.0050
# Epoch 34/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8471 - reconstruction_loss: 0.6542 - kl_loss: 0.7529 - val_total_loss: 0.9638 - val_reconstruction_loss: 0.7159 - val_kl_loss: 0.9917 - lr: 0.0050
# Epoch 35/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8537 - reconstruction_loss: 0.6533 - kl_loss: 0.7657 - val_total_loss: 0.8493 - val_reconstruction_loss: 0.6319 - val_kl_loss: 0.8696 - lr: 0.0050
# Epoch 36/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8470 - reconstruction_loss: 0.6545 - kl_loss: 0.7683 - val_total_loss: 0.9290 - val_reconstruction_loss: 0.7155 - val_kl_loss: 0.8541 - lr: 0.0050
# Epoch 37/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8409 - reconstruction_loss: 0.6523 - kl_loss: 0.7951 - val_total_loss: 0.8426 - val_reconstruction_loss: 0.6064 - val_kl_loss: 0.9452 - lr: 0.0050
# Epoch 38/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8517 - reconstruction_loss: 0.6529 - kl_loss: 0.7944 - val_total_loss: 0.9820 - val_reconstruction_loss: 0.7667 - val_kl_loss: 0.8611 - lr: 0.0050
# Epoch 39/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8541 - reconstruction_loss: 0.6561 - kl_loss: 0.7832 - val_total_loss: 0.9120 - val_reconstruction_loss: 0.6613 - val_kl_loss: 1.0031 - lr: 0.0050
# Epoch 40/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8476 - reconstruction_loss: 0.6518 - kl_loss: 0.7953 - val_total_loss: 0.7843 - val_reconstruction_loss: 0.5730 - val_kl_loss: 0.8455 - lr: 0.0050
# Epoch 41/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8451 - reconstruction_loss: 0.6551 - kl_loss: 0.7677 - val_total_loss: 0.8301 - val_reconstruction_loss: 0.6021 - val_kl_loss: 0.9119 - lr: 0.0050
# Epoch 42/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8608 - reconstruction_loss: 0.6575 - kl_loss: 0.7801 - val_total_loss: 0.8938 - val_reconstruction_loss: 0.6399 - val_kl_loss: 1.0157 - lr: 0.0050
# Epoch 43/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8492 - reconstruction_loss: 0.6504 - kl_loss: 0.7866 - val_total_loss: 0.8316 - val_reconstruction_loss: 0.6054 - val_kl_loss: 0.9046 - lr: 0.0050
# Epoch 44/100
# 202/210 [===========================>..] - ETA: 0s - loss: 0.8525 - reconstruction_loss: 0.6543 - kl_loss: 0.7802
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8523 - reconstruction_loss: 0.6533 - kl_loss: 0.7749 - val_total_loss: 0.9093 - val_reconstruction_loss: 0.6970 - val_kl_loss: 0.8490 - lr: 0.0050
# Epoch 45/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8397 - reconstruction_loss: 0.6454 - kl_loss: 0.7804 - val_total_loss: 0.8689 - val_reconstruction_loss: 0.6379 - val_kl_loss: 0.9241 - lr: 0.0025
# Epoch 46/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8595 - reconstruction_loss: 0.6422 - kl_loss: 0.8020 - val_total_loss: 0.9346 - val_reconstruction_loss: 0.7087 - val_kl_loss: 0.9035 - lr: 0.0025
# Epoch 47/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8397 - reconstruction_loss: 0.6449 - kl_loss: 0.7904 - val_total_loss: 0.8849 - val_reconstruction_loss: 0.6462 - val_kl_loss: 0.9547 - lr: 0.0025
# Epoch 48/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8423 - reconstruction_loss: 0.6395 - kl_loss: 0.7998 - val_total_loss: 0.8685 - val_reconstruction_loss: 0.6268 - val_kl_loss: 0.9670 - lr: 0.0025
# Epoch 49/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8403 - reconstruction_loss: 0.6419 - kl_loss: 0.7971 - val_total_loss: 0.9037 - val_reconstruction_loss: 0.6797 - val_kl_loss: 0.8961 - lr: 0.0025
# Epoch 50/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8518 - reconstruction_loss: 0.6403 - kl_loss: 0.7878 - val_total_loss: 0.8313 - val_reconstruction_loss: 0.6050 - val_kl_loss: 0.9048 - lr: 0.0025
# Epoch 51/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8364 - reconstruction_loss: 0.6510 - kl_loss: 0.7657 - val_total_loss: 0.8107 - val_reconstruction_loss: 0.5724 - val_kl_loss: 0.9534 - lr: 0.0025
# Epoch 52/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8499 - reconstruction_loss: 0.6387 - kl_loss: 0.7989 - val_total_loss: 0.7351 - val_reconstruction_loss: 0.5038 - val_kl_loss: 0.9256 - lr: 0.0025
# Epoch 53/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8244 - reconstruction_loss: 0.6425 - kl_loss: 0.7814 - val_total_loss: 0.8155 - val_reconstruction_loss: 0.5997 - val_kl_loss: 0.8633 - lr: 0.0025
# Epoch 54/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8545 - reconstruction_loss: 0.6436 - kl_loss: 0.7810 - val_total_loss: 1.0142 - val_reconstruction_loss: 0.7891 - val_kl_loss: 0.9004 - lr: 0.0025
# Epoch 55/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8448 - reconstruction_loss: 0.6433 - kl_loss: 0.7839 - val_total_loss: 0.9034 - val_reconstruction_loss: 0.6749 - val_kl_loss: 0.9140 - lr: 0.0025
# Epoch 56/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8384 - reconstruction_loss: 0.6413 - kl_loss: 0.8212 - val_total_loss: 0.7503 - val_reconstruction_loss: 0.5003 - val_kl_loss: 0.9999 - lr: 0.0025
# Epoch 57/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8335 - reconstruction_loss: 0.6417 - kl_loss: 0.7851 - val_total_loss: 0.7082 - val_reconstruction_loss: 0.4665 - val_kl_loss: 0.9666 - lr: 0.0025
# Epoch 58/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8552 - reconstruction_loss: 0.6411 - kl_loss: 0.8039 - val_total_loss: 0.8109 - val_reconstruction_loss: 0.5746 - val_kl_loss: 0.9451 - lr: 0.0025
# Epoch 59/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8418 - reconstruction_loss: 0.6485 - kl_loss: 0.7863 - val_total_loss: 0.8091 - val_reconstruction_loss: 0.5720 - val_kl_loss: 0.9487 - lr: 0.0025
# Epoch 60/100
# 207/210 [============================>.] - ETA: 0s - loss: 0.8340 - reconstruction_loss: 0.6391 - kl_loss: 0.7991
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8341 - reconstruction_loss: 0.6400 - kl_loss: 0.7994 - val_total_loss: 0.9532 - val_reconstruction_loss: 0.7241 - val_kl_loss: 0.9162 - lr: 0.0025
# Epoch 61/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8429 - reconstruction_loss: 0.6360 - kl_loss: 0.7940 - val_total_loss: 0.8950 - val_reconstruction_loss: 0.6671 - val_kl_loss: 0.9118 - lr: 0.0012
# Epoch 62/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8364 - reconstruction_loss: 0.6418 - kl_loss: 0.7845 - val_total_loss: 0.7682 - val_reconstruction_loss: 0.5448 - val_kl_loss: 0.8934 - lr: 0.0012
# Epoch 63/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8325 - reconstruction_loss: 0.6372 - kl_loss: 0.7916 - val_total_loss: 0.8621 - val_reconstruction_loss: 0.6307 - val_kl_loss: 0.9255 - lr: 0.0012
# Epoch 64/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8398 - reconstruction_loss: 0.6396 - kl_loss: 0.8007 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6374 - val_kl_loss: 0.9495 - lr: 0.0012
# Epoch 65/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8445 - reconstruction_loss: 0.6332 - kl_loss: 0.8005 - val_total_loss: 0.8667 - val_reconstruction_loss: 0.6369 - val_kl_loss: 0.9192 - lr: 0.0012
# Epoch 66/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8459 - reconstruction_loss: 0.6353 - kl_loss: 0.8046 - val_total_loss: 0.7516 - val_reconstruction_loss: 0.5149 - val_kl_loss: 0.9468 - lr: 0.0012
# Epoch 67/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8395 - reconstruction_loss: 0.6386 - kl_loss: 0.8049 - val_total_loss: 0.8766 - val_reconstruction_loss: 0.6467 - val_kl_loss: 0.9197 - lr: 0.0012
# Epoch 68/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8310 - reconstruction_loss: 0.6339 - kl_loss: 0.8097 - val_total_loss: 0.8003 - val_reconstruction_loss: 0.5655 - val_kl_loss: 0.9391 - lr: 0.0012
# Epoch 69/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8372 - reconstruction_loss: 0.6343 - kl_loss: 0.8035 - val_total_loss: 0.8193 - val_reconstruction_loss: 0.5948 - val_kl_loss: 0.8982 - lr: 0.0012
# Epoch 70/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8385 - reconstruction_loss: 0.6365 - kl_loss: 0.7982 - val_total_loss: 0.9080 - val_reconstruction_loss: 0.6792 - val_kl_loss: 0.9152 - lr: 0.0012
# Epoch 71/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8340 - reconstruction_loss: 0.6354 - kl_loss: 0.8000 - val_total_loss: 0.7757 - val_reconstruction_loss: 0.5547 - val_kl_loss: 0.8840 - lr: 0.0012
# Epoch 72/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8383 - reconstruction_loss: 0.6389 - kl_loss: 0.7940 - val_total_loss: 0.8566 - val_reconstruction_loss: 0.6287 - val_kl_loss: 0.9117 - lr: 0.0012
# Epoch 73/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8462 - reconstruction_loss: 0.6336 - kl_loss: 0.7940 - val_total_loss: 0.8011 - val_reconstruction_loss: 0.5629 - val_kl_loss: 0.9526 - lr: 0.0012
# Epoch 74/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8371 - reconstruction_loss: 0.6371 - kl_loss: 0.8058 - val_total_loss: 0.8370 - val_reconstruction_loss: 0.6014 - val_kl_loss: 0.9423 - lr: 0.0012
# Epoch 75/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8318 - reconstruction_loss: 0.6367 - kl_loss: 0.8139 - val_total_loss: 0.8874 - val_reconstruction_loss: 0.6419 - val_kl_loss: 0.9820 - lr: 0.0012
# Epoch 76/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8228 - reconstruction_loss: 0.6321 - kl_loss: 0.8048 - val_total_loss: 0.8483 - val_reconstruction_loss: 0.6024 - val_kl_loss: 0.9836 - lr: 0.0012
# Epoch 77/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8264 - reconstruction_loss: 0.6311 - kl_loss: 0.8114 - val_total_loss: 0.7838 - val_reconstruction_loss: 0.5463 - val_kl_loss: 0.9499 - lr: 0.0012
# Epoch 78/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8243 - reconstruction_loss: 0.6342 - kl_loss: 0.7897 - val_total_loss: 0.8089 - val_reconstruction_loss: 0.5790 - val_kl_loss: 0.9198 - lr: 0.0012
# Epoch 79/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8282 - reconstruction_loss: 0.6343 - kl_loss: 0.8167 - val_total_loss: 0.9955 - val_reconstruction_loss: 0.7638 - val_kl_loss: 0.9268 - lr: 0.0012
# Epoch 80/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8284 - reconstruction_loss: 0.6325 - kl_loss: 0.8007 - val_total_loss: 0.9388 - val_reconstruction_loss: 0.6959 - val_kl_loss: 0.9714 - lr: 0.0012
# Epoch 81/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8383 - reconstruction_loss: 0.6332 - kl_loss: 0.8080 - val_total_loss: 0.8044 - val_reconstruction_loss: 0.5806 - val_kl_loss: 0.8955 - lr: 0.0012
# Epoch 82/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8184 - reconstruction_loss: 0.6357 - kl_loss: 0.7988 - val_total_loss: 0.9602 - val_reconstruction_loss: 0.7406 - val_kl_loss: 0.8784 - lr: 0.0012
# Epoch 83/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8433 - reconstruction_loss: 0.6416 - kl_loss: 0.8022 - val_total_loss: 0.8475 - val_reconstruction_loss: 0.6057 - val_kl_loss: 0.9673 - lr: 0.0012
# Epoch 84/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8416 - reconstruction_loss: 0.6372 - kl_loss: 0.8005 - val_total_loss: 0.8941 - val_reconstruction_loss: 0.6599 - val_kl_loss: 0.9369 - lr: 0.0012
# Epoch 85/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8363 - reconstruction_loss: 0.6386 - kl_loss: 0.8090 - val_total_loss: 0.8831 - val_reconstruction_loss: 0.6454 - val_kl_loss: 0.9507 - lr: 0.0012
# Epoch 86/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8303 - reconstruction_loss: 0.6413 - kl_loss: 0.7841 - val_total_loss: 0.9715 - val_reconstruction_loss: 0.7242 - val_kl_loss: 0.9891 - lr: 0.0012
# Epoch 87/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8387 - reconstruction_loss: 0.6345 - kl_loss: 0.8111 - val_total_loss: 0.8078 - val_reconstruction_loss: 0.5546 - val_kl_loss: 1.0132 - lr: 0.0012
# Epoch 88/100
# 204/210 [============================>.] - ETA: 0s - loss: 0.8347 - reconstruction_loss: 0.6407 - kl_loss: 0.7916
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8348 - reconstruction_loss: 0.6395 - kl_loss: 0.7995 - val_total_loss: 0.8590 - val_reconstruction_loss: 0.6165 - val_kl_loss: 0.9698 - lr: 0.0012
# Epoch 89/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8365 - reconstruction_loss: 0.6309 - kl_loss: 0.7991 - val_total_loss: 0.9050 - val_reconstruction_loss: 0.6666 - val_kl_loss: 0.9539 - lr: 6.2500e-04
# Epoch 90/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8371 - reconstruction_loss: 0.6361 - kl_loss: 0.8137 - val_total_loss: 0.7842 - val_reconstruction_loss: 0.5394 - val_kl_loss: 0.9795 - lr: 6.2500e-04
# Epoch 91/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8473 - reconstruction_loss: 0.6327 - kl_loss: 0.8052 - val_total_loss: 1.0410 - val_reconstruction_loss: 0.8083 - val_kl_loss: 0.9309 - lr: 6.2500e-04
# Epoch 92/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8279 - reconstruction_loss: 0.6371 - kl_loss: 0.7941 - val_total_loss: 0.7020 - val_reconstruction_loss: 0.4677 - val_kl_loss: 0.9369 - lr: 6.2500e-04
# Epoch 93/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8346 - reconstruction_loss: 0.6315 - kl_loss: 0.8115 - val_total_loss: 0.8529 - val_reconstruction_loss: 0.6238 - val_kl_loss: 0.9167 - lr: 6.2500e-04
# Epoch 94/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8277 - reconstruction_loss: 0.6342 - kl_loss: 0.7979 - val_total_loss: 0.9965 - val_reconstruction_loss: 0.7573 - val_kl_loss: 0.9568 - lr: 6.2500e-04
# Epoch 95/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8321 - reconstruction_loss: 0.6301 - kl_loss: 0.8005 - val_total_loss: 0.8258 - val_reconstruction_loss: 0.5896 - val_kl_loss: 0.9450 - lr: 6.2500e-04
# Epoch 96/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8339 - reconstruction_loss: 0.6343 - kl_loss: 0.8161 - val_total_loss: 0.7777 - val_reconstruction_loss: 0.5422 - val_kl_loss: 0.9422 - lr: 6.2500e-04
# Epoch 97/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8455 - reconstruction_loss: 0.6338 - kl_loss: 0.8164 - val_total_loss: 0.8301 - val_reconstruction_loss: 0.5953 - val_kl_loss: 0.9390 - lr: 6.2500e-04
# Epoch 98/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8302 - reconstruction_loss: 0.6349 - kl_loss: 0.8149 - val_total_loss: 0.9004 - val_reconstruction_loss: 0.6584 - val_kl_loss: 0.9681 - lr: 6.2500e-04
# Epoch 99/100
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8256 - reconstruction_loss: 0.6277 - kl_loss: 0.8090 - val_total_loss: 0.9904 - val_reconstruction_loss: 0.7604 - val_kl_loss: 0.9200 - lr: 6.2500e-04
# Epoch 100/100
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8429 - reconstruction_loss: 0.6356 - kl_loss: 0.8041 - val_total_loss: 0.8405 - val_reconstruction_loss: 0.5986 - val_kl_loss: 0.9676 - lr: 6.2500e-04

# %%
_, _, z_input = encoder.predict(x_train)
reconstructed_z_input = vae.decoder.predict(z_input)
_, _, reconstructed_z_encoded = vae.encoder.predict(reconstructed_z_input)

_, _, z_test_input = encoder.predict(x_test)
reconstructed_z_test_input = vae.decoder.predict(z_test_input)
_, _, reconstructed_z_test_encoded = vae.encoder.predict(reconstructed_z_test_input)
# Out:
# 262/262 [==============================] - 0s 1ms/step
# 262/262 [==============================] - 1s 2ms/step
# 262/262 [==============================] - 0s 955us/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step

# %%
def plot_input_data(x_data, y_data):
    z_input = x_data
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za trening enkodirani u latentni prostor")
plot_input_data(z_input, y_train)

plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

# %%
def plot_input_and_reconstructed_data(x_input_data, x_reconstructed, y_input_data):
    z_input = x_input_data
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Reconstructed Data')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.title("Podaci za testiranje i rekonstruirani podaci enkodirani u latentni prostor")
    plt.legend()
    plt.show()

plt.figure(figsize=(10, 6))
plot_input_and_reconstructed_data(z_test_input, reconstructed_z_test_encoded, y_test)

# %%
def plot_reconstructed_data(x_reconstructed, y_data):
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=f'Label {label}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirani podaci enkodirani u latentni prostor")
plot_reconstructed_data(reconstructed_z_test_encoded, y_test)

# %%
selected_indices = np.random.choice(len(x_test), 10, replace=False)

selected_peptides = x_test[selected_indices]

_, _, encoded_selected_peptides = vae.encoder.predict(selected_peptides)
reconstructed_peptides = vae.decoder.predict(encoded_selected_peptides)
_, _, encoded_reconstructed_peptides = vae.encoder.predict(reconstructed_peptides)


def plot_selected_data(x_data):
    z_input = x_data
    num_peptides = z_input.shape[0]
    unique_colors = plt.cm.tab20(np.linspace(0, 1, num_peptides))

    for i in range(num_peptides):
        plt.scatter(z_input[i, 0], z_input[i, 1], color=unique_colors[i], label=f'Peptide {i}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

    
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))


plt.figure(figsize=(10, 6))
plt.title("Slučajno izabrane izvorne točke u latentnom prostoru")
plot_selected_data(encoded_selected_peptides)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirane točke u latentnom prostoru")
plot_selected_data(encoded_reconstructed_peptides)


distances = []

for i in range(10):
    dist = euclidean_distance(encoded_selected_peptides[i], encoded_reconstructed_peptides[i])
        
    distances.append(dist)

print("Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke: \n", distances, "\n")
print("Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka: ", np.sum(distances)/10)
# Out:
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 3ms/step
# Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke:
#  [2.276668, 0.75895494, 0.4064726, 0.79856974, 1.0697929, 1.3778251, 1.6985877, 1.5636203, 0.72957027, 0.2611449]
#
# Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka:  1.0941205978393556

# %%
#NORMALIZIRANA UDALJENOST U LATENTNOM PROSTORU

min_values = np.min(z_test_input, axis=0)
max_values = np.max(z_test_input, axis=0)

# Calculate the diagonal length of the latent space
latent_space_size = np.linalg.norm(max_values - min_values)
#print(min_values, max_values)
print(latent_space_size)

distances_test = []

for i in range(len(x_test)):
    dist = euclidean_distance(z_test_input[i], reconstructed_z_test_encoded[i])
        
    distances_test.append(dist)

print("Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka: ", 
      np.sum(distances_test)/latent_space_size/len(x_test))
# Out:
# 11.3555765
# Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka:  0.09141973054203886

# %%
#PEARSON
from scipy.stats import spearmanr, kendalltau, pearsonr

#print(x_test)
#print(reconstructed_z_test_input)

print(pearsonr(x_test.flatten(), reconstructed_z_test_input.flatten()))
# Out:
# PearsonRResult(statistic=0.7998940256892111, pvalue=0.0)

# %%
#RAZLIKA I RMSE

difference = x_test - reconstructed_z_test_input
print(np.abs(np.mean(difference)))

mse = np.mean(np.square(x_test - reconstructed_z_test_input))
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# 0.0016783076152294745
# RMSE: 0.0853721092031452

# %%
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
  
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    alignments = pairwise2.align.globalxx(seq1, seq2)

    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    similarity = (score / max(len(seq1), len(seq2)))

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,101):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.39534884 0.18604651 0.34883721]
#  [0.1025641  0.         0.12820513 ... 0.13157895 0.125      0.05263158]
#  [0.20512821 0.28       0.23076923 ... 0.18421053 0.32       0.23684211]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.34210526 0.32432432 0.34210526]
#  [0.33333333 0.17777778 0.26666667 ... 0.33333333 0.22222222 0.33333333]
#  [0.07692308 0.25       0.15384615 ... 0.18421053 0.16666667 0.23684211]]
# [[0.27272727 0.18604651 0.27906977 ... 0.27906977 0.20930233 0.30232558]
#  [0.36363636 0.25581395 0.27906977 ... 0.3255814  0.1627907  0.18604651]
#  [0.25       0.17241379 0.26666667 ... 0.14285714 0.3        0.2       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.26190476 0.28571429 0.14285714]
#  [0.34090909 0.2972973  0.54054054 ... 0.28571429 0.24324324 0.2972973 ]
#  [0.09090909 0.13793103 0.06666667 ... 0.0952381  0.17647059 0.2       ]]

# %%
distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,101):
        dist_train = euclidean_distance(z_input[i], z_input[j])
        dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.59369785 0.4078125  0.12681063 ... 0.20657846 0.57390624 0.3012585 ]
#  [0.5299482  0.80121857 0.7172516  ... 0.6363665  0.7685632  0.76853204]
#  [0.61334574 0.17264971 0.3064726  ... 0.35682154 0.3199302  0.10357583]
#  ...
#  [0.34318805 0.3151422  0.4593339  ... 0.2958018  0.1104116  0.29358485]
#  [0.61201453 0.60543007 0.30074114 ... 0.35827565 0.73081684 0.52020293]
#  [0.39560696 0.3281612  0.54875624 ... 0.41836876 0.         0.34157237]]
# [[0.72398055 0.8003984  0.3821185  ... 0.9082917  0.21145451 0.36464345]
#  [0.11775041 0.44776034 0.4615859  ... 0.15974134 0.59958255 0.37445527]
#  [0.14634548 0.401622   0.41661587 ... 0.10278948 0.55442655 0.34158844]
#  ...
#  [0.41055208 0.18370223 0.5998601  ... 0.15609184 0.55597854 0.56855327]
#  [0.11486845 0.4731149  0.21774536 ... 0.23868352 0.46413994 0.12789904]
#  [0.6029768  0.792743   0.27077007 ... 0.82736105 0.28526133 0.22123344]]

# %%
correlation_train, p_value_train = spearmanr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = spearmanr(similarities_test.flatten(), distances_test.flatten())

print("Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = kendalltau(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = kendalltau(similarities_test.flatten(), distances_test.flatten())

print("Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)
# Out:
# Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.1938012411697192 -0.2181828583045639
# p-value: 5.319247440844246e-23 7.419055154477761e-29
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2489108673984517 -0.2272186414822852
# p-value: 2.583546438541959e-37 3.235874370516689e-31
#
# Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.1318831251128829 -0.14809928875317147
# p-value: 2.684997113132263e-23 6.570470628616991e-29
