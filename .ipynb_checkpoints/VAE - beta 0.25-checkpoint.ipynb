# %%
#IMPORT KNJIŽNICA I ARHITEKTURA MODELA

#Import knjižnica
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback
import matplotlib.pyplot as plt

#Klasa za uzorkovanje iz latentnog prostora
class Sampling(layers.Layer):

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
latent_dim = 2

#Arhitektura enkodera
encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Arhitektura dekodera
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

#Klasa VAE
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
            total_loss = reconstruction_loss + 0.4 * kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + 0.4 * kl_loss

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d_10 (Conv1D)             (None, 88, 8)        32          ['input_5[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 44, 8)       0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 44, 16)       400         ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_11[0][0]']
#
#  flatten_2 (Flatten)            (None, 352)          0           ['max_pooling1d_5[0][0]']
#
#  dense_6 (Dense)                (None, 128)          45184       ['flatten_2[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_6[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_6[0][0]']
#
#  sampling_2 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 2)]               0
#
#  dense_7 (Dense)             (None, 128)               384
#
#  dense_8 (Dense)             (None, 704)               90816
#
#  reshape_2 (Reshape)         (None, 88, 8)             0
#
#  conv1d_12 (Conv1D)          (None, 88, 16)            400
#
#  up_sampling1d_4 (UpSampling  (None, 176, 16)          0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 176, 8)            392
#
#  up_sampling1d_5 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_14 (Conv1D)          (None, 352, 1)            25
#
#  cropping1d_2 (Cropping1D)   (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
#OBRADA PODATAKA

from sklearn.preprocessing import MinMaxScaler

#Učitavanje podataka i podjela na skupove za trening i testiranje
features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(
                                    features, labels, test_size=0.2, random_state=42)

#Odvajanje sekvenci peptida od ostatka podataka
x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]

#Odvajanje izračunatih značajki peptida
x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

#Normalizacija podataka
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

#Prilagođavanje dimenzionalnosti podataka
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
#OPTIMIZACIJA HIPERPARAMETARA

#Prostor pretrage
learn_rate = [0.001, 0.005, 0.008, 0.01]
batch_size = [32, 64, 128, 256]

param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

#Petlje u kojima se obavlja testiranje svih kombinacija hiperparametara iz prostora pretrage
for lr in learn_rate:
    for bs in batch_size:
        print("Learning rate: ", lr)
        print("Batch size: ", bs)
        
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))
        
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
        early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
        
        vae.fit(x_train, batch_size=bs, epochs=30, validation_split = 0.2, 
                callbacks=[reduce_lr, early_stop])

        score = vae.evaluate(x_train)
        print(score)

        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

#Ispis najboljih hiperparametara  
print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

#Spremanje najboljih hiperparametara u varijable za daljnje korištenje
lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Learning rate:  0.001
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 4s 8ms/step - loss: 1.4021 - reconstruction_loss: 1.1717 - kl_loss: 0.0115 - val_total_loss: 1.0396 - val_reconstruction_loss: 1.0302 - val_kl_loss: 0.0346 - lr: 0.0010
# Epoch 2/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9809 - reconstruction_loss: 0.9375 - kl_loss: 0.1025 - val_total_loss: 1.0600 - val_reconstruction_loss: 0.9743 - val_kl_loss: 0.3173 - lr: 0.0010
# Epoch 3/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9423 - reconstruction_loss: 0.8515 - kl_loss: 0.3073 - val_total_loss: 0.9048 - val_reconstruction_loss: 0.7714 - val_kl_loss: 0.4941 - lr: 0.0010
# Epoch 4/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9248 - reconstruction_loss: 0.8230 - kl_loss: 0.3454 - val_total_loss: 0.8901 - val_reconstruction_loss: 0.7591 - val_kl_loss: 0.4852 - lr: 0.0010
# Epoch 5/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9099 - reconstruction_loss: 0.8100 - kl_loss: 0.3709 - val_total_loss: 0.9038 - val_reconstruction_loss: 0.7652 - val_kl_loss: 0.5133 - lr: 0.0010
# Epoch 6/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9112 - reconstruction_loss: 0.7993 - kl_loss: 0.4000 - val_total_loss: 0.8446 - val_reconstruction_loss: 0.7075 - val_kl_loss: 0.5077 - lr: 0.0010
# Epoch 7/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8907 - reconstruction_loss: 0.7960 - kl_loss: 0.4065 - val_total_loss: 0.8534 - val_reconstruction_loss: 0.7104 - val_kl_loss: 0.5294 - lr: 0.0010
# Epoch 8/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8921 - reconstruction_loss: 0.7853 - kl_loss: 0.4192 - val_total_loss: 0.9528 - val_reconstruction_loss: 0.8181 - val_kl_loss: 0.4987 - lr: 0.0010
# Epoch 9/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9071 - reconstruction_loss: 0.7776 - kl_loss: 0.4447 - val_total_loss: 0.8737 - val_reconstruction_loss: 0.7389 - val_kl_loss: 0.4992 - lr: 0.0010
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8887 - reconstruction_loss: 0.7758 - kl_loss: 0.4468 - val_total_loss: 0.8288 - val_reconstruction_loss: 0.6605 - val_kl_loss: 0.6234 - lr: 0.0010
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8985 - reconstruction_loss: 0.7687 - kl_loss: 0.4591 - val_total_loss: 0.9518 - val_reconstruction_loss: 0.7654 - val_kl_loss: 0.6905 - lr: 0.0010
# Epoch 12/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8822 - reconstruction_loss: 0.7602 - kl_loss: 0.4858 - val_total_loss: 0.8712 - val_reconstruction_loss: 0.6985 - val_kl_loss: 0.6394 - lr: 0.0010
# Epoch 13/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8919 - reconstruction_loss: 0.7603 - kl_loss: 0.4777 - val_total_loss: 0.9068 - val_reconstruction_loss: 0.7605 - val_kl_loss: 0.5420 - lr: 0.0010
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8778 - reconstruction_loss: 0.7442 - kl_loss: 0.5143 - val_total_loss: 0.8762 - val_reconstruction_loss: 0.7366 - val_kl_loss: 0.5171 - lr: 0.0010
# Epoch 15/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8718 - reconstruction_loss: 0.7386 - kl_loss: 0.5331 - val_total_loss: 0.9082 - val_reconstruction_loss: 0.7423 - val_kl_loss: 0.6145 - lr: 0.0010
# Epoch 16/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8948 - reconstruction_loss: 0.7406 - kl_loss: 0.5373 - val_total_loss: 0.7881 - val_reconstruction_loss: 0.6142 - val_kl_loss: 0.6438 - lr: 0.0010
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8861 - reconstruction_loss: 0.7313 - kl_loss: 0.5688 - val_total_loss: 0.9556 - val_reconstruction_loss: 0.7843 - val_kl_loss: 0.6346 - lr: 0.0010
# Epoch 18/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8763 - reconstruction_loss: 0.7329 - kl_loss: 0.5429 - val_total_loss: 0.9150 - val_reconstruction_loss: 0.7394 - val_kl_loss: 0.6502 - lr: 0.0010
# Epoch 19/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8986 - reconstruction_loss: 0.7270 - kl_loss: 0.5648 - val_total_loss: 0.8247 - val_reconstruction_loss: 0.6705 - val_kl_loss: 0.5713 - lr: 0.0010
# Epoch 20/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8905 - reconstruction_loss: 0.7242 - kl_loss: 0.5650 - val_total_loss: 0.9664 - val_reconstruction_loss: 0.8057 - val_kl_loss: 0.5951 - lr: 0.0010
# Epoch 21/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8877 - reconstruction_loss: 0.7255 - kl_loss: 0.5709 - val_total_loss: 0.8009 - val_reconstruction_loss: 0.6049 - val_kl_loss: 0.7258 - lr: 0.0010
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8878 - reconstruction_loss: 0.7176 - kl_loss: 0.5799 - val_total_loss: 0.9258 - val_reconstruction_loss: 0.7448 - val_kl_loss: 0.6701 - lr: 0.0010
# Epoch 23/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8796 - reconstruction_loss: 0.7198 - kl_loss: 0.5757 - val_total_loss: 0.7545 - val_reconstruction_loss: 0.5656 - val_kl_loss: 0.6996 - lr: 0.0010
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8720 - reconstruction_loss: 0.7130 - kl_loss: 0.5954 - val_total_loss: 0.7899 - val_reconstruction_loss: 0.6142 - val_kl_loss: 0.6509 - lr: 0.0010
# Epoch 25/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8768 - reconstruction_loss: 0.7180 - kl_loss: 0.6002 - val_total_loss: 0.8498 - val_reconstruction_loss: 0.6632 - val_kl_loss: 0.6912 - lr: 0.0010
# Epoch 26/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8779 - reconstruction_loss: 0.7189 - kl_loss: 0.6004 - val_total_loss: 0.8184 - val_reconstruction_loss: 0.6168 - val_kl_loss: 0.7469 - lr: 0.0010
# Epoch 27/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8752 - reconstruction_loss: 0.7130 - kl_loss: 0.6146 - val_total_loss: 0.8645 - val_reconstruction_loss: 0.6909 - val_kl_loss: 0.6428 - lr: 0.0010
# Epoch 28/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8771 - reconstruction_loss: 0.7115 - kl_loss: 0.6087 - val_total_loss: 0.9846 - val_reconstruction_loss: 0.8215 - val_kl_loss: 0.6038 - lr: 0.0010
# Epoch 29/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8807 - reconstruction_loss: 0.7090 - kl_loss: 0.5972 - val_total_loss: 0.8585 - val_reconstruction_loss: 0.6803 - val_kl_loss: 0.6600 - lr: 0.0010
# Epoch 30/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8604 - reconstruction_loss: 0.7141 - kl_loss: 0.5971 - val_total_loss: 1.0029 - val_reconstruction_loss: 0.8114 - val_kl_loss: 0.7092 - lr: 0.0010
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9936 - reconstruction_loss: 0.8173 - kl_loss: 0.6529
# [0.9935975074768066, 0.8173036575317383, 0.6529401540756226]
# Learning rate:  0.001
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 12ms/step - loss: 0.8656 - reconstruction_loss: 0.7044 - kl_loss: 0.6151 - val_total_loss: 0.8211 - val_reconstruction_loss: 0.6256 - val_kl_loss: 0.7243 - lr: 0.0010
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8816 - reconstruction_loss: 0.7051 - kl_loss: 0.6261 - val_total_loss: 0.9156 - val_reconstruction_loss: 0.7385 - val_kl_loss: 0.6559 - lr: 0.0010
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8705 - reconstruction_loss: 0.7019 - kl_loss: 0.5998 - val_total_loss: 0.8905 - val_reconstruction_loss: 0.7178 - val_kl_loss: 0.6395 - lr: 0.0010
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8652 - reconstruction_loss: 0.7053 - kl_loss: 0.6248 - val_total_loss: 0.8146 - val_reconstruction_loss: 0.6312 - val_kl_loss: 0.6794 - lr: 0.0010
# Epoch 5/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8633 - reconstruction_loss: 0.7054 - kl_loss: 0.5930 - val_total_loss: 0.9584 - val_reconstruction_loss: 0.7574 - val_kl_loss: 0.7445 - lr: 0.0010
# Epoch 6/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8717 - reconstruction_loss: 0.7016 - kl_loss: 0.6213 - val_total_loss: 0.8309 - val_reconstruction_loss: 0.6355 - val_kl_loss: 0.7236 - lr: 0.0010
# Epoch 7/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8725 - reconstruction_loss: 0.7018 - kl_loss: 0.6088 - val_total_loss: 0.9276 - val_reconstruction_loss: 0.7523 - val_kl_loss: 0.6493 - lr: 0.0010
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8712 - reconstruction_loss: 0.6996 - kl_loss: 0.6432 - val_total_loss: 0.8311 - val_reconstruction_loss: 0.6230 - val_kl_loss: 0.7708 - lr: 0.0010
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8703 - reconstruction_loss: 0.6994 - kl_loss: 0.6406 - val_total_loss: 0.7755 - val_reconstruction_loss: 0.5939 - val_kl_loss: 0.6726 - lr: 0.0010
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8596 - reconstruction_loss: 0.7001 - kl_loss: 0.6376 - val_total_loss: 0.9650 - val_reconstruction_loss: 0.7633 - val_kl_loss: 0.7471 - lr: 0.0010
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8548 - reconstruction_loss: 0.7002 - kl_loss: 0.6292 - val_total_loss: 0.8335 - val_reconstruction_loss: 0.6376 - val_kl_loss: 0.7256 - lr: 0.0010
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8727 - reconstruction_loss: 0.6960 - kl_loss: 0.6328 - val_total_loss: 0.8813 - val_reconstruction_loss: 0.6933 - val_kl_loss: 0.6961 - lr: 0.0010
# Epoch 13/30
# 103/105 [============================>.] - ETA: 0s - loss: 0.8726 - reconstruction_loss: 0.6963 - kl_loss: 0.6386
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8724 - reconstruction_loss: 0.6955 - kl_loss: 0.6365 - val_total_loss: 0.9307 - val_reconstruction_loss: 0.7324 - val_kl_loss: 0.7346 - lr: 0.0010
# Epoch 14/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8733 - reconstruction_loss: 0.6907 - kl_loss: 0.6399 - val_total_loss: 0.8292 - val_reconstruction_loss: 0.6190 - val_kl_loss: 0.7785 - lr: 5.0000e-04
# Epoch 15/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8594 - reconstruction_loss: 0.6882 - kl_loss: 0.6432 - val_total_loss: 0.8149 - val_reconstruction_loss: 0.6243 - val_kl_loss: 0.7062 - lr: 5.0000e-04
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8569 - reconstruction_loss: 0.6908 - kl_loss: 0.6444 - val_total_loss: 0.9009 - val_reconstruction_loss: 0.6862 - val_kl_loss: 0.7952 - lr: 5.0000e-04
# Epoch 17/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8784 - reconstruction_loss: 0.6864 - kl_loss: 0.6468 - val_total_loss: 0.8361 - val_reconstruction_loss: 0.6407 - val_kl_loss: 0.7237 - lr: 5.0000e-04
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8634 - reconstruction_loss: 0.6891 - kl_loss: 0.6523 - val_total_loss: 0.9299 - val_reconstruction_loss: 0.7137 - val_kl_loss: 0.8008 - lr: 5.0000e-04
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8671 - reconstruction_loss: 0.6893 - kl_loss: 0.6545 - val_total_loss: 0.8070 - val_reconstruction_loss: 0.6078 - val_kl_loss: 0.7377 - lr: 5.0000e-04
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8708 - reconstruction_loss: 0.6881 - kl_loss: 0.6588 - val_total_loss: 0.9942 - val_reconstruction_loss: 0.7910 - val_kl_loss: 0.7528 - lr: 5.0000e-04
# Epoch 21/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8622 - reconstruction_loss: 0.6862 - kl_loss: 0.6455 - val_total_loss: 0.8179 - val_reconstruction_loss: 0.6181 - val_kl_loss: 0.7401 - lr: 5.0000e-04
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8703 - reconstruction_loss: 0.6856 - kl_loss: 0.6488 - val_total_loss: 0.9043 - val_reconstruction_loss: 0.7042 - val_kl_loss: 0.7413 - lr: 5.0000e-04
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8611 - reconstruction_loss: 0.6888 - kl_loss: 0.6500 - val_total_loss: 0.7925 - val_reconstruction_loss: 0.5881 - val_kl_loss: 0.7569 - lr: 5.0000e-04
# Epoch 24/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8614 - reconstruction_loss: 0.6857 - kl_loss: 0.6676 - val_total_loss: 0.8495 - val_reconstruction_loss: 0.6336 - val_kl_loss: 0.7995 - lr: 5.0000e-04
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8634 - reconstruction_loss: 0.6889 - kl_loss: 0.6511 - val_total_loss: 0.7820 - val_reconstruction_loss: 0.5706 - val_kl_loss: 0.7828 - lr: 5.0000e-04
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8579 - reconstruction_loss: 0.6839 - kl_loss: 0.6725 - val_total_loss: 0.8351 - val_reconstruction_loss: 0.6105 - val_kl_loss: 0.8319 - lr: 5.0000e-04
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8538 - reconstruction_loss: 0.6859 - kl_loss: 0.6578 - val_total_loss: 0.7707 - val_reconstruction_loss: 0.5578 - val_kl_loss: 0.7885 - lr: 5.0000e-04
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8594 - reconstruction_loss: 0.6830 - kl_loss: 0.6625 - val_total_loss: 0.7953 - val_reconstruction_loss: 0.5747 - val_kl_loss: 0.8173 - lr: 5.0000e-04
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8554 - reconstruction_loss: 0.6799 - kl_loss: 0.6523 - val_total_loss: 0.9328 - val_reconstruction_loss: 0.7277 - val_kl_loss: 0.7595 - lr: 5.0000e-04
# Epoch 30/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8592 - reconstruction_loss: 0.6854 - kl_loss: 0.6680 - val_total_loss: 0.7880 - val_reconstruction_loss: 0.5867 - val_kl_loss: 0.7455 - lr: 5.0000e-04
# 262/262 [==============================] - 1s 2ms/step - total_loss: 1.0261 - reconstruction_loss: 0.8414 - kl_loss: 0.6841
# [1.026078462600708, 0.8413763642311096, 0.6840819716453552]
# Learning rate:  0.001
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 19ms/step - loss: 0.8796 - reconstruction_loss: 0.6890 - kl_loss: 0.6611 - val_total_loss: 0.9203 - val_reconstruction_loss: 0.7012 - val_kl_loss: 0.8116 - lr: 0.0010
# Epoch 2/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8619 - reconstruction_loss: 0.6846 - kl_loss: 0.6709 - val_total_loss: 0.9036 - val_reconstruction_loss: 0.6952 - val_kl_loss: 0.7719 - lr: 0.0010
# Epoch 3/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8565 - reconstruction_loss: 0.6886 - kl_loss: 0.6690 - val_total_loss: 0.8689 - val_reconstruction_loss: 0.6622 - val_kl_loss: 0.7654 - lr: 0.0010
# Epoch 4/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8673 - reconstruction_loss: 0.6865 - kl_loss: 0.6615 - val_total_loss: 0.9803 - val_reconstruction_loss: 0.7952 - val_kl_loss: 0.6857 - lr: 0.0010
# Epoch 5/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8677 - reconstruction_loss: 0.6860 - kl_loss: 0.6553 - val_total_loss: 0.8473 - val_reconstruction_loss: 0.6430 - val_kl_loss: 0.7563 - lr: 0.0010
# Epoch 6/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8556 - reconstruction_loss: 0.6806 - kl_loss: 0.6493 - val_total_loss: 1.0191 - val_reconstruction_loss: 0.8129 - val_kl_loss: 0.7637 - lr: 0.0010
# Epoch 7/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8651 - reconstruction_loss: 0.6799 - kl_loss: 0.6736 - val_total_loss: 0.8822 - val_reconstruction_loss: 0.6717 - val_kl_loss: 0.7798 - lr: 0.0010
# Epoch 8/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8635 - reconstruction_loss: 0.6827 - kl_loss: 0.6768 - val_total_loss: 0.8613 - val_reconstruction_loss: 0.6455 - val_kl_loss: 0.7990 - lr: 0.0010
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8641 - reconstruction_loss: 0.6807 - kl_loss: 0.6579 - val_total_loss: 0.9535 - val_reconstruction_loss: 0.7335 - val_kl_loss: 0.8150 - lr: 0.0010
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8514 - reconstruction_loss: 0.6780 - kl_loss: 0.6631 - val_total_loss: 0.8668 - val_reconstruction_loss: 0.6619 - val_kl_loss: 0.7587 - lr: 0.0010
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8526 - reconstruction_loss: 0.6772 - kl_loss: 0.6619 - val_total_loss: 0.9331 - val_reconstruction_loss: 0.7301 - val_kl_loss: 0.7518 - lr: 0.0010
# Epoch 12/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8698 - reconstruction_loss: 0.6821 - kl_loss: 0.6644 - val_total_loss: 0.8401 - val_reconstruction_loss: 0.6136 - val_kl_loss: 0.8389 - lr: 0.0010
# Epoch 13/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8530 - reconstruction_loss: 0.6778 - kl_loss: 0.6713 - val_total_loss: 0.8745 - val_reconstruction_loss: 0.6556 - val_kl_loss: 0.8110 - lr: 0.0010
# Epoch 14/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8719 - reconstruction_loss: 0.6766 - kl_loss: 0.6869 - val_total_loss: 0.8832 - val_reconstruction_loss: 0.6701 - val_kl_loss: 0.7893 - lr: 0.0010
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8593 - reconstruction_loss: 0.6803 - kl_loss: 0.6640 - val_total_loss: 0.7478 - val_reconstruction_loss: 0.5462 - val_kl_loss: 0.7468 - lr: 0.0010
# Epoch 16/30
# 49/53 [==========================>...] - ETA: 0s - loss: 0.8616 - reconstruction_loss: 0.6831 - kl_loss: 0.6884
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8620 - reconstruction_loss: 0.6797 - kl_loss: 0.6817 - val_total_loss: 0.8227 - val_reconstruction_loss: 0.6098 - val_kl_loss: 0.7883 - lr: 0.0010
# Epoch 17/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8404 - reconstruction_loss: 0.6720 - kl_loss: 0.6776 - val_total_loss: 0.8807 - val_reconstruction_loss: 0.6666 - val_kl_loss: 0.7928 - lr: 5.0000e-04
# Epoch 18/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8500 - reconstruction_loss: 0.6797 - kl_loss: 0.6787 - val_total_loss: 0.8957 - val_reconstruction_loss: 0.6832 - val_kl_loss: 0.7868 - lr: 5.0000e-04
# Epoch 19/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8468 - reconstruction_loss: 0.6762 - kl_loss: 0.6916 - val_total_loss: 0.8262 - val_reconstruction_loss: 0.6047 - val_kl_loss: 0.8205 - lr: 5.0000e-04
# Epoch 20/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8450 - reconstruction_loss: 0.6747 - kl_loss: 0.6838 - val_total_loss: 0.9910 - val_reconstruction_loss: 0.7724 - val_kl_loss: 0.8093 - lr: 5.0000e-04
# Epoch 21/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8599 - reconstruction_loss: 0.6761 - kl_loss: 0.6668 - val_total_loss: 0.8079 - val_reconstruction_loss: 0.5960 - val_kl_loss: 0.7848 - lr: 5.0000e-04
# Epoch 22/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8596 - reconstruction_loss: 0.6734 - kl_loss: 0.6784 - val_total_loss: 0.9201 - val_reconstruction_loss: 0.6996 - val_kl_loss: 0.8166 - lr: 5.0000e-04
# Epoch 23/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8664 - reconstruction_loss: 0.6752 - kl_loss: 0.6929 - val_total_loss: 0.7397 - val_reconstruction_loss: 0.5266 - val_kl_loss: 0.7891 - lr: 5.0000e-04
# Epoch 24/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8603 - reconstruction_loss: 0.6781 - kl_loss: 0.6796 - val_total_loss: 0.8974 - val_reconstruction_loss: 0.6708 - val_kl_loss: 0.8392 - lr: 5.0000e-04
# Epoch 25/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8597 - reconstruction_loss: 0.6733 - kl_loss: 0.6886 - val_total_loss: 0.8255 - val_reconstruction_loss: 0.6019 - val_kl_loss: 0.8282 - lr: 5.0000e-04
# Epoch 26/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8479 - reconstruction_loss: 0.6751 - kl_loss: 0.6797 - val_total_loss: 0.8074 - val_reconstruction_loss: 0.5961 - val_kl_loss: 0.7826 - lr: 5.0000e-04
# Epoch 27/30
# 49/53 [==========================>...] - ETA: 0s - loss: 0.8621 - reconstruction_loss: 0.6791 - kl_loss: 0.6727
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8618 - reconstruction_loss: 0.6769 - kl_loss: 0.6741 - val_total_loss: 0.8103 - val_reconstruction_loss: 0.5739 - val_kl_loss: 0.8755 - lr: 5.0000e-04
# Epoch 28/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8694 - reconstruction_loss: 0.6738 - kl_loss: 0.6835 - val_total_loss: 0.7435 - val_reconstruction_loss: 0.5224 - val_kl_loss: 0.8190 - lr: 2.5000e-04
# Epoch 29/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8715 - reconstruction_loss: 0.6696 - kl_loss: 0.6905 - val_total_loss: 0.7986 - val_reconstruction_loss: 0.5723 - val_kl_loss: 0.8382 - lr: 2.5000e-04
# Epoch 30/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8623 - reconstruction_loss: 0.6754 - kl_loss: 0.6930 - val_total_loss: 0.9485 - val_reconstruction_loss: 0.7252 - val_kl_loss: 0.8273 - lr: 2.5000e-04
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.8402 - reconstruction_loss: 0.6393 - kl_loss: 0.7443
# [0.8402323722839355, 0.6392632722854614, 0.7443300485610962]
# Learning rate:  0.001
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 44ms/step - loss: 0.8579 - reconstruction_loss: 0.6757 - kl_loss: 0.6803 - val_total_loss: 0.8514 - val_reconstruction_loss: 0.6317 - val_kl_loss: 0.8136 - lr: 0.0010
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8498 - reconstruction_loss: 0.6785 - kl_loss: 0.6966 - val_total_loss: 0.8729 - val_reconstruction_loss: 0.6653 - val_kl_loss: 0.7688 - lr: 0.0010
# Epoch 3/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8620 - reconstruction_loss: 0.6735 - kl_loss: 0.6930 - val_total_loss: 0.8756 - val_reconstruction_loss: 0.6563 - val_kl_loss: 0.8123 - lr: 0.0010
# Epoch 4/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8604 - reconstruction_loss: 0.6868 - kl_loss: 0.6935 - val_total_loss: 0.8877 - val_reconstruction_loss: 0.6694 - val_kl_loss: 0.8086 - lr: 0.0010
# Epoch 5/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8640 - reconstruction_loss: 0.6789 - kl_loss: 0.6991 - val_total_loss: 0.8805 - val_reconstruction_loss: 0.6798 - val_kl_loss: 0.7434 - lr: 0.0010
# Epoch 6/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8566 - reconstruction_loss: 0.6720 - kl_loss: 0.6797 - val_total_loss: 0.8568 - val_reconstruction_loss: 0.6408 - val_kl_loss: 0.8000 - lr: 0.0010
# Epoch 7/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8493 - reconstruction_loss: 0.6729 - kl_loss: 0.6784 - val_total_loss: 0.8514 - val_reconstruction_loss: 0.6391 - val_kl_loss: 0.7861 - lr: 0.0010
# Epoch 8/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8578 - reconstruction_loss: 0.6748 - kl_loss: 0.6727 - val_total_loss: 0.8644 - val_reconstruction_loss: 0.6618 - val_kl_loss: 0.7504 - lr: 0.0010
# Epoch 9/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8536 - reconstruction_loss: 0.6759 - kl_loss: 0.6680 - val_total_loss: 0.8520 - val_reconstruction_loss: 0.6441 - val_kl_loss: 0.7698 - lr: 0.0010
# Epoch 10/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8474 - reconstruction_loss: 0.6731 - kl_loss: 0.6777 - val_total_loss: 0.9200 - val_reconstruction_loss: 0.7176 - val_kl_loss: 0.7497 - lr: 0.0010
# Epoch 11/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8647 - reconstruction_loss: 0.6777 - kl_loss: 0.6958 - val_total_loss: 0.8672 - val_reconstruction_loss: 0.6561 - val_kl_loss: 0.7818 - lr: 0.0010
# Epoch 12/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8715 - reconstruction_loss: 0.6703 - kl_loss: 0.6848 - val_total_loss: 0.8680 - val_reconstruction_loss: 0.6630 - val_kl_loss: 0.7595 - lr: 0.0010
# Epoch 13/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8745 - reconstruction_loss: 0.6802 - kl_loss: 0.6784 - val_total_loss: 0.8797 - val_reconstruction_loss: 0.6674 - val_kl_loss: 0.7865 - lr: 0.0010
# Epoch 14/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8677 - reconstruction_loss: 0.6712 - kl_loss: 0.6743 - val_total_loss: 0.8451 - val_reconstruction_loss: 0.6491 - val_kl_loss: 0.7261 - lr: 0.0010
# Epoch 15/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8547 - reconstruction_loss: 0.6784 - kl_loss: 0.6795 - val_total_loss: 0.8527 - val_reconstruction_loss: 0.6331 - val_kl_loss: 0.8134 - lr: 0.0010
# Epoch 16/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8565 - reconstruction_loss: 0.6662 - kl_loss: 0.7003 - val_total_loss: 0.8736 - val_reconstruction_loss: 0.6668 - val_kl_loss: 0.7661 - lr: 0.0010
# Epoch 17/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8436 - reconstruction_loss: 0.6697 - kl_loss: 0.6825 - val_total_loss: 0.8777 - val_reconstruction_loss: 0.6659 - val_kl_loss: 0.7844 - lr: 0.0010
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8522 - reconstruction_loss: 0.6704 - kl_loss: 0.6819 - val_total_loss: 0.8468 - val_reconstruction_loss: 0.6389 - val_kl_loss: 0.7700 - lr: 0.0010
# Epoch 19/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8580 - reconstruction_loss: 0.6678 - kl_loss: 0.6951 - val_total_loss: 0.8797 - val_reconstruction_loss: 0.6657 - val_kl_loss: 0.7928 - lr: 0.0010
# Epoch 20/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8599 - reconstruction_loss: 0.6661 - kl_loss: 0.6748 - val_total_loss: 0.8569 - val_reconstruction_loss: 0.6560 - val_kl_loss: 0.7438 - lr: 0.0010
# Epoch 21/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8506 - reconstruction_loss: 0.6795 - kl_loss: 0.6655 - val_total_loss: 0.8414 - val_reconstruction_loss: 0.6255 - val_kl_loss: 0.7998 - lr: 0.0010
# Epoch 22/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8614 - reconstruction_loss: 0.6640 - kl_loss: 0.7009 - val_total_loss: 0.8541 - val_reconstruction_loss: 0.6574 - val_kl_loss: 0.7287 - lr: 0.0010
# Epoch 23/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8562 - reconstruction_loss: 0.6780 - kl_loss: 0.6676 - val_total_loss: 0.9084 - val_reconstruction_loss: 0.7109 - val_kl_loss: 0.7313 - lr: 0.0010
# Epoch 24/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8549 - reconstruction_loss: 0.6744 - kl_loss: 0.6978 - val_total_loss: 0.8637 - val_reconstruction_loss: 0.6598 - val_kl_loss: 0.7554 - lr: 0.0010
# Epoch 25/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8527 - reconstruction_loss: 0.6693 - kl_loss: 0.6689 - val_total_loss: 0.8540 - val_reconstruction_loss: 0.6467 - val_kl_loss: 0.7679 - lr: 0.0010
# Epoch 26/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8485 - reconstruction_loss: 0.6699 - kl_loss: 0.6944 - val_total_loss: 0.8289 - val_reconstruction_loss: 0.6238 - val_kl_loss: 0.7595 - lr: 0.0010
# Epoch 27/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8589 - reconstruction_loss: 0.6734 - kl_loss: 0.7076 - val_total_loss: 0.8380 - val_reconstruction_loss: 0.6148 - val_kl_loss: 0.8268 - lr: 0.0010
# Epoch 28/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8638 - reconstruction_loss: 0.6698 - kl_loss: 0.7122 - val_total_loss: 0.8809 - val_reconstruction_loss: 0.6756 - val_kl_loss: 0.7604 - lr: 0.0010
# Epoch 29/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8528 - reconstruction_loss: 0.6674 - kl_loss: 0.6825 - val_total_loss: 0.8751 - val_reconstruction_loss: 0.6631 - val_kl_loss: 0.7853 - lr: 0.0010
# Epoch 30/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8618 - reconstruction_loss: 0.6685 - kl_loss: 0.6995
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8613 - reconstruction_loss: 0.6697 - kl_loss: 0.6914 - val_total_loss: 0.8543 - val_reconstruction_loss: 0.6395 - val_kl_loss: 0.7957 - lr: 0.0010
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9478 - reconstruction_loss: 0.7403 - kl_loss: 0.7684
# [0.9477633237838745, 0.7402852773666382, 0.7684370875358582]
# Learning rate:  0.005
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 4s 8ms/step - loss: 0.9515 - reconstruction_loss: 0.7435 - kl_loss: 0.6021 - val_total_loss: 0.8805 - val_reconstruction_loss: 0.6825 - val_kl_loss: 0.7336 - lr: 0.0050
# Epoch 2/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8856 - reconstruction_loss: 0.7140 - kl_loss: 0.6292 - val_total_loss: 0.7861 - val_reconstruction_loss: 0.5991 - val_kl_loss: 0.6926 - lr: 0.0050
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8811 - reconstruction_loss: 0.7190 - kl_loss: 0.6151 - val_total_loss: 0.9749 - val_reconstruction_loss: 0.8107 - val_kl_loss: 0.6083 - lr: 0.0050
# Epoch 4/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9036 - reconstruction_loss: 0.7178 - kl_loss: 0.6216 - val_total_loss: 0.8010 - val_reconstruction_loss: 0.6087 - val_kl_loss: 0.7122 - lr: 0.0050
# Epoch 5/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8852 - reconstruction_loss: 0.7159 - kl_loss: 0.6073 - val_total_loss: 0.9465 - val_reconstruction_loss: 0.7261 - val_kl_loss: 0.8161 - lr: 0.0050
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8783 - reconstruction_loss: 0.7108 - kl_loss: 0.6328 - val_total_loss: 0.7291 - val_reconstruction_loss: 0.5197 - val_kl_loss: 0.7757 - lr: 0.0050
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8923 - reconstruction_loss: 0.7099 - kl_loss: 0.6277 - val_total_loss: 0.9585 - val_reconstruction_loss: 0.7640 - val_kl_loss: 0.7205 - lr: 0.0050
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9002 - reconstruction_loss: 0.7046 - kl_loss: 0.6361 - val_total_loss: 0.9357 - val_reconstruction_loss: 0.7769 - val_kl_loss: 0.5880 - lr: 0.0050
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8740 - reconstruction_loss: 0.7119 - kl_loss: 0.6252 - val_total_loss: 0.8017 - val_reconstruction_loss: 0.6039 - val_kl_loss: 0.7327 - lr: 0.0050
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8737 - reconstruction_loss: 0.7143 - kl_loss: 0.6281 - val_total_loss: 0.7666 - val_reconstruction_loss: 0.5485 - val_kl_loss: 0.8075 - lr: 0.0050
# Epoch 11/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8760 - reconstruction_loss: 0.7056 - kl_loss: 0.6258 - val_total_loss: 0.7877 - val_reconstruction_loss: 0.5793 - val_kl_loss: 0.7719 - lr: 0.0050
# Epoch 12/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8721 - reconstruction_loss: 0.7090 - kl_loss: 0.6493 - val_total_loss: 0.9331 - val_reconstruction_loss: 0.7585 - val_kl_loss: 0.6465 - lr: 0.0050
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8868 - reconstruction_loss: 0.7075 - kl_loss: 0.6507 - val_total_loss: 1.0157 - val_reconstruction_loss: 0.8267 - val_kl_loss: 0.7001 - lr: 0.0050
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8791 - reconstruction_loss: 0.7050 - kl_loss: 0.6434 - val_total_loss: 0.8912 - val_reconstruction_loss: 0.6967 - val_kl_loss: 0.7204 - lr: 0.0050
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8773 - reconstruction_loss: 0.7012 - kl_loss: 0.6579 - val_total_loss: 0.7725 - val_reconstruction_loss: 0.5924 - val_kl_loss: 0.6670 - lr: 0.0050
# Epoch 16/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8802 - reconstruction_loss: 0.7082 - kl_loss: 0.6390 - val_total_loss: 0.8324 - val_reconstruction_loss: 0.6248 - val_kl_loss: 0.7689 - lr: 0.0050
# Epoch 17/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8612 - reconstruction_loss: 0.7018 - kl_loss: 0.6311 - val_total_loss: 0.9120 - val_reconstruction_loss: 0.7354 - val_kl_loss: 0.6540 - lr: 0.0050
# Epoch 18/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8796 - reconstruction_loss: 0.6977 - kl_loss: 0.6577 - val_total_loss: 0.9923 - val_reconstruction_loss: 0.8047 - val_kl_loss: 0.6948 - lr: 0.0050
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8602 - reconstruction_loss: 0.7000 - kl_loss: 0.6502 - val_total_loss: 1.0594 - val_reconstruction_loss: 0.8534 - val_kl_loss: 0.7630 - lr: 0.0050
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8633 - reconstruction_loss: 0.6959 - kl_loss: 0.6425 - val_total_loss: 0.7512 - val_reconstruction_loss: 0.5339 - val_kl_loss: 0.8046 - lr: 0.0050
# Epoch 21/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8570 - reconstruction_loss: 0.7003 - kl_loss: 0.6388 - val_total_loss: 0.9286 - val_reconstruction_loss: 0.7111 - val_kl_loss: 0.8057 - lr: 0.0050
# Epoch 22/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8704 - reconstruction_loss: 0.6948 - kl_loss: 0.6580 - val_total_loss: 0.8785 - val_reconstruction_loss: 0.6700 - val_kl_loss: 0.7723 - lr: 0.0050
# Epoch 23/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8756 - reconstruction_loss: 0.6937 - kl_loss: 0.6655 - val_total_loss: 0.8793 - val_reconstruction_loss: 0.6713 - val_kl_loss: 0.7705 - lr: 0.0050
# Epoch 24/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8867 - reconstruction_loss: 0.6928 - kl_loss: 0.6668 - val_total_loss: 0.7799 - val_reconstruction_loss: 0.5650 - val_kl_loss: 0.7962 - lr: 0.0050
# Epoch 25/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8775 - reconstruction_loss: 0.6941 - kl_loss: 0.6581 - val_total_loss: 0.9006 - val_reconstruction_loss: 0.6943 - val_kl_loss: 0.7638 - lr: 0.0050
# Epoch 26/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8719 - reconstruction_loss: 0.7021 - kl_loss: 0.6481 - val_total_loss: 0.7950 - val_reconstruction_loss: 0.5603 - val_kl_loss: 0.8690 - lr: 0.0050
# Epoch 27/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8759 - reconstruction_loss: 0.6958 - kl_loss: 0.6592 - val_total_loss: 0.9812 - val_reconstruction_loss: 0.7538 - val_kl_loss: 0.8421 - lr: 0.0050
# Epoch 28/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8867 - reconstruction_loss: 0.7001 - kl_loss: 0.6559 - val_total_loss: 0.7767 - val_reconstruction_loss: 0.5590 - val_kl_loss: 0.8062 - lr: 0.0050
# Epoch 29/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8654 - reconstruction_loss: 0.6922 - kl_loss: 0.6591 - val_total_loss: 0.8316 - val_reconstruction_loss: 0.6100 - val_kl_loss: 0.8208 - lr: 0.0050
# Epoch 30/30
# 210/210 [==============================] - ETA: 0s - loss: 0.8724 - reconstruction_loss: 0.6987 - kl_loss: 0.6590
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8725 - reconstruction_loss: 0.6987 - kl_loss: 0.6590 - val_total_loss: 0.8726 - val_reconstruction_loss: 0.6506 - val_kl_loss: 0.8220 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 1.0242 - reconstruction_loss: 0.8228 - kl_loss: 0.7459
# [1.0241700410842896, 0.8227667212486267, 0.7459380626678467]
# Learning rate:  0.005
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8651 - reconstruction_loss: 0.6917 - kl_loss: 0.6545 - val_total_loss: 0.9139 - val_reconstruction_loss: 0.6657 - val_kl_loss: 0.9192 - lr: 0.0050
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8757 - reconstruction_loss: 0.6838 - kl_loss: 0.6787 - val_total_loss: 0.8796 - val_reconstruction_loss: 0.6237 - val_kl_loss: 0.9479 - lr: 0.0050
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8594 - reconstruction_loss: 0.6751 - kl_loss: 0.6761 - val_total_loss: 0.9268 - val_reconstruction_loss: 0.7414 - val_kl_loss: 0.6865 - lr: 0.0050
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8662 - reconstruction_loss: 0.6850 - kl_loss: 0.6707 - val_total_loss: 0.7918 - val_reconstruction_loss: 0.6189 - val_kl_loss: 0.6404 - lr: 0.0050
# Epoch 5/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8398 - reconstruction_loss: 0.6803 - kl_loss: 0.6588 - val_total_loss: 0.8356 - val_reconstruction_loss: 0.6103 - val_kl_loss: 0.8347 - lr: 0.0050
# Epoch 6/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8458 - reconstruction_loss: 0.6848 - kl_loss: 0.6525 - val_total_loss: 0.8543 - val_reconstruction_loss: 0.6484 - val_kl_loss: 0.7626 - lr: 0.0050
# Epoch 7/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8702 - reconstruction_loss: 0.6836 - kl_loss: 0.6723 - val_total_loss: 0.9034 - val_reconstruction_loss: 0.7063 - val_kl_loss: 0.7299 - lr: 0.0050
# Epoch 8/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8734 - reconstruction_loss: 0.6839 - kl_loss: 0.6794 - val_total_loss: 0.8703 - val_reconstruction_loss: 0.6760 - val_kl_loss: 0.7197 - lr: 0.0050
# Epoch 9/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8676 - reconstruction_loss: 0.6826 - kl_loss: 0.6731 - val_total_loss: 0.9645 - val_reconstruction_loss: 0.7470 - val_kl_loss: 0.8056 - lr: 0.0050
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8497 - reconstruction_loss: 0.6799 - kl_loss: 0.6594 - val_total_loss: 0.8233 - val_reconstruction_loss: 0.6133 - val_kl_loss: 0.7780 - lr: 0.0050
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8633 - reconstruction_loss: 0.6768 - kl_loss: 0.6937 - val_total_loss: 0.8273 - val_reconstruction_loss: 0.6358 - val_kl_loss: 0.7092 - lr: 0.0050
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8688 - reconstruction_loss: 0.6776 - kl_loss: 0.6837 - val_total_loss: 0.9042 - val_reconstruction_loss: 0.6790 - val_kl_loss: 0.8343 - lr: 0.0050
# Epoch 13/30
# 102/105 [============================>.] - ETA: 0s - loss: 0.8822 - reconstruction_loss: 0.6748 - kl_loss: 0.7002
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8815 - reconstruction_loss: 0.6745 - kl_loss: 0.7007 - val_total_loss: 0.8167 - val_reconstruction_loss: 0.6110 - val_kl_loss: 0.7619 - lr: 0.0050
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8526 - reconstruction_loss: 0.6715 - kl_loss: 0.6875 - val_total_loss: 0.7916 - val_reconstruction_loss: 0.5659 - val_kl_loss: 0.8360 - lr: 0.0025
# Epoch 15/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8482 - reconstruction_loss: 0.6648 - kl_loss: 0.6998 - val_total_loss: 0.9081 - val_reconstruction_loss: 0.6742 - val_kl_loss: 0.8662 - lr: 0.0025
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8427 - reconstruction_loss: 0.6617 - kl_loss: 0.6982 - val_total_loss: 0.8976 - val_reconstruction_loss: 0.6661 - val_kl_loss: 0.8574 - lr: 0.0025
# Epoch 17/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8465 - reconstruction_loss: 0.6615 - kl_loss: 0.7051 - val_total_loss: 1.0968 - val_reconstruction_loss: 0.8786 - val_kl_loss: 0.8082 - lr: 0.0025
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8725 - reconstruction_loss: 0.6626 - kl_loss: 0.7234 - val_total_loss: 0.6729 - val_reconstruction_loss: 0.4505 - val_kl_loss: 0.8237 - lr: 0.0025
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8553 - reconstruction_loss: 0.6626 - kl_loss: 0.7232 - val_total_loss: 0.8762 - val_reconstruction_loss: 0.6427 - val_kl_loss: 0.8648 - lr: 0.0025
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8531 - reconstruction_loss: 0.6639 - kl_loss: 0.7191 - val_total_loss: 0.9262 - val_reconstruction_loss: 0.6936 - val_kl_loss: 0.8613 - lr: 0.0025
# Epoch 21/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8647 - reconstruction_loss: 0.6631 - kl_loss: 0.7108 - val_total_loss: 0.9419 - val_reconstruction_loss: 0.7285 - val_kl_loss: 0.7902 - lr: 0.0025
# Epoch 22/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8470 - reconstruction_loss: 0.6616 - kl_loss: 0.7106 - val_total_loss: 0.7919 - val_reconstruction_loss: 0.5858 - val_kl_loss: 0.7633 - lr: 0.0025
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8604 - reconstruction_loss: 0.6666 - kl_loss: 0.6982 - val_total_loss: 0.8141 - val_reconstruction_loss: 0.5926 - val_kl_loss: 0.8202 - lr: 0.0025
# Epoch 24/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8355 - reconstruction_loss: 0.6582 - kl_loss: 0.7050 - val_total_loss: 0.9275 - val_reconstruction_loss: 0.6942 - val_kl_loss: 0.8642 - lr: 0.0025
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8470 - reconstruction_loss: 0.6599 - kl_loss: 0.7183 - val_total_loss: 0.9852 - val_reconstruction_loss: 0.7854 - val_kl_loss: 0.7400 - lr: 0.0025
# Epoch 26/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8601 - reconstruction_loss: 0.6679 - kl_loss: 0.6894 - val_total_loss: 0.9079 - val_reconstruction_loss: 0.6679 - val_kl_loss: 0.8889 - lr: 0.0025
# Epoch 27/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8578 - reconstruction_loss: 0.6628 - kl_loss: 0.7270 - val_total_loss: 0.9103 - val_reconstruction_loss: 0.6882 - val_kl_loss: 0.8224 - lr: 0.0025
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8615 - reconstruction_loss: 0.6541 - kl_loss: 0.7380 - val_total_loss: 0.8477 - val_reconstruction_loss: 0.6067 - val_kl_loss: 0.8926 - lr: 0.0025
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8579 - reconstruction_loss: 0.6662 - kl_loss: 0.6954 - val_total_loss: 0.8264 - val_reconstruction_loss: 0.6102 - val_kl_loss: 0.8008 - lr: 0.0025
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8544 - reconstruction_loss: 0.6583 - kl_loss: 0.7232 - val_total_loss: 0.9452 - val_reconstruction_loss: 0.7153 - val_kl_loss: 0.8517 - lr: 0.0025
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9268 - reconstruction_loss: 0.7193 - kl_loss: 0.7683
# [0.9267753958702087, 0.7193210124969482, 0.7683494687080383]
# Learning rate:  0.005
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 20ms/step - loss: 0.8887 - reconstruction_loss: 0.6838 - kl_loss: 0.6905 - val_total_loss: 0.7748 - val_reconstruction_loss: 0.5055 - val_kl_loss: 0.9972 - lr: 0.0050
# Epoch 2/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8660 - reconstruction_loss: 0.6693 - kl_loss: 0.7214 - val_total_loss: 0.9620 - val_reconstruction_loss: 0.7319 - val_kl_loss: 0.8525 - lr: 0.0050
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8508 - reconstruction_loss: 0.6611 - kl_loss: 0.7084 - val_total_loss: 0.9979 - val_reconstruction_loss: 0.8055 - val_kl_loss: 0.7126 - lr: 0.0050
# Epoch 4/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8569 - reconstruction_loss: 0.6676 - kl_loss: 0.7028 - val_total_loss: 0.7699 - val_reconstruction_loss: 0.5464 - val_kl_loss: 0.8279 - lr: 0.0050
# Epoch 5/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8577 - reconstruction_loss: 0.6673 - kl_loss: 0.7081 - val_total_loss: 0.8515 - val_reconstruction_loss: 0.6307 - val_kl_loss: 0.8180 - lr: 0.0050
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8476 - reconstruction_loss: 0.6717 - kl_loss: 0.6970 - val_total_loss: 0.9345 - val_reconstruction_loss: 0.7116 - val_kl_loss: 0.8255 - lr: 0.0050
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8600 - reconstruction_loss: 0.6655 - kl_loss: 0.6879 - val_total_loss: 0.8863 - val_reconstruction_loss: 0.6865 - val_kl_loss: 0.7400 - lr: 0.0050
# Epoch 8/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8534 - reconstruction_loss: 0.6659 - kl_loss: 0.6997 - val_total_loss: 0.9788 - val_reconstruction_loss: 0.7643 - val_kl_loss: 0.7942 - lr: 0.0050
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8648 - reconstruction_loss: 0.6674 - kl_loss: 0.7087 - val_total_loss: 0.8297 - val_reconstruction_loss: 0.5986 - val_kl_loss: 0.8558 - lr: 0.0050
# Epoch 10/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8547 - reconstruction_loss: 0.6678 - kl_loss: 0.6994 - val_total_loss: 0.8901 - val_reconstruction_loss: 0.6701 - val_kl_loss: 0.8150 - lr: 0.0050
# Epoch 11/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8528 - reconstruction_loss: 0.6622 - kl_loss: 0.7308 - val_total_loss: 0.8241 - val_reconstruction_loss: 0.6005 - val_kl_loss: 0.8281 - lr: 0.0050
# Epoch 12/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8559 - reconstruction_loss: 0.6617 - kl_loss: 0.7226 - val_total_loss: 0.9339 - val_reconstruction_loss: 0.6992 - val_kl_loss: 0.8693 - lr: 0.0050
# Epoch 13/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8567 - reconstruction_loss: 0.6643 - kl_loss: 0.7085 - val_total_loss: 0.7995 - val_reconstruction_loss: 0.6011 - val_kl_loss: 0.7345 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8634 - reconstruction_loss: 0.6649 - kl_loss: 0.7295 - val_total_loss: 0.9236 - val_reconstruction_loss: 0.7032 - val_kl_loss: 0.8163 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8633 - reconstruction_loss: 0.6610 - kl_loss: 0.7079 - val_total_loss: 0.8976 - val_reconstruction_loss: 0.7140 - val_kl_loss: 0.6799 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8590 - reconstruction_loss: 0.6700 - kl_loss: 0.6970 - val_total_loss: 0.9586 - val_reconstruction_loss: 0.7554 - val_kl_loss: 0.7527 - lr: 0.0050
# Epoch 17/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8504 - reconstruction_loss: 0.6635 - kl_loss: 0.7070
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8505 - reconstruction_loss: 0.6642 - kl_loss: 0.7034 - val_total_loss: 0.8302 - val_reconstruction_loss: 0.6105 - val_kl_loss: 0.8138 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8486 - reconstruction_loss: 0.6620 - kl_loss: 0.6958 - val_total_loss: 0.8645 - val_reconstruction_loss: 0.6313 - val_kl_loss: 0.8638 - lr: 0.0025
# Epoch 19/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8469 - reconstruction_loss: 0.6522 - kl_loss: 0.7220 - val_total_loss: 0.7776 - val_reconstruction_loss: 0.5576 - val_kl_loss: 0.8147 - lr: 0.0025
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8507 - reconstruction_loss: 0.6571 - kl_loss: 0.7268 - val_total_loss: 0.9145 - val_reconstruction_loss: 0.6924 - val_kl_loss: 0.8229 - lr: 0.0025
# Epoch 21/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8554 - reconstruction_loss: 0.6603 - kl_loss: 0.7146 - val_total_loss: 1.1120 - val_reconstruction_loss: 0.8876 - val_kl_loss: 0.8310 - lr: 0.0025
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8415 - reconstruction_loss: 0.6614 - kl_loss: 0.7077 - val_total_loss: 0.8705 - val_reconstruction_loss: 0.6436 - val_kl_loss: 0.8403 - lr: 0.0025
# Epoch 23/30
# ...
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8551 - reconstruction_loss: 0.6713 - kl_loss: 0.6842 - val_total_loss: 0.8870 - val_reconstruction_loss: 0.6713 - val_kl_loss: 0.7987 - lr: 0.0050
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8650 - reconstruction_loss: 0.6700 - kl_loss: 0.7098 - val_total_loss: 0.9349 - val_reconstruction_loss: 0.6980 - val_kl_loss: 0.8774 - lr: 0.0050
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8711 - reconstruction_loss: 0.6728 - kl_loss: 0.6947 - val_total_loss: 0.7993 - val_reconstruction_loss: 0.5816 - val_kl_loss: 0.8063 - lr: 0.0050
# Epoch 28/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8436 - reconstruction_loss: 0.6681 - kl_loss: 0.6967 - val_total_loss: 1.0211 - val_reconstruction_loss: 0.7867 - val_kl_loss: 0.8684 - lr: 0.0050
# Epoch 29/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8481 - reconstruction_loss: 0.6651 - kl_loss: 0.7011 - val_total_loss: 0.9972 - val_reconstruction_loss: 0.7960 - val_kl_loss: 0.7453 - lr: 0.0050
# Epoch 30/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8500 - reconstruction_loss: 0.6753 - kl_loss: 0.6701 - val_total_loss: 0.9170 - val_reconstruction_loss: 0.7248 - val_kl_loss: 0.7119 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 1.0148 - reconstruction_loss: 0.8395 - kl_loss: 0.6490
# [1.0147733688354492, 0.8395302891731262, 0.6490486264228821]
# Learning rate:  0.01
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 19ms/step - loss: 0.8814 - reconstruction_loss: 0.6930 - kl_loss: 0.6747 - val_total_loss: 0.7999 - val_reconstruction_loss: 0.5939 - val_kl_loss: 0.7630 - lr: 0.0100
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8647 - reconstruction_loss: 0.6812 - kl_loss: 0.6776 - val_total_loss: 0.9626 - val_reconstruction_loss: 0.6951 - val_kl_loss: 0.9908 - lr: 0.0100
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8589 - reconstruction_loss: 0.6760 - kl_loss: 0.6901 - val_total_loss: 0.7816 - val_reconstruction_loss: 0.5413 - val_kl_loss: 0.8901 - lr: 0.0100
# Epoch 4/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8555 - reconstruction_loss: 0.6694 - kl_loss: 0.6895 - val_total_loss: 0.8196 - val_reconstruction_loss: 0.5939 - val_kl_loss: 0.8360 - lr: 0.0100
# Epoch 5/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8623 - reconstruction_loss: 0.6781 - kl_loss: 0.6609 - val_total_loss: 0.9897 - val_reconstruction_loss: 0.7779 - val_kl_loss: 0.7846 - lr: 0.0100
# Epoch 6/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8721 - reconstruction_loss: 0.6775 - kl_loss: 0.6905 - val_total_loss: 0.9116 - val_reconstruction_loss: 0.6956 - val_kl_loss: 0.7999 - lr: 0.0100
# Epoch 7/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8593 - reconstruction_loss: 0.6756 - kl_loss: 0.6992 - val_total_loss: 0.9477 - val_reconstruction_loss: 0.7346 - val_kl_loss: 0.7892 - lr: 0.0100
# Epoch 8/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8695 - reconstruction_loss: 0.6816 - kl_loss: 0.6850 - val_total_loss: 0.8123 - val_reconstruction_loss: 0.5895 - val_kl_loss: 0.8253 - lr: 0.0100
# Epoch 9/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8702 - reconstruction_loss: 0.6761 - kl_loss: 0.7060 - val_total_loss: 0.8692 - val_reconstruction_loss: 0.6584 - val_kl_loss: 0.7806 - lr: 0.0100
# Epoch 10/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8527 - reconstruction_loss: 0.6832 - kl_loss: 0.6635 - val_total_loss: 0.9579 - val_reconstruction_loss: 0.7312 - val_kl_loss: 0.8393 - lr: 0.0100
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8452 - reconstruction_loss: 0.6686 - kl_loss: 0.6832 - val_total_loss: 1.0308 - val_reconstruction_loss: 0.7961 - val_kl_loss: 0.8693 - lr: 0.0100
# Epoch 12/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8706 - reconstruction_loss: 0.6810 - kl_loss: 0.6784 - val_total_loss: 0.9805 - val_reconstruction_loss: 0.7317 - val_kl_loss: 0.9215 - lr: 0.0100
# Epoch 13/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8667 - reconstruction_loss: 0.6727 - kl_loss: 0.7215 - val_total_loss: 0.8211 - val_reconstruction_loss: 0.5425 - val_kl_loss: 1.0320 - lr: 0.0100
# Epoch 14/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8814 - reconstruction_loss: 0.6693 - kl_loss: 0.7268 - val_total_loss: 0.8331 - val_reconstruction_loss: 0.6383 - val_kl_loss: 0.7214 - lr: 0.0100
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8655 - reconstruction_loss: 0.6795 - kl_loss: 0.6875 - val_total_loss: 0.9197 - val_reconstruction_loss: 0.7107 - val_kl_loss: 0.7739 - lr: 0.0100
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8605 - reconstruction_loss: 0.6713 - kl_loss: 0.7059 - val_total_loss: 0.7845 - val_reconstruction_loss: 0.5598 - val_kl_loss: 0.8322 - lr: 0.0100
# Epoch 17/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8518 - reconstruction_loss: 0.6691 - kl_loss: 0.6929 - val_total_loss: 0.7565 - val_reconstruction_loss: 0.4911 - val_kl_loss: 0.9832 - lr: 0.0100
# Epoch 18/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8613 - reconstruction_loss: 0.6721 - kl_loss: 0.7047 - val_total_loss: 0.8466 - val_reconstruction_loss: 0.6000 - val_kl_loss: 0.9135 - lr: 0.0100
# Epoch 19/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8563 - reconstruction_loss: 0.6723 - kl_loss: 0.6873 - val_total_loss: 0.8425 - val_reconstruction_loss: 0.6224 - val_kl_loss: 0.8152 - lr: 0.0100
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8710 - reconstruction_loss: 0.6788 - kl_loss: 0.6873 - val_total_loss: 0.7673 - val_reconstruction_loss: 0.5465 - val_kl_loss: 0.8178 - lr: 0.0100
# Epoch 21/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8553 - reconstruction_loss: 0.6759 - kl_loss: 0.6837
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8555 - reconstruction_loss: 0.6763 - kl_loss: 0.6826 - val_total_loss: 0.8960 - val_reconstruction_loss: 0.6837 - val_kl_loss: 0.7862 - lr: 0.0100
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8551 - reconstruction_loss: 0.6653 - kl_loss: 0.7097 - val_total_loss: 0.8985 - val_reconstruction_loss: 0.6689 - val_kl_loss: 0.8501 - lr: 0.0050
# Epoch 23/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8586 - reconstruction_loss: 0.6640 - kl_loss: 0.7086 - val_total_loss: 0.7897 - val_reconstruction_loss: 0.5550 - val_kl_loss: 0.8693 - lr: 0.0050
# Epoch 24/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8531 - reconstruction_loss: 0.6676 - kl_loss: 0.6979 - val_total_loss: 0.9494 - val_reconstruction_loss: 0.7119 - val_kl_loss: 0.8798 - lr: 0.0050
# Epoch 25/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8556 - reconstruction_loss: 0.6671 - kl_loss: 0.6798 - val_total_loss: 0.7828 - val_reconstruction_loss: 0.5585 - val_kl_loss: 0.8306 - lr: 0.0050
# Epoch 26/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8591 - reconstruction_loss: 0.6650 - kl_loss: 0.7085 - val_total_loss: 0.8205 - val_reconstruction_loss: 0.6073 - val_kl_loss: 0.7896 - lr: 0.0050
# Epoch 27/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8620 - reconstruction_loss: 0.6666 - kl_loss: 0.6887 - val_total_loss: 0.9045 - val_reconstruction_loss: 0.6870 - val_kl_loss: 0.8056 - lr: 0.0050
# Epoch 28/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8563 - reconstruction_loss: 0.6658 - kl_loss: 0.7013 - val_total_loss: 0.9150 - val_reconstruction_loss: 0.6901 - val_kl_loss: 0.8330 - lr: 0.0050
# Epoch 29/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8609 - reconstruction_loss: 0.6617 - kl_loss: 0.7251 - val_total_loss: 0.8652 - val_reconstruction_loss: 0.6415 - val_kl_loss: 0.8286 - lr: 0.0050
# Epoch 30/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8566 - reconstruction_loss: 0.6587 - kl_loss: 0.7209 - val_total_loss: 0.7656 - val_reconstruction_loss: 0.5342 - val_kl_loss: 0.8571 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9773 - reconstruction_loss: 0.7715 - kl_loss: 0.7619
# [0.9772561192512512, 0.7715383768081665, 0.7619175314903259]
# Learning rate:  0.01
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 35ms/step - loss: 0.9245 - reconstruction_loss: 0.7229 - kl_loss: 0.6665 - val_total_loss: 0.8688 - val_reconstruction_loss: 0.6620 - val_kl_loss: 0.7656 - lr: 0.0100
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8627 - reconstruction_loss: 0.6697 - kl_loss: 0.6958 - val_total_loss: 0.8893 - val_reconstruction_loss: 0.6756 - val_kl_loss: 0.7914 - lr: 0.0100
# Epoch 3/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8689 - reconstruction_loss: 0.6636 - kl_loss: 0.7058 - val_total_loss: 0.8351 - val_reconstruction_loss: 0.6254 - val_kl_loss: 0.7768 - lr: 0.0100
# Epoch 4/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8533 - reconstruction_loss: 0.6714 - kl_loss: 0.6842 - val_total_loss: 0.8917 - val_reconstruction_loss: 0.6967 - val_kl_loss: 0.7224 - lr: 0.0100
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8552 - reconstruction_loss: 0.6645 - kl_loss: 0.7072 - val_total_loss: 0.8686 - val_reconstruction_loss: 0.6741 - val_kl_loss: 0.7202 - lr: 0.0100
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8585 - reconstruction_loss: 0.6739 - kl_loss: 0.6977 - val_total_loss: 0.8744 - val_reconstruction_loss: 0.6564 - val_kl_loss: 0.8075 - lr: 0.0100
# Epoch 7/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8650 - reconstruction_loss: 0.6681 - kl_loss: 0.7204 - val_total_loss: 0.8323 - val_reconstruction_loss: 0.6028 - val_kl_loss: 0.8503 - lr: 0.0100
# Epoch 8/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8566 - reconstruction_loss: 0.6645 - kl_loss: 0.7105 - val_total_loss: 0.8557 - val_reconstruction_loss: 0.6467 - val_kl_loss: 0.7740 - lr: 0.0100
# Epoch 9/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8597 - reconstruction_loss: 0.6601 - kl_loss: 0.6971 - val_total_loss: 0.8928 - val_reconstruction_loss: 0.6766 - val_kl_loss: 0.8008 - lr: 0.0100
# Epoch 10/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8519 - reconstruction_loss: 0.6660 - kl_loss: 0.6967 - val_total_loss: 0.8601 - val_reconstruction_loss: 0.6508 - val_kl_loss: 0.7752 - lr: 0.0100
# Epoch 11/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8657 - reconstruction_loss: 0.6673 - kl_loss: 0.7253 - val_total_loss: 0.8854 - val_reconstruction_loss: 0.6653 - val_kl_loss: 0.8151 - lr: 0.0100
# Epoch 12/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8517 - reconstruction_loss: 0.6603 - kl_loss: 0.7279 - val_total_loss: 0.8480 - val_reconstruction_loss: 0.6494 - val_kl_loss: 0.7357 - lr: 0.0100
# Epoch 13/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8542 - reconstruction_loss: 0.6718 - kl_loss: 0.6982 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6610 - val_kl_loss: 0.7919 - lr: 0.0100
# Epoch 14/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8594 - reconstruction_loss: 0.6613 - kl_loss: 0.7236 - val_total_loss: 0.8687 - val_reconstruction_loss: 0.6550 - val_kl_loss: 0.7915 - lr: 0.0100
# Epoch 15/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8626 - reconstruction_loss: 0.6675 - kl_loss: 0.7180 - val_total_loss: 0.8216 - val_reconstruction_loss: 0.6171 - val_kl_loss: 0.7573 - lr: 0.0100
# Epoch 16/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8665 - reconstruction_loss: 0.6717 - kl_loss: 0.6895 - val_total_loss: 0.8815 - val_reconstruction_loss: 0.6404 - val_kl_loss: 0.8929 - lr: 0.0100
# Epoch 17/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8595 - reconstruction_loss: 0.6737 - kl_loss: 0.6907 - val_total_loss: 0.8851 - val_reconstruction_loss: 0.6820 - val_kl_loss: 0.7521 - lr: 0.0100
# Epoch 18/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8587 - reconstruction_loss: 0.6753 - kl_loss: 0.6724 - val_total_loss: 0.8975 - val_reconstruction_loss: 0.7048 - val_kl_loss: 0.7139 - lr: 0.0100
# Epoch 19/30
# 24/27 [=========================>....] - ETA: 0s - loss: 0.8489 - reconstruction_loss: 0.6685 - kl_loss: 0.6938
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8502 - reconstruction_loss: 0.6714 - kl_loss: 0.6879 - val_total_loss: 0.8697 - val_reconstruction_loss: 0.6745 - val_kl_loss: 0.7230 - lr: 0.0100
# Epoch 20/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8596 - reconstruction_loss: 0.6668 - kl_loss: 0.6937 - val_total_loss: 0.8658 - val_reconstruction_loss: 0.6495 - val_kl_loss: 0.8013 - lr: 0.0050
# Epoch 21/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8663 - reconstruction_loss: 0.6621 - kl_loss: 0.7257 - val_total_loss: 0.9069 - val_reconstruction_loss: 0.6867 - val_kl_loss: 0.8155 - lr: 0.0050
# Epoch 22/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8484 - reconstruction_loss: 0.6676 - kl_loss: 0.7109 - val_total_loss: 0.8369 - val_reconstruction_loss: 0.6229 - val_kl_loss: 0.7926 - lr: 0.0050
# Epoch 23/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8525 - reconstruction_loss: 0.6610 - kl_loss: 0.7191 - val_total_loss: 0.8548 - val_reconstruction_loss: 0.6457 - val_kl_loss: 0.7747 - lr: 0.0050
# Epoch 24/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8523 - reconstruction_loss: 0.6478 - kl_loss: 0.7300 - val_total_loss: 0.8609 - val_reconstruction_loss: 0.6444 - val_kl_loss: 0.8019 - lr: 0.0050
# Epoch 25/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8599 - reconstruction_loss: 0.6587 - kl_loss: 0.7251 - val_total_loss: 0.8629 - val_reconstruction_loss: 0.6536 - val_kl_loss: 0.7752 - lr: 0.0050
# Epoch 26/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8676 - reconstruction_loss: 0.6621 - kl_loss: 0.7036 - val_total_loss: 0.8465 - val_reconstruction_loss: 0.6415 - val_kl_loss: 0.7594 - lr: 0.0050
# Epoch 27/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8729 - reconstruction_loss: 0.6629 - kl_loss: 0.7232 - val_total_loss: 0.8561 - val_reconstruction_loss: 0.6397 - val_kl_loss: 0.8013 - lr: 0.0050
# Epoch 28/30
# 27/27 [==============================] - 1s 23ms/step - loss: 0.8544 - reconstruction_loss: 0.6602 - kl_loss: 0.7173 - val_total_loss: 0.8406 - val_reconstruction_loss: 0.6470 - val_kl_loss: 0.7171 - lr: 0.0050
# Epoch 29/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8478 - reconstruction_loss: 0.6632 - kl_loss: 0.6988 - val_total_loss: 0.8588 - val_reconstruction_loss: 0.6409 - val_kl_loss: 0.8070 - lr: 0.0050
# Epoch 30/30
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8560 - reconstruction_loss: 0.6625 - kl_loss: 0.7131 - val_total_loss: 0.8812 - val_reconstruction_loss: 0.6629 - val_kl_loss: 0.8085 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9454 - reconstruction_loss: 0.7287 - kl_loss: 0.8026
# [0.9454078078269958, 0.7287086844444275, 0.8025893568992615]
# Best Hyperparameters: {'learn_rate': 0.001, 'batch_size': 128}
# Best Score: [0.8402323722839355, 0.6392632722854614, 0.7443300485610962]

# %%
#DEFINIRANJE POVRATNIH POZIVA ZA PRAĆENJE GUBITAKA I LEARNING RATES TIJEKOM TRENINGA

learning_rates = []

class LearningRateScheduler(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        lr = float(tf.keras.backend.get_value(self.model.optimizer.lr))
        learning_rates.append(lr)
        
class LossHistoryCallback(Callback):
    def on_train_begin(self, logs=None):
        self.losses = []

    def on_epoch_end(self, epoch, logs=None):
        self.losses.append(logs['loss'])
        self.losses.append(logs['reconstruction_loss'])
        self.losses.append(logs['kl_loss'])

# %%
#TRENING

#Instanciranje i kompajliranje modela
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

#Instanciranje povratnih poziva
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
learning_rates = []
lr_scheduler = LearningRateScheduler()
loss_callback = LossHistoryCallback()

#Treniranje modela
history = vae.fit(x_train, batch_size=bs, epochs=100, validation_split = 0.2,
        callbacks=[lr_scheduler, loss_callback, reduce_lr, early_stop])
# Out:
# Epoch 1/15
# 53/53 [==============================] - 3s 19ms/step - loss: 0.9190 - reconstruction_loss: 0.8264 - kl_loss: 0.2169 - val_total_loss: 0.9583 - val_reconstruction_loss: 0.8556 - val_kl_loss: 0.2567 - lr: 0.0010
# Epoch 2/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9174 - reconstruction_loss: 0.8251 - kl_loss: 0.2230 - val_total_loss: 0.9910 - val_reconstruction_loss: 0.8662 - val_kl_loss: 0.3120 - lr: 0.0010
# Epoch 3/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9185 - reconstruction_loss: 0.8275 - kl_loss: 0.2251 - val_total_loss: 1.1368 - val_reconstruction_loss: 1.0163 - val_kl_loss: 0.3011 - lr: 0.0010
# Epoch 4/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9100 - reconstruction_loss: 0.8275 - kl_loss: 0.2204 - val_total_loss: 1.0712 - val_reconstruction_loss: 0.9425 - val_kl_loss: 0.3218 - lr: 0.0010
# Epoch 5/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9155 - reconstruction_loss: 0.8284 - kl_loss: 0.2332 - val_total_loss: 0.9590 - val_reconstruction_loss: 0.8296 - val_kl_loss: 0.3237 - lr: 0.0010
# Epoch 6/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9189 - reconstruction_loss: 0.8252 - kl_loss: 0.2373 - val_total_loss: 0.8679 - val_reconstruction_loss: 0.7394 - val_kl_loss: 0.3214 - lr: 0.0010
# Epoch 7/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9134 - reconstruction_loss: 0.8311 - kl_loss: 0.2182 - val_total_loss: 0.9505 - val_reconstruction_loss: 0.8373 - val_kl_loss: 0.2831 - lr: 0.0010
# Epoch 8/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9262 - reconstruction_loss: 0.8305 - kl_loss: 0.2263 - val_total_loss: 0.9501 - val_reconstruction_loss: 0.8407 - val_kl_loss: 0.2735 - lr: 0.0010
# Epoch 9/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9422 - reconstruction_loss: 0.8311 - kl_loss: 0.2254 - val_total_loss: 0.8947 - val_reconstruction_loss: 0.7661 - val_kl_loss: 0.3214 - lr: 0.0010
# Epoch 10/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9178 - reconstruction_loss: 0.8276 - kl_loss: 0.2235 - val_total_loss: 0.9802 - val_reconstruction_loss: 0.8504 - val_kl_loss: 0.3245 - lr: 0.0010
# Epoch 11/15
# 52/53 [============================>.] - ETA: 0s - loss: 0.9321 - reconstruction_loss: 0.8329 - kl_loss: 0.2168
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9316 - reconstruction_loss: 0.8318 - kl_loss: 0.2157 - val_total_loss: 0.9087 - val_reconstruction_loss: 0.7833 - val_kl_loss: 0.3137 - lr: 0.0010
# Epoch 12/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9153 - reconstruction_loss: 0.8268 - kl_loss: 0.2189 - val_total_loss: 0.8978 - val_reconstruction_loss: 0.7780 - val_kl_loss: 0.2995 - lr: 5.0000e-04
# Epoch 13/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9204 - reconstruction_loss: 0.8217 - kl_loss: 0.2268 - val_total_loss: 0.9299 - val_reconstruction_loss: 0.8052 - val_kl_loss: 0.3116 - lr: 5.0000e-04
# Epoch 14/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9241 - reconstruction_loss: 0.8279 - kl_loss: 0.2315 - val_total_loss: 1.0065 - val_reconstruction_loss: 0.8812 - val_kl_loss: 0.3133 - lr: 5.0000e-04
# Epoch 15/15
# 53/53 [==============================] - 1s 14ms/step - loss: 0.9054 - reconstruction_loss: 0.8287 - kl_loss: 0.2273 - val_total_loss: 0.9727 - val_reconstruction_loss: 0.8534 - val_kl_loss: 0.2984 - lr: 5.0000e-04

# %%
#VIZUALIZACIJA GUBITAKA I LEARNING RATES TIJEKOM TRENINGA

#VIzualizacija gubitaka
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Total Loss')
plt.plot(history.history['reconstruction_loss'], label='Reconstruction Loss')
plt.plot(history.history['kl_loss'], label='KL Loss')
plt.xlabel('Epohe treninga')
plt.ylabel('Gubici')
plt.title('Gubici tijekom treninga')
plt.legend()

#Vizualizacija learning rates
plt.figure(figsize=(8, 4))
plt.plot(learning_rates, label='Learning Rate')
plt.xlabel('Epohe treninga')
plt.ylabel('Gubici')
plt.title('Promjene parametra learning_rate')
plt.legend()

plt.show()

# %%
#Stvaranje enkodiranih i rekonstruiranih podataka za daljnje korištenje
_, _, z_input = encoder.predict(x_train)
reconstructed_z_input = vae.decoder.predict(z_input)
_, _, reconstructed_z_encoded = vae.encoder.predict(reconstructed_z_input)

_, _, z_test_input = encoder.predict(x_test)
reconstructed_z_test_input = vae.decoder.predict(z_test_input)
_, _, reconstructed_z_test_encoded = vae.encoder.predict(reconstructed_z_test_input)
# Out:
# 262/262 [==============================] - 0s 977us/step
# 262/262 [==============================] - 1s 2ms/step
# 262/262 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 962us/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 1ms/step

# %%
#Funkcija za vizualizaciju ulaznih podataka
def plot_input_data(x_data, y_data):
    z_input = x_data
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=legend_labels[label])

    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

#Vizualizacija podataka za trening i testiranje
plt.figure(figsize=(10, 6))
plt.title("Podaci za trening enkodirani u latentni prostor")
plot_input_data(z_input, y_train)

plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

# %%
#Funkcija za vizualizaciju rekonstruiranih podataka preko ulaznih podataka
def plot_input_and_reconstructed_data(x_input_data, x_reconstructed, y_input_data):
    z_input = x_input_data
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=legend_labels[label])

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Rekonstruirani podaci')
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.title("Podaci za testiranje i rekonstruirani podaci enkodirani u latentni prostor")
    plt.legend()
    plt.show()

plt.figure(figsize=(10, 6))
plot_input_and_reconstructed_data(z_test_input, reconstructed_z_test_encoded, y_test)

# %%
#Funkcija za vizualizaciju rekonstruiranih podataka
def plot_reconstructed_data(x_reconstructed, y_data):
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=legend_labels[label])
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
#Vizualizacija ulaznih i rekonstruiranih podataka za testiranje
plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirani podaci enkodirani u latentni prostor")
plot_reconstructed_data(reconstructed_z_test_encoded, y_test)

# %%
#Vizualizacija 10 nasumično izabranih peptida i njihove rekonstrukcije za usporedbu

#Odabir 10 nasumičnih peptida
selected_indices = np.random.choice(len(x_test), 10, replace=False)

selected_peptides = x_test[selected_indices]

#Enkodiranje i rekonstrukcija
_, _, encoded_selected_peptides = vae.encoder.predict(selected_peptides)
reconstructed_peptides = vae.decoder.predict(encoded_selected_peptides)
_, _, encoded_reconstructed_peptides = vae.encoder.predict(reconstructed_peptides)

#Funkcija za vizualizaciju odabranih podataka
def plot_selected_data(x_data):
    z_input = x_data
    num_peptides = z_input.shape[0]
    unique_colors = plt.cm.tab20(np.linspace(0, 1, num_peptides))

    for i in range(num_peptides):
        plt.scatter(z_input[i, 0], z_input[i, 1], color=unique_colors[i], label=f'Peptide {i}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

#Funkcija za izračun euklidske udaljenosti     
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))

#Vizualizacija odabranih peptida u izvornom i rekonstruiranom obliku
plt.figure(figsize=(10, 6))
plt.title("Slučajno izabrane izvorne točke u latentnom prostoru")
plot_selected_data(encoded_selected_peptides)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirane točke u latentnom prostoru")
plot_selected_data(encoded_reconstructed_peptides)

#Izračun udaljenosti između izvornih i rekonstruiranih peptida
distances = []

for i in range(10):
    dist = euclidean_distance(encoded_selected_peptides[i], encoded_reconstructed_peptides[i])
        
    distances.append(dist)

print("Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke: \n", distances, "\n")
print("Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka: ", np.sum(distances)/10)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke:
#  [1.2131156, 0.6469871, 1.1682839, 0.2748333, 1.2287996, 0.5959763, 1.0395247, 1.1795548, 0.43891644, 0.86634517]
#
# Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka:  0.8652337074279786

# %%
#NORMALIZIRANA UDALJENOST REKONSTRUKCIJE U LATENTNOM PROSTORU

min_values = np.min(z_test_input, axis=0)
max_values = np.max(z_test_input, axis=0)

latent_space_size = np.linalg.norm(max_values - min_values)

print(latent_space_size)

distances_x_test = []

for i in range(len(x_test)):
    dist = euclidean_distance(z_test_input[i], reconstructed_z_test_encoded[i])
        
    distances_x_test.append(dist)

print("Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka: ", 
      np.sum(distances_x_test)/latent_space_size/len(x_test))
# Out:
# 11.670432
# Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka:  0.09525697317907504

# %%
#PEARSONOV KOEFICIJENT KORELACIJE

from scipy.stats import spearmanr, kendalltau, pearsonr

print(pearsonr(x_test.flatten(), reconstructed_z_test_input.flatten()))
# Out:
# PearsonRResult(statistic=0.7918595720729192, pvalue=0.0)

# %%
#RMSE

mse = np.mean(np.square(x_test - reconstructed_z_test_input))
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.0868824721508698

# %%
#IZRAČUN SLIČNOSTI PEPTIDA PREMA SEKVENCI
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
  
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    alignments = pairwise2.align.globalxx(seq1, seq2)

    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    similarity = (score / max(len(seq1), len(seq2)))

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,101):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.39534884 0.18604651 0.34883721]
#  [0.1025641  0.         0.12820513 ... 0.13157895 0.125      0.05263158]
#  [0.20512821 0.28       0.23076923 ... 0.18421053 0.32       0.23684211]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.34210526 0.32432432 0.34210526]
#  [0.33333333 0.17777778 0.26666667 ... 0.33333333 0.22222222 0.33333333]
#  [0.07692308 0.25       0.15384615 ... 0.18421053 0.16666667 0.23684211]]
# [[0.27272727 0.18604651 0.27906977 ... 0.27906977 0.20930233 0.30232558]
#  [0.36363636 0.25581395 0.27906977 ... 0.3255814  0.1627907  0.18604651]
#  [0.25       0.17241379 0.26666667 ... 0.14285714 0.3        0.2       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.26190476 0.28571429 0.14285714]
#  [0.34090909 0.2972973  0.54054054 ... 0.28571429 0.24324324 0.2972973 ]
#  [0.09090909 0.13793103 0.06666667 ... 0.0952381  0.17647059 0.2       ]]

# %%
#IZRAČUN SLIČNOSTI PEPTIDA PREMA UDALJENOSTI U LATENTNOM PROSTORU
distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,101):
        dist_train = euclidean_distance(z_input[i], z_input[j])
        dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.48651886 0.53953385 0.24207306 ... 0.00539171 0.37290722 0.24937476]
#  [0.81579024 0.85245967 0.78037596 ... 0.8038513  0.83685064 0.81018096]
#  [0.11089572 0.         0.5680626  ... 0.75142646 0.24346268 0.47807923]
#  ...
#  [0.03691828 0.11826042 0.32447752 ... 0.48490453 0.0553776  0.2465386 ]
#  [0.424262   0.5267215  0.17377701 ... 0.17382862 0.4021382  0.26875472]
#  [0.47623444 0.49236178 0.30574343 ... 0.10525261 0.31178433 0.24258067]]
# [[0.33304903 0.85433793 0.24743773 ... 0.7633518  0.27311918 0.33532518]
#  [0.57320887 0.34560892 0.39773923 ... 0.6812066  0.2772872  0.14275865]
#  [0.4605058  0.46394148 0.22992085 ... 0.66244584 0.17206913 0.11754028]
#  ...
#  [0.3041075  0.6507926  0.09149614 ... 0.6418579  0.22128567 0.2605291 ]
#  [0.37534282 0.61857736 0.13854665 ... 0.6809615  0.15787885 0.18439938]
#  [0.5437537  0.77802706 0.35431004 ... 0.88856494 0.01664831 0.06635238]]

# %%
#VIZUALIZACIJA OVISNOSTI UDALJENOSTI U LATENTNOM PROSTORU O SLIČNOSTI PREMA SEKVENCAMA

flat_normalized_distances_train = normalized_distances_train.flatten()
flat_similarities_train = similarities_train.flatten()

plt.figure(figsize=(8, 6))
plt.scatter(flat_normalized_distances_train, flat_similarities_train, alpha=0.5)
plt.title("Ovisnost udaljenosti u latentnom prostoru o sličnosti prema sekevencama")
plt.xlabel("Normalizirane udaljenosti")
plt.ylabel("Sličnost prema značajkama")
plt.grid(True)
plt.show()

# %%
#VIZUALIZACIJA DISTRIBUCIJE UDALJENOSTI U LATENTNOM PROSTORU O SLIČNOSTI PREMA ZNAČAJKAMA

plt.figure(figsize=(12, 6))

#Histogram udaljenosti
plt.subplot(1, 2, 1)
plt.hist(flat_normalized_distances_train, bins=20, color='blue', alpha=0.7)
plt.title("Histogram normaliziranih udaljenosti")
plt.xlabel("Normalizirane udaljenosti")
plt.ylabel("Frekvencija")

#Histogram sličnosti prema sekvenci
plt.subplot(1, 2, 2)
plt.hist(flat_similarities_train, bins=20, color='red', alpha=0.7)
plt.title("Histogram sličnosti prema sekvencama")
plt.xlabel("Sličnost prema sekvencama")
plt.ylabel("Frekvencija")

plt.tight_layout()
plt.show()

# %%
#KORELACIJSKA ANALIZA

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")
# Out:
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.3257247594837337 -0.23218405333112013
# p-value: 4.25326576585774e-64 1.473332511568481e-32

# %%
sum_train = 0
sum_test = 0
pval_train = 0
pval_test = 0

N = 50

for x in range(10):
    
    similarities_train = []
    similarities_test = []

    for i in range(N-50,N):
        row_similarities_train = []
        row_similarities_test = []
        for j in range(N,N+51):
            sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
            sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
            row_similarities_train.append(sim_train)
            row_similarities_test.append(sim_test)

        similarities_train.append(row_similarities_train)
        similarities_test.append(row_similarities_test)

    similarities_train = np.array(similarities_train)
    similarities_test = np.array(similarities_test)

    
    distances_train = []
    distances_test = []

    for i in range(N-50,N):
        row_distances_train = []
        row_distances_test = []
        for j in range(N,N+51):
            dist_train = euclidean_distance(z_input[i], z_input[j])
            dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
            row_distances_train.append(dist_train)
            row_distances_test.append(dist_test)

        distances_train.append(row_distances_train)
        distances_test.append(row_distances_test)

    distances_train = np.array(distances_train)
    distances_test = np.array(distances_test)

    normalized_distances_train = scaler.fit_transform(distances_train)
    normalized_distances_test = scaler.fit_transform(distances_test)

    correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
    correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())
    
    print("Rezultati ispitivanja pod rednim brojem ", x+1, ":\n")
    print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
    print("p-value:", p_value_train, p_value_test, "\n")
    
    sum_train += correlation_train
    sum_test += correlation_test
    pval_train += p_value_train
    pval_test += p_value_test

    N += 50

print("Konačni rezultati ispitivanja:")
print("Usrednjeni koeficijent korelacije za skupove podataka za trening i testiranje: \n", sum_train/10, sum_test/10)
print("p-value:", pval_train/10, pval_test/10, "\n")
# Out:
# Rezultati ispitivanja pod rednim brojem  1 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.3257247594837337 -0.23218405333112013
# p-value: 4.25326576585774e-64 1.473332511568481e-32
#
# Rezultati ispitivanja pod rednim brojem  2 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.1800779580098242 -0.20162714322663638
# p-value: 4.998844670170576e-20 8.454676810456165e-25
#
# Rezultati ispitivanja pod rednim brojem  3 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.13866276799810387 -0.11133072575036479
# p-value: 2.0258761667908307e-12 1.733398942120798e-08
#
# Rezultati ispitivanja pod rednim brojem  4 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.17304093513204766 -0.3103504639474191
# p-value: 1.3642803634420945e-18 4.673452022806178e-58
#
# Rezultati ispitivanja pod rednim brojem  5 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.12029896398101042 -0.35971846341124303
# p-value: 1.101487017110541e-09 9.383019136353557e-79
#
# Rezultati ispitivanja pod rednim brojem  6 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.09611168275261621 -0.15357479437515223
# p-value: 1.1604016443109549e-06 6.30737937568996e-15
#
# Rezultati ispitivanja pod rednim brojem  7 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.14994563639218195 -0.25502281112232483
# p-value: 2.7148170007827814e-14 3.820473790190876e-39
#
# Rezultati ispitivanja pod rednim brojem  8 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.26171352172161033 -0.22914397732873623
# p-value: 3.3207126534558875e-41 9.852067997206997e-32
#
# Rezultati ispitivanja pod rednim brojem  9 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.312268269365366 -0.2683167765064376
# p-value: 8.61828340414765e-59 2.6775938334824218e-43
#
# Rezultati ispitivanja pod rednim brojem  10 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2686834994943331 -0.3558929679293519
# p-value: 2.0404809262588485e-43 5.1763760676640885e-77
#
# Konačni rezultati ispitivanja:
# Usrednjeni koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.20265279943308276 -0.2477162176928786
# p-value: 1.1615051843538165e-07 1.7333995728587353e-09
