# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

class Sampling(layers.Layer):

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
latent_dim = 2

encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
            total_loss = reconstruction_loss + 0.27 * kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + 0.27 * kl_loss

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 88, 8)        32          ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 44, 8)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_1[0][0]']
#
#  flatten (Flatten)              (None, 352)          0           ['max_pooling1d_1[0][0]']
#
#  dense (Dense)                  (None, 128)          45184       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense[0][0]']
#
#  sampling (Sampling)            (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 128)               384
#
#  dense_2 (Dense)             (None, 704)               90816
#
#  reshape (Reshape)           (None, 88, 8)             0
#
#  conv1d_2 (Conv1D)           (None, 88, 16)            400
#
#  up_sampling1d (UpSampling1D  (None, 176, 16)          0
#  )
#
#  conv1d_3 (Conv1D)           (None, 176, 8)            392
#
#  up_sampling1d_1 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 352, 1)            25
#
#  cropping1d (Cropping1D)     (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(
                                    features, labels, test_size=0.2, random_state=42)

x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]

x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
learn_rate = [0.001, 0.005, 0.008, 0.01]
batch_size = [32, 64, 128, 256]

param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

for lr in learn_rate:
    for bs in batch_size:
        print("Learning rate: ", lr)
        print("Batch size: ", bs)
        
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))
        
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
        early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
        
        vae.fit(x_train, batch_size=bs, epochs=30, validation_split = 0.2, 
                callbacks=[reduce_lr, early_stop])

        score = vae.evaluate(x_test)
        print(score)

        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Learning rate:  0.001
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 8ms/step - loss: 1.3095 - reconstruction_loss: 1.1282 - kl_loss: 0.0147 - val_total_loss: 1.0830 - val_reconstruction_loss: 1.0700 - val_kl_loss: 0.0482 - lr: 0.0010
# Epoch 2/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9767 - reconstruction_loss: 0.8915 - kl_loss: 0.1966 - val_total_loss: 0.8939 - val_reconstruction_loss: 0.8013 - val_kl_loss: 0.3432 - lr: 0.0010
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9184 - reconstruction_loss: 0.8253 - kl_loss: 0.3384 - val_total_loss: 0.8876 - val_reconstruction_loss: 0.7421 - val_kl_loss: 0.5390 - lr: 0.0010
# Epoch 4/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9087 - reconstruction_loss: 0.8073 - kl_loss: 0.3848 - val_total_loss: 0.8667 - val_reconstruction_loss: 0.7477 - val_kl_loss: 0.4405 - lr: 0.0010
# Epoch 5/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9101 - reconstruction_loss: 0.7937 - kl_loss: 0.3880 - val_total_loss: 1.0148 - val_reconstruction_loss: 0.8831 - val_kl_loss: 0.4877 - lr: 0.0010
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8992 - reconstruction_loss: 0.7815 - kl_loss: 0.4138 - val_total_loss: 0.9021 - val_reconstruction_loss: 0.7565 - val_kl_loss: 0.5390 - lr: 0.0010
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8975 - reconstruction_loss: 0.7790 - kl_loss: 0.4169 - val_total_loss: 0.8453 - val_reconstruction_loss: 0.6970 - val_kl_loss: 0.5491 - lr: 0.0010
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8877 - reconstruction_loss: 0.7711 - kl_loss: 0.4398 - val_total_loss: 0.8567 - val_reconstruction_loss: 0.7176 - val_kl_loss: 0.5152 - lr: 0.0010
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8908 - reconstruction_loss: 0.7752 - kl_loss: 0.4362 - val_total_loss: 0.9484 - val_reconstruction_loss: 0.8044 - val_kl_loss: 0.5334 - lr: 0.0010
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8792 - reconstruction_loss: 0.7667 - kl_loss: 0.4369 - val_total_loss: 0.8554 - val_reconstruction_loss: 0.6953 - val_kl_loss: 0.5928 - lr: 0.0010
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8909 - reconstruction_loss: 0.7651 - kl_loss: 0.4453 - val_total_loss: 0.9391 - val_reconstruction_loss: 0.7922 - val_kl_loss: 0.5442 - lr: 0.0010
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8774 - reconstruction_loss: 0.7617 - kl_loss: 0.4501 - val_total_loss: 0.8222 - val_reconstruction_loss: 0.6785 - val_kl_loss: 0.5321 - lr: 0.0010
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8659 - reconstruction_loss: 0.7626 - kl_loss: 0.4347 - val_total_loss: 0.8790 - val_reconstruction_loss: 0.7297 - val_kl_loss: 0.5530 - lr: 0.0010
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8582 - reconstruction_loss: 0.7584 - kl_loss: 0.4543 - val_total_loss: 0.8333 - val_reconstruction_loss: 0.6805 - val_kl_loss: 0.5661 - lr: 0.0010
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8805 - reconstruction_loss: 0.7562 - kl_loss: 0.4592 - val_total_loss: 0.8668 - val_reconstruction_loss: 0.7262 - val_kl_loss: 0.5207 - lr: 0.0010
# Epoch 16/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8899 - reconstruction_loss: 0.7599 - kl_loss: 0.4613 - val_total_loss: 0.8471 - val_reconstruction_loss: 0.7132 - val_kl_loss: 0.4958 - lr: 0.0010
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8779 - reconstruction_loss: 0.7574 - kl_loss: 0.4665 - val_total_loss: 0.9235 - val_reconstruction_loss: 0.7792 - val_kl_loss: 0.5347 - lr: 0.0010
# Epoch 18/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8741 - reconstruction_loss: 0.7589 - kl_loss: 0.4530 - val_total_loss: 0.9561 - val_reconstruction_loss: 0.7964 - val_kl_loss: 0.5914 - lr: 0.0010
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8944 - reconstruction_loss: 0.7580 - kl_loss: 0.4711 - val_total_loss: 0.8609 - val_reconstruction_loss: 0.6807 - val_kl_loss: 0.6674 - lr: 0.0010
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8720 - reconstruction_loss: 0.7512 - kl_loss: 0.4739 - val_total_loss: 0.8151 - val_reconstruction_loss: 0.6741 - val_kl_loss: 0.5222 - lr: 0.0010
# Epoch 21/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8816 - reconstruction_loss: 0.7528 - kl_loss: 0.4658 - val_total_loss: 0.8692 - val_reconstruction_loss: 0.6934 - val_kl_loss: 0.6512 - lr: 0.0010
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8821 - reconstruction_loss: 0.7508 - kl_loss: 0.4648 - val_total_loss: 1.0964 - val_reconstruction_loss: 0.9272 - val_kl_loss: 0.6268 - lr: 0.0010
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8767 - reconstruction_loss: 0.7530 - kl_loss: 0.4587 - val_total_loss: 0.8344 - val_reconstruction_loss: 0.6778 - val_kl_loss: 0.5799 - lr: 0.0010
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8852 - reconstruction_loss: 0.7541 - kl_loss: 0.4672 - val_total_loss: 0.8222 - val_reconstruction_loss: 0.6441 - val_kl_loss: 0.6598 - lr: 0.0010
# Epoch 25/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8863 - reconstruction_loss: 0.7466 - kl_loss: 0.4838 - val_total_loss: 0.8715 - val_reconstruction_loss: 0.7085 - val_kl_loss: 0.6038 - lr: 0.0010
# Epoch 26/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8675 - reconstruction_loss: 0.7512 - kl_loss: 0.4653 - val_total_loss: 0.8143 - val_reconstruction_loss: 0.6571 - val_kl_loss: 0.5823 - lr: 0.0010
# Epoch 27/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8914 - reconstruction_loss: 0.7526 - kl_loss: 0.4785 - val_total_loss: 0.8847 - val_reconstruction_loss: 0.7266 - val_kl_loss: 0.5856 - lr: 0.0010
# Epoch 28/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8903 - reconstruction_loss: 0.7446 - kl_loss: 0.4922 - val_total_loss: 0.9548 - val_reconstruction_loss: 0.7886 - val_kl_loss: 0.6158 - lr: 0.0010
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8679 - reconstruction_loss: 0.7502 - kl_loss: 0.4665 - val_total_loss: 0.8780 - val_reconstruction_loss: 0.7042 - val_kl_loss: 0.6438 - lr: 0.0010
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8864 - reconstruction_loss: 0.7483 - kl_loss: 0.4842 - val_total_loss: 0.7911 - val_reconstruction_loss: 0.6165 - val_kl_loss: 0.6470 - lr: 0.0010
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8005 - reconstruction_loss: 0.6382 - kl_loss: 0.6012
# [0.800513505935669, 0.6382009983062744, 0.601157546043396]
# Learning rate:  0.001
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8815 - reconstruction_loss: 0.7403 - kl_loss: 0.4987 - val_total_loss: 0.8170 - val_reconstruction_loss: 0.6594 - val_kl_loss: 0.5837 - lr: 0.0010
# Epoch 2/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8777 - reconstruction_loss: 0.7397 - kl_loss: 0.4906 - val_total_loss: 0.8824 - val_reconstruction_loss: 0.7186 - val_kl_loss: 0.6066 - lr: 0.0010
# Epoch 3/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8554 - reconstruction_loss: 0.7380 - kl_loss: 0.4801 - val_total_loss: 0.9150 - val_reconstruction_loss: 0.7546 - val_kl_loss: 0.5942 - lr: 0.0010
# Epoch 4/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8778 - reconstruction_loss: 0.7430 - kl_loss: 0.4936 - val_total_loss: 0.8038 - val_reconstruction_loss: 0.6405 - val_kl_loss: 0.6049 - lr: 0.0010
# Epoch 5/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8755 - reconstruction_loss: 0.7412 - kl_loss: 0.4915 - val_total_loss: 0.7939 - val_reconstruction_loss: 0.6121 - val_kl_loss: 0.6734 - lr: 0.0010
# Epoch 6/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8630 - reconstruction_loss: 0.7342 - kl_loss: 0.5111 - val_total_loss: 0.7886 - val_reconstruction_loss: 0.6239 - val_kl_loss: 0.6098 - lr: 0.0010
# Epoch 7/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8745 - reconstruction_loss: 0.7341 - kl_loss: 0.5107 - val_total_loss: 0.8991 - val_reconstruction_loss: 0.7228 - val_kl_loss: 0.6526 - lr: 0.0010
# Epoch 8/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8788 - reconstruction_loss: 0.7356 - kl_loss: 0.5224 - val_total_loss: 0.9041 - val_reconstruction_loss: 0.7236 - val_kl_loss: 0.6684 - lr: 0.0010
# Epoch 9/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8710 - reconstruction_loss: 0.7336 - kl_loss: 0.5124 - val_total_loss: 0.9689 - val_reconstruction_loss: 0.8034 - val_kl_loss: 0.6131 - lr: 0.0010
# Epoch 10/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8727 - reconstruction_loss: 0.7292 - kl_loss: 0.5299 - val_total_loss: 0.8928 - val_reconstruction_loss: 0.7248 - val_kl_loss: 0.6224 - lr: 0.0010
# Epoch 11/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8614 - reconstruction_loss: 0.7270 - kl_loss: 0.5306 - val_total_loss: 0.8232 - val_reconstruction_loss: 0.6547 - val_kl_loss: 0.6238 - lr: 0.0010
# Epoch 12/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8617 - reconstruction_loss: 0.7242 - kl_loss: 0.5348 - val_total_loss: 0.9374 - val_reconstruction_loss: 0.7845 - val_kl_loss: 0.5661 - lr: 0.0010
# Epoch 13/30
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8735 - reconstruction_loss: 0.7226 - kl_loss: 0.5597
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8736 - reconstruction_loss: 0.7240 - kl_loss: 0.5607 - val_total_loss: 0.8514 - val_reconstruction_loss: 0.6805 - val_kl_loss: 0.6331 - lr: 0.0010
# Epoch 14/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8761 - reconstruction_loss: 0.7187 - kl_loss: 0.5646 - val_total_loss: 0.7711 - val_reconstruction_loss: 0.5901 - val_kl_loss: 0.6703 - lr: 5.0000e-04
# Epoch 15/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8507 - reconstruction_loss: 0.7150 - kl_loss: 0.5576 - val_total_loss: 0.7873 - val_reconstruction_loss: 0.6070 - val_kl_loss: 0.6677 - lr: 5.0000e-04
# Epoch 16/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8572 - reconstruction_loss: 0.7129 - kl_loss: 0.5641 - val_total_loss: 0.7957 - val_reconstruction_loss: 0.6121 - val_kl_loss: 0.6800 - lr: 5.0000e-04
# Epoch 17/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8786 - reconstruction_loss: 0.7123 - kl_loss: 0.5918 - val_total_loss: 0.7383 - val_reconstruction_loss: 0.5574 - val_kl_loss: 0.6701 - lr: 5.0000e-04
# Epoch 18/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8730 - reconstruction_loss: 0.7105 - kl_loss: 0.5780 - val_total_loss: 0.8157 - val_reconstruction_loss: 0.6384 - val_kl_loss: 0.6565 - lr: 5.0000e-04
# Epoch 19/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8531 - reconstruction_loss: 0.7065 - kl_loss: 0.5832 - val_total_loss: 0.9854 - val_reconstruction_loss: 0.7884 - val_kl_loss: 0.7295 - lr: 5.0000e-04
# Epoch 20/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8662 - reconstruction_loss: 0.7085 - kl_loss: 0.5892 - val_total_loss: 0.9680 - val_reconstruction_loss: 0.7672 - val_kl_loss: 0.7439 - lr: 5.0000e-04
# Epoch 21/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8653 - reconstruction_loss: 0.7026 - kl_loss: 0.5981 - val_total_loss: 0.8558 - val_reconstruction_loss: 0.6669 - val_kl_loss: 0.6998 - lr: 5.0000e-04
# Epoch 22/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8765 - reconstruction_loss: 0.7090 - kl_loss: 0.5839 - val_total_loss: 0.8035 - val_reconstruction_loss: 0.6206 - val_kl_loss: 0.6772 - lr: 5.0000e-04
# Epoch 23/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8646 - reconstruction_loss: 0.7016 - kl_loss: 0.6020 - val_total_loss: 0.8641 - val_reconstruction_loss: 0.6689 - val_kl_loss: 0.7230 - lr: 5.0000e-04
# Epoch 24/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8571 - reconstruction_loss: 0.7043 - kl_loss: 0.6012 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6789 - val_kl_loss: 0.7257 - lr: 5.0000e-04
# Epoch 25/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8622 - reconstruction_loss: 0.7078 - kl_loss: 0.6025 - val_total_loss: 0.9284 - val_reconstruction_loss: 0.7449 - val_kl_loss: 0.6797 - lr: 5.0000e-04
# Epoch 26/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8691 - reconstruction_loss: 0.7033 - kl_loss: 0.6103 - val_total_loss: 0.8675 - val_reconstruction_loss: 0.6745 - val_kl_loss: 0.7147 - lr: 5.0000e-04
# Epoch 27/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8693 - reconstruction_loss: 0.7046 - kl_loss: 0.5987 - val_total_loss: 0.9949 - val_reconstruction_loss: 0.8074 - val_kl_loss: 0.6946 - lr: 5.0000e-04
# Epoch 28/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8717 - reconstruction_loss: 0.7039 - kl_loss: 0.6240 - val_total_loss: 0.7793 - val_reconstruction_loss: 0.5681 - val_kl_loss: 0.7821 - lr: 5.0000e-04
# Epoch 29/30
#  99/105 [===========================>..] - ETA: 0s - loss: 0.8805 - reconstruction_loss: 0.7046 - kl_loss: 0.6155
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8799 - reconstruction_loss: 0.7038 - kl_loss: 0.6178 - val_total_loss: 0.8052 - val_reconstruction_loss: 0.6033 - val_kl_loss: 0.7479 - lr: 5.0000e-04
# Epoch 30/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8665 - reconstruction_loss: 0.6992 - kl_loss: 0.6128 - val_total_loss: 0.8506 - val_reconstruction_loss: 0.6617 - val_kl_loss: 0.6994 - lr: 2.5000e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.6909 - reconstruction_loss: 0.5023 - kl_loss: 0.6987
# [0.6909022331237793, 0.5022605061531067, 0.6986730694770813]
# Learning rate:  0.001
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 18ms/step - loss: 0.8577 - reconstruction_loss: 0.6992 - kl_loss: 0.5962 - val_total_loss: 0.8823 - val_reconstruction_loss: 0.6916 - val_kl_loss: 0.7062 - lr: 0.0010
# Epoch 2/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8500 - reconstruction_loss: 0.7029 - kl_loss: 0.6118 - val_total_loss: 0.7639 - val_reconstruction_loss: 0.5626 - val_kl_loss: 0.7457 - lr: 0.0010
# Epoch 3/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8523 - reconstruction_loss: 0.6981 - kl_loss: 0.6037 - val_total_loss: 1.0577 - val_reconstruction_loss: 0.8541 - val_kl_loss: 0.7541 - lr: 0.0010
# Epoch 4/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8758 - reconstruction_loss: 0.6948 - kl_loss: 0.6193 - val_total_loss: 0.9459 - val_reconstruction_loss: 0.7701 - val_kl_loss: 0.6510 - lr: 0.0010
# Epoch 5/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8754 - reconstruction_loss: 0.7055 - kl_loss: 0.5997 - val_total_loss: 0.8899 - val_reconstruction_loss: 0.6821 - val_kl_loss: 0.7697 - lr: 0.0010
# Epoch 6/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8751 - reconstruction_loss: 0.7007 - kl_loss: 0.6264 - val_total_loss: 0.9232 - val_reconstruction_loss: 0.7212 - val_kl_loss: 0.7481 - lr: 0.0010
# Epoch 7/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8645 - reconstruction_loss: 0.6943 - kl_loss: 0.6155 - val_total_loss: 0.8346 - val_reconstruction_loss: 0.6288 - val_kl_loss: 0.7620 - lr: 0.0010
# Epoch 8/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8452 - reconstruction_loss: 0.6947 - kl_loss: 0.6114 - val_total_loss: 0.8008 - val_reconstruction_loss: 0.5976 - val_kl_loss: 0.7524 - lr: 0.0010
# Epoch 9/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8706 - reconstruction_loss: 0.7026 - kl_loss: 0.6338 - val_total_loss: 0.8605 - val_reconstruction_loss: 0.6656 - val_kl_loss: 0.7219 - lr: 0.0010
# Epoch 10/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8618 - reconstruction_loss: 0.6943 - kl_loss: 0.6315 - val_total_loss: 0.9965 - val_reconstruction_loss: 0.8039 - val_kl_loss: 0.7134 - lr: 0.0010
# Epoch 11/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8589 - reconstruction_loss: 0.6947 - kl_loss: 0.6318 - val_total_loss: 0.7463 - val_reconstruction_loss: 0.5585 - val_kl_loss: 0.6958 - lr: 0.0010
# Epoch 12/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8608 - reconstruction_loss: 0.6963 - kl_loss: 0.6186 - val_total_loss: 0.8897 - val_reconstruction_loss: 0.7190 - val_kl_loss: 0.6321 - lr: 0.0010
# Epoch 13/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8569 - reconstruction_loss: 0.6968 - kl_loss: 0.6092 - val_total_loss: 0.8112 - val_reconstruction_loss: 0.6102 - val_kl_loss: 0.7444 - lr: 0.0010
# Epoch 14/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8522 - reconstruction_loss: 0.6943 - kl_loss: 0.6411 - val_total_loss: 0.8357 - val_reconstruction_loss: 0.6255 - val_kl_loss: 0.7784 - lr: 0.0010
# Epoch 15/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8720 - reconstruction_loss: 0.6932 - kl_loss: 0.6446 - val_total_loss: 0.9182 - val_reconstruction_loss: 0.6933 - val_kl_loss: 0.8328 - lr: 0.0010
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8830 - reconstruction_loss: 0.6966 - kl_loss: 0.6469 - val_total_loss: 0.8072 - val_reconstruction_loss: 0.6261 - val_kl_loss: 0.6705 - lr: 0.0010
# Epoch 17/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8680 - reconstruction_loss: 0.6889 - kl_loss: 0.6464 - val_total_loss: 0.7767 - val_reconstruction_loss: 0.5866 - val_kl_loss: 0.7040 - lr: 0.0010
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8526 - reconstruction_loss: 0.6912 - kl_loss: 0.6224 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6560 - val_kl_loss: 0.8103 - lr: 0.0010
# Epoch 19/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8588 - reconstruction_loss: 0.6871 - kl_loss: 0.6500 - val_total_loss: 0.9377 - val_reconstruction_loss: 0.7397 - val_kl_loss: 0.7332 - lr: 0.0010
# Epoch 20/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8602 - reconstruction_loss: 0.6839 - kl_loss: 0.6413 - val_total_loss: 0.8777 - val_reconstruction_loss: 0.6675 - val_kl_loss: 0.7788 - lr: 0.0010
# Epoch 21/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8534 - reconstruction_loss: 0.6861 - kl_loss: 0.6493 - val_total_loss: 0.8053 - val_reconstruction_loss: 0.6090 - val_kl_loss: 0.7270 - lr: 0.0010
# Epoch 22/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8602 - reconstruction_loss: 0.6874 - kl_loss: 0.6375 - val_total_loss: 0.9530 - val_reconstruction_loss: 0.7418 - val_kl_loss: 0.7826 - lr: 0.0010
# Epoch 23/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8563 - reconstruction_loss: 0.6907 - kl_loss: 0.6307 - val_total_loss: 0.7938 - val_reconstruction_loss: 0.6004 - val_kl_loss: 0.7162 - lr: 0.0010
# Epoch 24/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8623 - reconstruction_loss: 0.6862 - kl_loss: 0.6561 - val_total_loss: 0.9345 - val_reconstruction_loss: 0.7140 - val_kl_loss: 0.8168 - lr: 0.0010
# Epoch 25/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8548 - reconstruction_loss: 0.6870 - kl_loss: 0.6466 - val_total_loss: 0.8400 - val_reconstruction_loss: 0.6344 - val_kl_loss: 0.7614 - lr: 0.0010
# Epoch 26/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8735 - reconstruction_loss: 0.6875 - kl_loss: 0.6521 - val_total_loss: 0.7291 - val_reconstruction_loss: 0.5405 - val_kl_loss: 0.6983 - lr: 0.0010
# Epoch 27/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8511 - reconstruction_loss: 0.6879 - kl_loss: 0.6381 - val_total_loss: 0.8028 - val_reconstruction_loss: 0.5934 - val_kl_loss: 0.7754 - lr: 0.0010
# Epoch 28/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8667 - reconstruction_loss: 0.6829 - kl_loss: 0.6670 - val_total_loss: 0.9173 - val_reconstruction_loss: 0.7090 - val_kl_loss: 0.7717 - lr: 0.0010
# Epoch 29/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8618 - reconstruction_loss: 0.6796 - kl_loss: 0.6586 - val_total_loss: 0.8413 - val_reconstruction_loss: 0.6312 - val_kl_loss: 0.7782 - lr: 0.0010
# Epoch 30/30
# 51/53 [===========================>..] - ETA: 0s - loss: 0.8583 - reconstruction_loss: 0.6835 - kl_loss: 0.6477
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8584 - reconstruction_loss: 0.6850 - kl_loss: 0.6479 - val_total_loss: 0.8351 - val_reconstruction_loss: 0.6153 - val_kl_loss: 0.8141 - lr: 0.0010
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8816 - reconstruction_loss: 0.6655 - kl_loss: 0.8003
# [0.8815538287162781, 0.6654617786407471, 0.8003408312797546]
# Learning rate:  0.001
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 2s 34ms/step - loss: 0.8623 - reconstruction_loss: 0.6807 - kl_loss: 0.6423 - val_total_loss: 0.8692 - val_reconstruction_loss: 0.6781 - val_kl_loss: 0.7077 - lr: 0.0010
# Epoch 2/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8651 - reconstruction_loss: 0.6878 - kl_loss: 0.6601 - val_total_loss: 0.8701 - val_reconstruction_loss: 0.6729 - val_kl_loss: 0.7304 - lr: 0.0010
# Epoch 3/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8640 - reconstruction_loss: 0.6805 - kl_loss: 0.6663 - val_total_loss: 0.8657 - val_reconstruction_loss: 0.6809 - val_kl_loss: 0.6844 - lr: 0.0010
# Epoch 4/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8494 - reconstruction_loss: 0.6774 - kl_loss: 0.6460 - val_total_loss: 0.8932 - val_reconstruction_loss: 0.6971 - val_kl_loss: 0.7263 - lr: 0.0010
# Epoch 5/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8520 - reconstruction_loss: 0.6850 - kl_loss: 0.6413 - val_total_loss: 0.8499 - val_reconstruction_loss: 0.6463 - val_kl_loss: 0.7542 - lr: 0.0010
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8698 - reconstruction_loss: 0.6754 - kl_loss: 0.6524 - val_total_loss: 0.8854 - val_reconstruction_loss: 0.6770 - val_kl_loss: 0.7716 - lr: 0.0010
# Epoch 7/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8541 - reconstruction_loss: 0.6837 - kl_loss: 0.6597 - val_total_loss: 0.8621 - val_reconstruction_loss: 0.6600 - val_kl_loss: 0.7484 - lr: 0.0010
# Epoch 8/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8560 - reconstruction_loss: 0.6773 - kl_loss: 0.6548 - val_total_loss: 0.8952 - val_reconstruction_loss: 0.6801 - val_kl_loss: 0.7969 - lr: 0.0010
# Epoch 9/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8508 - reconstruction_loss: 0.6791 - kl_loss: 0.6737 - val_total_loss: 0.9123 - val_reconstruction_loss: 0.7234 - val_kl_loss: 0.6998 - lr: 0.0010
# Epoch 10/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8754 - reconstruction_loss: 0.6801 - kl_loss: 0.6830 - val_total_loss: 0.8529 - val_reconstruction_loss: 0.6410 - val_kl_loss: 0.7845 - lr: 0.0010
# Epoch 11/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8525 - reconstruction_loss: 0.6772 - kl_loss: 0.6769 - val_total_loss: 0.8624 - val_reconstruction_loss: 0.6581 - val_kl_loss: 0.7569 - lr: 0.0010
# Epoch 12/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8602 - reconstruction_loss: 0.6744 - kl_loss: 0.6699 - val_total_loss: 0.8656 - val_reconstruction_loss: 0.6659 - val_kl_loss: 0.7396 - lr: 0.0010
# Epoch 13/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8640 - reconstruction_loss: 0.6826 - kl_loss: 0.6704 - val_total_loss: 0.8455 - val_reconstruction_loss: 0.6317 - val_kl_loss: 0.7920 - lr: 0.0010
# Epoch 14/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8637 - reconstruction_loss: 0.6740 - kl_loss: 0.6867 - val_total_loss: 0.8493 - val_reconstruction_loss: 0.6462 - val_kl_loss: 0.7523 - lr: 0.0010
# Epoch 15/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8623 - reconstruction_loss: 0.6804 - kl_loss: 0.6741 - val_total_loss: 0.8554 - val_reconstruction_loss: 0.6578 - val_kl_loss: 0.7318 - lr: 0.0010
# Epoch 16/30
# 24/27 [=========================>....] - ETA: 0s - loss: 0.8712 - reconstruction_loss: 0.6783 - kl_loss: 0.6830
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8691 - reconstruction_loss: 0.6725 - kl_loss: 0.6688 - val_total_loss: 0.8697 - val_reconstruction_loss: 0.6629 - val_kl_loss: 0.7658 - lr: 0.0010
# Epoch 17/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8644 - reconstruction_loss: 0.6728 - kl_loss: 0.6797 - val_total_loss: 0.8981 - val_reconstruction_loss: 0.6860 - val_kl_loss: 0.7855 - lr: 5.0000e-04
# Epoch 18/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8605 - reconstruction_loss: 0.6748 - kl_loss: 0.6747 - val_total_loss: 0.8946 - val_reconstruction_loss: 0.6964 - val_kl_loss: 0.7341 - lr: 5.0000e-04
# Epoch 19/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8491 - reconstruction_loss: 0.6783 - kl_loss: 0.6623 - val_total_loss: 0.8629 - val_reconstruction_loss: 0.6519 - val_kl_loss: 0.7815 - lr: 5.0000e-04
# Epoch 20/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8508 - reconstruction_loss: 0.6715 - kl_loss: 0.6619 - val_total_loss: 0.8750 - val_reconstruction_loss: 0.6664 - val_kl_loss: 0.7724 - lr: 5.0000e-04
# Epoch 21/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8546 - reconstruction_loss: 0.6789 - kl_loss: 0.6680 - val_total_loss: 0.8414 - val_reconstruction_loss: 0.6317 - val_kl_loss: 0.7768 - lr: 5.0000e-04
# Epoch 22/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8556 - reconstruction_loss: 0.6761 - kl_loss: 0.6652 - val_total_loss: 0.8685 - val_reconstruction_loss: 0.6574 - val_kl_loss: 0.7818 - lr: 5.0000e-04
# Epoch 23/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8447 - reconstruction_loss: 0.6750 - kl_loss: 0.6755 - val_total_loss: 0.8564 - val_reconstruction_loss: 0.6565 - val_kl_loss: 0.7406 - lr: 5.0000e-04
# Epoch 24/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8582 - reconstruction_loss: 0.6764 - kl_loss: 0.6685 - val_total_loss: 0.8418 - val_reconstruction_loss: 0.6343 - val_kl_loss: 0.7684 - lr: 5.0000e-04
# Epoch 25/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8639 - reconstruction_loss: 0.6820 - kl_loss: 0.6750 - val_total_loss: 0.8750 - val_reconstruction_loss: 0.6686 - val_kl_loss: 0.7646 - lr: 5.0000e-04
# Epoch 26/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8543 - reconstruction_loss: 0.6734 - kl_loss: 0.6929 - val_total_loss: 0.8758 - val_reconstruction_loss: 0.6633 - val_kl_loss: 0.7873 - lr: 5.0000e-04
# Epoch 27/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8569 - reconstruction_loss: 0.6746 - kl_loss: 0.6858 - val_total_loss: 0.8653 - val_reconstruction_loss: 0.6538 - val_kl_loss: 0.7830 - lr: 5.0000e-04
# Epoch 28/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8602 - reconstruction_loss: 0.6779 - kl_loss: 0.6992 - val_total_loss: 0.8285 - val_reconstruction_loss: 0.6115 - val_kl_loss: 0.8038 - lr: 5.0000e-04
# Epoch 29/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8629 - reconstruction_loss: 0.6713 - kl_loss: 0.6841 - val_total_loss: 0.8314 - val_reconstruction_loss: 0.6256 - val_kl_loss: 0.7623 - lr: 5.0000e-04
# Epoch 30/30
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8609 - reconstruction_loss: 0.6721 - kl_loss: 0.6874
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8606 - reconstruction_loss: 0.6725 - kl_loss: 0.6855 - val_total_loss: 0.8669 - val_reconstruction_loss: 0.6621 - val_kl_loss: 0.7584 - lr: 5.0000e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7592 - reconstruction_loss: 0.5568 - kl_loss: 0.7493
# [0.7591637372970581, 0.5568446516990662, 0.7493298649787903]
# Learning rate:  0.005
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 7ms/step - loss: 0.9328 - reconstruction_loss: 0.7300 - kl_loss: 0.6120 - val_total_loss: 0.8874 - val_reconstruction_loss: 0.6396 - val_kl_loss: 0.9179 - lr: 0.0050
# Epoch 2/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8975 - reconstruction_loss: 0.7275 - kl_loss: 0.6032 - val_total_loss: 0.8877 - val_reconstruction_loss: 0.6967 - val_kl_loss: 0.7075 - lr: 0.0050
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8775 - reconstruction_loss: 0.7162 - kl_loss: 0.6126 - val_total_loss: 0.8752 - val_reconstruction_loss: 0.6735 - val_kl_loss: 0.7469 - lr: 0.0050
# Epoch 4/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8694 - reconstruction_loss: 0.7173 - kl_loss: 0.5905 - val_total_loss: 0.8023 - val_reconstruction_loss: 0.5803 - val_kl_loss: 0.8222 - lr: 0.0050
# Epoch 5/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8860 - reconstruction_loss: 0.7116 - kl_loss: 0.6267 - val_total_loss: 1.0169 - val_reconstruction_loss: 0.8427 - val_kl_loss: 0.6451 - lr: 0.0050
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8731 - reconstruction_loss: 0.7137 - kl_loss: 0.6076 - val_total_loss: 0.8931 - val_reconstruction_loss: 0.7138 - val_kl_loss: 0.6638 - lr: 0.0050
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8752 - reconstruction_loss: 0.7050 - kl_loss: 0.6255 - val_total_loss: 0.9444 - val_reconstruction_loss: 0.7633 - val_kl_loss: 0.6707 - lr: 0.0050
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8883 - reconstruction_loss: 0.7072 - kl_loss: 0.6441 - val_total_loss: 0.8735 - val_reconstruction_loss: 0.6061 - val_kl_loss: 0.9905 - lr: 0.0050
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8830 - reconstruction_loss: 0.6984 - kl_loss: 0.6487 - val_total_loss: 0.9474 - val_reconstruction_loss: 0.7206 - val_kl_loss: 0.8401 - lr: 0.0050
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8707 - reconstruction_loss: 0.7052 - kl_loss: 0.6505 - val_total_loss: 0.8875 - val_reconstruction_loss: 0.6062 - val_kl_loss: 1.0418 - lr: 0.0050
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8833 - reconstruction_loss: 0.6996 - kl_loss: 0.6514 - val_total_loss: 0.8125 - val_reconstruction_loss: 0.6072 - val_kl_loss: 0.7603 - lr: 0.0050
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8815 - reconstruction_loss: 0.7097 - kl_loss: 0.6259 - val_total_loss: 1.0144 - val_reconstruction_loss: 0.8302 - val_kl_loss: 0.6823 - lr: 0.0050
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8760 - reconstruction_loss: 0.7088 - kl_loss: 0.6263 - val_total_loss: 0.9165 - val_reconstruction_loss: 0.6941 - val_kl_loss: 0.8234 - lr: 0.0050
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8693 - reconstruction_loss: 0.6997 - kl_loss: 0.6458 - val_total_loss: 0.7607 - val_reconstruction_loss: 0.5255 - val_kl_loss: 0.8709 - lr: 0.0050
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8708 - reconstruction_loss: 0.7012 - kl_loss: 0.6357 - val_total_loss: 0.7262 - val_reconstruction_loss: 0.5145 - val_kl_loss: 0.7842 - lr: 0.0050
# Epoch 16/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8831 - reconstruction_loss: 0.7011 - kl_loss: 0.6296 - val_total_loss: 0.8562 - val_reconstruction_loss: 0.6486 - val_kl_loss: 0.7691 - lr: 0.0050
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8846 - reconstruction_loss: 0.7008 - kl_loss: 0.6608 - val_total_loss: 0.9624 - val_reconstruction_loss: 0.7272 - val_kl_loss: 0.8711 - lr: 0.0050
# Epoch 18/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8765 - reconstruction_loss: 0.6968 - kl_loss: 0.6590 - val_total_loss: 0.7860 - val_reconstruction_loss: 0.5923 - val_kl_loss: 0.7175 - lr: 0.0050
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8823 - reconstruction_loss: 0.7047 - kl_loss: 0.6339 - val_total_loss: 0.8245 - val_reconstruction_loss: 0.6126 - val_kl_loss: 0.7848 - lr: 0.0050
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8734 - reconstruction_loss: 0.6948 - kl_loss: 0.6542 - val_total_loss: 0.7184 - val_reconstruction_loss: 0.5312 - val_kl_loss: 0.6933 - lr: 0.0050
# Epoch 21/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8893 - reconstruction_loss: 0.7005 - kl_loss: 0.6471 - val_total_loss: 0.9050 - val_reconstruction_loss: 0.6894 - val_kl_loss: 0.7985 - lr: 0.0050
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8739 - reconstruction_loss: 0.7020 - kl_loss: 0.6287 - val_total_loss: 0.8496 - val_reconstruction_loss: 0.6181 - val_kl_loss: 0.8576 - lr: 0.0050
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8742 - reconstruction_loss: 0.6989 - kl_loss: 0.6398 - val_total_loss: 0.8716 - val_reconstruction_loss: 0.7173 - val_kl_loss: 0.5715 - lr: 0.0050
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8758 - reconstruction_loss: 0.7023 - kl_loss: 0.6602 - val_total_loss: 0.8334 - val_reconstruction_loss: 0.6187 - val_kl_loss: 0.7953 - lr: 0.0050
# Epoch 25/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8763 - reconstruction_loss: 0.6971 - kl_loss: 0.6656 - val_total_loss: 0.8398 - val_reconstruction_loss: 0.6170 - val_kl_loss: 0.8252 - lr: 0.0050
# Epoch 26/30
# 202/210 [===========================>..] - ETA: 0s - loss: 0.8685 - reconstruction_loss: 0.6950 - kl_loss: 0.6518
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8687 - reconstruction_loss: 0.6973 - kl_loss: 0.6580 - val_total_loss: 0.9874 - val_reconstruction_loss: 0.7909 - val_kl_loss: 0.7278 - lr: 0.0050
# Epoch 27/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8702 - reconstruction_loss: 0.6811 - kl_loss: 0.6818 - val_total_loss: 0.7895 - val_reconstruction_loss: 0.5601 - val_kl_loss: 0.8493 - lr: 0.0025
# Epoch 28/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8574 - reconstruction_loss: 0.6801 - kl_loss: 0.6841 - val_total_loss: 0.9275 - val_reconstruction_loss: 0.6902 - val_kl_loss: 0.8787 - lr: 0.0025
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8537 - reconstruction_loss: 0.6736 - kl_loss: 0.6982 - val_total_loss: 1.0059 - val_reconstruction_loss: 0.7878 - val_kl_loss: 0.8078 - lr: 0.0025
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8651 - reconstruction_loss: 0.6749 - kl_loss: 0.7064 - val_total_loss: 0.8033 - val_reconstruction_loss: 0.5582 - val_kl_loss: 0.9076 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8421 - reconstruction_loss: 0.6471 - kl_loss: 0.7223
# [0.8421235084533691, 0.6471117734909058, 0.7222657799720764]
# Learning rate:  0.005
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8798 - reconstruction_loss: 0.6869 - kl_loss: 0.6651 - val_total_loss: 0.8935 - val_reconstruction_loss: 0.6882 - val_kl_loss: 0.7603 - lr: 0.0050
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8540 - reconstruction_loss: 0.6823 - kl_loss: 0.6749 - val_total_loss: 0.9952 - val_reconstruction_loss: 0.7740 - val_kl_loss: 0.8193 - lr: 0.0050
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8532 - reconstruction_loss: 0.6790 - kl_loss: 0.6756 - val_total_loss: 0.8011 - val_reconstruction_loss: 0.6013 - val_kl_loss: 0.7399 - lr: 0.0050
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8838 - reconstruction_loss: 0.6779 - kl_loss: 0.7012 - val_total_loss: 0.7362 - val_reconstruction_loss: 0.5313 - val_kl_loss: 0.7587 - lr: 0.0050
# Epoch 5/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8741 - reconstruction_loss: 0.6764 - kl_loss: 0.6822 - val_total_loss: 0.8639 - val_reconstruction_loss: 0.6363 - val_kl_loss: 0.8429 - lr: 0.0050
# Epoch 6/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8536 - reconstruction_loss: 0.6747 - kl_loss: 0.6778 - val_total_loss: 0.8722 - val_reconstruction_loss: 0.6375 - val_kl_loss: 0.8692 - lr: 0.0050
# Epoch 7/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8548 - reconstruction_loss: 0.6732 - kl_loss: 0.6976 - val_total_loss: 0.8400 - val_reconstruction_loss: 0.6071 - val_kl_loss: 0.8628 - lr: 0.0050
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8648 - reconstruction_loss: 0.6773 - kl_loss: 0.6895 - val_total_loss: 0.9748 - val_reconstruction_loss: 0.7872 - val_kl_loss: 0.6946 - lr: 0.0050
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8713 - reconstruction_loss: 0.6822 - kl_loss: 0.6762 - val_total_loss: 0.8711 - val_reconstruction_loss: 0.6209 - val_kl_loss: 0.9267 - lr: 0.0050
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8750 - reconstruction_loss: 0.6810 - kl_loss: 0.6803 - val_total_loss: 0.8982 - val_reconstruction_loss: 0.6903 - val_kl_loss: 0.7700 - lr: 0.0050
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8615 - reconstruction_loss: 0.6754 - kl_loss: 0.6956 - val_total_loss: 0.9153 - val_reconstruction_loss: 0.6777 - val_kl_loss: 0.8801 - lr: 0.0050
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8680 - reconstruction_loss: 0.6721 - kl_loss: 0.6989 - val_total_loss: 0.9144 - val_reconstruction_loss: 0.6829 - val_kl_loss: 0.8575 - lr: 0.0050
# Epoch 13/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8553 - reconstruction_loss: 0.6750 - kl_loss: 0.6882 - val_total_loss: 0.9373 - val_reconstruction_loss: 0.7269 - val_kl_loss: 0.7794 - lr: 0.0050
# Epoch 14/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8630 - reconstruction_loss: 0.6739 - kl_loss: 0.6925 - val_total_loss: 0.9263 - val_reconstruction_loss: 0.7057 - val_kl_loss: 0.8173 - lr: 0.0050
# Epoch 15/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8663 - reconstruction_loss: 0.6737 - kl_loss: 0.6829 - val_total_loss: 0.9426 - val_reconstruction_loss: 0.7373 - val_kl_loss: 0.7604 - lr: 0.0050
# Epoch 16/30
# 102/105 [============================>.] - ETA: 0s - loss: 0.8511 - reconstruction_loss: 0.6750 - kl_loss: 0.6821
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8514 - reconstruction_loss: 0.6734 - kl_loss: 0.6824 - val_total_loss: 0.7755 - val_reconstruction_loss: 0.5489 - val_kl_loss: 0.8393 - lr: 0.0050
# Epoch 17/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8610 - reconstruction_loss: 0.6662 - kl_loss: 0.6913 - val_total_loss: 0.8018 - val_reconstruction_loss: 0.5748 - val_kl_loss: 0.8407 - lr: 0.0025
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8568 - reconstruction_loss: 0.6635 - kl_loss: 0.7145 - val_total_loss: 0.8027 - val_reconstruction_loss: 0.5660 - val_kl_loss: 0.8765 - lr: 0.0025
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8537 - reconstruction_loss: 0.6652 - kl_loss: 0.7074 - val_total_loss: 0.8208 - val_reconstruction_loss: 0.5972 - val_kl_loss: 0.8278 - lr: 0.0025
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8623 - reconstruction_loss: 0.6632 - kl_loss: 0.7282 - val_total_loss: 0.8647 - val_reconstruction_loss: 0.6166 - val_kl_loss: 0.9187 - lr: 0.0025
# Epoch 21/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8642 - reconstruction_loss: 0.6601 - kl_loss: 0.7228 - val_total_loss: 0.9291 - val_reconstruction_loss: 0.7071 - val_kl_loss: 0.8221 - lr: 0.0025
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8628 - reconstruction_loss: 0.6642 - kl_loss: 0.7093 - val_total_loss: 0.8679 - val_reconstruction_loss: 0.6532 - val_kl_loss: 0.7955 - lr: 0.0025
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8499 - reconstruction_loss: 0.6632 - kl_loss: 0.6885 - val_total_loss: 0.8280 - val_reconstruction_loss: 0.5948 - val_kl_loss: 0.8640 - lr: 0.0025
# Epoch 24/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8652 - reconstruction_loss: 0.6603 - kl_loss: 0.7219 - val_total_loss: 0.7796 - val_reconstruction_loss: 0.5266 - val_kl_loss: 0.9369 - lr: 0.0025
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8499 - reconstruction_loss: 0.6606 - kl_loss: 0.7175 - val_total_loss: 0.7943 - val_reconstruction_loss: 0.5659 - val_kl_loss: 0.8461 - lr: 0.0025
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8530 - reconstruction_loss: 0.6634 - kl_loss: 0.7148 - val_total_loss: 0.9746 - val_reconstruction_loss: 0.7398 - val_kl_loss: 0.8695 - lr: 0.0025
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8622 - reconstruction_loss: 0.6652 - kl_loss: 0.7388 - val_total_loss: 0.8769 - val_reconstruction_loss: 0.6363 - val_kl_loss: 0.8913 - lr: 0.0025
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8530 - reconstruction_loss: 0.6602 - kl_loss: 0.7076 - val_total_loss: 0.8386 - val_reconstruction_loss: 0.6104 - val_kl_loss: 0.8453 - lr: 0.0025
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8570 - reconstruction_loss: 0.6608 - kl_loss: 0.7234 - val_total_loss: 0.8802 - val_reconstruction_loss: 0.6634 - val_kl_loss: 0.8031 - lr: 0.0025
# Epoch 30/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8513 - reconstruction_loss: 0.6607 - kl_loss: 0.7018 - val_total_loss: 0.9376 - val_reconstruction_loss: 0.6929 - val_kl_loss: 0.9062 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8877 - reconstruction_loss: 0.6719 - kl_loss: 0.7993
# [0.8876805901527405, 0.6718605160713196, 0.7993335127830505]
# Learning rate:  0.005
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 2s 18ms/step - loss: 0.8803 - reconstruction_loss: 0.6818 - kl_loss: 0.7038 - val_total_loss: 0.8110 - val_reconstruction_loss: 0.5997 - val_kl_loss: 0.7828 - lr: 0.0050
# Epoch 2/30
# 53/53 [==============================] - 1s 13ms/step - loss: 0.8554 - reconstruction_loss: 0.6655 - kl_loss: 0.7122 - val_total_loss: 0.8753 - val_reconstruction_loss: 0.6678 - val_kl_loss: 0.7685 - lr: 0.0050
# Epoch 3/30
# 53/53 [==============================] - 1s 13ms/step - loss: 0.8565 - reconstruction_loss: 0.6664 - kl_loss: 0.7061 - val_total_loss: 0.8139 - val_reconstruction_loss: 0.6045 - val_kl_loss: 0.7757 - lr: 0.0050
# Epoch 4/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8518 - reconstruction_loss: 0.6674 - kl_loss: 0.6980 - val_total_loss: 0.7164 - val_reconstruction_loss: 0.4622 - val_kl_loss: 0.9414 - lr: 0.0050
# Epoch 5/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8756 - reconstruction_loss: 0.6642 - kl_loss: 0.7325 - val_total_loss: 0.8196 - val_reconstruction_loss: 0.5816 - val_kl_loss: 0.8815 - lr: 0.0050
# Epoch 6/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8379 - reconstruction_loss: 0.6623 - kl_loss: 0.6995 - val_total_loss: 0.7878 - val_reconstruction_loss: 0.5496 - val_kl_loss: 0.8822 - lr: 0.0050
# Epoch 7/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8550 - reconstruction_loss: 0.6639 - kl_loss: 0.7152 - val_total_loss: 0.8905 - val_reconstruction_loss: 0.6804 - val_kl_loss: 0.7784 - lr: 0.0050
# Epoch 8/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8615 - reconstruction_loss: 0.6679 - kl_loss: 0.6997 - val_total_loss: 0.9381 - val_reconstruction_loss: 0.6700 - val_kl_loss: 0.9929 - lr: 0.0050
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8542 - reconstruction_loss: 0.6554 - kl_loss: 0.7248 - val_total_loss: 0.9673 - val_reconstruction_loss: 0.7269 - val_kl_loss: 0.8901 - lr: 0.0050
# Epoch 10/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8517 - reconstruction_loss: 0.6625 - kl_loss: 0.7011 - val_total_loss: 0.9485 - val_reconstruction_loss: 0.7257 - val_kl_loss: 0.8251 - lr: 0.0050
# Epoch 11/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8717 - reconstruction_loss: 0.6632 - kl_loss: 0.7302 - val_total_loss: 0.8589 - val_reconstruction_loss: 0.6111 - val_kl_loss: 0.9178 - lr: 0.0050
# Epoch 12/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8587 - reconstruction_loss: 0.6557 - kl_loss: 0.7303 - val_total_loss: 0.7317 - val_reconstruction_loss: 0.5294 - val_kl_loss: 0.7490 - lr: 0.0050
# Epoch 13/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8709 - reconstruction_loss: 0.6677 - kl_loss: 0.7058 - val_total_loss: 0.8157 - val_reconstruction_loss: 0.5506 - val_kl_loss: 0.9818 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8513 - reconstruction_loss: 0.6688 - kl_loss: 0.6982 - val_total_loss: 0.8573 - val_reconstruction_loss: 0.6043 - val_kl_loss: 0.9371 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8532 - reconstruction_loss: 0.6683 - kl_loss: 0.6865 - val_total_loss: 0.8545 - val_reconstruction_loss: 0.6236 - val_kl_loss: 0.8554 - lr: 0.0050
# Epoch 16/30
# 51/53 [===========================>..] - ETA: 0s - loss: 0.8548 - reconstruction_loss: 0.6625 - kl_loss: 0.7194
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8548 - reconstruction_loss: 0.6604 - kl_loss: 0.7177 - val_total_loss: 1.0111 - val_reconstruction_loss: 0.7884 - val_kl_loss: 0.8248 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8616 - reconstruction_loss: 0.6672 - kl_loss: 0.7174 - val_total_loss: 1.0029 - val_reconstruction_loss: 0.7701 - val_kl_loss: 0.8623 - lr: 0.0025
# Epoch 18/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8466 - reconstruction_loss: 0.6605 - kl_loss: 0.7338 - val_total_loss: 0.7898 - val_reconstruction_loss: 0.5479 - val_kl_loss: 0.8958 - lr: 0.0025
# Epoch 19/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8411 - reconstruction_loss: 0.6568 - kl_loss: 0.7113 - val_total_loss: 0.8046 - val_reconstruction_loss: 0.5763 - val_kl_loss: 0.8455 - lr: 0.0025
# Epoch 20/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8540 - reconstruction_loss: 0.6581 - kl_loss: 0.7214 - val_total_loss: 0.9036 - val_reconstruction_loss: 0.6776 - val_kl_loss: 0.8369 - lr: 0.0025
# Epoch 21/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8563 - reconstruction_loss: 0.6562 - kl_loss: 0.7197 - val_total_loss: 0.7816 - val_reconstruction_loss: 0.5572 - val_kl_loss: 0.8311 - lr: 0.0025
# Epoch 22/30
# ...
# Epoch 26/30
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8516 - reconstruction_loss: 0.6861 - kl_loss: 0.6544 - val_total_loss: 0.8508 - val_reconstruction_loss: 0.6266 - val_kl_loss: 0.8304 - lr: 0.0100
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8539 - reconstruction_loss: 0.6786 - kl_loss: 0.6748 - val_total_loss: 0.9186 - val_reconstruction_loss: 0.7061 - val_kl_loss: 0.7870 - lr: 0.0100
# Epoch 28/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8672 - reconstruction_loss: 0.6899 - kl_loss: 0.6725 - val_total_loss: 0.8412 - val_reconstruction_loss: 0.6275 - val_kl_loss: 0.7914 - lr: 0.0100
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8597 - reconstruction_loss: 0.6894 - kl_loss: 0.6554 - val_total_loss: 0.8815 - val_reconstruction_loss: 0.6315 - val_kl_loss: 0.9259 - lr: 0.0100
# Epoch 30/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8730 - reconstruction_loss: 0.6841 - kl_loss: 0.6771 - val_total_loss: 0.7981 - val_reconstruction_loss: 0.5969 - val_kl_loss: 0.7452 - lr: 0.0100
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7882 - reconstruction_loss: 0.6071 - kl_loss: 0.6707
# [0.7881722450256348, 0.6070707440376282, 0.670746386051178]
# Learning rate:  0.01
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 19ms/step - loss: 0.9053 - reconstruction_loss: 0.7019 - kl_loss: 0.6600 - val_total_loss: 0.8065 - val_reconstruction_loss: 0.5764 - val_kl_loss: 0.8521 - lr: 0.0100
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8690 - reconstruction_loss: 0.6759 - kl_loss: 0.6857 - val_total_loss: 0.8458 - val_reconstruction_loss: 0.6000 - val_kl_loss: 0.9102 - lr: 0.0100
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8677 - reconstruction_loss: 0.6727 - kl_loss: 0.6834 - val_total_loss: 0.8617 - val_reconstruction_loss: 0.6300 - val_kl_loss: 0.8581 - lr: 0.0100
# Epoch 4/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8669 - reconstruction_loss: 0.6766 - kl_loss: 0.6817 - val_total_loss: 0.7250 - val_reconstruction_loss: 0.4933 - val_kl_loss: 0.8582 - lr: 0.0100
# Epoch 5/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8660 - reconstruction_loss: 0.6788 - kl_loss: 0.6665 - val_total_loss: 0.8973 - val_reconstruction_loss: 0.6951 - val_kl_loss: 0.7491 - lr: 0.0100
# Epoch 6/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8477 - reconstruction_loss: 0.6816 - kl_loss: 0.6623 - val_total_loss: 0.7996 - val_reconstruction_loss: 0.5852 - val_kl_loss: 0.7940 - lr: 0.0100
# Epoch 7/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8694 - reconstruction_loss: 0.6795 - kl_loss: 0.6693 - val_total_loss: 0.6877 - val_reconstruction_loss: 0.4604 - val_kl_loss: 0.8417 - lr: 0.0100
# Epoch 8/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8684 - reconstruction_loss: 0.6719 - kl_loss: 0.7111 - val_total_loss: 0.7431 - val_reconstruction_loss: 0.4975 - val_kl_loss: 0.9098 - lr: 0.0100
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8516 - reconstruction_loss: 0.6828 - kl_loss: 0.6720 - val_total_loss: 0.8610 - val_reconstruction_loss: 0.6357 - val_kl_loss: 0.8343 - lr: 0.0100
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8575 - reconstruction_loss: 0.6709 - kl_loss: 0.7034 - val_total_loss: 0.9254 - val_reconstruction_loss: 0.6784 - val_kl_loss: 0.9149 - lr: 0.0100
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8734 - reconstruction_loss: 0.6674 - kl_loss: 0.7098 - val_total_loss: 0.7842 - val_reconstruction_loss: 0.5413 - val_kl_loss: 0.8996 - lr: 0.0100
# Epoch 12/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8737 - reconstruction_loss: 0.6751 - kl_loss: 0.6869 - val_total_loss: 0.9059 - val_reconstruction_loss: 0.6765 - val_kl_loss: 0.8496 - lr: 0.0100
# Epoch 13/30
# 49/53 [==========================>...] - ETA: 0s - loss: 0.8662 - reconstruction_loss: 0.6774 - kl_loss: 0.6982
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8662 - reconstruction_loss: 0.6773 - kl_loss: 0.6955 - val_total_loss: 0.9218 - val_reconstruction_loss: 0.6945 - val_kl_loss: 0.8418 - lr: 0.0100
# Epoch 14/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8683 - reconstruction_loss: 0.6758 - kl_loss: 0.6890 - val_total_loss: 0.8779 - val_reconstruction_loss: 0.6276 - val_kl_loss: 0.9269 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8621 - reconstruction_loss: 0.6635 - kl_loss: 0.7049 - val_total_loss: 0.9404 - val_reconstruction_loss: 0.7076 - val_kl_loss: 0.8625 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8577 - reconstruction_loss: 0.6654 - kl_loss: 0.6973 - val_total_loss: 0.8632 - val_reconstruction_loss: 0.6468 - val_kl_loss: 0.8016 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8621 - reconstruction_loss: 0.6752 - kl_loss: 0.6961 - val_total_loss: 0.8125 - val_reconstruction_loss: 0.5553 - val_kl_loss: 0.9527 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8562 - reconstruction_loss: 0.6637 - kl_loss: 0.7103 - val_total_loss: 0.7050 - val_reconstruction_loss: 0.4773 - val_kl_loss: 0.8432 - lr: 0.0050
# Epoch 19/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8644 - reconstruction_loss: 0.6700 - kl_loss: 0.6950 - val_total_loss: 0.9567 - val_reconstruction_loss: 0.7214 - val_kl_loss: 0.8715 - lr: 0.0050
# Epoch 20/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8514 - reconstruction_loss: 0.6651 - kl_loss: 0.7036 - val_total_loss: 0.8669 - val_reconstruction_loss: 0.6227 - val_kl_loss: 0.9047 - lr: 0.0050
# Epoch 21/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8541 - reconstruction_loss: 0.6680 - kl_loss: 0.6956 - val_total_loss: 0.8655 - val_reconstruction_loss: 0.6238 - val_kl_loss: 0.8949 - lr: 0.0050
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8635 - reconstruction_loss: 0.6662 - kl_loss: 0.7079 - val_total_loss: 0.9724 - val_reconstruction_loss: 0.7408 - val_kl_loss: 0.8579 - lr: 0.0050
# Epoch 23/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8507 - reconstruction_loss: 0.6727 - kl_loss: 0.6729 - val_total_loss: 0.9954 - val_reconstruction_loss: 0.7611 - val_kl_loss: 0.8678 - lr: 0.0050
# Epoch 24/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8527 - reconstruction_loss: 0.6667 - kl_loss: 0.7038 - val_total_loss: 0.7347 - val_reconstruction_loss: 0.4961 - val_kl_loss: 0.8836 - lr: 0.0050
# Epoch 25/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8421 - reconstruction_loss: 0.6730 - kl_loss: 0.6901 - val_total_loss: 0.9216 - val_reconstruction_loss: 0.6768 - val_kl_loss: 0.9067 - lr: 0.0050
# Epoch 26/30
# 49/53 [==========================>...] - ETA: 0s - loss: 0.8528 - reconstruction_loss: 0.6616 - kl_loss: 0.7143
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8530 - reconstruction_loss: 0.6630 - kl_loss: 0.7137 - val_total_loss: 0.8263 - val_reconstruction_loss: 0.6035 - val_kl_loss: 0.8253 - lr: 0.0050
# Epoch 27/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8572 - reconstruction_loss: 0.6634 - kl_loss: 0.7023 - val_total_loss: 0.8370 - val_reconstruction_loss: 0.5904 - val_kl_loss: 0.9132 - lr: 0.0025
# Epoch 28/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8499 - reconstruction_loss: 0.6648 - kl_loss: 0.6941 - val_total_loss: 0.9775 - val_reconstruction_loss: 0.7404 - val_kl_loss: 0.8779 - lr: 0.0025
# Epoch 29/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8452 - reconstruction_loss: 0.6644 - kl_loss: 0.6911 - val_total_loss: 0.8888 - val_reconstruction_loss: 0.6586 - val_kl_loss: 0.8523 - lr: 0.0025
# Epoch 30/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8490 - reconstruction_loss: 0.6644 - kl_loss: 0.6907 - val_total_loss: 0.8805 - val_reconstruction_loss: 0.6520 - val_kl_loss: 0.8464 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7764 - reconstruction_loss: 0.5870 - kl_loss: 0.7014
# [0.7764155268669128, 0.5870372653007507, 0.7014009952545166]
# Learning rate:  0.01
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 34ms/step - loss: 0.9244 - reconstruction_loss: 0.7245 - kl_loss: 0.6606 - val_total_loss: 0.8887 - val_reconstruction_loss: 0.6750 - val_kl_loss: 0.7915 - lr: 0.0100
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8471 - reconstruction_loss: 0.6752 - kl_loss: 0.6799 - val_total_loss: 0.8389 - val_reconstruction_loss: 0.6402 - val_kl_loss: 0.7358 - lr: 0.0100
# Epoch 3/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8520 - reconstruction_loss: 0.6688 - kl_loss: 0.6876 - val_total_loss: 0.8889 - val_reconstruction_loss: 0.6824 - val_kl_loss: 0.7648 - lr: 0.0100
# Epoch 4/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8565 - reconstruction_loss: 0.6754 - kl_loss: 0.6894 - val_total_loss: 0.8540 - val_reconstruction_loss: 0.6476 - val_kl_loss: 0.7646 - lr: 0.0100
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8600 - reconstruction_loss: 0.6743 - kl_loss: 0.6987 - val_total_loss: 0.8647 - val_reconstruction_loss: 0.6660 - val_kl_loss: 0.7362 - lr: 0.0100
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8680 - reconstruction_loss: 0.6680 - kl_loss: 0.6941 - val_total_loss: 0.8981 - val_reconstruction_loss: 0.6858 - val_kl_loss: 0.7860 - lr: 0.0100
# Epoch 7/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8544 - reconstruction_loss: 0.6719 - kl_loss: 0.6834 - val_total_loss: 0.8894 - val_reconstruction_loss: 0.6810 - val_kl_loss: 0.7720 - lr: 0.0100
# Epoch 8/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8533 - reconstruction_loss: 0.6667 - kl_loss: 0.6904 - val_total_loss: 0.8561 - val_reconstruction_loss: 0.6548 - val_kl_loss: 0.7455 - lr: 0.0100
# Epoch 9/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8616 - reconstruction_loss: 0.6680 - kl_loss: 0.6853 - val_total_loss: 0.8513 - val_reconstruction_loss: 0.6412 - val_kl_loss: 0.7783 - lr: 0.0100
# Epoch 10/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8588 - reconstruction_loss: 0.6670 - kl_loss: 0.7001 - val_total_loss: 0.8544 - val_reconstruction_loss: 0.6525 - val_kl_loss: 0.7478 - lr: 0.0100
# Epoch 11/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8487 - reconstruction_loss: 0.6690 - kl_loss: 0.6679 - val_total_loss: 0.8769 - val_reconstruction_loss: 0.6642 - val_kl_loss: 0.7878 - lr: 0.0100
# Epoch 12/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8665 - reconstruction_loss: 0.6632 - kl_loss: 0.7070 - val_total_loss: 0.8966 - val_reconstruction_loss: 0.6871 - val_kl_loss: 0.7758 - lr: 0.0100
# Epoch 13/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8542 - reconstruction_loss: 0.6725 - kl_loss: 0.6911 - val_total_loss: 0.8661 - val_reconstruction_loss: 0.6470 - val_kl_loss: 0.8116 - lr: 0.0100
# Epoch 14/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8497 - reconstruction_loss: 0.6678 - kl_loss: 0.6909 - val_total_loss: 0.8743 - val_reconstruction_loss: 0.6791 - val_kl_loss: 0.7227 - lr: 0.0100
# Epoch 15/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8631 - reconstruction_loss: 0.6685 - kl_loss: 0.6816 - val_total_loss: 0.8520 - val_reconstruction_loss: 0.6249 - val_kl_loss: 0.8410 - lr: 0.0100
# Epoch 16/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8602 - reconstruction_loss: 0.6711 - kl_loss: 0.6776 - val_total_loss: 0.8518 - val_reconstruction_loss: 0.6282 - val_kl_loss: 0.8282 - lr: 0.0100
# Epoch 17/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8613 - reconstruction_loss: 0.6665 - kl_loss: 0.7040 - val_total_loss: 0.8930 - val_reconstruction_loss: 0.7016 - val_kl_loss: 0.7089 - lr: 0.0100
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8588 - reconstruction_loss: 0.6692 - kl_loss: 0.6899 - val_total_loss: 0.8956 - val_reconstruction_loss: 0.6864 - val_kl_loss: 0.7750 - lr: 0.0100
# Epoch 19/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8537 - reconstruction_loss: 0.6744 - kl_loss: 0.7037 - val_total_loss: 0.9305 - val_reconstruction_loss: 0.7195 - val_kl_loss: 0.7812 - lr: 0.0100
# Epoch 20/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8596 - reconstruction_loss: 0.6716 - kl_loss: 0.6938 - val_total_loss: 0.8428 - val_reconstruction_loss: 0.6394 - val_kl_loss: 0.7531 - lr: 0.0100
# Epoch 21/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8621 - reconstruction_loss: 0.6743 - kl_loss: 0.6688
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8617 - reconstruction_loss: 0.6756 - kl_loss: 0.6838 - val_total_loss: 0.8677 - val_reconstruction_loss: 0.6605 - val_kl_loss: 0.7675 - lr: 0.0100
# Epoch 22/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8683 - reconstruction_loss: 0.6668 - kl_loss: 0.6789 - val_total_loss: 0.8743 - val_reconstruction_loss: 0.6638 - val_kl_loss: 0.7795 - lr: 0.0050
# Epoch 23/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8381 - reconstruction_loss: 0.6646 - kl_loss: 0.6817 - val_total_loss: 0.8242 - val_reconstruction_loss: 0.6243 - val_kl_loss: 0.7405 - lr: 0.0050
# Epoch 24/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8548 - reconstruction_loss: 0.6649 - kl_loss: 0.6960 - val_total_loss: 0.8772 - val_reconstruction_loss: 0.6792 - val_kl_loss: 0.7334 - lr: 0.0050
# Epoch 25/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8545 - reconstruction_loss: 0.6656 - kl_loss: 0.7195 - val_total_loss: 0.8312 - val_reconstruction_loss: 0.6288 - val_kl_loss: 0.7499 - lr: 0.0050
# Epoch 26/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8612 - reconstruction_loss: 0.6631 - kl_loss: 0.6883 - val_total_loss: 0.8500 - val_reconstruction_loss: 0.6495 - val_kl_loss: 0.7429 - lr: 0.0050
# Epoch 27/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8490 - reconstruction_loss: 0.6679 - kl_loss: 0.6888 - val_total_loss: 0.8550 - val_reconstruction_loss: 0.6358 - val_kl_loss: 0.8118 - lr: 0.0050
# Epoch 28/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8613 - reconstruction_loss: 0.6622 - kl_loss: 0.7166 - val_total_loss: 0.8562 - val_reconstruction_loss: 0.6448 - val_kl_loss: 0.7829 - lr: 0.0050
# Epoch 29/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8579 - reconstruction_loss: 0.6636 - kl_loss: 0.7155 - val_total_loss: 0.8705 - val_reconstruction_loss: 0.6603 - val_kl_loss: 0.7787 - lr: 0.0050
# Epoch 30/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8615 - reconstruction_loss: 0.6661 - kl_loss: 0.7090 - val_total_loss: 0.8155 - val_reconstruction_loss: 0.5983 - val_kl_loss: 0.8043 - lr: 0.0050
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.0924 - reconstruction_loss: 0.8860 - kl_loss: 0.7644
# [1.092384696006775, 0.8859993815422058, 0.7643899917602539]
# Best Hyperparameters: {'learn_rate': 0.008, 'batch_size': 64}
# Best Score: [0.6887722611427307, 0.48396357893943787, 0.7585505843162537]

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)

vae.fit(x_train, batch_size=bs, epochs=100, validation_split = 0.2,
        callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 105/105 [==============================] - 3s 14ms/step - loss: 0.8943 - reconstruction_loss: 0.6898 - kl_loss: 0.6695 - val_total_loss: 0.8940 - val_reconstruction_loss: 0.6785 - val_kl_loss: 0.7979 - lr: 0.0080
# Epoch 2/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8547 - reconstruction_loss: 0.6769 - kl_loss: 0.6926 - val_total_loss: 0.9916 - val_reconstruction_loss: 0.7543 - val_kl_loss: 0.8791 - lr: 0.0080
# Epoch 3/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8703 - reconstruction_loss: 0.6730 - kl_loss: 0.6899 - val_total_loss: 0.8605 - val_reconstruction_loss: 0.6461 - val_kl_loss: 0.7938 - lr: 0.0080
# Epoch 4/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8738 - reconstruction_loss: 0.6797 - kl_loss: 0.7194 - val_total_loss: 0.7735 - val_reconstruction_loss: 0.5580 - val_kl_loss: 0.7982 - lr: 0.0080
# Epoch 5/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8606 - reconstruction_loss: 0.6789 - kl_loss: 0.6836 - val_total_loss: 0.7748 - val_reconstruction_loss: 0.5607 - val_kl_loss: 0.7931 - lr: 0.0080
# Epoch 6/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8612 - reconstruction_loss: 0.6744 - kl_loss: 0.6901 - val_total_loss: 0.8182 - val_reconstruction_loss: 0.5849 - val_kl_loss: 0.8640 - lr: 0.0080
# Epoch 7/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8806 - reconstruction_loss: 0.6795 - kl_loss: 0.6728 - val_total_loss: 0.7278 - val_reconstruction_loss: 0.5135 - val_kl_loss: 0.7939 - lr: 0.0080
# Epoch 8/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8617 - reconstruction_loss: 0.6735 - kl_loss: 0.7000 - val_total_loss: 0.8938 - val_reconstruction_loss: 0.6842 - val_kl_loss: 0.7762 - lr: 0.0080
# Epoch 9/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8519 - reconstruction_loss: 0.6792 - kl_loss: 0.6847 - val_total_loss: 0.7210 - val_reconstruction_loss: 0.4878 - val_kl_loss: 0.8634 - lr: 0.0080
# Epoch 10/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8606 - reconstruction_loss: 0.6741 - kl_loss: 0.6876 - val_total_loss: 0.7565 - val_reconstruction_loss: 0.5494 - val_kl_loss: 0.7669 - lr: 0.0080
# Epoch 11/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8694 - reconstruction_loss: 0.6805 - kl_loss: 0.6921 - val_total_loss: 0.9320 - val_reconstruction_loss: 0.6813 - val_kl_loss: 0.9284 - lr: 0.0080
# Epoch 12/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8633 - reconstruction_loss: 0.6833 - kl_loss: 0.6849 - val_total_loss: 0.8511 - val_reconstruction_loss: 0.6360 - val_kl_loss: 0.7966 - lr: 0.0080
# Epoch 13/100
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8667 - reconstruction_loss: 0.6758 - kl_loss: 0.6900
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8664 - reconstruction_loss: 0.6766 - kl_loss: 0.6900 - val_total_loss: 0.8689 - val_reconstruction_loss: 0.6470 - val_kl_loss: 0.8219 - lr: 0.0080
# Epoch 14/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8570 - reconstruction_loss: 0.6713 - kl_loss: 0.6987 - val_total_loss: 0.8505 - val_reconstruction_loss: 0.6107 - val_kl_loss: 0.8880 - lr: 0.0040
# Epoch 15/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8768 - reconstruction_loss: 0.6663 - kl_loss: 0.7069 - val_total_loss: 0.9159 - val_reconstruction_loss: 0.6751 - val_kl_loss: 0.8920 - lr: 0.0040
# Epoch 16/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8540 - reconstruction_loss: 0.6680 - kl_loss: 0.7139 - val_total_loss: 0.9018 - val_reconstruction_loss: 0.6671 - val_kl_loss: 0.8690 - lr: 0.0040
# Epoch 17/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8711 - reconstruction_loss: 0.6655 - kl_loss: 0.7036 - val_total_loss: 0.9270 - val_reconstruction_loss: 0.6950 - val_kl_loss: 0.8593 - lr: 0.0040
# Epoch 18/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8668 - reconstruction_loss: 0.6669 - kl_loss: 0.6904 - val_total_loss: 0.9620 - val_reconstruction_loss: 0.7439 - val_kl_loss: 0.8080 - lr: 0.0040
# Epoch 19/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8487 - reconstruction_loss: 0.6743 - kl_loss: 0.6747 - val_total_loss: 0.8608 - val_reconstruction_loss: 0.6302 - val_kl_loss: 0.8542 - lr: 0.0040
# Epoch 20/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8669 - reconstruction_loss: 0.6646 - kl_loss: 0.7223 - val_total_loss: 0.8281 - val_reconstruction_loss: 0.5975 - val_kl_loss: 0.8542 - lr: 0.0040
# Epoch 21/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8519 - reconstruction_loss: 0.6645 - kl_loss: 0.7142 - val_total_loss: 0.7236 - val_reconstruction_loss: 0.4946 - val_kl_loss: 0.8482 - lr: 0.0040
# Epoch 22/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8620 - reconstruction_loss: 0.6643 - kl_loss: 0.7165 - val_total_loss: 0.7407 - val_reconstruction_loss: 0.5152 - val_kl_loss: 0.8351 - lr: 0.0040
# Epoch 23/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8628 - reconstruction_loss: 0.6682 - kl_loss: 0.6968 - val_total_loss: 0.9281 - val_reconstruction_loss: 0.7177 - val_kl_loss: 0.7794 - lr: 0.0040
# Epoch 24/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8487 - reconstruction_loss: 0.6634 - kl_loss: 0.7099 - val_total_loss: 0.9948 - val_reconstruction_loss: 0.7593 - val_kl_loss: 0.8722 - lr: 0.0040
# Epoch 25/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8584 - reconstruction_loss: 0.6692 - kl_loss: 0.6895 - val_total_loss: 1.0412 - val_reconstruction_loss: 0.8144 - val_kl_loss: 0.8403 - lr: 0.0040
# Epoch 26/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8609 - reconstruction_loss: 0.6667 - kl_loss: 0.7146 - val_total_loss: 0.8374 - val_reconstruction_loss: 0.6099 - val_kl_loss: 0.8425 - lr: 0.0040
# Epoch 27/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8477 - reconstruction_loss: 0.6668 - kl_loss: 0.6858 - val_total_loss: 0.7681 - val_reconstruction_loss: 0.5497 - val_kl_loss: 0.8086 - lr: 0.0040
# Epoch 28/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8455 - reconstruction_loss: 0.6736 - kl_loss: 0.6813 - val_total_loss: 0.8136 - val_reconstruction_loss: 0.5714 - val_kl_loss: 0.8972 - lr: 0.0040
# Epoch 29/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8622 - reconstruction_loss: 0.6646 - kl_loss: 0.7260 - val_total_loss: 0.8807 - val_reconstruction_loss: 0.6504 - val_kl_loss: 0.8530 - lr: 0.0040
# Epoch 30/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8521 - reconstruction_loss: 0.6675 - kl_loss: 0.6947 - val_total_loss: 0.8249 - val_reconstruction_loss: 0.5765 - val_kl_loss: 0.9200 - lr: 0.0040
# Epoch 31/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8600 - reconstruction_loss: 0.6683 - kl_loss: 0.6912 - val_total_loss: 0.7717 - val_reconstruction_loss: 0.5551 - val_kl_loss: 0.8020 - lr: 0.0040
# Epoch 32/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8579 - reconstruction_loss: 0.6682 - kl_loss: 0.6989 - val_total_loss: 0.8884 - val_reconstruction_loss: 0.6599 - val_kl_loss: 0.8464 - lr: 0.0040
# Epoch 33/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8538 - reconstruction_loss: 0.6649 - kl_loss: 0.6956 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6604 - val_kl_loss: 0.7943 - lr: 0.0040
# Epoch 34/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8507 - reconstruction_loss: 0.6666 - kl_loss: 0.6951 - val_total_loss: 0.9436 - val_reconstruction_loss: 0.7201 - val_kl_loss: 0.8275 - lr: 0.0040
# Epoch 35/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8467 - reconstruction_loss: 0.6652 - kl_loss: 0.6917 - val_total_loss: 0.8969 - val_reconstruction_loss: 0.6694 - val_kl_loss: 0.8425 - lr: 0.0040
# Epoch 36/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8524 - reconstruction_loss: 0.6662 - kl_loss: 0.6839 - val_total_loss: 0.7935 - val_reconstruction_loss: 0.5611 - val_kl_loss: 0.8609 - lr: 0.0040
# Epoch 37/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8496 - reconstruction_loss: 0.6698 - kl_loss: 0.6967 - val_total_loss: 0.8027 - val_reconstruction_loss: 0.5507 - val_kl_loss: 0.9333 - lr: 0.0040
# Epoch 38/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8636 - reconstruction_loss: 0.6621 - kl_loss: 0.7154 - val_total_loss: 0.8433 - val_reconstruction_loss: 0.6103 - val_kl_loss: 0.8628 - lr: 0.0040
# Epoch 39/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8580 - reconstruction_loss: 0.6652 - kl_loss: 0.7195 - val_total_loss: 0.8616 - val_reconstruction_loss: 0.6159 - val_kl_loss: 0.9100 - lr: 0.0040
# Epoch 40/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8560 - reconstruction_loss: 0.6658 - kl_loss: 0.7063 - val_total_loss: 0.8778 - val_reconstruction_loss: 0.6238 - val_kl_loss: 0.9411 - lr: 0.0040
# Epoch 41/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8602 - reconstruction_loss: 0.6653 - kl_loss: 0.7277 - val_total_loss: 0.7613 - val_reconstruction_loss: 0.5222 - val_kl_loss: 0.8853 - lr: 0.0040
# Epoch 42/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8595 - reconstruction_loss: 0.6613 - kl_loss: 0.7287 - val_total_loss: 0.9067 - val_reconstruction_loss: 0.6606 - val_kl_loss: 0.9115 - lr: 0.0040
# Epoch 43/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8599 - reconstruction_loss: 0.6687 - kl_loss: 0.7048 - val_total_loss: 0.9547 - val_reconstruction_loss: 0.7247 - val_kl_loss: 0.8517 - lr: 0.0040
# Epoch 44/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8634 - reconstruction_loss: 0.6673 - kl_loss: 0.7107 - val_total_loss: 0.8375 - val_reconstruction_loss: 0.6097 - val_kl_loss: 0.8436 - lr: 0.0040
# Epoch 45/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8545 - reconstruction_loss: 0.6648 - kl_loss: 0.6930 - val_total_loss: 0.9240 - val_reconstruction_loss: 0.7037 - val_kl_loss: 0.8158 - lr: 0.0040
# Epoch 46/100
#  99/105 [===========================>..] - ETA: 0s - loss: 0.8644 - reconstruction_loss: 0.6731 - kl_loss: 0.7027
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8641 - reconstruction_loss: 0.6697 - kl_loss: 0.7007 - val_total_loss: 0.9480 - val_reconstruction_loss: 0.7162 - val_kl_loss: 0.8584 - lr: 0.0040
# Epoch 47/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8520 - reconstruction_loss: 0.6599 - kl_loss: 0.7151 - val_total_loss: 0.8634 - val_reconstruction_loss: 0.6379 - val_kl_loss: 0.8352 - lr: 0.0020
# Epoch 48/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8428 - reconstruction_loss: 0.6606 - kl_loss: 0.7070 - val_total_loss: 0.8478 - val_reconstruction_loss: 0.5979 - val_kl_loss: 0.9255 - lr: 0.0020
# Epoch 49/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8547 - reconstruction_loss: 0.6594 - kl_loss: 0.7150 - val_total_loss: 0.8392 - val_reconstruction_loss: 0.5953 - val_kl_loss: 0.9034 - lr: 0.0020
# Epoch 50/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8543 - reconstruction_loss: 0.6620 - kl_loss: 0.7194 - val_total_loss: 0.7682 - val_reconstruction_loss: 0.5344 - val_kl_loss: 0.8658 - lr: 0.0020
# Epoch 51/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8490 - reconstruction_loss: 0.6573 - kl_loss: 0.7051 - val_total_loss: 0.8938 - val_reconstruction_loss: 0.6672 - val_kl_loss: 0.8392 - lr: 0.0020
# Epoch 52/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8585 - reconstruction_loss: 0.6583 - kl_loss: 0.7225 - val_total_loss: 0.9040 - val_reconstruction_loss: 0.6663 - val_kl_loss: 0.8801 - lr: 0.0020
# Epoch 53/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8530 - reconstruction_loss: 0.6588 - kl_loss: 0.7173 - val_total_loss: 0.8991 - val_reconstruction_loss: 0.6754 - val_kl_loss: 0.8287 - lr: 0.0020
# Epoch 54/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8493 - reconstruction_loss: 0.6597 - kl_loss: 0.7095 - val_total_loss: 0.7346 - val_reconstruction_loss: 0.4897 - val_kl_loss: 0.9071 - lr: 0.0020
# Epoch 55/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8388 - reconstruction_loss: 0.6560 - kl_loss: 0.7126 - val_total_loss: 0.9097 - val_reconstruction_loss: 0.6794 - val_kl_loss: 0.8528 - lr: 0.0020
# Epoch 56/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8429 - reconstruction_loss: 0.6580 - kl_loss: 0.7061 - val_total_loss: 0.9132 - val_reconstruction_loss: 0.6834 - val_kl_loss: 0.8510 - lr: 0.0020
# Epoch 57/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8416 - reconstruction_loss: 0.6635 - kl_loss: 0.6974 - val_total_loss: 0.8362 - val_reconstruction_loss: 0.6107 - val_kl_loss: 0.8352 - lr: 0.0020
# Epoch 58/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8554 - reconstruction_loss: 0.6621 - kl_loss: 0.7121 - val_total_loss: 0.8773 - val_reconstruction_loss: 0.6443 - val_kl_loss: 0.8629 - lr: 0.0020
# Epoch 59/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8586 - reconstruction_loss: 0.6670 - kl_loss: 0.6969 - val_total_loss: 0.8138 - val_reconstruction_loss: 0.5892 - val_kl_loss: 0.8318 - lr: 0.0020
# Epoch 60/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8401 - reconstruction_loss: 0.6614 - kl_loss: 0.6885 - val_total_loss: 0.9149 - val_reconstruction_loss: 0.7020 - val_kl_loss: 0.7886 - lr: 0.0020
# Epoch 61/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8488 - reconstruction_loss: 0.6584 - kl_loss: 0.6993 - val_total_loss: 0.8371 - val_reconstruction_loss: 0.6148 - val_kl_loss: 0.8234 - lr: 0.0020
# Epoch 62/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8516 - reconstruction_loss: 0.6623 - kl_loss: 0.6960 - val_total_loss: 0.9131 - val_reconstruction_loss: 0.6906 - val_kl_loss: 0.8241 - lr: 0.0020
# Epoch 63/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8402 - reconstruction_loss: 0.6593 - kl_loss: 0.7025 - val_total_loss: 0.8793 - val_reconstruction_loss: 0.6474 - val_kl_loss: 0.8589 - lr: 0.0020
# Epoch 64/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8480 - reconstruction_loss: 0.6601 - kl_loss: 0.6998 - val_total_loss: 0.8694 - val_reconstruction_loss: 0.6348 - val_kl_loss: 0.8687 - lr: 0.0020
# Epoch 65/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8672 - reconstruction_loss: 0.6576 - kl_loss: 0.7153 - val_total_loss: 0.9522 - val_reconstruction_loss: 0.7305 - val_kl_loss: 0.8208 - lr: 0.0020
# Epoch 66/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8615 - reconstruction_loss: 0.6600 - kl_loss: 0.7005 - val_total_loss: 0.9056 - val_reconstruction_loss: 0.6779 - val_kl_loss: 0.8432 - lr: 0.0020
# Epoch 67/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8427 - reconstruction_loss: 0.6622 - kl_loss: 0.6965 - val_total_loss: 0.7858 - val_reconstruction_loss: 0.5474 - val_kl_loss: 0.8827 - lr: 0.0020
# Epoch 68/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8598 - reconstruction_loss: 0.6589 - kl_loss: 0.7234 - val_total_loss: 1.0438 - val_reconstruction_loss: 0.8065 - val_kl_loss: 0.8789 - lr: 0.0020
# Epoch 69/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8626 - reconstruction_loss: 0.6594 - kl_loss: 0.7228 - val_total_loss: 0.9184 - val_reconstruction_loss: 0.6578 - val_kl_loss: 0.9653 - lr: 0.0020
# Epoch 70/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8466 - reconstruction_loss: 0.6541 - kl_loss: 0.7210 - val_total_loss: 0.9462 - val_reconstruction_loss: 0.7030 - val_kl_loss: 0.9009 - lr: 0.0020
# Epoch 71/100
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8433 - reconstruction_loss: 0.6568 - kl_loss: 0.7191
# Epoch 71: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8437 - reconstruction_loss: 0.6572 - kl_loss: 0.7217 - val_total_loss: 0.8097 - val_reconstruction_loss: 0.5691 - val_kl_loss: 0.8911 - lr: 0.0020
# Epoch 72/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8421 - reconstruction_loss: 0.6579 - kl_loss: 0.6978 - val_total_loss: 0.7416 - val_reconstruction_loss: 0.5103 - val_kl_loss: 0.8566 - lr: 0.0010
# Epoch 73/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8380 - reconstruction_loss: 0.6591 - kl_loss: 0.7093 - val_total_loss: 0.8157 - val_reconstruction_loss: 0.5806 - val_kl_loss: 0.8706 - lr: 0.0010
# Epoch 74/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8457 - reconstruction_loss: 0.6616 - kl_loss: 0.7156 - val_total_loss: 0.7948 - val_reconstruction_loss: 0.5622 - val_kl_loss: 0.8614 - lr: 0.0010
# Epoch 75/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8447 - reconstruction_loss: 0.6559 - kl_loss: 0.7210 - val_total_loss: 0.8868 - val_reconstruction_loss: 0.6601 - val_kl_loss: 0.8398 - lr: 0.0010
# Epoch 76/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8408 - reconstruction_loss: 0.6620 - kl_loss: 0.7200 - val_total_loss: 0.8210 - val_reconstruction_loss: 0.5788 - val_kl_loss: 0.8969 - lr: 0.0010
# Epoch 77/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8540 - reconstruction_loss: 0.6561 - kl_loss: 0.7092 - val_total_loss: 0.8066 - val_reconstruction_loss: 0.5777 - val_kl_loss: 0.8480 - lr: 0.0010
# Epoch 78/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8369 - reconstruction_loss: 0.6546 - kl_loss: 0.7128 - val_total_loss: 0.8346 - val_reconstruction_loss: 0.5998 - val_kl_loss: 0.8694 - lr: 0.0010
# Epoch 79/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8548 - reconstruction_loss: 0.6573 - kl_loss: 0.7210 - val_total_loss: 0.8727 - val_reconstruction_loss: 0.6399 - val_kl_loss: 0.8620 - lr: 0.0010
# Epoch 80/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8519 - reconstruction_loss: 0.6567 - kl_loss: 0.7040 - val_total_loss: 0.9418 - val_reconstruction_loss: 0.7006 - val_kl_loss: 0.8934 - lr: 0.0010
# Epoch 81/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8503 - reconstruction_loss: 0.6586 - kl_loss: 0.7083 - val_total_loss: 0.8795 - val_reconstruction_loss: 0.6427 - val_kl_loss: 0.8770 - lr: 0.0010
# Epoch 82/100
#  98/105 [===========================>..] - ETA: 0s - loss: 0.8514 - reconstruction_loss: 0.6552 - kl_loss: 0.7104
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8511 - reconstruction_loss: 0.6558 - kl_loss: 0.7129 - val_total_loss: 0.9485 - val_reconstruction_loss: 0.7126 - val_kl_loss: 0.8737 - lr: 0.0010
# Epoch 83/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8544 - reconstruction_loss: 0.6544 - kl_loss: 0.7267 - val_total_loss: 0.7932 - val_reconstruction_loss: 0.5563 - val_kl_loss: 0.8775 - lr: 5.0000e-04
# Epoch 84/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8494 - reconstruction_loss: 0.6577 - kl_loss: 0.7146 - val_total_loss: 1.0429 - val_reconstruction_loss: 0.8040 - val_kl_loss: 0.8851 - lr: 5.0000e-04
# Epoch 85/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8562 - reconstruction_loss: 0.6568 - kl_loss: 0.7182 - val_total_loss: 0.9372 - val_reconstruction_loss: 0.7017 - val_kl_loss: 0.8724 - lr: 5.0000e-04
# Epoch 86/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8463 - reconstruction_loss: 0.6564 - kl_loss: 0.7129 - val_total_loss: 0.8374 - val_reconstruction_loss: 0.6058 - val_kl_loss: 0.8578 - lr: 5.0000e-04
# Epoch 87/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8295 - reconstruction_loss: 0.6572 - kl_loss: 0.7028 - val_total_loss: 0.8683 - val_reconstruction_loss: 0.6344 - val_kl_loss: 0.8665 - lr: 5.0000e-04
# Epoch 88/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8513 - reconstruction_loss: 0.6606 - kl_loss: 0.7101 - val_total_loss: 0.9339 - val_reconstruction_loss: 0.6958 - val_kl_loss: 0.8819 - lr: 5.0000e-04
# Epoch 89/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8351 - reconstruction_loss: 0.6569 - kl_loss: 0.7026 - val_total_loss: 1.0439 - val_reconstruction_loss: 0.8108 - val_kl_loss: 0.8633 - lr: 5.0000e-04
# Epoch 90/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8513 - reconstruction_loss: 0.6566 - kl_loss: 0.7140 - val_total_loss: 1.0390 - val_reconstruction_loss: 0.8039 - val_kl_loss: 0.8709 - lr: 5.0000e-04
# Epoch 91/100
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8399 - reconstruction_loss: 0.6577 - kl_loss: 0.7161 - val_total_loss: 0.8412 - val_reconstruction_loss: 0.6109 - val_kl_loss: 0.8530 - lr: 5.0000e-04
# Epoch 92/100
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8409 - reconstruction_loss: 0.6560 - kl_loss: 0.7142
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 72.
# 105/105 [==============================] - 1s 8ms/step - loss: 0.8413 - reconstruction_loss: 0.6575 - kl_loss: 0.7109 - val_total_loss: 0.8606 - val_reconstruction_loss: 0.6280 - val_kl_loss: 0.8614 - lr: 5.0000e-04
# Epoch 92: early stopping

# %%
_, _, z_input = encoder.predict(x_train)
reconstructed_z_input = vae.decoder.predict(z_input)
_, _, reconstructed_z_encoded = vae.encoder.predict(reconstructed_z_input)

_, _, z_test_input = encoder.predict(x_test)
reconstructed_z_test_input = vae.decoder.predict(z_test_input)
_, _, reconstructed_z_test_encoded = vae.encoder.predict(reconstructed_z_test_input)
# Out:
# 262/262 [==============================] - 0s 913us/step
# 262/262 [==============================] - 0s 1ms/step
# 262/262 [==============================] - 0s 898us/step
# 66/66 [==============================] - 0s 962us/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 962us/step

# %%
def plot_input_data(x_data, y_data):
    z_input = x_data
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za trening enkodirani u latentni prostor")
plot_input_data(z_input, y_train)

plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

# %%
def plot_input_and_reconstructed_data(x_input_data, x_reconstructed, y_input_data):
    z_input = x_input_data
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Reconstructed Data')
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.title("Podaci za testiranje i rekonstruirani podaci enkodirani u latentni prostor")
    plt.legend()
    plt.show()

plt.figure(figsize=(10, 6))
plot_input_and_reconstructed_data(z_test_input, reconstructed_z_test_encoded, y_test)

# %%
def plot_reconstructed_data(x_reconstructed, y_data):
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=f'Label {label}')
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirani podaci enkodirani u latentni prostor")
plot_reconstructed_data(reconstructed_z_test_encoded, y_test)

# %%
selected_indices = np.random.choice(len(x_test), 10, replace=False)

selected_peptides = x_test[selected_indices]

_, _, encoded_selected_peptides = vae.encoder.predict(selected_peptides)
reconstructed_peptides = vae.decoder.predict(encoded_selected_peptides)
_, _, encoded_reconstructed_peptides = vae.encoder.predict(reconstructed_peptides)


def plot_selected_data(x_data):
    z_input = x_data
    num_peptides = z_input.shape[0]
    unique_colors = plt.cm.tab20(np.linspace(0, 1, num_peptides))

    for i in range(num_peptides):
        plt.scatter(z_input[i, 0], z_input[i, 1], color=unique_colors[i], label=f'Peptide {i}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

    
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))


plt.figure(figsize=(10, 6))
plt.title("Slučajno izabrane izvorne točke u latentnom prostoru")
plot_selected_data(encoded_selected_peptides)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirane točke u latentnom prostoru")
plot_selected_data(encoded_reconstructed_peptides)


distances = []

for i in range(10):
    dist = euclidean_distance(encoded_selected_peptides[i], encoded_reconstructed_peptides[i])
        
    distances.append(dist)

print("Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke: \n", distances, "\n")
print("Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka: ", np.sum(distances)/10)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 0s/step
# Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke:
#  [2.370133, 1.4891131, 0.26502588, 0.25001997, 0.9617837, 1.290007, 0.9350733, 0.58391976, 1.2317334, 1.7596855]
#
# Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka:  1.1136494636535645

# %%
#NORMALIZIRANA UDALJENOST REKONSTRUKCIJE U LATENTNOM PROSTORU

min_values = np.min(z_test_input, axis=0)
max_values = np.max(z_test_input, axis=0)

latent_space_size = np.linalg.norm(max_values - min_values)

print(latent_space_size)

distances_x_test = []

for i in range(len(x_test)):
    dist = euclidean_distance(z_test_input[i], reconstructed_z_test_encoded[i])
        
    distances_x_test.append(dist)

print("Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka: ", 
      np.sum(distances_x_test)/latent_space_size/len(x_test))
# Out:
# 11.128653
# Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka:  0.10251389862702408

# %%
#PEARSONOV KOEFICIJENT KORELACIJE

from scipy.stats import spearmanr, kendalltau, pearsonr

print(pearsonr(x_test.flatten(), reconstructed_z_test_input.flatten()))
# Out:
# PearsonRResult(statistic=0.7916564323599347, pvalue=0.0)

# %%
#RMSE

mse = np.mean(np.square(x_test - reconstructed_z_test_input))
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.08689653642010638

# %%
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
  
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    alignments = pairwise2.align.globalxx(seq1, seq2)

    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    similarity = (score / max(len(seq1), len(seq2)))

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,101):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.39534884 0.18604651 0.34883721]
#  [0.1025641  0.         0.12820513 ... 0.13157895 0.125      0.05263158]
#  [0.20512821 0.28       0.23076923 ... 0.18421053 0.32       0.23684211]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.34210526 0.32432432 0.34210526]
#  [0.33333333 0.17777778 0.26666667 ... 0.33333333 0.22222222 0.33333333]
#  [0.07692308 0.25       0.15384615 ... 0.18421053 0.16666667 0.23684211]]
# [[0.27272727 0.18604651 0.27906977 ... 0.27906977 0.20930233 0.30232558]
#  [0.36363636 0.25581395 0.27906977 ... 0.3255814  0.1627907  0.18604651]
#  [0.25       0.17241379 0.26666667 ... 0.14285714 0.3        0.2       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.26190476 0.28571429 0.14285714]
#  [0.34090909 0.2972973  0.54054054 ... 0.28571429 0.24324324 0.2972973 ]
#  [0.09090909 0.13793103 0.06666667 ... 0.0952381  0.17647059 0.2       ]]

# %%
distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,101):
        dist_train = euclidean_distance(z_input[i], z_input[j])
        dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.22327691 0.47507972 0.15318015 ... 0.03795848 0.40554753 0.11764523]
#  [0.93748796 0.9936229  0.5168867  ... 0.8610952  0.46822435 0.8854347 ]
#  [0.28915015 0.14654729 0.50389576 ... 0.6232342  0.19657189 0.581149  ]
#  ...
#  [0.36759877 0.48097908 0.21707979 ... 0.4874217  0.09600076 0.52844536]
#  [0.3198411  0.53486586 0.239883   ... 0.         0.49870664 0.01872221]
#  [0.10924413 0.3748197  0.22625953 ... 0.15813354 0.3703054  0.17400114]]
# [[0.         0.5468578  0.49967256 ... 0.554418   0.09991054 0.26542708]
#  [0.9435051  0.51092213 0.4709452  ... 0.49880135 1.0000001  1.        ]
#  [0.52142155 0.48228157 0.13434425 ... 0.4813347  0.6420693  0.60107744]
#  ...
#  [0.29970038 0.4823385  0.18167491 ... 0.48578686 0.4507991  0.42677733]
#  [0.14899522 0.34369406 0.4003345  ... 0.35049227 0.34195852 0.492215  ]
#  [0.8986432  0.99999994 0.38471016 ... 1.0000001  0.8236556  0.49504784]]

# %%
correlation_train, p_value_train = spearmanr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = spearmanr(similarities_test.flatten(), distances_test.flatten())

print("Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = kendalltau(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = kendalltau(similarities_test.flatten(), distances_test.flatten())

print("Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)
# Out:
# Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.20259947140169615 -0.0964622445633118
# p-value: 4.992501072999934e-25 1.0603213427944898e-06
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2666415148414513 -0.12464585880602896
# p-value: 9.215158569145648e-43 2.6865301665228923e-10
#
# Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.13834675445844405 -0.06513548973584699
# p-value: 1.787929545852769e-25 9.236599559826124e-07
