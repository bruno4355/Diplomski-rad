# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

#Build the encoder
encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Build the decoder
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + 0.4 * kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + 0.4 * kl_loss

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d_5 (Conv1D)              (None, 88, 8)        32          ['input_3[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 44, 8)       0           ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_6[0][0]']
#
#  flatten_1 (Flatten)            (None, 352)          0           ['max_pooling1d_3[0][0]']
#
#  dense_3 (Dense)                (None, 128)          45184       ['flatten_1[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_3[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_3[0][0]']
#
#  sampling_1 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 128)               384
#
#  dense_5 (Dense)             (None, 704)               90816
#
#  reshape_1 (Reshape)         (None, 88, 8)             0
#
#  conv1d_7 (Conv1D)           (None, 88, 16)            400
#
#  up_sampling1d_2 (UpSampling  (None, 176, 16)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 176, 8)            392
#
#  up_sampling1d_3 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 352, 1)            25
#
#  cropping1d_1 (Cropping1D)   (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(
                                    features, labels, test_size=0.2, random_state=42)

x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]

x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
learn_rate = [0.001, 0.005, 0.008, 0.01]
batch_size = [32, 64, 128, 256]

param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

for lr in learn_rate:
    for bs in batch_size:
        print("Learning rate: ", lr)
        print("Batch size: ", bs)
        
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))
        
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=1, min_lr=1e-6)
        early_stop = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)
        
        vae.fit(x_train, batch_size=bs, epochs=30, validation_split = 0.2, 
                callbacks=[reduce_lr, early_stop])

        score = vae.evaluate(x_test)
        print(score)

        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Learning rate:  0.001
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 8ms/step - loss: 1.3796 - reconstruction_loss: 1.1592 - kl_loss: 0.0245 - val_total_loss: 1.0063 - val_reconstruction_loss: 0.9927 - val_kl_loss: 0.0455 - lr: 0.0010
# Epoch 2/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9675 - reconstruction_loss: 0.9426 - kl_loss: 0.0655 - val_total_loss: 1.0504 - val_reconstruction_loss: 0.9994 - val_kl_loss: 0.1698 - lr: 0.0010
# Epoch 3/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9360 - reconstruction_loss: 0.8700 - kl_loss: 0.2130 - val_total_loss: 0.9059 - val_reconstruction_loss: 0.7802 - val_kl_loss: 0.4189 - lr: 0.0010
# Epoch 4/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9091 - reconstruction_loss: 0.8310 - kl_loss: 0.3005 - val_total_loss: 0.8901 - val_reconstruction_loss: 0.7689 - val_kl_loss: 0.4042 - lr: 0.0010
# Epoch 5/30
# 210/210 [==============================] - 2s 8ms/step - loss: 0.8997 - reconstruction_loss: 0.8133 - kl_loss: 0.3315 - val_total_loss: 0.9213 - val_reconstruction_loss: 0.7705 - val_kl_loss: 0.5025 - lr: 0.0010
# Epoch 6/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.9188 - reconstruction_loss: 0.8080 - kl_loss: 0.3431 - val_total_loss: 0.9313 - val_reconstruction_loss: 0.7763 - val_kl_loss: 0.5164 - lr: 0.0010
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8955 - reconstruction_loss: 0.7950 - kl_loss: 0.3676 - val_total_loss: 0.8245 - val_reconstruction_loss: 0.6623 - val_kl_loss: 0.5405 - lr: 0.0010
# Epoch 8/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9068 - reconstruction_loss: 0.7889 - kl_loss: 0.3774 - val_total_loss: 0.9131 - val_reconstruction_loss: 0.7543 - val_kl_loss: 0.5293 - lr: 0.0010
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8925 - reconstruction_loss: 0.7852 - kl_loss: 0.3838 - val_total_loss: 0.8205 - val_reconstruction_loss: 0.6808 - val_kl_loss: 0.4655 - lr: 0.0010
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9014 - reconstruction_loss: 0.7856 - kl_loss: 0.3827 - val_total_loss: 0.8918 - val_reconstruction_loss: 0.7499 - val_kl_loss: 0.4730 - lr: 0.0010
# Epoch 11/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8848 - reconstruction_loss: 0.7829 - kl_loss: 0.3902 - val_total_loss: 0.8377 - val_reconstruction_loss: 0.6831 - val_kl_loss: 0.5151 - lr: 0.0010
# Epoch 12/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8865 - reconstruction_loss: 0.7781 - kl_loss: 0.3935 - val_total_loss: 0.9209 - val_reconstruction_loss: 0.7717 - val_kl_loss: 0.4974 - lr: 0.0010
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8924 - reconstruction_loss: 0.7764 - kl_loss: 0.3947 - val_total_loss: 0.8399 - val_reconstruction_loss: 0.6758 - val_kl_loss: 0.5469 - lr: 0.0010
# Epoch 14/30
# 210/210 [==============================] - 2s 8ms/step - loss: 0.8721 - reconstruction_loss: 0.7784 - kl_loss: 0.3922 - val_total_loss: 0.8442 - val_reconstruction_loss: 0.6846 - val_kl_loss: 0.5321 - lr: 0.0010
# Epoch 15/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9037 - reconstruction_loss: 0.7745 - kl_loss: 0.4108 - val_total_loss: 0.9362 - val_reconstruction_loss: 0.7513 - val_kl_loss: 0.6165 - lr: 0.0010
# Epoch 16/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8946 - reconstruction_loss: 0.7735 - kl_loss: 0.4042 - val_total_loss: 0.8124 - val_reconstruction_loss: 0.6569 - val_kl_loss: 0.5184 - lr: 0.0010
# Epoch 17/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9011 - reconstruction_loss: 0.7698 - kl_loss: 0.4101 - val_total_loss: 0.8323 - val_reconstruction_loss: 0.6722 - val_kl_loss: 0.5338 - lr: 0.0010
# Epoch 18/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8934 - reconstruction_loss: 0.7732 - kl_loss: 0.4075 - val_total_loss: 0.8730 - val_reconstruction_loss: 0.7129 - val_kl_loss: 0.5338 - lr: 0.0010
# Epoch 19/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8893 - reconstruction_loss: 0.7698 - kl_loss: 0.3984 - val_total_loss: 0.9079 - val_reconstruction_loss: 0.7579 - val_kl_loss: 0.5000 - lr: 0.0010
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8796 - reconstruction_loss: 0.7742 - kl_loss: 0.3939 - val_total_loss: 0.9673 - val_reconstruction_loss: 0.8065 - val_kl_loss: 0.5360 - lr: 0.0010
# Epoch 21/30
# 210/210 [==============================] - 2s 8ms/step - loss: 0.8971 - reconstruction_loss: 0.7703 - kl_loss: 0.3995 - val_total_loss: 0.8309 - val_reconstruction_loss: 0.6686 - val_kl_loss: 0.5410 - lr: 0.0010
# Epoch 22/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8918 - reconstruction_loss: 0.7672 - kl_loss: 0.4164 - val_total_loss: 0.9340 - val_reconstruction_loss: 0.7783 - val_kl_loss: 0.5190 - lr: 0.0010
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8874 - reconstruction_loss: 0.7740 - kl_loss: 0.4046 - val_total_loss: 0.9350 - val_reconstruction_loss: 0.7704 - val_kl_loss: 0.5486 - lr: 0.0010
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8871 - reconstruction_loss: 0.7649 - kl_loss: 0.4082 - val_total_loss: 0.8247 - val_reconstruction_loss: 0.6698 - val_kl_loss: 0.5166 - lr: 0.0010
# Epoch 25/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9001 - reconstruction_loss: 0.7702 - kl_loss: 0.4028 - val_total_loss: 0.9174 - val_reconstruction_loss: 0.7573 - val_kl_loss: 0.5338 - lr: 0.0010
# Epoch 26/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8947 - reconstruction_loss: 0.7688 - kl_loss: 0.4105 - val_total_loss: 0.9902 - val_reconstruction_loss: 0.8465 - val_kl_loss: 0.4792 - lr: 0.0010
# Epoch 27/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9041 - reconstruction_loss: 0.7686 - kl_loss: 0.4230 - val_total_loss: 0.8254 - val_reconstruction_loss: 0.6721 - val_kl_loss: 0.5109 - lr: 0.0010
# Epoch 28/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8886 - reconstruction_loss: 0.7706 - kl_loss: 0.4170 - val_total_loss: 0.8272 - val_reconstruction_loss: 0.6649 - val_kl_loss: 0.5412 - lr: 0.0010
# Epoch 29/30
# 210/210 [==============================] - ETA: 0s - loss: 0.8805 - reconstruction_loss: 0.7649 - kl_loss: 0.4140
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8806 - reconstruction_loss: 0.7649 - kl_loss: 0.4140 - val_total_loss: 0.8866 - val_reconstruction_loss: 0.7502 - val_kl_loss: 0.4547 - lr: 0.0010
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8815 - reconstruction_loss: 0.7615 - kl_loss: 0.4160 - val_total_loss: 0.8256 - val_reconstruction_loss: 0.6758 - val_kl_loss: 0.4994 - lr: 5.0000e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9733 - reconstruction_loss: 0.8300 - kl_loss: 0.4774
# Learning rate:  0.001
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8911 - reconstruction_loss: 0.7627 - kl_loss: 0.4120 - val_total_loss: 0.8574 - val_reconstruction_loss: 0.6990 - val_kl_loss: 0.5279 - lr: 0.0010
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8922 - reconstruction_loss: 0.7664 - kl_loss: 0.4143 - val_total_loss: 0.8313 - val_reconstruction_loss: 0.6587 - val_kl_loss: 0.5753 - lr: 0.0010
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8629 - reconstruction_loss: 0.7631 - kl_loss: 0.4169 - val_total_loss: 0.7914 - val_reconstruction_loss: 0.6396 - val_kl_loss: 0.5060 - lr: 0.0010
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8991 - reconstruction_loss: 0.7675 - kl_loss: 0.4137 - val_total_loss: 0.9697 - val_reconstruction_loss: 0.8118 - val_kl_loss: 0.5264 - lr: 0.0010
# Epoch 5/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8928 - reconstruction_loss: 0.7647 - kl_loss: 0.4177 - val_total_loss: 0.8605 - val_reconstruction_loss: 0.7121 - val_kl_loss: 0.4944 - lr: 0.0010
# Epoch 6/30
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8953 - reconstruction_loss: 0.7643 - kl_loss: 0.4109
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8949 - reconstruction_loss: 0.7630 - kl_loss: 0.4107 - val_total_loss: 0.9299 - val_reconstruction_loss: 0.7685 - val_kl_loss: 0.5379 - lr: 0.0010
# Epoch 7/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8852 - reconstruction_loss: 0.7613 - kl_loss: 0.4160 - val_total_loss: 0.8794 - val_reconstruction_loss: 0.7247 - val_kl_loss: 0.5156 - lr: 5.0000e-04
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8867 - reconstruction_loss: 0.7549 - kl_loss: 0.4232 - val_total_loss: 0.9536 - val_reconstruction_loss: 0.7950 - val_kl_loss: 0.5285 - lr: 5.0000e-04
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8934 - reconstruction_loss: 0.7567 - kl_loss: 0.4241 - val_total_loss: 0.9045 - val_reconstruction_loss: 0.7433 - val_kl_loss: 0.5374 - lr: 5.0000e-04
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8818 - reconstruction_loss: 0.7556 - kl_loss: 0.4209 - val_total_loss: 0.9070 - val_reconstruction_loss: 0.7450 - val_kl_loss: 0.5399 - lr: 5.0000e-04
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8734 - reconstruction_loss: 0.7539 - kl_loss: 0.4148 - val_total_loss: 0.9020 - val_reconstruction_loss: 0.7420 - val_kl_loss: 0.5331 - lr: 5.0000e-04
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8943 - reconstruction_loss: 0.7553 - kl_loss: 0.4254 - val_total_loss: 0.8035 - val_reconstruction_loss: 0.6481 - val_kl_loss: 0.5182 - lr: 5.0000e-04
# Epoch 13/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8761 - reconstruction_loss: 0.7600 - kl_loss: 0.4216 - val_total_loss: 0.8704 - val_reconstruction_loss: 0.7001 - val_kl_loss: 0.5678 - lr: 5.0000e-04
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8937 - reconstruction_loss: 0.7597 - kl_loss: 0.4220 - val_total_loss: 0.8742 - val_reconstruction_loss: 0.7156 - val_kl_loss: 0.5288 - lr: 5.0000e-04
# Epoch 15/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8857 - reconstruction_loss: 0.7578 - kl_loss: 0.4386 - val_total_loss: 0.8292 - val_reconstruction_loss: 0.6554 - val_kl_loss: 0.5795 - lr: 5.0000e-04
# Epoch 16/30
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8921 - reconstruction_loss: 0.7567 - kl_loss: 0.4247
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8916 - reconstruction_loss: 0.7546 - kl_loss: 0.4231 - val_total_loss: 0.8860 - val_reconstruction_loss: 0.7248 - val_kl_loss: 0.5374 - lr: 5.0000e-04
# Epoch 17/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8741 - reconstruction_loss: 0.7531 - kl_loss: 0.4196 - val_total_loss: 0.8136 - val_reconstruction_loss: 0.6570 - val_kl_loss: 0.5221 - lr: 2.5000e-04
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8941 - reconstruction_loss: 0.7556 - kl_loss: 0.4354 - val_total_loss: 1.0022 - val_reconstruction_loss: 0.8367 - val_kl_loss: 0.5519 - lr: 2.5000e-04
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8777 - reconstruction_loss: 0.7550 - kl_loss: 0.4304 - val_total_loss: 0.9736 - val_reconstruction_loss: 0.8124 - val_kl_loss: 0.5371 - lr: 2.5000e-04
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8885 - reconstruction_loss: 0.7534 - kl_loss: 0.4234 - val_total_loss: 0.9235 - val_reconstruction_loss: 0.7616 - val_kl_loss: 0.5397 - lr: 2.5000e-04
# Epoch 21/30
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8751 - reconstruction_loss: 0.7572 - kl_loss: 0.4293
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 11.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8757 - reconstruction_loss: 0.7571 - kl_loss: 0.4304 - val_total_loss: 0.8503 - val_reconstruction_loss: 0.6769 - val_kl_loss: 0.5781 - lr: 2.5000e-04
# Epoch 21: early stopping
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.7703 - reconstruction_loss: 0.6196 - kl_loss: 0.5023
# Learning rate:  0.001
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 24ms/step - loss: 0.8855 - reconstruction_loss: 0.7605 - kl_loss: 0.4204 - val_total_loss: 0.8833 - val_reconstruction_loss: 0.7155 - val_kl_loss: 0.5595 - lr: 0.0010
# Epoch 2/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8882 - reconstruction_loss: 0.7590 - kl_loss: 0.4307 - val_total_loss: 0.9313 - val_reconstruction_loss: 0.7625 - val_kl_loss: 0.5627 - lr: 0.0010
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8913 - reconstruction_loss: 0.7602 - kl_loss: 0.4332 - val_total_loss: 0.8562 - val_reconstruction_loss: 0.6881 - val_kl_loss: 0.5604 - lr: 0.0010
# Epoch 4/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8828 - reconstruction_loss: 0.7576 - kl_loss: 0.4183 - val_total_loss: 0.7663 - val_reconstruction_loss: 0.6119 - val_kl_loss: 0.5146 - lr: 0.0010
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8860 - reconstruction_loss: 0.7557 - kl_loss: 0.4324 - val_total_loss: 0.8475 - val_reconstruction_loss: 0.6968 - val_kl_loss: 0.5022 - lr: 0.0010
# Epoch 6/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8796 - reconstruction_loss: 0.7563 - kl_loss: 0.4306 - val_total_loss: 0.8286 - val_reconstruction_loss: 0.6602 - val_kl_loss: 0.5613 - lr: 0.0010
# Epoch 7/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8663 - reconstruction_loss: 0.7532 - kl_loss: 0.4398 - val_total_loss: 0.8857 - val_reconstruction_loss: 0.7314 - val_kl_loss: 0.5145 - lr: 0.0010
# Epoch 8/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8812 - reconstruction_loss: 0.7554 - kl_loss: 0.4199 - val_total_loss: 0.8763 - val_reconstruction_loss: 0.7213 - val_kl_loss: 0.5166 - lr: 0.0010
# Epoch 9/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8841 - reconstruction_loss: 0.7535 - kl_loss: 0.4213 - val_total_loss: 0.8448 - val_reconstruction_loss: 0.6809 - val_kl_loss: 0.5463 - lr: 0.0010
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8804 - reconstruction_loss: 0.7522 - kl_loss: 0.4305 - val_total_loss: 0.8067 - val_reconstruction_loss: 0.6470 - val_kl_loss: 0.5322 - lr: 0.0010
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8822 - reconstruction_loss: 0.7542 - kl_loss: 0.4424 - val_total_loss: 0.8063 - val_reconstruction_loss: 0.6571 - val_kl_loss: 0.4973 - lr: 0.0010
# Epoch 12/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8767 - reconstruction_loss: 0.7560 - kl_loss: 0.4346 - val_total_loss: 0.8879 - val_reconstruction_loss: 0.7106 - val_kl_loss: 0.5910 - lr: 0.0010
# Epoch 13/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8943 - reconstruction_loss: 0.7509 - kl_loss: 0.4383 - val_total_loss: 0.7865 - val_reconstruction_loss: 0.6159 - val_kl_loss: 0.5687 - lr: 0.0010
# Epoch 14/30
# 49/53 [==========================>...] - ETA: 0s - loss: 0.8788 - reconstruction_loss: 0.7516 - kl_loss: 0.4349
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8792 - reconstruction_loss: 0.7527 - kl_loss: 0.4353 - val_total_loss: 0.8832 - val_reconstruction_loss: 0.7195 - val_kl_loss: 0.5455 - lr: 0.0010
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8774 - reconstruction_loss: 0.7529 - kl_loss: 0.4275 - val_total_loss: 1.0652 - val_reconstruction_loss: 0.9023 - val_kl_loss: 0.5431 - lr: 5.0000e-04
# Epoch 16/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8855 - reconstruction_loss: 0.7524 - kl_loss: 0.4307 - val_total_loss: 0.9099 - val_reconstruction_loss: 0.7450 - val_kl_loss: 0.5496 - lr: 5.0000e-04
# Epoch 17/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8896 - reconstruction_loss: 0.7471 - kl_loss: 0.4490 - val_total_loss: 0.9373 - val_reconstruction_loss: 0.7818 - val_kl_loss: 0.5182 - lr: 5.0000e-04
# Epoch 18/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8835 - reconstruction_loss: 0.7493 - kl_loss: 0.4374 - val_total_loss: 0.8098 - val_reconstruction_loss: 0.6494 - val_kl_loss: 0.5348 - lr: 5.0000e-04
# Epoch 19/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8916 - reconstruction_loss: 0.7520 - kl_loss: 0.4376
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Restoring model weights from the end of the best epoch: 9.
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8912 - reconstruction_loss: 0.7499 - kl_loss: 0.4362 - val_total_loss: 0.8222 - val_reconstruction_loss: 0.6588 - val_kl_loss: 0.5445 - lr: 5.0000e-04
# Epoch 19: early stopping
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.0750 - reconstruction_loss: 0.9193 - kl_loss: 0.5190
# Learning rate:  0.001
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 2s 35ms/step - loss: 0.8895 - reconstruction_loss: 0.7530 - kl_loss: 0.4307 - val_total_loss: 0.9298 - val_reconstruction_loss: 0.7795 - val_kl_loss: 0.5008 - lr: 0.0010
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8847 - reconstruction_loss: 0.7611 - kl_loss: 0.4470 - val_total_loss: 0.9161 - val_reconstruction_loss: 0.7595 - val_kl_loss: 0.5221 - lr: 0.0010
# Epoch 3/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8798 - reconstruction_loss: 0.7607 - kl_loss: 0.4140 - val_total_loss: 0.9207 - val_reconstruction_loss: 0.7789 - val_kl_loss: 0.4727 - lr: 0.0010
# Epoch 4/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8833 - reconstruction_loss: 0.7548 - kl_loss: 0.4419 - val_total_loss: 0.9140 - val_reconstruction_loss: 0.7697 - val_kl_loss: 0.4809 - lr: 0.0010
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8749 - reconstruction_loss: 0.7499 - kl_loss: 0.4252 - val_total_loss: 0.9119 - val_reconstruction_loss: 0.7687 - val_kl_loss: 0.4776 - lr: 0.0010
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8741 - reconstruction_loss: 0.7589 - kl_loss: 0.4366 - val_total_loss: 0.8914 - val_reconstruction_loss: 0.7359 - val_kl_loss: 0.5182 - lr: 0.0010
# Epoch 7/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8826 - reconstruction_loss: 0.7598 - kl_loss: 0.4230 - val_total_loss: 0.8979 - val_reconstruction_loss: 0.7375 - val_kl_loss: 0.5345 - lr: 0.0010
# Epoch 8/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8728 - reconstruction_loss: 0.7541 - kl_loss: 0.4344 - val_total_loss: 0.9076 - val_reconstruction_loss: 0.7448 - val_kl_loss: 0.5425 - lr: 0.0010
# Epoch 9/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8923 - reconstruction_loss: 0.7477 - kl_loss: 0.4365 - val_total_loss: 0.8803 - val_reconstruction_loss: 0.7242 - val_kl_loss: 0.5205 - lr: 0.0010
# Epoch 10/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8893 - reconstruction_loss: 0.7481 - kl_loss: 0.4392
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8891 - reconstruction_loss: 0.7590 - kl_loss: 0.4405 - val_total_loss: 0.8977 - val_reconstruction_loss: 0.7396 - val_kl_loss: 0.5269 - lr: 0.0010
# Epoch 11/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8803 - reconstruction_loss: 0.7466 - kl_loss: 0.4304 - val_total_loss: 0.8785 - val_reconstruction_loss: 0.7214 - val_kl_loss: 0.5239 - lr: 5.0000e-04
# Epoch 12/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8886 - reconstruction_loss: 0.7466 - kl_loss: 0.4414 - val_total_loss: 0.8825 - val_reconstruction_loss: 0.7288 - val_kl_loss: 0.5123 - lr: 5.0000e-04
# Epoch 13/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8891 - reconstruction_loss: 0.7507 - kl_loss: 0.4345 - val_total_loss: 0.8821 - val_reconstruction_loss: 0.7329 - val_kl_loss: 0.4973 - lr: 5.0000e-04
# Epoch 14/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8784 - reconstruction_loss: 0.7562 - kl_loss: 0.4296 - val_total_loss: 0.9263 - val_reconstruction_loss: 0.7776 - val_kl_loss: 0.4958 - lr: 5.0000e-04
# Epoch 15/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8651 - reconstruction_loss: 0.7418 - kl_loss: 0.4423 - val_total_loss: 0.8716 - val_reconstruction_loss: 0.7154 - val_kl_loss: 0.5209 - lr: 5.0000e-04
# Epoch 16/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8860 - reconstruction_loss: 0.7538 - kl_loss: 0.4479 - val_total_loss: 0.8907 - val_reconstruction_loss: 0.7333 - val_kl_loss: 0.5247 - lr: 5.0000e-04
# Epoch 17/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8820 - reconstruction_loss: 0.7464 - kl_loss: 0.4388 - val_total_loss: 0.9213 - val_reconstruction_loss: 0.7642 - val_kl_loss: 0.5237 - lr: 5.0000e-04
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8893 - reconstruction_loss: 0.7478 - kl_loss: 0.4550 - val_total_loss: 0.8949 - val_reconstruction_loss: 0.7408 - val_kl_loss: 0.5137 - lr: 5.0000e-04
# Epoch 19/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8793 - reconstruction_loss: 0.7566 - kl_loss: 0.4378 - val_total_loss: 0.9055 - val_reconstruction_loss: 0.7562 - val_kl_loss: 0.4977 - lr: 5.0000e-04
# Epoch 20/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8886 - reconstruction_loss: 0.7476 - kl_loss: 0.4407
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8876 - reconstruction_loss: 0.7477 - kl_loss: 0.4380 - val_total_loss: 0.8913 - val_reconstruction_loss: 0.7401 - val_kl_loss: 0.5038 - lr: 5.0000e-04
# Epoch 21/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8721 - reconstruction_loss: 0.7521 - kl_loss: 0.4374 - val_total_loss: 0.9030 - val_reconstruction_loss: 0.7481 - val_kl_loss: 0.5162 - lr: 2.5000e-04
# Epoch 22/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8713 - reconstruction_loss: 0.7533 - kl_loss: 0.4396 - val_total_loss: 0.8742 - val_reconstruction_loss: 0.7181 - val_kl_loss: 0.5203 - lr: 2.5000e-04
# Epoch 23/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8872 - reconstruction_loss: 0.7457 - kl_loss: 0.4403 - val_total_loss: 0.8941 - val_reconstruction_loss: 0.7359 - val_kl_loss: 0.5273 - lr: 2.5000e-04
# Epoch 24/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8705 - reconstruction_loss: 0.7497 - kl_loss: 0.4533 - val_total_loss: 0.8983 - val_reconstruction_loss: 0.7426 - val_kl_loss: 0.5191 - lr: 2.5000e-04
# Epoch 25/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8798 - reconstruction_loss: 0.7469 - kl_loss: 0.4334
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 15.
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8796 - reconstruction_loss: 0.7456 - kl_loss: 0.4423 - val_total_loss: 0.8857 - val_reconstruction_loss: 0.7318 - val_kl_loss: 0.5130 - lr: 2.5000e-04
# Epoch 25: early stopping
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8457 - reconstruction_loss: 0.6866 - kl_loss: 0.5303
# Learning rate:  0.005
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 8ms/step - loss: 0.9209 - reconstruction_loss: 0.7944 - kl_loss: 0.3947 - val_total_loss: 0.9998 - val_reconstruction_loss: 0.8744 - val_kl_loss: 0.4180 - lr: 0.0050
# Epoch 2/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9327 - reconstruction_loss: 0.7905 - kl_loss: 0.3795 - val_total_loss: 0.9117 - val_reconstruction_loss: 0.7665 - val_kl_loss: 0.4842 - lr: 0.0050
# Epoch 3/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9091 - reconstruction_loss: 0.7912 - kl_loss: 0.3727 - val_total_loss: 0.8749 - val_reconstruction_loss: 0.7111 - val_kl_loss: 0.5460 - lr: 0.0050
# Epoch 4/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.9117 - reconstruction_loss: 0.7880 - kl_loss: 0.3840 - val_total_loss: 1.0091 - val_reconstruction_loss: 0.8899 - val_kl_loss: 0.3973 - lr: 0.0050
# Epoch 5/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9052 - reconstruction_loss: 0.7890 - kl_loss: 0.3935 - val_total_loss: 0.7963 - val_reconstruction_loss: 0.6375 - val_kl_loss: 0.5293 - lr: 0.0050
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8923 - reconstruction_loss: 0.7884 - kl_loss: 0.3800 - val_total_loss: 0.8745 - val_reconstruction_loss: 0.7474 - val_kl_loss: 0.4238 - lr: 0.0050
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9033 - reconstruction_loss: 0.7929 - kl_loss: 0.3748 - val_total_loss: 0.9457 - val_reconstruction_loss: 0.7829 - val_kl_loss: 0.5427 - lr: 0.0050
# Epoch 8/30
# 210/210 [==============================] - 2s 8ms/step - loss: 0.8935 - reconstruction_loss: 0.7858 - kl_loss: 0.3813 - val_total_loss: 0.8361 - val_reconstruction_loss: 0.6883 - val_kl_loss: 0.4926 - lr: 0.0050
# Epoch 9/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8955 - reconstruction_loss: 0.7855 - kl_loss: 0.3780 - val_total_loss: 0.9267 - val_reconstruction_loss: 0.8130 - val_kl_loss: 0.3792 - lr: 0.0050
# Epoch 10/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.9117 - reconstruction_loss: 0.7891 - kl_loss: 0.3930 - val_total_loss: 0.9710 - val_reconstruction_loss: 0.7993 - val_kl_loss: 0.5725 - lr: 0.0050
# Epoch 11/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8946 - reconstruction_loss: 0.7817 - kl_loss: 0.3864 - val_total_loss: 0.9633 - val_reconstruction_loss: 0.8324 - val_kl_loss: 0.4364 - lr: 0.0050
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8910 - reconstruction_loss: 0.7848 - kl_loss: 0.3856 - val_total_loss: 0.8548 - val_reconstruction_loss: 0.6563 - val_kl_loss: 0.6617 - lr: 0.0050
# Epoch 13/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9051 - reconstruction_loss: 0.7760 - kl_loss: 0.4002 - val_total_loss: 0.8858 - val_reconstruction_loss: 0.7030 - val_kl_loss: 0.6093 - lr: 0.0050
# Epoch 14/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9064 - reconstruction_loss: 0.7866 - kl_loss: 0.3823 - val_total_loss: 0.8478 - val_reconstruction_loss: 0.6951 - val_kl_loss: 0.5089 - lr: 0.0050
# Epoch 15/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8895 - reconstruction_loss: 0.7827 - kl_loss: 0.3745 - val_total_loss: 0.9333 - val_reconstruction_loss: 0.7643 - val_kl_loss: 0.5631 - lr: 0.0050
# Epoch 16/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8955 - reconstruction_loss: 0.7800 - kl_loss: 0.3935 - val_total_loss: 0.9605 - val_reconstruction_loss: 0.8109 - val_kl_loss: 0.4986 - lr: 0.0050
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9176 - reconstruction_loss: 0.7815 - kl_loss: 0.3810 - val_total_loss: 0.8810 - val_reconstruction_loss: 0.7426 - val_kl_loss: 0.4612 - lr: 0.0050
# Epoch 18/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8930 - reconstruction_loss: 0.7790 - kl_loss: 0.3850 - val_total_loss: 0.8178 - val_reconstruction_loss: 0.6747 - val_kl_loss: 0.4770 - lr: 0.0050
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8941 - reconstruction_loss: 0.7798 - kl_loss: 0.3995 - val_total_loss: 0.8892 - val_reconstruction_loss: 0.7539 - val_kl_loss: 0.4512 - lr: 0.0050
# Epoch 20/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8887 - reconstruction_loss: 0.7797 - kl_loss: 0.3950 - val_total_loss: 0.8268 - val_reconstruction_loss: 0.6756 - val_kl_loss: 0.5041 - lr: 0.0050
# Epoch 21/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8975 - reconstruction_loss: 0.7751 - kl_loss: 0.4145 - val_total_loss: 0.7975 - val_reconstruction_loss: 0.6514 - val_kl_loss: 0.4868 - lr: 0.0050
# Epoch 22/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8962 - reconstruction_loss: 0.7768 - kl_loss: 0.4056 - val_total_loss: 0.9733 - val_reconstruction_loss: 0.8392 - val_kl_loss: 0.4470 - lr: 0.0050
# Epoch 23/30
# 204/210 [============================>.] - ETA: 0s - loss: 0.8947 - reconstruction_loss: 0.7782 - kl_loss: 0.3986
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8948 - reconstruction_loss: 0.7763 - kl_loss: 0.4002 - val_total_loss: 0.9089 - val_reconstruction_loss: 0.7234 - val_kl_loss: 0.6183 - lr: 0.0050
# Epoch 24/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8954 - reconstruction_loss: 0.7624 - kl_loss: 0.4031 - val_total_loss: 0.9979 - val_reconstruction_loss: 0.8406 - val_kl_loss: 0.5242 - lr: 0.0025
# Epoch 25/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8952 - reconstruction_loss: 0.7679 - kl_loss: 0.4076 - val_total_loss: 0.9034 - val_reconstruction_loss: 0.7538 - val_kl_loss: 0.4987 - lr: 0.0025
# Epoch 26/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8930 - reconstruction_loss: 0.7706 - kl_loss: 0.4109 - val_total_loss: 0.7746 - val_reconstruction_loss: 0.6257 - val_kl_loss: 0.4963 - lr: 0.0025
# Epoch 27/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8965 - reconstruction_loss: 0.7634 - kl_loss: 0.4067 - val_total_loss: 1.0022 - val_reconstruction_loss: 0.8647 - val_kl_loss: 0.4582 - lr: 0.0025
# Epoch 28/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8718 - reconstruction_loss: 0.7567 - kl_loss: 0.4201 - val_total_loss: 0.9303 - val_reconstruction_loss: 0.7778 - val_kl_loss: 0.5085 - lr: 0.0025
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8885 - reconstruction_loss: 0.7605 - kl_loss: 0.4240 - val_total_loss: 0.8718 - val_reconstruction_loss: 0.6908 - val_kl_loss: 0.6032 - lr: 0.0025
# Epoch 30/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8921 - reconstruction_loss: 0.7665 - kl_loss: 0.4178 - val_total_loss: 0.9083 - val_reconstruction_loss: 0.7363 - val_kl_loss: 0.5731 - lr: 0.0025
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.7609 - reconstruction_loss: 0.5924 - kl_loss: 0.5615
# Learning rate:  0.005
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8742 - reconstruction_loss: 0.7671 - kl_loss: 0.4245 - val_total_loss: 0.8408 - val_reconstruction_loss: 0.6791 - val_kl_loss: 0.5389 - lr: 0.0050
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.9025 - reconstruction_loss: 0.7650 - kl_loss: 0.4215 - val_total_loss: 0.9502 - val_reconstruction_loss: 0.7872 - val_kl_loss: 0.5432 - lr: 0.0050
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8896 - reconstruction_loss: 0.7632 - kl_loss: 0.4153 - val_total_loss: 0.8028 - val_reconstruction_loss: 0.6564 - val_kl_loss: 0.4881 - lr: 0.0050
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8941 - reconstruction_loss: 0.7647 - kl_loss: 0.4039 - val_total_loss: 0.8713 - val_reconstruction_loss: 0.6924 - val_kl_loss: 0.5961 - lr: 0.0050
# Epoch 5/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8690 - reconstruction_loss: 0.7670 - kl_loss: 0.4022 - val_total_loss: 0.9729 - val_reconstruction_loss: 0.8064 - val_kl_loss: 0.5550 - lr: 0.0050
# Epoch 6/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8819 - reconstruction_loss: 0.7603 - kl_loss: 0.4139 - val_total_loss: 0.8550 - val_reconstruction_loss: 0.7133 - val_kl_loss: 0.4722 - lr: 0.0050
# Epoch 7/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8870 - reconstruction_loss: 0.7672 - kl_loss: 0.4046 - val_total_loss: 0.9257 - val_reconstruction_loss: 0.7457 - val_kl_loss: 0.6001 - lr: 0.0050
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.9026 - reconstruction_loss: 0.7669 - kl_loss: 0.4263 - val_total_loss: 0.8373 - val_reconstruction_loss: 0.6921 - val_kl_loss: 0.4840 - lr: 0.0050
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8877 - reconstruction_loss: 0.7610 - kl_loss: 0.4324 - val_total_loss: 0.8754 - val_reconstruction_loss: 0.7065 - val_kl_loss: 0.5629 - lr: 0.0050
# Epoch 10/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.9001 - reconstruction_loss: 0.7669 - kl_loss: 0.4092 - val_total_loss: 0.8671 - val_reconstruction_loss: 0.7098 - val_kl_loss: 0.5243 - lr: 0.0050
# Epoch 11/30
# 102/105 [============================>.] - ETA: 0s - loss: 0.8972 - reconstruction_loss: 0.7606 - kl_loss: 0.4241
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8969 - reconstruction_loss: 0.7618 - kl_loss: 0.4255 - val_total_loss: 0.8691 - val_reconstruction_loss: 0.6958 - val_kl_loss: 0.5774 - lr: 0.0050
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8831 - reconstruction_loss: 0.7479 - kl_loss: 0.4306 - val_total_loss: 0.8567 - val_reconstruction_loss: 0.6972 - val_kl_loss: 0.5315 - lr: 0.0025
# Epoch 13/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8915 - reconstruction_loss: 0.7525 - kl_loss: 0.4365 - val_total_loss: 0.8187 - val_reconstruction_loss: 0.6618 - val_kl_loss: 0.5228 - lr: 0.0025
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8905 - reconstruction_loss: 0.7509 - kl_loss: 0.4418 - val_total_loss: 0.9036 - val_reconstruction_loss: 0.7387 - val_kl_loss: 0.5496 - lr: 0.0025
# Epoch 15/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8793 - reconstruction_loss: 0.7539 - kl_loss: 0.4299 - val_total_loss: 0.9377 - val_reconstruction_loss: 0.7761 - val_kl_loss: 0.5385 - lr: 0.0025
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8750 - reconstruction_loss: 0.7535 - kl_loss: 0.4133 - val_total_loss: 1.0299 - val_reconstruction_loss: 0.8682 - val_kl_loss: 0.5388 - lr: 0.0025
# Epoch 17/30
# 105/105 [==============================] - ETA: 0s - loss: 0.8926 - reconstruction_loss: 0.7593 - kl_loss: 0.4204
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8926 - reconstruction_loss: 0.7593 - kl_loss: 0.4204 - val_total_loss: 0.8056 - val_reconstruction_loss: 0.6554 - val_kl_loss: 0.5006 - lr: 0.0025
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8837 - reconstruction_loss: 0.7535 - kl_loss: 0.4180 - val_total_loss: 0.9633 - val_reconstruction_loss: 0.8011 - val_kl_loss: 0.5407 - lr: 0.0012
# Epoch 19/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8718 - reconstruction_loss: 0.7528 - kl_loss: 0.4351 - val_total_loss: 0.8222 - val_reconstruction_loss: 0.6576 - val_kl_loss: 0.5488 - lr: 0.0012
# Epoch 20/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8903 - reconstruction_loss: 0.7510 - kl_loss: 0.4339 - val_total_loss: 0.8702 - val_reconstruction_loss: 0.6978 - val_kl_loss: 0.5748 - lr: 0.0012
# Epoch 21/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8796 - reconstruction_loss: 0.7494 - kl_loss: 0.4345 - val_total_loss: 0.8432 - val_reconstruction_loss: 0.6712 - val_kl_loss: 0.5733 - lr: 0.0012
# Epoch 22/30
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8849 - reconstruction_loss: 0.7485 - kl_loss: 0.4439
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Restoring model weights from the end of the best epoch: 12.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8847 - reconstruction_loss: 0.7477 - kl_loss: 0.4430 - val_total_loss: 0.8690 - val_reconstruction_loss: 0.6994 - val_kl_loss: 0.5655 - lr: 0.0012
# Epoch 22: early stopping
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.8970 - reconstruction_loss: 0.7450 - kl_loss: 0.5067
# Learning rate:  0.005
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 25ms/step - loss: 0.8854 - reconstruction_loss: 0.7602 - kl_loss: 0.4299 - val_total_loss: 0.8994 - val_reconstruction_loss: 0.7215 - val_kl_loss: 0.5930 - lr: 0.0050
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8770 - reconstruction_loss: 0.7590 - kl_loss: 0.4173 - val_total_loss: 0.8747 - val_reconstruction_loss: 0.7246 - val_kl_loss: 0.5003 - lr: 0.0050
# Epoch 3/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8885 - reconstruction_loss: 0.7491 - kl_loss: 0.4359 - val_total_loss: 0.9926 - val_reconstruction_loss: 0.8106 - val_kl_loss: 0.6065 - lr: 0.0050
# Epoch 4/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8923 - reconstruction_loss: 0.7533 - kl_loss: 0.4274 - val_total_loss: 0.8770 - val_reconstruction_loss: 0.7143 - val_kl_loss: 0.5425 - lr: 0.0050
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8981 - reconstruction_loss: 0.7541 - kl_loss: 0.4550 - val_total_loss: 0.9417 - val_reconstruction_loss: 0.7586 - val_kl_loss: 0.6102 - lr: 0.0050
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8830 - reconstruction_loss: 0.7550 - kl_loss: 0.4312 - val_total_loss: 0.8389 - val_reconstruction_loss: 0.6963 - val_kl_loss: 0.4753 - lr: 0.0050
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8967 - reconstruction_loss: 0.7562 - kl_loss: 0.4316 - val_total_loss: 0.8838 - val_reconstruction_loss: 0.7145 - val_kl_loss: 0.5645 - lr: 0.0050
# Epoch 8/30
# 53/53 [==============================] - ETA: 0s - loss: 0.8767 - reconstruction_loss: 0.7503 - kl_loss: 0.4446
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8768 - reconstruction_loss: 0.7503 - kl_loss: 0.4446 - val_total_loss: 0.7978 - val_reconstruction_loss: 0.6273 - val_kl_loss: 0.5684 - lr: 0.0050
# Epoch 9/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8833 - reconstruction_loss: 0.7463 - kl_loss: 0.4523 - val_total_loss: 0.8920 - val_reconstruction_loss: 0.7215 - val_kl_loss: 0.5683 - lr: 0.0025
# Epoch 10/30
# 53/53 [==============================] - 1s 21ms/step - loss: 0.8834 - reconstruction_loss: 0.7471 - kl_loss: 0.4339 - val_total_loss: 0.8235 - val_reconstruction_loss: 0.6556 - val_kl_loss: 0.5598 - lr: 0.0025
# Epoch 11/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.8875 - reconstruction_loss: 0.7540 - kl_loss: 0.4356 - val_total_loss: 0.9114 - val_reconstruction_loss: 0.7376 - val_kl_loss: 0.5796 - lr: 0.0025
# Epoch 12/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8845 - reconstruction_loss: 0.7453 - kl_loss: 0.4403 - val_total_loss: 0.9092 - val_reconstruction_loss: 0.7444 - val_kl_loss: 0.5493 - lr: 0.0025
# Epoch 13/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8869 - reconstruction_loss: 0.7463 - kl_loss: 0.4612 - val_total_loss: 0.8793 - val_reconstruction_loss: 0.7093 - val_kl_loss: 0.5665 - lr: 0.0025
# Epoch 14/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.8876 - reconstruction_loss: 0.7486 - kl_loss: 0.4538 - val_total_loss: 0.8604 - val_reconstruction_loss: 0.6897 - val_kl_loss: 0.5690 - lr: 0.0025
# Epoch 15/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8776 - reconstruction_loss: 0.7439 - kl_loss: 0.4442 - val_total_loss: 0.8795 - val_reconstruction_loss: 0.7105 - val_kl_loss: 0.5633 - lr: 0.0025
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8838 - reconstruction_loss: 0.7444 - kl_loss: 0.4368 - val_total_loss: 0.8818 - val_reconstruction_loss: 0.7299 - val_kl_loss: 0.5064 - lr: 0.0025
# Epoch 17/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8783 - reconstruction_loss: 0.7489 - kl_loss: 0.4451 - val_total_loss: 1.1637 - val_reconstruction_loss: 0.9919 - val_kl_loss: 0.5727 - lr: 0.0025
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8996 - reconstruction_loss: 0.7480 - kl_loss: 0.4369 - val_total_loss: 0.9247 - val_reconstruction_loss: 0.7587 - val_kl_loss: 0.5532 - lr: 0.0025
# Epoch 19/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8724 - reconstruction_loss: 0.7440 - kl_loss: 0.4456 - val_total_loss: 0.8791 - val_reconstruction_loss: 0.7036 - val_kl_loss: 0.5851 - lr: 0.0025
# Epoch 20/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8932 - reconstruction_loss: 0.7465 - kl_loss: 0.4617 - val_total_loss: 0.8772 - val_reconstruction_loss: 0.7170 - val_kl_loss: 0.5340 - lr: 0.0025
# Epoch 21/30
# 53/53 [==============================] - ETA: 0s - loss: 0.8897 - reconstruction_loss: 0.7420 - kl_loss: 0.4603
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8896 - reconstruction_loss: 0.7420 - kl_loss: 0.4603 - val_total_loss: 0.8998 - val_reconstruction_loss: 0.7386 - val_kl_loss: 0.5373 - lr: 0.0025
# Epoch 22/30
# 53/53 [==============================] - 1s 21ms/step - loss: 0.8719 - reconstruction_loss: 0.7467 - kl_loss: 0.4401 - val_total_loss: 0.8683 - val_reconstruction_loss: 0.6890 - val_kl_loss: 0.5979 - lr: 0.0012
# Epoch 23/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8897 - reconstruction_loss: 0.7390 - kl_loss: 0.4653 - val_total_loss: 0.9915 - val_reconstruction_loss: 0.8124 - val_kl_loss: 0.5969 - lr: 0.0012
# Epoch 24/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8711 - reconstruction_loss: 0.7430 - kl_loss: 0.4539 - val_total_loss: 0.9447 - val_reconstruction_loss: 0.7709 - val_kl_loss: 0.5794 - lr: 0.0012
# Epoch 25/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8737 - reconstruction_loss: 0.7407 - kl_loss: 0.4536 - val_total_loss: 0.8218 - val_reconstruction_loss: 0.6429 - val_kl_loss: 0.5962 - lr: 0.0012
# Epoch 26/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8854 - reconstruction_loss: 0.7352 - kl_loss: 0.4659 - val_total_loss: 0.7762 - val_reconstruction_loss: 0.5986 - val_kl_loss: 0.5921 - lr: 0.0012
# Epoch 27/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8853 - reconstruction_loss: 0.7415 - kl_loss: 0.4515 - val_total_loss: 0.9438 - val_reconstruction_loss: 0.7618 - val_kl_loss: 0.6069 - lr: 0.0012
# Epoch 28/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8778 - reconstruction_loss: 0.7500 - kl_loss: 0.4423 - val_total_loss: 0.8380 - val_reconstruction_loss: 0.6647 - val_kl_loss: 0.5776 - lr: 0.0012
# Epoch 29/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8775 - reconstruction_loss: 0.7451 - kl_loss: 0.4514 - val_total_loss: 0.9717 - val_reconstruction_loss: 0.7958 - val_kl_loss: 0.5864 - lr: 0.0012
# Epoch 30/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8813 - reconstruction_loss: 0.7407 - kl_loss: 0.4611 - val_total_loss: 0.9017 - val_reconstruction_loss: 0.7288 - val_kl_loss: 0.5764 - lr: 0.0012
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.0150 - reconstruction_loss: 0.8576 - kl_loss: 0.5244
# Learning rate:  0.005
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 36ms/step - loss: 0.8979 - reconstruction_loss: 0.7593 - kl_loss: 0.4445 - val_total_loss: 0.9190 - val_reconstruction_loss: 0.7570 - val_kl_loss: 0.5400 - lr: 0.0050
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8817 - reconstruction_loss: 0.7515 - kl_loss: 0.4465 - val_total_loss: 0.8836 - val_reconstruction_loss: 0.7120 - val_kl_loss: 0.5721 - lr: 0.0050
# Epoch 3/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8998 - reconstruction_loss: 0.7435 - kl_loss: 0.4602 - val_total_loss: 0.9361 - val_reconstruction_loss: 0.7656 - val_kl_loss: 0.5683 - lr: 0.0050
# Epoch 4/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8782 - reconstruction_loss: 0.7491 - kl_loss: 0.4428 - val_total_loss: 0.8953 - val_reconstruction_loss: 0.7249 - val_kl_loss: 0.5677 - lr: 0.0050
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8770 - reconstruction_loss: 0.7429 - kl_loss: 0.4707 - val_total_loss: 0.8813 - val_reconstruction_loss: 0.7120 - val_kl_loss: 0.5643 - lr: 0.0050
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8709 - reconstruction_loss: 0.7490 - kl_loss: 0.4642 - val_total_loss: 0.8809 - val_reconstruction_loss: 0.7172 - val_kl_loss: 0.5454 - lr: 0.0050
# Epoch 7/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8800 - reconstruction_loss: 0.7479 - kl_loss: 0.4637 - val_total_loss: 0.8961 - val_reconstruction_loss: 0.7334 - val_kl_loss: 0.5420 - lr: 0.0050
# Epoch 8/30
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8864 - reconstruction_loss: 0.7480 - kl_loss: 0.4407 - val_total_loss: 0.9011 - val_reconstruction_loss: 0.7361 - val_kl_loss: 0.5500 - lr: 0.0050
# Epoch 9/30
# 27/27 [==============================] - 1s 34ms/step - loss: 0.8964 - reconstruction_loss: 0.7503 - kl_loss: 0.4527 - val_total_loss: 0.8987 - val_reconstruction_loss: 0.7369 - val_kl_loss: 0.5395 - lr: 0.0050
# Epoch 10/30
# 27/27 [==============================] - 1s 34ms/step - loss: 0.8850 - reconstruction_loss: 0.7450 - kl_loss: 0.4493 - val_total_loss: 0.8850 - val_reconstruction_loss: 0.7158 - val_kl_loss: 0.5640 - lr: 0.0050
# Epoch 11/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8948 - reconstruction_loss: 0.7446 - kl_loss: 0.4609 - val_total_loss: 0.8911 - val_reconstruction_loss: 0.7210 - val_kl_loss: 0.5672 - lr: 0.0050
# Epoch 12/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8795 - reconstruction_loss: 0.7516 - kl_loss: 0.4632 - val_total_loss: 0.8703 - val_reconstruction_loss: 0.6807 - val_kl_loss: 0.6322 - lr: 0.0050
# Epoch 13/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8816 - reconstruction_loss: 0.7450 - kl_loss: 0.4665 - val_total_loss: 0.9087 - val_reconstruction_loss: 0.7536 - val_kl_loss: 0.5171 - lr: 0.0050
# Epoch 14/30
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8754 - reconstruction_loss: 0.7340 - kl_loss: 0.4531 - val_total_loss: 0.9077 - val_reconstruction_loss: 0.7408 - val_kl_loss: 0.5562 - lr: 0.0050
# Epoch 15/30
# 27/27 [==============================] - 1s 34ms/step - loss: 0.8888 - reconstruction_loss: 0.7532 - kl_loss: 0.4547 - val_total_loss: 0.8856 - val_reconstruction_loss: 0.7104 - val_kl_loss: 0.5839 - lr: 0.0050
# Epoch 16/30
# 27/27 [==============================] - 1s 30ms/step - loss: 0.8721 - reconstruction_loss: 0.7408 - kl_loss: 0.4569 - val_total_loss: 0.8705 - val_reconstruction_loss: 0.7027 - val_kl_loss: 0.5595 - lr: 0.0050
# Epoch 17/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8843 - reconstruction_loss: 0.7396 - kl_loss: 0.4638 - val_total_loss: 0.8920 - val_reconstruction_loss: 0.7330 - val_kl_loss: 0.5302 - lr: 0.0050
# Epoch 18/30
# ...
# Epoch 21/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8900 - reconstruction_loss: 0.7526 - kl_loss: 0.4363 - val_total_loss: 0.9699 - val_reconstruction_loss: 0.8193 - val_kl_loss: 0.5019 - lr: 0.0025
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8919 - reconstruction_loss: 0.7549 - kl_loss: 0.4399 - val_total_loss: 0.9442 - val_reconstruction_loss: 0.7626 - val_kl_loss: 0.6054 - lr: 0.0025
# Epoch 23/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8704 - reconstruction_loss: 0.7530 - kl_loss: 0.4445 - val_total_loss: 0.9195 - val_reconstruction_loss: 0.7449 - val_kl_loss: 0.5821 - lr: 0.0025
# Epoch 24/30
# 104/105 [============================>.] - ETA: 0s - loss: 0.8986 - reconstruction_loss: 0.7509 - kl_loss: 0.4450
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8983 - reconstruction_loss: 0.7494 - kl_loss: 0.4447 - val_total_loss: 0.7557 - val_reconstruction_loss: 0.5902 - val_kl_loss: 0.5516 - lr: 0.0025
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8930 - reconstruction_loss: 0.7469 - kl_loss: 0.4460 - val_total_loss: 0.8746 - val_reconstruction_loss: 0.7187 - val_kl_loss: 0.5197 - lr: 0.0012
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8778 - reconstruction_loss: 0.7516 - kl_loss: 0.4462 - val_total_loss: 0.8042 - val_reconstruction_loss: 0.6365 - val_kl_loss: 0.5590 - lr: 0.0012
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8852 - reconstruction_loss: 0.7474 - kl_loss: 0.4414 - val_total_loss: 0.8611 - val_reconstruction_loss: 0.6906 - val_kl_loss: 0.5683 - lr: 0.0012
# Epoch 28/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8798 - reconstruction_loss: 0.7459 - kl_loss: 0.4362 - val_total_loss: 0.7895 - val_reconstruction_loss: 0.6253 - val_kl_loss: 0.5472 - lr: 0.0012
# Epoch 29/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8816 - reconstruction_loss: 0.7493 - kl_loss: 0.4382 - val_total_loss: 0.7992 - val_reconstruction_loss: 0.6391 - val_kl_loss: 0.5337 - lr: 0.0012
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8674 - reconstruction_loss: 0.7469 - kl_loss: 0.4305 - val_total_loss: 0.8696 - val_reconstruction_loss: 0.7195 - val_kl_loss: 0.5005 - lr: 0.0012
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.8612 - reconstruction_loss: 0.7194 - kl_loss: 0.4727
# Learning rate:  0.01
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 20ms/step - loss: 0.8935 - reconstruction_loss: 0.7694 - kl_loss: 0.4192 - val_total_loss: 0.8058 - val_reconstruction_loss: 0.6478 - val_kl_loss: 0.5266 - lr: 0.0100
# Epoch 2/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8839 - reconstruction_loss: 0.7626 - kl_loss: 0.4167 - val_total_loss: 0.9304 - val_reconstruction_loss: 0.7932 - val_kl_loss: 0.4572 - lr: 0.0100
# Epoch 3/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8902 - reconstruction_loss: 0.7656 - kl_loss: 0.4187 - val_total_loss: 0.9186 - val_reconstruction_loss: 0.7677 - val_kl_loss: 0.5028 - lr: 0.0100
# Epoch 4/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8817 - reconstruction_loss: 0.7583 - kl_loss: 0.4189 - val_total_loss: 0.8161 - val_reconstruction_loss: 0.6818 - val_kl_loss: 0.4475 - lr: 0.0100
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8783 - reconstruction_loss: 0.7598 - kl_loss: 0.4312 - val_total_loss: 0.8485 - val_reconstruction_loss: 0.6905 - val_kl_loss: 0.5268 - lr: 0.0100
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.9115 - reconstruction_loss: 0.7665 - kl_loss: 0.4318 - val_total_loss: 0.8919 - val_reconstruction_loss: 0.7345 - val_kl_loss: 0.5248 - lr: 0.0100
# Epoch 7/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8904 - reconstruction_loss: 0.7646 - kl_loss: 0.4151 - val_total_loss: 0.8628 - val_reconstruction_loss: 0.7055 - val_kl_loss: 0.5244 - lr: 0.0100
# Epoch 8/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.9023 - reconstruction_loss: 0.7657 - kl_loss: 0.4174 - val_total_loss: 0.7659 - val_reconstruction_loss: 0.6307 - val_kl_loss: 0.4507 - lr: 0.0100
# Epoch 9/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8914 - reconstruction_loss: 0.7591 - kl_loss: 0.4193
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8913 - reconstruction_loss: 0.7592 - kl_loss: 0.4231 - val_total_loss: 0.9794 - val_reconstruction_loss: 0.8204 - val_kl_loss: 0.5300 - lr: 0.0100
# Epoch 10/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8903 - reconstruction_loss: 0.7503 - kl_loss: 0.4445 - val_total_loss: 0.8249 - val_reconstruction_loss: 0.6615 - val_kl_loss: 0.5445 - lr: 0.0050
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8825 - reconstruction_loss: 0.7565 - kl_loss: 0.4340 - val_total_loss: 0.9080 - val_reconstruction_loss: 0.7464 - val_kl_loss: 0.5385 - lr: 0.0050
# Epoch 12/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8798 - reconstruction_loss: 0.7511 - kl_loss: 0.4263 - val_total_loss: 0.8250 - val_reconstruction_loss: 0.6738 - val_kl_loss: 0.5040 - lr: 0.0050
# Epoch 13/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8802 - reconstruction_loss: 0.7527 - kl_loss: 0.4301 - val_total_loss: 0.9082 - val_reconstruction_loss: 0.7554 - val_kl_loss: 0.5092 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8910 - reconstruction_loss: 0.7535 - kl_loss: 0.4326 - val_total_loss: 0.8105 - val_reconstruction_loss: 0.6630 - val_kl_loss: 0.4918 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8985 - reconstruction_loss: 0.7534 - kl_loss: 0.4294 - val_total_loss: 0.8260 - val_reconstruction_loss: 0.6507 - val_kl_loss: 0.5846 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8910 - reconstruction_loss: 0.7553 - kl_loss: 0.4435 - val_total_loss: 0.8224 - val_reconstruction_loss: 0.6657 - val_kl_loss: 0.5224 - lr: 0.0050
# Epoch 17/30
# 50/53 [===========================>..] - ETA: 0s - loss: 0.8869 - reconstruction_loss: 0.7513 - kl_loss: 0.4480
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8868 - reconstruction_loss: 0.7530 - kl_loss: 0.4494 - val_total_loss: 0.9185 - val_reconstruction_loss: 0.7551 - val_kl_loss: 0.5447 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8768 - reconstruction_loss: 0.7511 - kl_loss: 0.4403 - val_total_loss: 0.8681 - val_reconstruction_loss: 0.7033 - val_kl_loss: 0.5491 - lr: 0.0025
# Epoch 19/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8742 - reconstruction_loss: 0.7534 - kl_loss: 0.4332 - val_total_loss: 0.9637 - val_reconstruction_loss: 0.8156 - val_kl_loss: 0.4935 - lr: 0.0025
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8865 - reconstruction_loss: 0.7518 - kl_loss: 0.4428 - val_total_loss: 0.9522 - val_reconstruction_loss: 0.7933 - val_kl_loss: 0.5298 - lr: 0.0025
# Epoch 21/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8688 - reconstruction_loss: 0.7499 - kl_loss: 0.4260 - val_total_loss: 0.9152 - val_reconstruction_loss: 0.7658 - val_kl_loss: 0.4981 - lr: 0.0025
# Epoch 22/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8772 - reconstruction_loss: 0.7499 - kl_loss: 0.4377 - val_total_loss: 0.8705 - val_reconstruction_loss: 0.6955 - val_kl_loss: 0.5832 - lr: 0.0025
# Epoch 23/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8806 - reconstruction_loss: 0.7446 - kl_loss: 0.4441 - val_total_loss: 0.7788 - val_reconstruction_loss: 0.6167 - val_kl_loss: 0.5402 - lr: 0.0025
# Epoch 24/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8892 - reconstruction_loss: 0.7527 - kl_loss: 0.4453 - val_total_loss: 0.9459 - val_reconstruction_loss: 0.7740 - val_kl_loss: 0.5731 - lr: 0.0025
# Epoch 25/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8808 - reconstruction_loss: 0.7489 - kl_loss: 0.4500 - val_total_loss: 0.9629 - val_reconstruction_loss: 0.7961 - val_kl_loss: 0.5558 - lr: 0.0025
# Epoch 26/30
# 51/53 [===========================>..] - ETA: 0s - loss: 0.8732 - reconstruction_loss: 0.7522 - kl_loss: 0.4468
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8738 - reconstruction_loss: 0.7487 - kl_loss: 0.4451 - val_total_loss: 0.8998 - val_reconstruction_loss: 0.7317 - val_kl_loss: 0.5604 - lr: 0.0025
# Epoch 27/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8706 - reconstruction_loss: 0.7500 - kl_loss: 0.4396 - val_total_loss: 0.8902 - val_reconstruction_loss: 0.7241 - val_kl_loss: 0.5538 - lr: 0.0012
# Epoch 28/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8698 - reconstruction_loss: 0.7493 - kl_loss: 0.4383 - val_total_loss: 0.7868 - val_reconstruction_loss: 0.6170 - val_kl_loss: 0.5661 - lr: 0.0012
# Epoch 29/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8707 - reconstruction_loss: 0.7483 - kl_loss: 0.4505 - val_total_loss: 0.8403 - val_reconstruction_loss: 0.6650 - val_kl_loss: 0.5841 - lr: 0.0012
# Epoch 30/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8854 - reconstruction_loss: 0.7471 - kl_loss: 0.4508 - val_total_loss: 0.9682 - val_reconstruction_loss: 0.7979 - val_kl_loss: 0.5678 - lr: 0.0012
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.1705 - reconstruction_loss: 1.0047 - kl_loss: 0.5527
# Learning rate:  0.01
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 35ms/step - loss: 0.8954 - reconstruction_loss: 0.7674 - kl_loss: 0.4339 - val_total_loss: 0.8973 - val_reconstruction_loss: 0.7491 - val_kl_loss: 0.4941 - lr: 0.0100
# Epoch 2/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8941 - reconstruction_loss: 0.7493 - kl_loss: 0.4574 - val_total_loss: 0.8979 - val_reconstruction_loss: 0.7275 - val_kl_loss: 0.5680 - lr: 0.0100
# Epoch 3/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8747 - reconstruction_loss: 0.7495 - kl_loss: 0.4416 - val_total_loss: 0.8942 - val_reconstruction_loss: 0.7427 - val_kl_loss: 0.5049 - lr: 0.0100
# Epoch 4/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8829 - reconstruction_loss: 0.7546 - kl_loss: 0.4453 - val_total_loss: 0.9150 - val_reconstruction_loss: 0.7552 - val_kl_loss: 0.5325 - lr: 0.0100
# Epoch 5/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8867 - reconstruction_loss: 0.7485 - kl_loss: 0.4421 - val_total_loss: 0.9025 - val_reconstruction_loss: 0.7455 - val_kl_loss: 0.5231 - lr: 0.0100
# Epoch 6/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8809 - reconstruction_loss: 0.7593 - kl_loss: 0.4176 - val_total_loss: 0.8931 - val_reconstruction_loss: 0.7395 - val_kl_loss: 0.5119 - lr: 0.0100
# Epoch 7/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8834 - reconstruction_loss: 0.7589 - kl_loss: 0.4294 - val_total_loss: 0.8943 - val_reconstruction_loss: 0.7382 - val_kl_loss: 0.5202 - lr: 0.0100
# Epoch 8/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8756 - reconstruction_loss: 0.7546 - kl_loss: 0.4472 - val_total_loss: 0.9218 - val_reconstruction_loss: 0.7675 - val_kl_loss: 0.5145 - lr: 0.0100
# Epoch 9/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8835 - reconstruction_loss: 0.7563 - kl_loss: 0.4219 - val_total_loss: 0.8835 - val_reconstruction_loss: 0.7344 - val_kl_loss: 0.4972 - lr: 0.0100
# Epoch 10/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8835 - reconstruction_loss: 0.7533 - kl_loss: 0.4293
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8835 - reconstruction_loss: 0.7559 - kl_loss: 0.4265 - val_total_loss: 0.8998 - val_reconstruction_loss: 0.7555 - val_kl_loss: 0.4811 - lr: 0.0100
# Epoch 11/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8893 - reconstruction_loss: 0.7485 - kl_loss: 0.4459 - val_total_loss: 0.8819 - val_reconstruction_loss: 0.7235 - val_kl_loss: 0.5280 - lr: 0.0050
# Epoch 12/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8784 - reconstruction_loss: 0.7463 - kl_loss: 0.4304 - val_total_loss: 0.9185 - val_reconstruction_loss: 0.7580 - val_kl_loss: 0.5352 - lr: 0.0050
# Epoch 13/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8653 - reconstruction_loss: 0.7445 - kl_loss: 0.4468 - val_total_loss: 0.8904 - val_reconstruction_loss: 0.7333 - val_kl_loss: 0.5237 - lr: 0.0050
# Epoch 14/30
# 27/27 [==============================] - 1s 29ms/step - loss: 0.8797 - reconstruction_loss: 0.7504 - kl_loss: 0.4307 - val_total_loss: 0.9183 - val_reconstruction_loss: 0.7579 - val_kl_loss: 0.5344 - lr: 0.0050
# Epoch 15/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8826 - reconstruction_loss: 0.7474 - kl_loss: 0.4299 - val_total_loss: 0.8686 - val_reconstruction_loss: 0.7038 - val_kl_loss: 0.5493 - lr: 0.0050
# Epoch 16/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8783 - reconstruction_loss: 0.7452 - kl_loss: 0.4370 - val_total_loss: 0.9159 - val_reconstruction_loss: 0.7583 - val_kl_loss: 0.5255 - lr: 0.0050
# Epoch 17/30
# 27/27 [==============================] - ETA: 0s - loss: 0.8874 - reconstruction_loss: 0.7513 - kl_loss: 0.4380
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8872 - reconstruction_loss: 0.7513 - kl_loss: 0.4380 - val_total_loss: 0.8884 - val_reconstruction_loss: 0.7147 - val_kl_loss: 0.5790 - lr: 0.0050
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8848 - reconstruction_loss: 0.7459 - kl_loss: 0.4616 - val_total_loss: 0.9087 - val_reconstruction_loss: 0.7450 - val_kl_loss: 0.5456 - lr: 0.0025
# Epoch 19/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8912 - reconstruction_loss: 0.7441 - kl_loss: 0.4542 - val_total_loss: 0.8794 - val_reconstruction_loss: 0.7149 - val_kl_loss: 0.5480 - lr: 0.0025
# Epoch 20/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8786 - reconstruction_loss: 0.7389 - kl_loss: 0.4649 - val_total_loss: 0.8886 - val_reconstruction_loss: 0.7206 - val_kl_loss: 0.5600 - lr: 0.0025
# Epoch 21/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8887 - reconstruction_loss: 0.7415 - kl_loss: 0.4563 - val_total_loss: 0.9021 - val_reconstruction_loss: 0.7385 - val_kl_loss: 0.5453 - lr: 0.0025
# Epoch 22/30
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8795 - reconstruction_loss: 0.7451 - kl_loss: 0.4348
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# Restoring model weights from the end of the best epoch: 12.
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8800 - reconstruction_loss: 0.7548 - kl_loss: 0.4378 - val_total_loss: 0.9081 - val_reconstruction_loss: 0.7366 - val_kl_loss: 0.5714 - lr: 0.0025
# Epoch 22: early stopping
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.8272 - reconstruction_loss: 0.6776 - kl_loss: 0.4987
# Best Hyperparameters: {'learn_rate': 0.008, 'batch_size': 64}
# Best Score: [0.7302433252334595, 0.564076840877533, 0.5538883209228516]

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)

vae.fit(x_train, batch_size=bs, epochs=100, validation_split = 0.2,
        callbacks=[reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 105/105 [==============================] - 3s 12ms/step - loss: 0.9157 - reconstruction_loss: 0.7709 - kl_loss: 0.4267 - val_total_loss: 0.9549 - val_reconstruction_loss: 0.7938 - val_kl_loss: 0.5369 - lr: 0.0080
# Epoch 2/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8842 - reconstruction_loss: 0.7587 - kl_loss: 0.4342 - val_total_loss: 0.8806 - val_reconstruction_loss: 0.7190 - val_kl_loss: 0.5388 - lr: 0.0080
# Epoch 3/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8968 - reconstruction_loss: 0.7685 - kl_loss: 0.4230 - val_total_loss: 0.8810 - val_reconstruction_loss: 0.7190 - val_kl_loss: 0.5400 - lr: 0.0080
# Epoch 4/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8765 - reconstruction_loss: 0.7654 - kl_loss: 0.4123 - val_total_loss: 0.8440 - val_reconstruction_loss: 0.6712 - val_kl_loss: 0.5762 - lr: 0.0080
# Epoch 5/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8822 - reconstruction_loss: 0.7600 - kl_loss: 0.4249 - val_total_loss: 0.8967 - val_reconstruction_loss: 0.7391 - val_kl_loss: 0.5256 - lr: 0.0080
# Epoch 6/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8812 - reconstruction_loss: 0.7590 - kl_loss: 0.4436 - val_total_loss: 0.9572 - val_reconstruction_loss: 0.7753 - val_kl_loss: 0.6062 - lr: 0.0080
# Epoch 7/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8975 - reconstruction_loss: 0.7625 - kl_loss: 0.4262 - val_total_loss: 0.8874 - val_reconstruction_loss: 0.7274 - val_kl_loss: 0.5336 - lr: 0.0080
# Epoch 8/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.9090 - reconstruction_loss: 0.7568 - kl_loss: 0.4265 - val_total_loss: 0.8572 - val_reconstruction_loss: 0.6723 - val_kl_loss: 0.6161 - lr: 0.0080
# Epoch 9/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.9012 - reconstruction_loss: 0.7694 - kl_loss: 0.4212 - val_total_loss: 0.8308 - val_reconstruction_loss: 0.6736 - val_kl_loss: 0.5241 - lr: 0.0080
# Epoch 10/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8796 - reconstruction_loss: 0.7633 - kl_loss: 0.4287 - val_total_loss: 0.9078 - val_reconstruction_loss: 0.7381 - val_kl_loss: 0.5659 - lr: 0.0080
# Epoch 11/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8918 - reconstruction_loss: 0.7561 - kl_loss: 0.4461 - val_total_loss: 0.8879 - val_reconstruction_loss: 0.7240 - val_kl_loss: 0.5464 - lr: 0.0080
# Epoch 12/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8927 - reconstruction_loss: 0.7609 - kl_loss: 0.4364 - val_total_loss: 0.9138 - val_reconstruction_loss: 0.7505 - val_kl_loss: 0.5442 - lr: 0.0080
# Epoch 13/100
# 104/105 [============================>.] - ETA: 0s - loss: 0.8945 - reconstruction_loss: 0.7613 - kl_loss: 0.4188
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004000000189989805.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8943 - reconstruction_loss: 0.7604 - kl_loss: 0.4178 - val_total_loss: 0.8681 - val_reconstruction_loss: 0.7181 - val_kl_loss: 0.5001 - lr: 0.0080
# Epoch 14/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8912 - reconstruction_loss: 0.7551 - kl_loss: 0.4389 - val_total_loss: 0.8572 - val_reconstruction_loss: 0.6845 - val_kl_loss: 0.5756 - lr: 0.0040
# Epoch 15/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8865 - reconstruction_loss: 0.7530 - kl_loss: 0.4489 - val_total_loss: 0.8101 - val_reconstruction_loss: 0.6259 - val_kl_loss: 0.6138 - lr: 0.0040
# Epoch 16/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8702 - reconstruction_loss: 0.7461 - kl_loss: 0.4522 - val_total_loss: 0.8165 - val_reconstruction_loss: 0.6585 - val_kl_loss: 0.5266 - lr: 0.0040
# Epoch 17/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8918 - reconstruction_loss: 0.7533 - kl_loss: 0.4541 - val_total_loss: 1.0663 - val_reconstruction_loss: 0.8927 - val_kl_loss: 0.5786 - lr: 0.0040
# Epoch 18/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8916 - reconstruction_loss: 0.7534 - kl_loss: 0.4437 - val_total_loss: 0.9874 - val_reconstruction_loss: 0.8440 - val_kl_loss: 0.4782 - lr: 0.0040
# Epoch 19/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8662 - reconstruction_loss: 0.7495 - kl_loss: 0.4422 - val_total_loss: 0.8430 - val_reconstruction_loss: 0.6762 - val_kl_loss: 0.5557 - lr: 0.0040
# Epoch 20/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8863 - reconstruction_loss: 0.7533 - kl_loss: 0.4419 - val_total_loss: 0.9191 - val_reconstruction_loss: 0.7611 - val_kl_loss: 0.5266 - lr: 0.0040
# Epoch 21/100
# 103/105 [============================>.] - ETA: 0s - loss: 0.8749 - reconstruction_loss: 0.7527 - kl_loss: 0.4366
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0020000000949949026.
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8752 - reconstruction_loss: 0.7522 - kl_loss: 0.4366 - val_total_loss: 0.8930 - val_reconstruction_loss: 0.7325 - val_kl_loss: 0.5351 - lr: 0.0040
# Epoch 22/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8843 - reconstruction_loss: 0.7481 - kl_loss: 0.4420 - val_total_loss: 0.8546 - val_reconstruction_loss: 0.6976 - val_kl_loss: 0.5231 - lr: 0.0020
# Epoch 23/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8767 - reconstruction_loss: 0.7480 - kl_loss: 0.4541 - val_total_loss: 0.8300 - val_reconstruction_loss: 0.6613 - val_kl_loss: 0.5625 - lr: 0.0020
# Epoch 24/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8751 - reconstruction_loss: 0.7476 - kl_loss: 0.4400 - val_total_loss: 0.8766 - val_reconstruction_loss: 0.7177 - val_kl_loss: 0.5294 - lr: 0.0020
# Epoch 25/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8778 - reconstruction_loss: 0.7462 - kl_loss: 0.4477 - val_total_loss: 0.8912 - val_reconstruction_loss: 0.7182 - val_kl_loss: 0.5767 - lr: 0.0020
# Epoch 26/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8748 - reconstruction_loss: 0.7478 - kl_loss: 0.4499 - val_total_loss: 0.8483 - val_reconstruction_loss: 0.6824 - val_kl_loss: 0.5533 - lr: 0.0020
# Epoch 27/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8887 - reconstruction_loss: 0.7509 - kl_loss: 0.4437 - val_total_loss: 0.8240 - val_reconstruction_loss: 0.6561 - val_kl_loss: 0.5597 - lr: 0.0020
# Epoch 28/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8875 - reconstruction_loss: 0.7433 - kl_loss: 0.4703 - val_total_loss: 0.8733 - val_reconstruction_loss: 0.7094 - val_kl_loss: 0.5463 - lr: 0.0020
# Epoch 29/100
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8717 - reconstruction_loss: 0.7433 - kl_loss: 0.4537
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8722 - reconstruction_loss: 0.7463 - kl_loss: 0.4525 - val_total_loss: 0.8030 - val_reconstruction_loss: 0.6345 - val_kl_loss: 0.5614 - lr: 0.0020
# Epoch 30/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8901 - reconstruction_loss: 0.7441 - kl_loss: 0.4573 - val_total_loss: 0.8169 - val_reconstruction_loss: 0.6488 - val_kl_loss: 0.5602 - lr: 0.0010
# Epoch 31/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8886 - reconstruction_loss: 0.7424 - kl_loss: 0.4648 - val_total_loss: 0.8967 - val_reconstruction_loss: 0.7372 - val_kl_loss: 0.5319 - lr: 0.0010
# Epoch 32/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8762 - reconstruction_loss: 0.7453 - kl_loss: 0.4507 - val_total_loss: 1.0271 - val_reconstruction_loss: 0.8635 - val_kl_loss: 0.5455 - lr: 0.0010
# Epoch 33/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8752 - reconstruction_loss: 0.7441 - kl_loss: 0.4575 - val_total_loss: 0.8636 - val_reconstruction_loss: 0.6959 - val_kl_loss: 0.5590 - lr: 0.0010
# Epoch 34/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.8861 - reconstruction_loss: 0.7396 - kl_loss: 0.4642 - val_total_loss: 0.9113 - val_reconstruction_loss: 0.7419 - val_kl_loss: 0.5646 - lr: 0.0010
# Epoch 35/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8791 - reconstruction_loss: 0.7473 - kl_loss: 0.4507 - val_total_loss: 0.8709 - val_reconstruction_loss: 0.7002 - val_kl_loss: 0.5690 - lr: 0.0010
# Epoch 36/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8830 - reconstruction_loss: 0.7397 - kl_loss: 0.4625 - val_total_loss: 0.9354 - val_reconstruction_loss: 0.7713 - val_kl_loss: 0.5472 - lr: 0.0010
# Epoch 37/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8821 - reconstruction_loss: 0.7419 - kl_loss: 0.4526 - val_total_loss: 0.8486 - val_reconstruction_loss: 0.6828 - val_kl_loss: 0.5526 - lr: 0.0010
# Epoch 38/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8716 - reconstruction_loss: 0.7427 - kl_loss: 0.4487 - val_total_loss: 0.8648 - val_reconstruction_loss: 0.7010 - val_kl_loss: 0.5460 - lr: 0.0010
# Epoch 39/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8826 - reconstruction_loss: 0.7422 - kl_loss: 0.4631 - val_total_loss: 0.9540 - val_reconstruction_loss: 0.7820 - val_kl_loss: 0.5735 - lr: 0.0010
# Epoch 40/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8774 - reconstruction_loss: 0.7416 - kl_loss: 0.4628 - val_total_loss: 0.8584 - val_reconstruction_loss: 0.6799 - val_kl_loss: 0.5949 - lr: 0.0010
# Epoch 41/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8843 - reconstruction_loss: 0.7413 - kl_loss: 0.4672 - val_total_loss: 0.8774 - val_reconstruction_loss: 0.7100 - val_kl_loss: 0.5582 - lr: 0.0010
# Epoch 42/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8769 - reconstruction_loss: 0.7428 - kl_loss: 0.4478 - val_total_loss: 0.9551 - val_reconstruction_loss: 0.7878 - val_kl_loss: 0.5575 - lr: 0.0010
# Epoch 43/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8752 - reconstruction_loss: 0.7423 - kl_loss: 0.4596 - val_total_loss: 0.7879 - val_reconstruction_loss: 0.6226 - val_kl_loss: 0.5512 - lr: 0.0010
# Epoch 44/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8864 - reconstruction_loss: 0.7391 - kl_loss: 0.4576 - val_total_loss: 0.8790 - val_reconstruction_loss: 0.7026 - val_kl_loss: 0.5881 - lr: 0.0010
# Epoch 45/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8853 - reconstruction_loss: 0.7428 - kl_loss: 0.4509 - val_total_loss: 0.9258 - val_reconstruction_loss: 0.7543 - val_kl_loss: 0.5717 - lr: 0.0010
# Epoch 46/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8835 - reconstruction_loss: 0.7416 - kl_loss: 0.4644 - val_total_loss: 0.8027 - val_reconstruction_loss: 0.6323 - val_kl_loss: 0.5678 - lr: 0.0010
# Epoch 47/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8858 - reconstruction_loss: 0.7432 - kl_loss: 0.4578 - val_total_loss: 0.8367 - val_reconstruction_loss: 0.6692 - val_kl_loss: 0.5585 - lr: 0.0010
# Epoch 48/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8821 - reconstruction_loss: 0.7439 - kl_loss: 0.4420 - val_total_loss: 0.8733 - val_reconstruction_loss: 0.7072 - val_kl_loss: 0.5537 - lr: 0.0010
# Epoch 49/100
# 104/105 [============================>.] - ETA: 0s - loss: 0.8813 - reconstruction_loss: 0.7424 - kl_loss: 0.4656
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8813 - reconstruction_loss: 0.7420 - kl_loss: 0.4654 - val_total_loss: 0.8306 - val_reconstruction_loss: 0.6616 - val_kl_loss: 0.5636 - lr: 0.0010
# Epoch 50/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8719 - reconstruction_loss: 0.7401 - kl_loss: 0.4521 - val_total_loss: 0.9496 - val_reconstruction_loss: 0.7832 - val_kl_loss: 0.5547 - lr: 5.0000e-04
# Epoch 51/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8703 - reconstruction_loss: 0.7398 - kl_loss: 0.4639 - val_total_loss: 0.8098 - val_reconstruction_loss: 0.6380 - val_kl_loss: 0.5727 - lr: 5.0000e-04
# Epoch 52/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8700 - reconstruction_loss: 0.7366 - kl_loss: 0.4569 - val_total_loss: 0.9111 - val_reconstruction_loss: 0.7459 - val_kl_loss: 0.5507 - lr: 5.0000e-04
# Epoch 53/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8738 - reconstruction_loss: 0.7375 - kl_loss: 0.4620 - val_total_loss: 0.9262 - val_reconstruction_loss: 0.7594 - val_kl_loss: 0.5560 - lr: 5.0000e-04
# Epoch 54/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8833 - reconstruction_loss: 0.7442 - kl_loss: 0.4567 - val_total_loss: 0.9667 - val_reconstruction_loss: 0.7956 - val_kl_loss: 0.5703 - lr: 5.0000e-04
# Epoch 55/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8651 - reconstruction_loss: 0.7329 - kl_loss: 0.4658 - val_total_loss: 0.8303 - val_reconstruction_loss: 0.6621 - val_kl_loss: 0.5604 - lr: 5.0000e-04
# Epoch 56/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8913 - reconstruction_loss: 0.7436 - kl_loss: 0.4540 - val_total_loss: 0.9756 - val_reconstruction_loss: 0.8129 - val_kl_loss: 0.5423 - lr: 5.0000e-04
# Epoch 57/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8630 - reconstruction_loss: 0.7409 - kl_loss: 0.4552 - val_total_loss: 0.8365 - val_reconstruction_loss: 0.6702 - val_kl_loss: 0.5545 - lr: 5.0000e-04
# Epoch 58/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8744 - reconstruction_loss: 0.7400 - kl_loss: 0.4556 - val_total_loss: 0.8920 - val_reconstruction_loss: 0.7200 - val_kl_loss: 0.5735 - lr: 5.0000e-04
# Epoch 59/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8753 - reconstruction_loss: 0.7379 - kl_loss: 0.4601 - val_total_loss: 0.9769 - val_reconstruction_loss: 0.8104 - val_kl_loss: 0.5551 - lr: 5.0000e-04
# Epoch 60/100
# 101/105 [===========================>..] - ETA: 0s - loss: 0.8995 - reconstruction_loss: 0.7410 - kl_loss: 0.4726
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8986 - reconstruction_loss: 0.7393 - kl_loss: 0.4698 - val_total_loss: 0.8746 - val_reconstruction_loss: 0.6991 - val_kl_loss: 0.5850 - lr: 5.0000e-04
# Epoch 61/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8782 - reconstruction_loss: 0.7336 - kl_loss: 0.4682 - val_total_loss: 0.9510 - val_reconstruction_loss: 0.7818 - val_kl_loss: 0.5640 - lr: 2.5000e-04
# Epoch 62/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8721 - reconstruction_loss: 0.7390 - kl_loss: 0.4578 - val_total_loss: 0.9173 - val_reconstruction_loss: 0.7450 - val_kl_loss: 0.5743 - lr: 2.5000e-04
# Epoch 63/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8700 - reconstruction_loss: 0.7372 - kl_loss: 0.4635 - val_total_loss: 0.9137 - val_reconstruction_loss: 0.7440 - val_kl_loss: 0.5654 - lr: 2.5000e-04
# Epoch 64/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8730 - reconstruction_loss: 0.7404 - kl_loss: 0.4612 - val_total_loss: 0.9516 - val_reconstruction_loss: 0.7801 - val_kl_loss: 0.5719 - lr: 2.5000e-04
# Epoch 65/100
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8771 - reconstruction_loss: 0.7376 - kl_loss: 0.4663
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Restoring model weights from the end of the best epoch: 55.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8772 - reconstruction_loss: 0.7405 - kl_loss: 0.4666 - val_total_loss: 0.8892 - val_reconstruction_loss: 0.7182 - val_kl_loss: 0.5700 - lr: 2.5000e-04
# Epoch 65: early stopping

# %%
_, _, z_input = encoder.predict(x_train)
reconstructed_z_input = vae.decoder.predict(z_input)
_, _, reconstructed_z_encoded = vae.encoder.predict(reconstructed_z_input)

_, _, z_test_input = encoder.predict(x_test)
reconstructed_z_test_input = vae.decoder.predict(z_test_input)
_, _, reconstructed_z_test_encoded = vae.encoder.predict(reconstructed_z_test_input)
# Out:
# 262/262 [==============================] - 1s 2ms/step
# 262/262 [==============================] - 1s 2ms/step
# 262/262 [==============================] - 0s 966us/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step

# %%
def plot_input_data(x_data, y_data):
    z_input = x_data
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za trening enkodirani u latentni prostor")
plot_input_data(z_input, y_train)

plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

# %%
def plot_input_and_reconstructed_data(x_input_data, x_reconstructed, y_input_data):
    z_input = x_input_data
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Reconstructed Data')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.title("Podaci za testiranje i rekonstruirani podaci enkodirani u latentni prostor")
    plt.legend()
    plt.show()

plt.figure(figsize=(10, 6))
plot_input_and_reconstructed_data(z_test_input, reconstructed_z_test_encoded, y_test)

# %%
def plot_reconstructed_data(x_reconstructed, y_data):
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=f'Label {label}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirani podaci enkodirani u latentni prostor")
plot_reconstructed_data(reconstructed_z_test_encoded, y_test)

# %%
selected_indices = np.random.choice(len(x_test), 10, replace=False)

selected_peptides = x_test[selected_indices]

_, _, encoded_selected_peptides = vae.encoder.predict(selected_peptides)
reconstructed_peptides = vae.decoder.predict(encoded_selected_peptides)
_, _, encoded_reconstructed_peptides = vae.encoder.predict(reconstructed_peptides)


def plot_selected_data(x_data):
    z_input = x_data
    num_peptides = z_input.shape[0]
    unique_colors = plt.cm.tab20(np.linspace(0, 1, num_peptides))

    for i in range(num_peptides):
        plt.scatter(z_input[i, 0], z_input[i, 1], color=unique_colors[i], label=f'Peptide {i}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

    
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))


plt.figure(figsize=(10, 6))
plt.title("Slučajno izabrane izvorne točke u latentnom prostoru")
plot_selected_data(encoded_selected_peptides)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirane točke u latentnom prostoru")
plot_selected_data(encoded_reconstructed_peptides)


distances = []

for i in range(10):
    dist = euclidean_distance(encoded_selected_peptides[i], encoded_reconstructed_peptides[i])
        
    distances.append(dist)

print("Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke: \n", distances, "\n")
print("Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka: ", np.sum(distances)/10)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke:
#  [1.791477, 0.42107636, 2.1618125, 1.5641197, 2.0295622, 1.0867342, 0.8166532, 0.330507, 1.1754193, 2.0917373]
#
# Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka:  1.3469099044799804

# %%
#NORMALIZIRANA UDALJENOST U LATENTNOM PROSTORU

min_values = np.min(z_test_input, axis=0)
max_values = np.max(z_test_input, axis=0)

# Calculate the diagonal length of the latent space
latent_space_size = np.linalg.norm(max_values - min_values)
#print(min_values, max_values)
print(latent_space_size)

distances_test = []

for i in range(len(x_test)):
    dist = euclidean_distance(z_test_input[i], reconstructed_z_test_encoded[i])
        
    distances_test.append(dist)

print("Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka: ", 
      np.sum(distances_test)/latent_space_size/len(x_test))
# Out:
# 9.795956
# Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka:  0.14364332268388505

# %%
#PEARSON
from scipy.stats import spearmanr, kendalltau, pearsonr

#print(x_test)
#print(reconstructed_z_test_input)

print(pearsonr(x_test.flatten(), reconstructed_z_test_input.flatten()))
# Out:
# PearsonRResult(statistic=0.7640447776720707, pvalue=0.0)

# %%
#RAZLIKA I RMSE

difference = x_test - reconstructed_z_test_input
print(np.abs(np.mean(difference)))

mse = np.mean(np.square(x_test - reconstructed_z_test_input))
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# 0.00026770974818089233
# RMSE: 0.0917590835724783

# %%
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
  
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    alignments = pairwise2.align.globalxx(seq1, seq2)

    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    similarity = (score / max(len(seq1), len(seq2)))

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,101):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.39534884 0.18604651 0.34883721]
#  [0.1025641  0.         0.12820513 ... 0.13157895 0.125      0.05263158]
#  [0.20512821 0.28       0.23076923 ... 0.18421053 0.32       0.23684211]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.34210526 0.32432432 0.34210526]
#  [0.33333333 0.17777778 0.26666667 ... 0.33333333 0.22222222 0.33333333]
#  [0.07692308 0.25       0.15384615 ... 0.18421053 0.16666667 0.23684211]]
# [[0.27272727 0.18604651 0.27906977 ... 0.27906977 0.20930233 0.30232558]
#  [0.36363636 0.25581395 0.27906977 ... 0.3255814  0.1627907  0.18604651]
#  [0.25       0.17241379 0.26666667 ... 0.14285714 0.3        0.2       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.26190476 0.28571429 0.14285714]
#  [0.34090909 0.2972973  0.54054054 ... 0.28571429 0.24324324 0.2972973 ]
#  [0.09090909 0.13793103 0.06666667 ... 0.0952381  0.17647059 0.2       ]]

# %%
distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,101):
        dist_train = euclidean_distance(z_input[i], z_input[j])
        dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.3766685  0.21655884 0.33267403 ... 0.18163612 0.25886577 0.30867654]
#  [0.80666673 0.8699163  0.876983   ... 0.28625205 0.8234853  0.4655162 ]
#  [0.3423988  0.15107809 0.11826513 ... 0.43926975 0.15788235 0.5069553 ]
#  ...
#  [0.2831726  0.20807675 0.22184792 ... 0.32731903 0.12074105 0.3815717 ]
#  [0.20305565 0.66550386 0.56080586 ... 0.30332837 0.33258837 0.13383202]
#  [0.414969   0.16153082 0.31526175 ... 0.2129997  0.28202915 0.36088365]]
# [[0.84656334 0.66878915 0.631295   ... 0.7659976  0.35143295 0.46749026]
#  [0.47083908 0.3821946  0.31082767 ... 0.5392793  0.35363078 0.49984154]
#  [0.8351845  0.6104141  0.60458344 ... 0.7009303  0.27655756 0.3333082 ]
#  ...
#  [0.61060333 0.5305797  0.8113485  ... 0.31622088 0.7791612  0.4811223 ]
#  [0.89823073 1.         1.         ... 1.         0.9440422  1.        ]
#  [0.6857082  0.67471004 0.62964565 ... 0.76302814 0.58468795 0.7060619 ]]

# %%
correlation_train, p_value_train = spearmanr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = spearmanr(similarities_test.flatten(), distances_test.flatten())

print("Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")

correlation_train, p_value_train = kendalltau(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = kendalltau(similarities_test.flatten(), distances_test.flatten())

print("Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)
# Out:
# Spearmanov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.08254272489278679 -0.12102153871740108
# p-value: 3.002423328843935e-05 8.741765160754858e-10
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.1659878709320862 -0.13724351305571292
# p-value: 3.2711309983792234e-17 3.402317968800747e-12
#
# Kendall tau koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.05454112614586385 -0.081376154112266
# p-value: 3.9172601145813674e-05 8.743971930772916e-10
