# %%
#IMPORT KNJIŽNICA I ARHITEKTURA MODELA

#Import knjižnica
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback
import matplotlib.pyplot as plt

#Klasa za uzorkovanje iz latentnog prostora
class Sampling(layers.Layer):

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
latent_dim = 2

#Arhitektura enkodera
encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Arhitektura dekodera
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

#Klasa VAE
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
            total_loss = reconstruction_loss + 0.27 * kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + 0.27 * kl_loss

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 88, 8)        32          ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 44, 8)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_1[0][0]']
#
#  flatten (Flatten)              (None, 352)          0           ['max_pooling1d_1[0][0]']
#
#  dense (Dense)                  (None, 128)          45184       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense[0][0]']
#
#  sampling (Sampling)            (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 128)               384
#
#  dense_2 (Dense)             (None, 704)               90816
#
#  reshape (Reshape)           (None, 88, 8)             0
#
#  conv1d_2 (Conv1D)           (None, 88, 16)            400
#
#  up_sampling1d (UpSampling1D  (None, 176, 16)          0
#  )
#
#  conv1d_3 (Conv1D)           (None, 176, 8)            392
#
#  up_sampling1d_1 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 352, 1)            25
#
#  cropping1d (Cropping1D)     (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
#OBRADA PODATAKA

from sklearn.preprocessing import MinMaxScaler

#Učitavanje podataka i podjela na skupove za trening i testiranje
features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(
                                    features, labels, test_size=0.2, random_state=42)

#Odvajanje sekvenci peptida od ostatka podataka
x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]

#Odvajanje izračunatih značajki peptida
x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

#Normalizacija podataka
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

#Prilagođavanje dimenzionalnosti podataka
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
#OPTIMIZACIJA HIPERPARAMETARA

#Prostor pretrage
learn_rate = [0.001, 0.005, 0.008, 0.01]
batch_size = [32, 64, 128, 256]

param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

#Petlje u kojima se obavlja testiranje svih kombinacija hiperparametara iz prostora pretrage
for lr in learn_rate:
    for bs in batch_size:
        print("Learning rate: ", lr)
        print("Batch size: ", bs)
        
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))
        
        reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
        early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
        
        vae.fit(x_train, batch_size=bs, epochs=30, validation_split = 0.2, 
                callbacks=[reduce_lr, early_stop])

        score = vae.evaluate(x_train)
        print(score)

        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

#Ispis najboljih hiperparametara  
print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

#Spremanje najboljih hiperparametara u varijable za daljnje korištenje
lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Learning rate:  0.001
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 7ms/step - loss: 1.3435 - reconstruction_loss: 1.1404 - kl_loss: 0.0240 - val_total_loss: 0.9974 - val_reconstruction_loss: 0.9827 - val_kl_loss: 0.0547 - lr: 0.0010
# Epoch 2/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9626 - reconstruction_loss: 0.9367 - kl_loss: 0.0912 - val_total_loss: 0.9185 - val_reconstruction_loss: 0.8535 - val_kl_loss: 0.2408 - lr: 0.0010
# Epoch 3/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9576 - reconstruction_loss: 0.8523 - kl_loss: 0.2888 - val_total_loss: 0.8538 - val_reconstruction_loss: 0.7397 - val_kl_loss: 0.4227 - lr: 0.0010
# Epoch 4/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9190 - reconstruction_loss: 0.7937 - kl_loss: 0.4234 - val_total_loss: 0.9395 - val_reconstruction_loss: 0.7487 - val_kl_loss: 0.7066 - lr: 0.0010
# Epoch 5/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.9093 - reconstruction_loss: 0.7612 - kl_loss: 0.4953 - val_total_loss: 0.8979 - val_reconstruction_loss: 0.7404 - val_kl_loss: 0.5831 - lr: 0.0010
# Epoch 6/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8801 - reconstruction_loss: 0.7479 - kl_loss: 0.5308 - val_total_loss: 0.8948 - val_reconstruction_loss: 0.6992 - val_kl_loss: 0.7247 - lr: 0.0010
# Epoch 7/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8848 - reconstruction_loss: 0.7436 - kl_loss: 0.5311 - val_total_loss: 0.9619 - val_reconstruction_loss: 0.7821 - val_kl_loss: 0.6661 - lr: 0.0010
# Epoch 8/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8846 - reconstruction_loss: 0.7344 - kl_loss: 0.5632 - val_total_loss: 1.0207 - val_reconstruction_loss: 0.8376 - val_kl_loss: 0.6781 - lr: 0.0010
# Epoch 9/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8840 - reconstruction_loss: 0.7302 - kl_loss: 0.5627 - val_total_loss: 0.9344 - val_reconstruction_loss: 0.7651 - val_kl_loss: 0.6272 - lr: 0.0010
# Epoch 10/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8809 - reconstruction_loss: 0.7281 - kl_loss: 0.5674 - val_total_loss: 0.8726 - val_reconstruction_loss: 0.6770 - val_kl_loss: 0.7246 - lr: 0.0010
# Epoch 11/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8773 - reconstruction_loss: 0.7180 - kl_loss: 0.5856 - val_total_loss: 0.8187 - val_reconstruction_loss: 0.6390 - val_kl_loss: 0.6655 - lr: 0.0010
# Epoch 12/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8810 - reconstruction_loss: 0.7132 - kl_loss: 0.5971 - val_total_loss: 0.9771 - val_reconstruction_loss: 0.7698 - val_kl_loss: 0.7677 - lr: 0.0010
# Epoch 13/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8694 - reconstruction_loss: 0.7178 - kl_loss: 0.5924 - val_total_loss: 0.9193 - val_reconstruction_loss: 0.7201 - val_kl_loss: 0.7376 - lr: 0.0010
# Epoch 14/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8728 - reconstruction_loss: 0.7076 - kl_loss: 0.6191 - val_total_loss: 0.9299 - val_reconstruction_loss: 0.7152 - val_kl_loss: 0.7952 - lr: 0.0010
# Epoch 15/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8634 - reconstruction_loss: 0.7159 - kl_loss: 0.6040 - val_total_loss: 0.8628 - val_reconstruction_loss: 0.6592 - val_kl_loss: 0.7540 - lr: 0.0010
# Epoch 16/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8728 - reconstruction_loss: 0.7054 - kl_loss: 0.6122 - val_total_loss: 0.9210 - val_reconstruction_loss: 0.7350 - val_kl_loss: 0.6889 - lr: 0.0010
# Epoch 17/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8761 - reconstruction_loss: 0.7042 - kl_loss: 0.6136 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6905 - val_kl_loss: 0.6826 - lr: 0.0010
# Epoch 18/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8629 - reconstruction_loss: 0.7050 - kl_loss: 0.6027 - val_total_loss: 1.0496 - val_reconstruction_loss: 0.8613 - val_kl_loss: 0.6975 - lr: 0.0010
# Epoch 19/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8753 - reconstruction_loss: 0.7099 - kl_loss: 0.6266 - val_total_loss: 0.8530 - val_reconstruction_loss: 0.6358 - val_kl_loss: 0.8043 - lr: 0.0010
# Epoch 20/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8609 - reconstruction_loss: 0.7041 - kl_loss: 0.6154 - val_total_loss: 0.7736 - val_reconstruction_loss: 0.5887 - val_kl_loss: 0.6848 - lr: 0.0010
# Epoch 21/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8858 - reconstruction_loss: 0.6993 - kl_loss: 0.6554 - val_total_loss: 0.8191 - val_reconstruction_loss: 0.6461 - val_kl_loss: 0.6406 - lr: 0.0010
# Epoch 22/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8760 - reconstruction_loss: 0.7007 - kl_loss: 0.6500 - val_total_loss: 0.9731 - val_reconstruction_loss: 0.7772 - val_kl_loss: 0.7257 - lr: 0.0010
# Epoch 23/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8708 - reconstruction_loss: 0.6973 - kl_loss: 0.6420 - val_total_loss: 0.8525 - val_reconstruction_loss: 0.6100 - val_kl_loss: 0.8980 - lr: 0.0010
# Epoch 24/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8880 - reconstruction_loss: 0.6957 - kl_loss: 0.6430 - val_total_loss: 0.8493 - val_reconstruction_loss: 0.6474 - val_kl_loss: 0.7479 - lr: 0.0010
# Epoch 25/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8732 - reconstruction_loss: 0.6990 - kl_loss: 0.6421 - val_total_loss: 0.8686 - val_reconstruction_loss: 0.6456 - val_kl_loss: 0.8259 - lr: 0.0010
# Epoch 26/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8804 - reconstruction_loss: 0.6967 - kl_loss: 0.6476 - val_total_loss: 0.9571 - val_reconstruction_loss: 0.7213 - val_kl_loss: 0.8735 - lr: 0.0010
# Epoch 27/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8839 - reconstruction_loss: 0.6913 - kl_loss: 0.6516 - val_total_loss: 0.9050 - val_reconstruction_loss: 0.6988 - val_kl_loss: 0.7640 - lr: 0.0010
# Epoch 28/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8698 - reconstruction_loss: 0.6919 - kl_loss: 0.6417 - val_total_loss: 0.8357 - val_reconstruction_loss: 0.6156 - val_kl_loss: 0.8151 - lr: 0.0010
# Epoch 29/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8656 - reconstruction_loss: 0.6898 - kl_loss: 0.6411 - val_total_loss: 0.9024 - val_reconstruction_loss: 0.6963 - val_kl_loss: 0.7634 - lr: 0.0010
# Epoch 30/30
# 210/210 [==============================] - 1s 6ms/step - loss: 0.8675 - reconstruction_loss: 0.6885 - kl_loss: 0.6751 - val_total_loss: 0.9044 - val_reconstruction_loss: 0.6870 - val_kl_loss: 0.8052 - lr: 0.0010
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9290 - reconstruction_loss: 0.7285 - kl_loss: 0.7424
# [0.9289858341217041, 0.7285494208335876, 0.7423569560050964]
# Learning rate:  0.001
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8699 - reconstruction_loss: 0.6846 - kl_loss: 0.6629 - val_total_loss: 0.8690 - val_reconstruction_loss: 0.6493 - val_kl_loss: 0.8138 - lr: 0.0010
# Epoch 2/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8618 - reconstruction_loss: 0.6842 - kl_loss: 0.6654 - val_total_loss: 0.9166 - val_reconstruction_loss: 0.7047 - val_kl_loss: 0.7849 - lr: 0.0010
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8718 - reconstruction_loss: 0.6819 - kl_loss: 0.6789 - val_total_loss: 0.9279 - val_reconstruction_loss: 0.6960 - val_kl_loss: 0.8588 - lr: 0.0010
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8520 - reconstruction_loss: 0.6865 - kl_loss: 0.6622 - val_total_loss: 0.8025 - val_reconstruction_loss: 0.5941 - val_kl_loss: 0.7717 - lr: 0.0010
# Epoch 5/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8620 - reconstruction_loss: 0.6831 - kl_loss: 0.6761 - val_total_loss: 0.8554 - val_reconstruction_loss: 0.6387 - val_kl_loss: 0.8025 - lr: 0.0010
# Epoch 6/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8669 - reconstruction_loss: 0.6854 - kl_loss: 0.6686 - val_total_loss: 0.8821 - val_reconstruction_loss: 0.6752 - val_kl_loss: 0.7663 - lr: 0.0010
# Epoch 7/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8579 - reconstruction_loss: 0.6781 - kl_loss: 0.6557 - val_total_loss: 0.7658 - val_reconstruction_loss: 0.5448 - val_kl_loss: 0.8187 - lr: 0.0010
# Epoch 8/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8759 - reconstruction_loss: 0.6835 - kl_loss: 0.6730 - val_total_loss: 0.8645 - val_reconstruction_loss: 0.6599 - val_kl_loss: 0.7579 - lr: 0.0010
# Epoch 9/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8596 - reconstruction_loss: 0.6802 - kl_loss: 0.6591 - val_total_loss: 0.8984 - val_reconstruction_loss: 0.6779 - val_kl_loss: 0.8167 - lr: 0.0010
# Epoch 10/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8753 - reconstruction_loss: 0.6781 - kl_loss: 0.7042 - val_total_loss: 0.9566 - val_reconstruction_loss: 0.7332 - val_kl_loss: 0.8274 - lr: 0.0010
# Epoch 11/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8534 - reconstruction_loss: 0.6776 - kl_loss: 0.6801 - val_total_loss: 0.9869 - val_reconstruction_loss: 0.7574 - val_kl_loss: 0.8499 - lr: 0.0010
# Epoch 12/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8725 - reconstruction_loss: 0.6782 - kl_loss: 0.6743 - val_total_loss: 0.8226 - val_reconstruction_loss: 0.5729 - val_kl_loss: 0.9246 - lr: 0.0010
# Epoch 13/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8769 - reconstruction_loss: 0.6770 - kl_loss: 0.6905 - val_total_loss: 0.8386 - val_reconstruction_loss: 0.5967 - val_kl_loss: 0.8957 - lr: 0.0010
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8627 - reconstruction_loss: 0.6769 - kl_loss: 0.6761 - val_total_loss: 0.9975 - val_reconstruction_loss: 0.7719 - val_kl_loss: 0.8358 - lr: 0.0010
# Epoch 15/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8590 - reconstruction_loss: 0.6753 - kl_loss: 0.6975 - val_total_loss: 0.7395 - val_reconstruction_loss: 0.5079 - val_kl_loss: 0.8577 - lr: 0.0010
# Epoch 16/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8707 - reconstruction_loss: 0.6747 - kl_loss: 0.7074 - val_total_loss: 0.9581 - val_reconstruction_loss: 0.7454 - val_kl_loss: 0.7876 - lr: 0.0010
# Epoch 17/30
# 102/105 [============================>.] - ETA: 0s - loss: 0.8572 - reconstruction_loss: 0.6700 - kl_loss: 0.6964
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8572 - reconstruction_loss: 0.6690 - kl_loss: 0.6959 - val_total_loss: 1.0181 - val_reconstruction_loss: 0.7844 - val_kl_loss: 0.8655 - lr: 0.0010
# Epoch 18/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8612 - reconstruction_loss: 0.6721 - kl_loss: 0.6959 - val_total_loss: 0.9519 - val_reconstruction_loss: 0.7212 - val_kl_loss: 0.8544 - lr: 5.0000e-04
# Epoch 19/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8526 - reconstruction_loss: 0.6676 - kl_loss: 0.6938 - val_total_loss: 0.8927 - val_reconstruction_loss: 0.6650 - val_kl_loss: 0.8435 - lr: 5.0000e-04
# Epoch 20/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8479 - reconstruction_loss: 0.6718 - kl_loss: 0.6942 - val_total_loss: 0.7391 - val_reconstruction_loss: 0.5043 - val_kl_loss: 0.8699 - lr: 5.0000e-04
# Epoch 21/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8580 - reconstruction_loss: 0.6642 - kl_loss: 0.6988 - val_total_loss: 0.7151 - val_reconstruction_loss: 0.4820 - val_kl_loss: 0.8634 - lr: 5.0000e-04
# Epoch 22/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8671 - reconstruction_loss: 0.6710 - kl_loss: 0.6965 - val_total_loss: 0.9136 - val_reconstruction_loss: 0.6813 - val_kl_loss: 0.8604 - lr: 5.0000e-04
# Epoch 23/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8640 - reconstruction_loss: 0.6707 - kl_loss: 0.6984 - val_total_loss: 0.7405 - val_reconstruction_loss: 0.5046 - val_kl_loss: 0.8737 - lr: 5.0000e-04
# Epoch 24/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8613 - reconstruction_loss: 0.6719 - kl_loss: 0.6917 - val_total_loss: 1.0285 - val_reconstruction_loss: 0.8058 - val_kl_loss: 0.8250 - lr: 5.0000e-04
# Epoch 25/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8625 - reconstruction_loss: 0.6704 - kl_loss: 0.7103 - val_total_loss: 0.9323 - val_reconstruction_loss: 0.6959 - val_kl_loss: 0.8755 - lr: 5.0000e-04
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8681 - reconstruction_loss: 0.6691 - kl_loss: 0.7085 - val_total_loss: 0.8303 - val_reconstruction_loss: 0.5995 - val_kl_loss: 0.8547 - lr: 5.0000e-04
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8589 - reconstruction_loss: 0.6694 - kl_loss: 0.7010 - val_total_loss: 0.8355 - val_reconstruction_loss: 0.5941 - val_kl_loss: 0.8943 - lr: 5.0000e-04
# Epoch 28/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8499 - reconstruction_loss: 0.6702 - kl_loss: 0.7036 - val_total_loss: 1.0435 - val_reconstruction_loss: 0.8089 - val_kl_loss: 0.8688 - lr: 5.0000e-04
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8525 - reconstruction_loss: 0.6741 - kl_loss: 0.6920 - val_total_loss: 0.7696 - val_reconstruction_loss: 0.5220 - val_kl_loss: 0.9168 - lr: 5.0000e-04
# Epoch 30/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8661 - reconstruction_loss: 0.6664 - kl_loss: 0.7110 - val_total_loss: 0.7677 - val_reconstruction_loss: 0.5404 - val_kl_loss: 0.8417 - lr: 5.0000e-04
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9588 - reconstruction_loss: 0.7547 - kl_loss: 0.7557
# [0.9587522745132446, 0.754703938961029, 0.7557346820831299]
# Learning rate:  0.001
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 23ms/step - loss: 0.8621 - reconstruction_loss: 0.6681 - kl_loss: 0.7056 - val_total_loss: 0.8597 - val_reconstruction_loss: 0.6106 - val_kl_loss: 0.9228 - lr: 0.0010
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8638 - reconstruction_loss: 0.6638 - kl_loss: 0.7197 - val_total_loss: 0.8068 - val_reconstruction_loss: 0.5717 - val_kl_loss: 0.8707 - lr: 0.0010
# Epoch 3/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8612 - reconstruction_loss: 0.6682 - kl_loss: 0.7190 - val_total_loss: 0.8948 - val_reconstruction_loss: 0.6639 - val_kl_loss: 0.8551 - lr: 0.0010
# Epoch 4/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8653 - reconstruction_loss: 0.6666 - kl_loss: 0.7234 - val_total_loss: 0.8055 - val_reconstruction_loss: 0.5828 - val_kl_loss: 0.8247 - lr: 0.0010
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8641 - reconstruction_loss: 0.6696 - kl_loss: 0.7183 - val_total_loss: 0.8766 - val_reconstruction_loss: 0.6264 - val_kl_loss: 0.9266 - lr: 0.0010
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8657 - reconstruction_loss: 0.6679 - kl_loss: 0.7002 - val_total_loss: 0.8170 - val_reconstruction_loss: 0.5773 - val_kl_loss: 0.8878 - lr: 0.0010
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8601 - reconstruction_loss: 0.6669 - kl_loss: 0.6897 - val_total_loss: 0.8338 - val_reconstruction_loss: 0.6196 - val_kl_loss: 0.7930 - lr: 0.0010
# Epoch 8/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8557 - reconstruction_loss: 0.6716 - kl_loss: 0.7074 - val_total_loss: 0.8639 - val_reconstruction_loss: 0.6443 - val_kl_loss: 0.8131 - lr: 0.0010
# Epoch 9/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8575 - reconstruction_loss: 0.6643 - kl_loss: 0.7238 - val_total_loss: 0.8940 - val_reconstruction_loss: 0.6455 - val_kl_loss: 0.9203 - lr: 0.0010
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8630 - reconstruction_loss: 0.6660 - kl_loss: 0.7081 - val_total_loss: 0.8191 - val_reconstruction_loss: 0.5914 - val_kl_loss: 0.8432 - lr: 0.0010
# Epoch 11/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8511 - reconstruction_loss: 0.6684 - kl_loss: 0.6914 - val_total_loss: 0.8259 - val_reconstruction_loss: 0.6072 - val_kl_loss: 0.8101 - lr: 0.0010
# Epoch 12/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8595 - reconstruction_loss: 0.6655 - kl_loss: 0.7083 - val_total_loss: 0.6933 - val_reconstruction_loss: 0.4563 - val_kl_loss: 0.8778 - lr: 0.0010
# Epoch 13/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8648 - reconstruction_loss: 0.6703 - kl_loss: 0.6945 - val_total_loss: 0.7779 - val_reconstruction_loss: 0.5409 - val_kl_loss: 0.8775 - lr: 0.0010
# Epoch 14/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8583 - reconstruction_loss: 0.6644 - kl_loss: 0.7193 - val_total_loss: 1.0432 - val_reconstruction_loss: 0.8061 - val_kl_loss: 0.8783 - lr: 0.0010
# Epoch 15/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8518 - reconstruction_loss: 0.6663 - kl_loss: 0.7051 - val_total_loss: 0.9403 - val_reconstruction_loss: 0.7172 - val_kl_loss: 0.8262 - lr: 0.0010
# Epoch 16/30
# 53/53 [==============================] - 1s 14ms/step - loss: 0.8609 - reconstruction_loss: 0.6667 - kl_loss: 0.7038 - val_total_loss: 0.8541 - val_reconstruction_loss: 0.6213 - val_kl_loss: 0.8623 - lr: 0.0010
# Epoch 17/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8484 - reconstruction_loss: 0.6628 - kl_loss: 0.7210
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8487 - reconstruction_loss: 0.6616 - kl_loss: 0.7223 - val_total_loss: 0.8557 - val_reconstruction_loss: 0.6066 - val_kl_loss: 0.9223 - lr: 0.0010
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8372 - reconstruction_loss: 0.6597 - kl_loss: 0.7037 - val_total_loss: 0.9237 - val_reconstruction_loss: 0.6909 - val_kl_loss: 0.8622 - lr: 5.0000e-04
# Epoch 19/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8604 - reconstruction_loss: 0.6615 - kl_loss: 0.7199 - val_total_loss: 0.8887 - val_reconstruction_loss: 0.6487 - val_kl_loss: 0.8889 - lr: 5.0000e-04
# Epoch 20/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8540 - reconstruction_loss: 0.6583 - kl_loss: 0.7097 - val_total_loss: 0.9277 - val_reconstruction_loss: 0.6989 - val_kl_loss: 0.8474 - lr: 5.0000e-04
# Epoch 21/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8481 - reconstruction_loss: 0.6628 - kl_loss: 0.6865 - val_total_loss: 0.9937 - val_reconstruction_loss: 0.7558 - val_kl_loss: 0.8812 - lr: 5.0000e-04
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8438 - reconstruction_loss: 0.6612 - kl_loss: 0.7117 - val_total_loss: 0.7717 - val_reconstruction_loss: 0.5538 - val_kl_loss: 0.8067 - lr: 5.0000e-04
# Epoch 23/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8661 - reconstruction_loss: 0.6684 - kl_loss: 0.7242 - val_total_loss: 0.8590 - val_reconstruction_loss: 0.6170 - val_kl_loss: 0.8963 - lr: 5.0000e-04
# Epoch 24/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8549 - reconstruction_loss: 0.6624 - kl_loss: 0.7252 - val_total_loss: 0.9822 - val_reconstruction_loss: 0.7391 - val_kl_loss: 0.9005 - lr: 5.0000e-04
# Epoch 25/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8591 - reconstruction_loss: 0.6639 - kl_loss: 0.7182 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6266 - val_kl_loss: 0.9191 - lr: 5.0000e-04
# Epoch 26/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8489 - reconstruction_loss: 0.6616 - kl_loss: 0.7112 - val_total_loss: 0.7701 - val_reconstruction_loss: 0.5340 - val_kl_loss: 0.8742 - lr: 5.0000e-04
# Epoch 27/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8533 - reconstruction_loss: 0.6603 - kl_loss: 0.7224 - val_total_loss: 0.7584 - val_reconstruction_loss: 0.5277 - val_kl_loss: 0.8542 - lr: 5.0000e-04
# Epoch 28/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8551 - reconstruction_loss: 0.6610 - kl_loss: 0.7043 - val_total_loss: 0.8254 - val_reconstruction_loss: 0.5981 - val_kl_loss: 0.8418 - lr: 5.0000e-04
# Epoch 29/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8511 - reconstruction_loss: 0.6644 - kl_loss: 0.6946 - val_total_loss: 0.8628 - val_reconstruction_loss: 0.6414 - val_kl_loss: 0.8199 - lr: 5.0000e-04
# Epoch 30/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8619 - reconstruction_loss: 0.6613 - kl_loss: 0.7065 - val_total_loss: 0.8141 - val_reconstruction_loss: 0.5840 - val_kl_loss: 0.8520 - lr: 5.0000e-04
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.8869 - reconstruction_loss: 0.6827 - kl_loss: 0.7563
# [0.8869089484214783, 0.6827007532119751, 0.7563266158103943]
# Learning rate:  0.001
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 2s 35ms/step - loss: 0.8551 - reconstruction_loss: 0.6667 - kl_loss: 0.7281 - val_total_loss: 0.8573 - val_reconstruction_loss: 0.6465 - val_kl_loss: 0.7807 - lr: 0.0010
# Epoch 2/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8517 - reconstruction_loss: 0.6595 - kl_loss: 0.7137 - val_total_loss: 0.8711 - val_reconstruction_loss: 0.6587 - val_kl_loss: 0.7868 - lr: 0.0010
# Epoch 3/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8596 - reconstruction_loss: 0.6566 - kl_loss: 0.7308 - val_total_loss: 0.8800 - val_reconstruction_loss: 0.6572 - val_kl_loss: 0.8250 - lr: 0.0010
# Epoch 4/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8526 - reconstruction_loss: 0.6637 - kl_loss: 0.7078 - val_total_loss: 0.8558 - val_reconstruction_loss: 0.6375 - val_kl_loss: 0.8086 - lr: 0.0010
# Epoch 5/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8512 - reconstruction_loss: 0.6584 - kl_loss: 0.7119 - val_total_loss: 0.8669 - val_reconstruction_loss: 0.6519 - val_kl_loss: 0.7963 - lr: 0.0010
# Epoch 6/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8496 - reconstruction_loss: 0.6646 - kl_loss: 0.7030 - val_total_loss: 0.8495 - val_reconstruction_loss: 0.6389 - val_kl_loss: 0.7800 - lr: 0.0010
# Epoch 7/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8498 - reconstruction_loss: 0.6587 - kl_loss: 0.7371 - val_total_loss: 0.8280 - val_reconstruction_loss: 0.6126 - val_kl_loss: 0.7978 - lr: 0.0010
# Epoch 8/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8527 - reconstruction_loss: 0.6591 - kl_loss: 0.7137 - val_total_loss: 0.8683 - val_reconstruction_loss: 0.6668 - val_kl_loss: 0.7461 - lr: 0.0010
# Epoch 9/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8529 - reconstruction_loss: 0.6640 - kl_loss: 0.7253 - val_total_loss: 0.8457 - val_reconstruction_loss: 0.6326 - val_kl_loss: 0.7892 - lr: 0.0010
# Epoch 10/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8569 - reconstruction_loss: 0.6581 - kl_loss: 0.7161 - val_total_loss: 0.8765 - val_reconstruction_loss: 0.6528 - val_kl_loss: 0.8284 - lr: 0.0010
# Epoch 11/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8500 - reconstruction_loss: 0.6599 - kl_loss: 0.7020 - val_total_loss: 0.8523 - val_reconstruction_loss: 0.6493 - val_kl_loss: 0.7517 - lr: 0.0010
# Epoch 12/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8544 - reconstruction_loss: 0.6617 - kl_loss: 0.7196 - val_total_loss: 0.8525 - val_reconstruction_loss: 0.6214 - val_kl_loss: 0.8560 - lr: 0.0010
# Epoch 13/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8626 - reconstruction_loss: 0.6544 - kl_loss: 0.7259 - val_total_loss: 0.8388 - val_reconstruction_loss: 0.6307 - val_kl_loss: 0.7708 - lr: 0.0010
# Epoch 14/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8539 - reconstruction_loss: 0.6682 - kl_loss: 0.7046 - val_total_loss: 0.8347 - val_reconstruction_loss: 0.6197 - val_kl_loss: 0.7961 - lr: 0.0010
# Epoch 15/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8515 - reconstruction_loss: 0.6575 - kl_loss: 0.7148 - val_total_loss: 0.8546 - val_reconstruction_loss: 0.6272 - val_kl_loss: 0.8420 - lr: 0.0010
# Epoch 16/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8564 - reconstruction_loss: 0.6580 - kl_loss: 0.7168 - val_total_loss: 0.8326 - val_reconstruction_loss: 0.6150 - val_kl_loss: 0.8059 - lr: 0.0010
# Epoch 17/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8557 - reconstruction_loss: 0.6601 - kl_loss: 0.7103 - val_total_loss: 0.8954 - val_reconstruction_loss: 0.6830 - val_kl_loss: 0.7865 - lr: 0.0010
# Epoch 18/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8400 - reconstruction_loss: 0.6575 - kl_loss: 0.6962 - val_total_loss: 0.8942 - val_reconstruction_loss: 0.6893 - val_kl_loss: 0.7589 - lr: 0.0010
# Epoch 19/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8458 - reconstruction_loss: 0.6646 - kl_loss: 0.7040 - val_total_loss: 0.8634 - val_reconstruction_loss: 0.6482 - val_kl_loss: 0.7971 - lr: 0.0010
# Epoch 20/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8401 - reconstruction_loss: 0.6603 - kl_loss: 0.7204 - val_total_loss: 0.8617 - val_reconstruction_loss: 0.6390 - val_kl_loss: 0.8249 - lr: 0.0010
# Epoch 21/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8475 - reconstruction_loss: 0.6648 - kl_loss: 0.7130 - val_total_loss: 0.8918 - val_reconstruction_loss: 0.6729 - val_kl_loss: 0.8107 - lr: 0.0010
# Epoch 22/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8499 - reconstruction_loss: 0.6538 - kl_loss: 0.7250 - val_total_loss: 0.8816 - val_reconstruction_loss: 0.6669 - val_kl_loss: 0.7952 - lr: 0.0010
# Epoch 23/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8628 - reconstruction_loss: 0.6608 - kl_loss: 0.7115 - val_total_loss: 0.8950 - val_reconstruction_loss: 0.6816 - val_kl_loss: 0.7906 - lr: 0.0010
# Epoch 24/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8516 - reconstruction_loss: 0.6674 - kl_loss: 0.7029 - val_total_loss: 0.8502 - val_reconstruction_loss: 0.6298 - val_kl_loss: 0.8162 - lr: 0.0010
# Epoch 25/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8596 - reconstruction_loss: 0.6570 - kl_loss: 0.7331 - val_total_loss: 0.8748 - val_reconstruction_loss: 0.6485 - val_kl_loss: 0.8382 - lr: 0.0010
# Epoch 26/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8429 - reconstruction_loss: 0.6600 - kl_loss: 0.7144 - val_total_loss: 0.8893 - val_reconstruction_loss: 0.6830 - val_kl_loss: 0.7638 - lr: 0.0010
# Epoch 27/30
# 27/27 [==============================] - 1s 28ms/step - loss: 0.8640 - reconstruction_loss: 0.6658 - kl_loss: 0.7443 - val_total_loss: 0.8867 - val_reconstruction_loss: 0.6655 - val_kl_loss: 0.8192 - lr: 0.0010
# Epoch 28/30
# 26/27 [===========================>..] - ETA: 0s - loss: 0.8591 - reconstruction_loss: 0.6587 - kl_loss: 0.7340
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8592 - reconstruction_loss: 0.6602 - kl_loss: 0.7408 - val_total_loss: 0.8987 - val_reconstruction_loss: 0.6776 - val_kl_loss: 0.8190 - lr: 0.0010
# Epoch 29/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8501 - reconstruction_loss: 0.6580 - kl_loss: 0.7204 - val_total_loss: 0.8263 - val_reconstruction_loss: 0.6090 - val_kl_loss: 0.8051 - lr: 5.0000e-04
# Epoch 30/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8465 - reconstruction_loss: 0.6574 - kl_loss: 0.7220 - val_total_loss: 0.8878 - val_reconstruction_loss: 0.6784 - val_kl_loss: 0.7756 - lr: 5.0000e-04
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9111 - reconstruction_loss: 0.7076 - kl_loss: 0.7539
# [0.9111257195472717, 0.7075737714767456, 0.7538960576057434]
# Learning rate:  0.005
# Batch size:  32
# Epoch 1/30
# 210/210 [==============================] - 3s 8ms/step - loss: 0.8989 - reconstruction_loss: 0.7207 - kl_loss: 0.6296 - val_total_loss: 0.7955 - val_reconstruction_loss: 0.5350 - val_kl_loss: 0.9648 - lr: 0.0050
# Epoch 2/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8781 - reconstruction_loss: 0.7127 - kl_loss: 0.6337 - val_total_loss: 0.9669 - val_reconstruction_loss: 0.7645 - val_kl_loss: 0.7500 - lr: 0.0050
# Epoch 3/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8792 - reconstruction_loss: 0.7060 - kl_loss: 0.6448 - val_total_loss: 0.8623 - val_reconstruction_loss: 0.6300 - val_kl_loss: 0.8604 - lr: 0.0050
# Epoch 4/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8809 - reconstruction_loss: 0.7097 - kl_loss: 0.6550 - val_total_loss: 0.9970 - val_reconstruction_loss: 0.8057 - val_kl_loss: 0.7087 - lr: 0.0050
# Epoch 5/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8808 - reconstruction_loss: 0.7030 - kl_loss: 0.6584 - val_total_loss: 0.8576 - val_reconstruction_loss: 0.6583 - val_kl_loss: 0.7383 - lr: 0.0050
# Epoch 6/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8894 - reconstruction_loss: 0.7020 - kl_loss: 0.6660 - val_total_loss: 0.9011 - val_reconstruction_loss: 0.7134 - val_kl_loss: 0.6953 - lr: 0.0050
# Epoch 7/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8887 - reconstruction_loss: 0.7094 - kl_loss: 0.6330 - val_total_loss: 1.0271 - val_reconstruction_loss: 0.7712 - val_kl_loss: 0.9478 - lr: 0.0050
# Epoch 8/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8947 - reconstruction_loss: 0.7051 - kl_loss: 0.6714 - val_total_loss: 0.8827 - val_reconstruction_loss: 0.6544 - val_kl_loss: 0.8455 - lr: 0.0050
# Epoch 9/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8679 - reconstruction_loss: 0.7003 - kl_loss: 0.6767 - val_total_loss: 0.7913 - val_reconstruction_loss: 0.6097 - val_kl_loss: 0.6727 - lr: 0.0050
# Epoch 10/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.9211 - reconstruction_loss: 0.7311 - kl_loss: 0.5771 - val_total_loss: 0.8571 - val_reconstruction_loss: 0.6753 - val_kl_loss: 0.6736 - lr: 0.0050
# Epoch 11/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8976 - reconstruction_loss: 0.7004 - kl_loss: 0.6538 - val_total_loss: 0.8442 - val_reconstruction_loss: 0.5882 - val_kl_loss: 0.9480 - lr: 0.0050
# Epoch 12/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8751 - reconstruction_loss: 0.6956 - kl_loss: 0.6684 - val_total_loss: 0.8251 - val_reconstruction_loss: 0.6202 - val_kl_loss: 0.7591 - lr: 0.0050
# Epoch 13/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8749 - reconstruction_loss: 0.6961 - kl_loss: 0.6743 - val_total_loss: 0.9043 - val_reconstruction_loss: 0.6445 - val_kl_loss: 0.9621 - lr: 0.0050
# Epoch 14/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8691 - reconstruction_loss: 0.6924 - kl_loss: 0.6689 - val_total_loss: 0.8044 - val_reconstruction_loss: 0.6185 - val_kl_loss: 0.6885 - lr: 0.0050
# Epoch 15/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8816 - reconstruction_loss: 0.6981 - kl_loss: 0.6491 - val_total_loss: 0.9593 - val_reconstruction_loss: 0.7214 - val_kl_loss: 0.8811 - lr: 0.0050
# Epoch 16/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8748 - reconstruction_loss: 0.6983 - kl_loss: 0.6496 - val_total_loss: 0.8742 - val_reconstruction_loss: 0.6530 - val_kl_loss: 0.8190 - lr: 0.0050
# Epoch 17/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8735 - reconstruction_loss: 0.6899 - kl_loss: 0.6780 - val_total_loss: 0.9979 - val_reconstruction_loss: 0.8146 - val_kl_loss: 0.6789 - lr: 0.0050
# Epoch 18/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8787 - reconstruction_loss: 0.7055 - kl_loss: 0.6447 - val_total_loss: 0.9177 - val_reconstruction_loss: 0.6729 - val_kl_loss: 0.9067 - lr: 0.0050
# Epoch 19/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8599 - reconstruction_loss: 0.6939 - kl_loss: 0.6773 - val_total_loss: 0.8647 - val_reconstruction_loss: 0.6086 - val_kl_loss: 0.9486 - lr: 0.0050
# Epoch 20/30
# 210/210 [==============================] - 2s 7ms/step - loss: 0.8908 - reconstruction_loss: 0.6994 - kl_loss: 0.6663 - val_total_loss: 1.0025 - val_reconstruction_loss: 0.7592 - val_kl_loss: 0.9010 - lr: 0.0050
# Epoch 21/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8720 - reconstruction_loss: 0.6865 - kl_loss: 0.6761 - val_total_loss: 0.8996 - val_reconstruction_loss: 0.6980 - val_kl_loss: 0.7468 - lr: 0.0050
# Epoch 22/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8668 - reconstruction_loss: 0.6920 - kl_loss: 0.6628 - val_total_loss: 0.8113 - val_reconstruction_loss: 0.6278 - val_kl_loss: 0.6796 - lr: 0.0050
# Epoch 23/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8860 - reconstruction_loss: 0.7000 - kl_loss: 0.6399 - val_total_loss: 0.8893 - val_reconstruction_loss: 0.6884 - val_kl_loss: 0.7440 - lr: 0.0050
# Epoch 24/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8831 - reconstruction_loss: 0.6964 - kl_loss: 0.6625 - val_total_loss: 0.8953 - val_reconstruction_loss: 0.6694 - val_kl_loss: 0.8366 - lr: 0.0050
# Epoch 25/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8722 - reconstruction_loss: 0.6890 - kl_loss: 0.6697 - val_total_loss: 0.9533 - val_reconstruction_loss: 0.7303 - val_kl_loss: 0.8258 - lr: 0.0050
# Epoch 26/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8806 - reconstruction_loss: 0.6972 - kl_loss: 0.6627 - val_total_loss: 0.8075 - val_reconstruction_loss: 0.5899 - val_kl_loss: 0.8062 - lr: 0.0050
# Epoch 27/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8793 - reconstruction_loss: 0.6953 - kl_loss: 0.6627 - val_total_loss: 0.9090 - val_reconstruction_loss: 0.6912 - val_kl_loss: 0.8067 - lr: 0.0050
# Epoch 28/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8810 - reconstruction_loss: 0.6904 - kl_loss: 0.6664 - val_total_loss: 0.9398 - val_reconstruction_loss: 0.7295 - val_kl_loss: 0.7790 - lr: 0.0050
# Epoch 29/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8554 - reconstruction_loss: 0.6922 - kl_loss: 0.6514 - val_total_loss: 0.8841 - val_reconstruction_loss: 0.6601 - val_kl_loss: 0.8297 - lr: 0.0050
# Epoch 30/30
# 210/210 [==============================] - 1s 7ms/step - loss: 0.8663 - reconstruction_loss: 0.6861 - kl_loss: 0.6644 - val_total_loss: 0.8707 - val_reconstruction_loss: 0.6706 - val_kl_loss: 0.7412 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 1.0806 - reconstruction_loss: 0.9001 - kl_loss: 0.6687
# [1.0806282758712769, 0.9000669717788696, 0.6687453985214233]
# Learning rate:  0.005
# Batch size:  64
# Epoch 1/30
# 105/105 [==============================] - 3s 12ms/step - loss: 0.8735 - reconstruction_loss: 0.6932 - kl_loss: 0.6565 - val_total_loss: 0.9631 - val_reconstruction_loss: 0.7509 - val_kl_loss: 0.7860 - lr: 0.0050
# Epoch 2/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8492 - reconstruction_loss: 0.6831 - kl_loss: 0.6535 - val_total_loss: 0.9366 - val_reconstruction_loss: 0.7129 - val_kl_loss: 0.8286 - lr: 0.0050
# Epoch 3/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8593 - reconstruction_loss: 0.6782 - kl_loss: 0.6663 - val_total_loss: 0.8156 - val_reconstruction_loss: 0.6065 - val_kl_loss: 0.7744 - lr: 0.0050
# Epoch 4/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8517 - reconstruction_loss: 0.6796 - kl_loss: 0.6694 - val_total_loss: 0.8263 - val_reconstruction_loss: 0.5987 - val_kl_loss: 0.8429 - lr: 0.0050
# Epoch 5/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8584 - reconstruction_loss: 0.6803 - kl_loss: 0.6802 - val_total_loss: 0.8456 - val_reconstruction_loss: 0.6155 - val_kl_loss: 0.8521 - lr: 0.0050
# Epoch 6/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8576 - reconstruction_loss: 0.6746 - kl_loss: 0.6946 - val_total_loss: 0.9135 - val_reconstruction_loss: 0.6798 - val_kl_loss: 0.8656 - lr: 0.0050
# Epoch 7/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8634 - reconstruction_loss: 0.6804 - kl_loss: 0.6665 - val_total_loss: 0.9257 - val_reconstruction_loss: 0.7059 - val_kl_loss: 0.8141 - lr: 0.0050
# Epoch 8/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8515 - reconstruction_loss: 0.6727 - kl_loss: 0.7072 - val_total_loss: 0.9914 - val_reconstruction_loss: 0.7777 - val_kl_loss: 0.7914 - lr: 0.0050
# Epoch 9/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8540 - reconstruction_loss: 0.6736 - kl_loss: 0.6948 - val_total_loss: 0.8480 - val_reconstruction_loss: 0.6268 - val_kl_loss: 0.8196 - lr: 0.0050
# Epoch 10/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8604 - reconstruction_loss: 0.6751 - kl_loss: 0.6801 - val_total_loss: 0.8148 - val_reconstruction_loss: 0.5962 - val_kl_loss: 0.8095 - lr: 0.0050
# Epoch 11/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8579 - reconstruction_loss: 0.6757 - kl_loss: 0.6957 - val_total_loss: 0.8415 - val_reconstruction_loss: 0.6464 - val_kl_loss: 0.7226 - lr: 0.0050
# Epoch 12/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8517 - reconstruction_loss: 0.6782 - kl_loss: 0.6703 - val_total_loss: 0.8793 - val_reconstruction_loss: 0.6571 - val_kl_loss: 0.8232 - lr: 0.0050
# Epoch 13/30
#  99/105 [===========================>..] - ETA: 0s - loss: 0.8642 - reconstruction_loss: 0.6792 - kl_loss: 0.6778
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8642 - reconstruction_loss: 0.6800 - kl_loss: 0.6854 - val_total_loss: 0.8960 - val_reconstruction_loss: 0.6519 - val_kl_loss: 0.9041 - lr: 0.0050
# Epoch 14/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8521 - reconstruction_loss: 0.6668 - kl_loss: 0.7117 - val_total_loss: 0.8624 - val_reconstruction_loss: 0.6236 - val_kl_loss: 0.8845 - lr: 0.0025
# Epoch 15/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8548 - reconstruction_loss: 0.6623 - kl_loss: 0.7099 - val_total_loss: 0.8480 - val_reconstruction_loss: 0.6080 - val_kl_loss: 0.8888 - lr: 0.0025
# Epoch 16/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8393 - reconstruction_loss: 0.6616 - kl_loss: 0.7064 - val_total_loss: 0.7868 - val_reconstruction_loss: 0.5548 - val_kl_loss: 0.8591 - lr: 0.0025
# Epoch 17/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8474 - reconstruction_loss: 0.6611 - kl_loss: 0.7081 - val_total_loss: 0.7597 - val_reconstruction_loss: 0.5177 - val_kl_loss: 0.8962 - lr: 0.0025
# Epoch 18/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8583 - reconstruction_loss: 0.6623 - kl_loss: 0.7166 - val_total_loss: 0.8063 - val_reconstruction_loss: 0.5672 - val_kl_loss: 0.8857 - lr: 0.0025
# Epoch 19/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8473 - reconstruction_loss: 0.6622 - kl_loss: 0.7021 - val_total_loss: 0.9209 - val_reconstruction_loss: 0.6709 - val_kl_loss: 0.9257 - lr: 0.0025
# Epoch 20/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8561 - reconstruction_loss: 0.6672 - kl_loss: 0.6999 - val_total_loss: 1.0143 - val_reconstruction_loss: 0.7745 - val_kl_loss: 0.8880 - lr: 0.0025
# Epoch 21/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8525 - reconstruction_loss: 0.6670 - kl_loss: 0.6911 - val_total_loss: 0.8396 - val_reconstruction_loss: 0.6068 - val_kl_loss: 0.8625 - lr: 0.0025
# Epoch 22/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8472 - reconstruction_loss: 0.6658 - kl_loss: 0.6973 - val_total_loss: 0.8272 - val_reconstruction_loss: 0.5816 - val_kl_loss: 0.9098 - lr: 0.0025
# Epoch 23/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8463 - reconstruction_loss: 0.6610 - kl_loss: 0.7041 - val_total_loss: 0.9718 - val_reconstruction_loss: 0.7491 - val_kl_loss: 0.8248 - lr: 0.0025
# Epoch 24/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8533 - reconstruction_loss: 0.6658 - kl_loss: 0.7136 - val_total_loss: 0.9238 - val_reconstruction_loss: 0.6708 - val_kl_loss: 0.9373 - lr: 0.0025
# Epoch 25/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8497 - reconstruction_loss: 0.6663 - kl_loss: 0.7125 - val_total_loss: 0.8279 - val_reconstruction_loss: 0.6031 - val_kl_loss: 0.8327 - lr: 0.0025
# Epoch 26/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8564 - reconstruction_loss: 0.6630 - kl_loss: 0.7251 - val_total_loss: 0.9980 - val_reconstruction_loss: 0.7609 - val_kl_loss: 0.8780 - lr: 0.0025
# Epoch 27/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8504 - reconstruction_loss: 0.6650 - kl_loss: 0.7143 - val_total_loss: 0.7935 - val_reconstruction_loss: 0.5686 - val_kl_loss: 0.8329 - lr: 0.0025
# Epoch 28/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8634 - reconstruction_loss: 0.6662 - kl_loss: 0.7176 - val_total_loss: 0.8478 - val_reconstruction_loss: 0.6128 - val_kl_loss: 0.8704 - lr: 0.0025
# Epoch 29/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8554 - reconstruction_loss: 0.6657 - kl_loss: 0.6904 - val_total_loss: 0.8842 - val_reconstruction_loss: 0.6438 - val_kl_loss: 0.8902 - lr: 0.0025
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8527 - reconstruction_loss: 0.6606 - kl_loss: 0.7141 - val_total_loss: 0.8924 - val_reconstruction_loss: 0.6626 - val_kl_loss: 0.8515 - lr: 0.0025
# 262/262 [==============================] - 1s 3ms/step - total_loss: 0.9677 - reconstruction_loss: 0.7631 - kl_loss: 0.7577
# [0.9676913619041443, 0.7631133198738098, 0.7576964497566223]
# Learning rate:  0.005
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 20ms/step - loss: 0.8740 - reconstruction_loss: 0.6641 - kl_loss: 0.7229 - val_total_loss: 0.9505 - val_reconstruction_loss: 0.7365 - val_kl_loss: 0.7929 - lr: 0.0050
# Epoch 2/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8570 - reconstruction_loss: 0.6687 - kl_loss: 0.7055 - val_total_loss: 0.8215 - val_reconstruction_loss: 0.5902 - val_kl_loss: 0.8567 - lr: 0.0050
# Epoch 3/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8579 - reconstruction_loss: 0.6694 - kl_loss: 0.7114 - val_total_loss: 0.9048 - val_reconstruction_loss: 0.6841 - val_kl_loss: 0.8175 - lr: 0.0050
# Epoch 4/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8606 - reconstruction_loss: 0.6710 - kl_loss: 0.7041 - val_total_loss: 0.9146 - val_reconstruction_loss: 0.6831 - val_kl_loss: 0.8577 - lr: 0.0050
# Epoch 5/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8582 - reconstruction_loss: 0.6654 - kl_loss: 0.7089 - val_total_loss: 0.9107 - val_reconstruction_loss: 0.6894 - val_kl_loss: 0.8195 - lr: 0.0050
# Epoch 6/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8469 - reconstruction_loss: 0.6634 - kl_loss: 0.7102 - val_total_loss: 0.9726 - val_reconstruction_loss: 0.7175 - val_kl_loss: 0.9446 - lr: 0.0050
# Epoch 7/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8603 - reconstruction_loss: 0.6639 - kl_loss: 0.7163 - val_total_loss: 0.9381 - val_reconstruction_loss: 0.7091 - val_kl_loss: 0.8482 - lr: 0.0050
# Epoch 8/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8461 - reconstruction_loss: 0.6670 - kl_loss: 0.6860 - val_total_loss: 0.8600 - val_reconstruction_loss: 0.6304 - val_kl_loss: 0.8505 - lr: 0.0050
# Epoch 9/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8582 - reconstruction_loss: 0.6605 - kl_loss: 0.7359 - val_total_loss: 0.8399 - val_reconstruction_loss: 0.6071 - val_kl_loss: 0.8625 - lr: 0.0050
# Epoch 10/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8449 - reconstruction_loss: 0.6574 - kl_loss: 0.7146 - val_total_loss: 0.9175 - val_reconstruction_loss: 0.6927 - val_kl_loss: 0.8324 - lr: 0.0050
# Epoch 11/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8600 - reconstruction_loss: 0.6729 - kl_loss: 0.6908 - val_total_loss: 0.9722 - val_reconstruction_loss: 0.7572 - val_kl_loss: 0.7965 - lr: 0.0050
# Epoch 12/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8513 - reconstruction_loss: 0.6649 - kl_loss: 0.7112 - val_total_loss: 0.8313 - val_reconstruction_loss: 0.5924 - val_kl_loss: 0.8849 - lr: 0.0050
# Epoch 13/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8474 - reconstruction_loss: 0.6615 - kl_loss: 0.6929 - val_total_loss: 0.7648 - val_reconstruction_loss: 0.5300 - val_kl_loss: 0.8697 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8532 - reconstruction_loss: 0.6652 - kl_loss: 0.7242 - val_total_loss: 0.8303 - val_reconstruction_loss: 0.5843 - val_kl_loss: 0.9112 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8525 - reconstruction_loss: 0.6644 - kl_loss: 0.7118 - val_total_loss: 0.9043 - val_reconstruction_loss: 0.6688 - val_kl_loss: 0.8723 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8490 - reconstruction_loss: 0.6670 - kl_loss: 0.6974 - val_total_loss: 0.8299 - val_reconstruction_loss: 0.6063 - val_kl_loss: 0.8282 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8616 - reconstruction_loss: 0.6565 - kl_loss: 0.7270 - val_total_loss: 0.7478 - val_reconstruction_loss: 0.5288 - val_kl_loss: 0.8111 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8570 - reconstruction_loss: 0.6630 - kl_loss: 0.7231 - val_total_loss: 0.9886 - val_reconstruction_loss: 0.7711 - val_kl_loss: 0.8056 - lr: 0.0050
# Epoch 19/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8661 - reconstruction_loss: 0.6614 - kl_loss: 0.7128 - val_total_loss: 0.7764 - val_reconstruction_loss: 0.5784 - val_kl_loss: 0.7336 - lr: 0.0050
# Epoch 20/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8519 - reconstruction_loss: 0.6591 - kl_loss: 0.7150 - val_total_loss: 0.9627 - val_reconstruction_loss: 0.7278 - val_kl_loss: 0.8702 - lr: 0.0050
# Epoch 21/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8628 - reconstruction_loss: 0.6637 - kl_loss: 0.7267 - val_total_loss: 0.8927 - val_reconstruction_loss: 0.6253 - val_kl_loss: 0.9903 - lr: 0.0050
# Epoch 22/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8517 - reconstruction_loss: 0.6603 - kl_loss: 0.7177 - val_total_loss: 0.9167 - val_reconstruction_loss: 0.7108 - val_kl_loss: 0.7627 - lr: 0.0050
# Epoch 23/30
# 52/53 [============================>.] - ETA: 0s - loss: 0.8632 - reconstruction_loss: 0.6691 - kl_loss: 0.6997
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8630 - reconstruction_loss: 0.6695 - kl_loss: 0.6999 - val_total_loss: 0.7792 - val_reconstruction_loss: 0.5465 - val_kl_loss: 0.8620 - lr: 0.0050
# Epoch 24/30
# ...
# Epoch 25/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8546 - reconstruction_loss: 0.6660 - kl_loss: 0.6979 - val_total_loss: 0.8621 - val_reconstruction_loss: 0.6126 - val_kl_loss: 0.9240 - lr: 0.0050
# Epoch 26/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8580 - reconstruction_loss: 0.6656 - kl_loss: 0.6918 - val_total_loss: 0.7569 - val_reconstruction_loss: 0.4967 - val_kl_loss: 0.9637 - lr: 0.0050
# Epoch 27/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8449 - reconstruction_loss: 0.6616 - kl_loss: 0.7216 - val_total_loss: 0.7843 - val_reconstruction_loss: 0.5405 - val_kl_loss: 0.9029 - lr: 0.0050
# Epoch 28/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8667 - reconstruction_loss: 0.6628 - kl_loss: 0.7288 - val_total_loss: 0.8149 - val_reconstruction_loss: 0.5739 - val_kl_loss: 0.8927 - lr: 0.0050
# Epoch 29/30
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8641 - reconstruction_loss: 0.6711 - kl_loss: 0.6964 - val_total_loss: 0.9423 - val_reconstruction_loss: 0.6713 - val_kl_loss: 1.0036 - lr: 0.0050
# Epoch 30/30
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8626 - reconstruction_loss: 0.6659 - kl_loss: 0.7086 - val_total_loss: 0.9521 - val_reconstruction_loss: 0.7308 - val_kl_loss: 0.8194 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9773 - reconstruction_loss: 0.7806 - kl_loss: 0.7284
# [0.9772849082946777, 0.7806230783462524, 0.7283770442008972]
# Learning rate:  0.01
# Batch size:  128
# Epoch 1/30
# 53/53 [==============================] - 3s 21ms/step - loss: 0.9165 - reconstruction_loss: 0.7013 - kl_loss: 0.6825 - val_total_loss: 0.8572 - val_reconstruction_loss: 0.6148 - val_kl_loss: 0.8981 - lr: 0.0100
# Epoch 2/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8522 - reconstruction_loss: 0.6629 - kl_loss: 0.6990 - val_total_loss: 0.8973 - val_reconstruction_loss: 0.6774 - val_kl_loss: 0.8144 - lr: 0.0100
# Epoch 3/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8666 - reconstruction_loss: 0.6716 - kl_loss: 0.7065 - val_total_loss: 0.8269 - val_reconstruction_loss: 0.5998 - val_kl_loss: 0.8412 - lr: 0.0100
# Epoch 4/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8554 - reconstruction_loss: 0.6754 - kl_loss: 0.6871 - val_total_loss: 0.9951 - val_reconstruction_loss: 0.7474 - val_kl_loss: 0.9175 - lr: 0.0100
# Epoch 5/30
# 53/53 [==============================] - 1s 18ms/step - loss: 0.8628 - reconstruction_loss: 0.6749 - kl_loss: 0.6777 - val_total_loss: 0.8971 - val_reconstruction_loss: 0.6507 - val_kl_loss: 0.9126 - lr: 0.0100
# Epoch 6/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8540 - reconstruction_loss: 0.6736 - kl_loss: 0.6808 - val_total_loss: 0.8401 - val_reconstruction_loss: 0.6025 - val_kl_loss: 0.8801 - lr: 0.0100
# Epoch 7/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8588 - reconstruction_loss: 0.6672 - kl_loss: 0.7157 - val_total_loss: 0.9588 - val_reconstruction_loss: 0.6956 - val_kl_loss: 0.9747 - lr: 0.0100
# Epoch 8/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8649 - reconstruction_loss: 0.6742 - kl_loss: 0.6835 - val_total_loss: 0.7979 - val_reconstruction_loss: 0.5607 - val_kl_loss: 0.8785 - lr: 0.0100
# Epoch 9/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8555 - reconstruction_loss: 0.6767 - kl_loss: 0.6844 - val_total_loss: 0.8652 - val_reconstruction_loss: 0.6081 - val_kl_loss: 0.9523 - lr: 0.0100
# Epoch 10/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8523 - reconstruction_loss: 0.6692 - kl_loss: 0.7035 - val_total_loss: 0.8547 - val_reconstruction_loss: 0.6095 - val_kl_loss: 0.9082 - lr: 0.0100
# Epoch 11/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8560 - reconstruction_loss: 0.6741 - kl_loss: 0.6929 - val_total_loss: 0.8608 - val_reconstruction_loss: 0.6348 - val_kl_loss: 0.8371 - lr: 0.0100
# Epoch 12/30
# 53/53 [==============================] - ETA: 0s - loss: 0.8618 - reconstruction_loss: 0.6820 - kl_loss: 0.6815
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 53/53 [==============================] - 1s 21ms/step - loss: 0.8619 - reconstruction_loss: 0.6820 - kl_loss: 0.6815 - val_total_loss: 0.8482 - val_reconstruction_loss: 0.6066 - val_kl_loss: 0.8948 - lr: 0.0100
# Epoch 13/30
# 53/53 [==============================] - 1s 20ms/step - loss: 0.8639 - reconstruction_loss: 0.6682 - kl_loss: 0.6883 - val_total_loss: 0.8494 - val_reconstruction_loss: 0.6086 - val_kl_loss: 0.8921 - lr: 0.0050
# Epoch 14/30
# 53/53 [==============================] - 1s 21ms/step - loss: 0.8547 - reconstruction_loss: 0.6624 - kl_loss: 0.7214 - val_total_loss: 0.8675 - val_reconstruction_loss: 0.6303 - val_kl_loss: 0.8787 - lr: 0.0050
# Epoch 15/30
# 53/53 [==============================] - 1s 17ms/step - loss: 0.8471 - reconstruction_loss: 0.6619 - kl_loss: 0.7139 - val_total_loss: 0.9134 - val_reconstruction_loss: 0.6473 - val_kl_loss: 0.9855 - lr: 0.0050
# Epoch 16/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8710 - reconstruction_loss: 0.6618 - kl_loss: 0.7174 - val_total_loss: 1.0295 - val_reconstruction_loss: 0.7875 - val_kl_loss: 0.8963 - lr: 0.0050
# Epoch 17/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8602 - reconstruction_loss: 0.6653 - kl_loss: 0.7177 - val_total_loss: 0.8794 - val_reconstruction_loss: 0.6444 - val_kl_loss: 0.8704 - lr: 0.0050
# Epoch 18/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8699 - reconstruction_loss: 0.6674 - kl_loss: 0.7052 - val_total_loss: 0.8569 - val_reconstruction_loss: 0.6269 - val_kl_loss: 0.8520 - lr: 0.0050
# Epoch 19/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8548 - reconstruction_loss: 0.6595 - kl_loss: 0.7085 - val_total_loss: 0.8098 - val_reconstruction_loss: 0.5753 - val_kl_loss: 0.8685 - lr: 0.0050
# Epoch 20/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8585 - reconstruction_loss: 0.6665 - kl_loss: 0.7032 - val_total_loss: 1.0308 - val_reconstruction_loss: 0.8040 - val_kl_loss: 0.8399 - lr: 0.0050
# Epoch 21/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8501 - reconstruction_loss: 0.6579 - kl_loss: 0.7048 - val_total_loss: 0.7169 - val_reconstruction_loss: 0.4745 - val_kl_loss: 0.8977 - lr: 0.0050
# Epoch 22/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8632 - reconstruction_loss: 0.6601 - kl_loss: 0.7043 - val_total_loss: 0.8418 - val_reconstruction_loss: 0.6051 - val_kl_loss: 0.8764 - lr: 0.0050
# Epoch 23/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8544 - reconstruction_loss: 0.6644 - kl_loss: 0.7121 - val_total_loss: 0.8349 - val_reconstruction_loss: 0.6142 - val_kl_loss: 0.8174 - lr: 0.0050
# Epoch 24/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8632 - reconstruction_loss: 0.6659 - kl_loss: 0.7081 - val_total_loss: 0.9046 - val_reconstruction_loss: 0.6616 - val_kl_loss: 0.8997 - lr: 0.0050
# Epoch 25/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8714 - reconstruction_loss: 0.6617 - kl_loss: 0.7277 - val_total_loss: 0.9232 - val_reconstruction_loss: 0.6858 - val_kl_loss: 0.8793 - lr: 0.0050
# Epoch 26/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8559 - reconstruction_loss: 0.6600 - kl_loss: 0.7194 - val_total_loss: 0.9395 - val_reconstruction_loss: 0.7083 - val_kl_loss: 0.8562 - lr: 0.0050
# Epoch 27/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8499 - reconstruction_loss: 0.6615 - kl_loss: 0.7040 - val_total_loss: 0.8357 - val_reconstruction_loss: 0.6163 - val_kl_loss: 0.8127 - lr: 0.0050
# Epoch 28/30
# 53/53 [==============================] - 1s 15ms/step - loss: 0.8482 - reconstruction_loss: 0.6655 - kl_loss: 0.6954 - val_total_loss: 0.8822 - val_reconstruction_loss: 0.6456 - val_kl_loss: 0.8763 - lr: 0.0050
# Epoch 29/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8519 - reconstruction_loss: 0.6618 - kl_loss: 0.7148 - val_total_loss: 0.8407 - val_reconstruction_loss: 0.5803 - val_kl_loss: 0.9644 - lr: 0.0050
# Epoch 30/30
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8471 - reconstruction_loss: 0.6587 - kl_loss: 0.7173 - val_total_loss: 0.7642 - val_reconstruction_loss: 0.5267 - val_kl_loss: 0.8795 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9450 - reconstruction_loss: 0.7343 - kl_loss: 0.7804
# [0.9450161457061768, 0.7343205809593201, 0.7803537845611572]
# Learning rate:  0.01
# Batch size:  256
# Epoch 1/30
# 27/27 [==============================] - 3s 35ms/step - loss: 0.9261 - reconstruction_loss: 0.7012 - kl_loss: 0.6911 - val_total_loss: 0.8498 - val_reconstruction_loss: 0.6414 - val_kl_loss: 0.7720 - lr: 0.0100
# Epoch 2/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8542 - reconstruction_loss: 0.6712 - kl_loss: 0.6924 - val_total_loss: 0.8754 - val_reconstruction_loss: 0.6586 - val_kl_loss: 0.8031 - lr: 0.0100
# Epoch 3/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8501 - reconstruction_loss: 0.6676 - kl_loss: 0.6737 - val_total_loss: 0.8713 - val_reconstruction_loss: 0.6640 - val_kl_loss: 0.7677 - lr: 0.0100
# Epoch 4/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8455 - reconstruction_loss: 0.6703 - kl_loss: 0.6736 - val_total_loss: 0.8571 - val_reconstruction_loss: 0.6432 - val_kl_loss: 0.7923 - lr: 0.0100
# Epoch 5/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8513 - reconstruction_loss: 0.6720 - kl_loss: 0.6983 - val_total_loss: 0.8607 - val_reconstruction_loss: 0.6526 - val_kl_loss: 0.7707 - lr: 0.0100
# Epoch 6/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8716 - reconstruction_loss: 0.6715 - kl_loss: 0.7094 - val_total_loss: 0.8613 - val_reconstruction_loss: 0.6455 - val_kl_loss: 0.7992 - lr: 0.0100
# Epoch 7/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8630 - reconstruction_loss: 0.6657 - kl_loss: 0.7130 - val_total_loss: 0.8490 - val_reconstruction_loss: 0.6433 - val_kl_loss: 0.7618 - lr: 0.0100
# Epoch 8/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8588 - reconstruction_loss: 0.6688 - kl_loss: 0.6920 - val_total_loss: 0.8893 - val_reconstruction_loss: 0.6815 - val_kl_loss: 0.7698 - lr: 0.0100
# Epoch 9/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8428 - reconstruction_loss: 0.6698 - kl_loss: 0.7003 - val_total_loss: 0.8948 - val_reconstruction_loss: 0.6974 - val_kl_loss: 0.7314 - lr: 0.0100
# Epoch 10/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8541 - reconstruction_loss: 0.6648 - kl_loss: 0.7262 - val_total_loss: 0.8716 - val_reconstruction_loss: 0.6534 - val_kl_loss: 0.8083 - lr: 0.0100
# Epoch 11/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8560 - reconstruction_loss: 0.6576 - kl_loss: 0.7136 - val_total_loss: 0.8733 - val_reconstruction_loss: 0.6673 - val_kl_loss: 0.7630 - lr: 0.0100
# Epoch 12/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8485 - reconstruction_loss: 0.6701 - kl_loss: 0.6868 - val_total_loss: 0.8696 - val_reconstruction_loss: 0.6497 - val_kl_loss: 0.8143 - lr: 0.0100
# Epoch 13/30
# 25/27 [==========================>...] - ETA: 0s - loss: 0.8407 - reconstruction_loss: 0.6635 - kl_loss: 0.7101
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8423 - reconstruction_loss: 0.6641 - kl_loss: 0.7074 - val_total_loss: 0.8416 - val_reconstruction_loss: 0.6467 - val_kl_loss: 0.7220 - lr: 0.0100
# Epoch 14/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8552 - reconstruction_loss: 0.6546 - kl_loss: 0.7144 - val_total_loss: 0.8880 - val_reconstruction_loss: 0.6838 - val_kl_loss: 0.7564 - lr: 0.0050
# Epoch 15/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8508 - reconstruction_loss: 0.6628 - kl_loss: 0.6981 - val_total_loss: 0.8424 - val_reconstruction_loss: 0.6312 - val_kl_loss: 0.7821 - lr: 0.0050
# Epoch 16/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8478 - reconstruction_loss: 0.6629 - kl_loss: 0.7109 - val_total_loss: 0.8859 - val_reconstruction_loss: 0.6561 - val_kl_loss: 0.8512 - lr: 0.0050
# Epoch 17/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8495 - reconstruction_loss: 0.6607 - kl_loss: 0.7256 - val_total_loss: 0.8373 - val_reconstruction_loss: 0.6197 - val_kl_loss: 0.8059 - lr: 0.0050
# Epoch 18/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8461 - reconstruction_loss: 0.6591 - kl_loss: 0.7194 - val_total_loss: 0.8638 - val_reconstruction_loss: 0.6458 - val_kl_loss: 0.8072 - lr: 0.0050
# Epoch 19/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8542 - reconstruction_loss: 0.6592 - kl_loss: 0.7149 - val_total_loss: 0.8911 - val_reconstruction_loss: 0.6775 - val_kl_loss: 0.7911 - lr: 0.0050
# Epoch 20/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8461 - reconstruction_loss: 0.6529 - kl_loss: 0.7219 - val_total_loss: 0.8706 - val_reconstruction_loss: 0.6651 - val_kl_loss: 0.7610 - lr: 0.0050
# Epoch 21/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8630 - reconstruction_loss: 0.6533 - kl_loss: 0.7258 - val_total_loss: 0.8469 - val_reconstruction_loss: 0.6400 - val_kl_loss: 0.7665 - lr: 0.0050
# Epoch 22/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8474 - reconstruction_loss: 0.6596 - kl_loss: 0.6939 - val_total_loss: 0.8254 - val_reconstruction_loss: 0.6202 - val_kl_loss: 0.7600 - lr: 0.0050
# Epoch 23/30
# 27/27 [==============================] - 1s 27ms/step - loss: 0.8593 - reconstruction_loss: 0.6588 - kl_loss: 0.7135 - val_total_loss: 0.8431 - val_reconstruction_loss: 0.6349 - val_kl_loss: 0.7713 - lr: 0.0050
# Epoch 24/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8547 - reconstruction_loss: 0.6591 - kl_loss: 0.7133 - val_total_loss: 0.8591 - val_reconstruction_loss: 0.6423 - val_kl_loss: 0.8031 - lr: 0.0050
# Epoch 25/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8536 - reconstruction_loss: 0.6525 - kl_loss: 0.7047 - val_total_loss: 0.8341 - val_reconstruction_loss: 0.6270 - val_kl_loss: 0.7672 - lr: 0.0050
# Epoch 26/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8671 - reconstruction_loss: 0.6661 - kl_loss: 0.7080 - val_total_loss: 0.8685 - val_reconstruction_loss: 0.6510 - val_kl_loss: 0.8057 - lr: 0.0050
# Epoch 27/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8474 - reconstruction_loss: 0.6542 - kl_loss: 0.7087 - val_total_loss: 0.8669 - val_reconstruction_loss: 0.6555 - val_kl_loss: 0.7829 - lr: 0.0050
# Epoch 28/30
# 27/27 [==============================] - 1s 26ms/step - loss: 0.8516 - reconstruction_loss: 0.6643 - kl_loss: 0.6985 - val_total_loss: 0.8396 - val_reconstruction_loss: 0.6346 - val_kl_loss: 0.7592 - lr: 0.0050
# Epoch 29/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8505 - reconstruction_loss: 0.6592 - kl_loss: 0.7215 - val_total_loss: 0.8386 - val_reconstruction_loss: 0.6280 - val_kl_loss: 0.7798 - lr: 0.0050
# Epoch 30/30
# 27/27 [==============================] - 1s 25ms/step - loss: 0.8331 - reconstruction_loss: 0.6561 - kl_loss: 0.7087 - val_total_loss: 0.8593 - val_reconstruction_loss: 0.6527 - val_kl_loss: 0.7652 - lr: 0.0050
# 262/262 [==============================] - 1s 2ms/step - total_loss: 0.9674 - reconstruction_loss: 0.7554 - kl_loss: 0.7855
# [0.9674460887908936, 0.7553563714027405, 0.7855175733566284]
# Best Hyperparameters: {'learn_rate': 0.001, 'batch_size': 128}
# Best Score: [0.8869089484214783, 0.6827007532119751, 0.7563266158103943]

# %%
#DEFINIRANJE POVRATNIH POZIVA ZA PRAĆENJE GUBITAKA I LEARNING RATES TIJEKOM TRENINGA

learning_rates = []

class LearningRateScheduler(Callback):
    def on_epoch_begin(self, epoch, logs=None):
        lr = float(tf.keras.backend.get_value(self.model.optimizer.lr))
        learning_rates.append(lr)
        
class LossHistoryCallback(Callback):
    def on_train_begin(self, logs=None):
        self.losses = []

    def on_epoch_end(self, epoch, logs=None):
        self.losses.append(logs['loss'])
        self.losses.append(logs['reconstruction_loss'])
        self.losses.append(logs['kl_loss'])

# %%
#TRENING

#Instanciranje i kompajliranje modela
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

#Instanciranje povratnih poziva
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=10, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=20, verbose=1, restore_best_weights=True)
learning_rates = []
lr_scheduler = LearningRateScheduler()
loss_callback = LossHistoryCallback()

#Treniranje modela
history = vae.fit(x_train, batch_size=bs, epochs=100, validation_split = 0.2,
        callbacks=[lr_scheduler, loss_callback, reduce_lr, early_stop])
# Out:
# Epoch 1/100
# 105/105 [==============================] - 3s 11ms/step - loss: 0.8894 - reconstruction_loss: 0.6885 - kl_loss: 0.6837 - val_total_loss: 0.8027 - val_reconstruction_loss: 0.5514 - val_kl_loss: 0.9305 - lr: 0.0100
# Epoch 2/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8708 - reconstruction_loss: 0.6820 - kl_loss: 0.6922 - val_total_loss: 0.8166 - val_reconstruction_loss: 0.5772 - val_kl_loss: 0.8868 - lr: 0.0100
# Epoch 3/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8633 - reconstruction_loss: 0.6759 - kl_loss: 0.6752 - val_total_loss: 0.9707 - val_reconstruction_loss: 0.7488 - val_kl_loss: 0.8222 - lr: 0.0100
# Epoch 4/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8735 - reconstruction_loss: 0.6771 - kl_loss: 0.6871 - val_total_loss: 0.8232 - val_reconstruction_loss: 0.5563 - val_kl_loss: 0.9886 - lr: 0.0100
# Epoch 5/100
# 105/105 [==============================] - 1s 12ms/step - loss: 0.8678 - reconstruction_loss: 0.6821 - kl_loss: 0.6740 - val_total_loss: 0.9701 - val_reconstruction_loss: 0.7562 - val_kl_loss: 0.7922 - lr: 0.0100
# Epoch 6/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8582 - reconstruction_loss: 0.6828 - kl_loss: 0.6817 - val_total_loss: 1.1655 - val_reconstruction_loss: 0.9572 - val_kl_loss: 0.7715 - lr: 0.0100
# Epoch 7/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8651 - reconstruction_loss: 0.6792 - kl_loss: 0.7029 - val_total_loss: 0.8404 - val_reconstruction_loss: 0.6034 - val_kl_loss: 0.8778 - lr: 0.0100
# Epoch 8/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8688 - reconstruction_loss: 0.6763 - kl_loss: 0.6877 - val_total_loss: 0.8828 - val_reconstruction_loss: 0.6476 - val_kl_loss: 0.8712 - lr: 0.0100
# Epoch 9/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8765 - reconstruction_loss: 0.6783 - kl_loss: 0.6784 - val_total_loss: 0.8196 - val_reconstruction_loss: 0.5975 - val_kl_loss: 0.8226 - lr: 0.0100
# Epoch 10/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8676 - reconstruction_loss: 0.6803 - kl_loss: 0.6735 - val_total_loss: 0.8439 - val_reconstruction_loss: 0.6113 - val_kl_loss: 0.8613 - lr: 0.0100
# Epoch 11/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8587 - reconstruction_loss: 0.6769 - kl_loss: 0.6768 - val_total_loss: 0.8564 - val_reconstruction_loss: 0.6358 - val_kl_loss: 0.8171 - lr: 0.0100
# Epoch 12/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8571 - reconstruction_loss: 0.6836 - kl_loss: 0.6704 - val_total_loss: 0.8599 - val_reconstruction_loss: 0.6360 - val_kl_loss: 0.8294 - lr: 0.0100
# Epoch 13/100
# 100/105 [===========================>..] - ETA: 0s - loss: 0.8742 - reconstruction_loss: 0.6866 - kl_loss: 0.6811
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8739 - reconstruction_loss: 0.6865 - kl_loss: 0.6750 - val_total_loss: 0.8250 - val_reconstruction_loss: 0.6337 - val_kl_loss: 0.7083 - lr: 0.0100
# Epoch 14/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8574 - reconstruction_loss: 0.6729 - kl_loss: 0.6932 - val_total_loss: 0.9330 - val_reconstruction_loss: 0.7091 - val_kl_loss: 0.8290 - lr: 0.0050
# Epoch 15/100
# 105/105 [==============================] - 1s 11ms/step - loss: 0.8586 - reconstruction_loss: 0.6634 - kl_loss: 0.7300 - val_total_loss: 0.9700 - val_reconstruction_loss: 0.7409 - val_kl_loss: 0.8486 - lr: 0.0050
# Epoch 16/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8684 - reconstruction_loss: 0.6661 - kl_loss: 0.7059 - val_total_loss: 0.9093 - val_reconstruction_loss: 0.6920 - val_kl_loss: 0.8049 - lr: 0.0050
# Epoch 17/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8365 - reconstruction_loss: 0.6707 - kl_loss: 0.6986 - val_total_loss: 0.8966 - val_reconstruction_loss: 0.6574 - val_kl_loss: 0.8859 - lr: 0.0050
# Epoch 18/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8589 - reconstruction_loss: 0.6655 - kl_loss: 0.7051 - val_total_loss: 0.8345 - val_reconstruction_loss: 0.6075 - val_kl_loss: 0.8408 - lr: 0.0050
# Epoch 19/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8554 - reconstruction_loss: 0.6700 - kl_loss: 0.6858 - val_total_loss: 0.9748 - val_reconstruction_loss: 0.7224 - val_kl_loss: 0.9349 - lr: 0.0050
# Epoch 20/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8524 - reconstruction_loss: 0.6688 - kl_loss: 0.7171 - val_total_loss: 0.8596 - val_reconstruction_loss: 0.6561 - val_kl_loss: 0.7537 - lr: 0.0050
# Epoch 21/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8425 - reconstruction_loss: 0.6719 - kl_loss: 0.6889 - val_total_loss: 0.8576 - val_reconstruction_loss: 0.6222 - val_kl_loss: 0.8718 - lr: 0.0050
# Epoch 22/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8507 - reconstruction_loss: 0.6701 - kl_loss: 0.6902 - val_total_loss: 0.9463 - val_reconstruction_loss: 0.7089 - val_kl_loss: 0.8793 - lr: 0.0050
# Epoch 23/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8533 - reconstruction_loss: 0.6701 - kl_loss: 0.7058 - val_total_loss: 0.9551 - val_reconstruction_loss: 0.7195 - val_kl_loss: 0.8726 - lr: 0.0050
# Epoch 24/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8577 - reconstruction_loss: 0.6669 - kl_loss: 0.7054 - val_total_loss: 0.8590 - val_reconstruction_loss: 0.6287 - val_kl_loss: 0.8528 - lr: 0.0050
# Epoch 25/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8595 - reconstruction_loss: 0.6684 - kl_loss: 0.6945 - val_total_loss: 0.9170 - val_reconstruction_loss: 0.6656 - val_kl_loss: 0.9312 - lr: 0.0050
# Epoch 26/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8693 - reconstruction_loss: 0.6695 - kl_loss: 0.7023 - val_total_loss: 0.9787 - val_reconstruction_loss: 0.7251 - val_kl_loss: 0.9392 - lr: 0.0050
# Epoch 27/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8548 - reconstruction_loss: 0.6676 - kl_loss: 0.7019 - val_total_loss: 0.8470 - val_reconstruction_loss: 0.5917 - val_kl_loss: 0.9456 - lr: 0.0050
# Epoch 28/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8604 - reconstruction_loss: 0.6678 - kl_loss: 0.6993 - val_total_loss: 0.9581 - val_reconstruction_loss: 0.6888 - val_kl_loss: 0.9976 - lr: 0.0050
# Epoch 29/100
# 104/105 [============================>.] - ETA: 0s - loss: 0.8535 - reconstruction_loss: 0.6679 - kl_loss: 0.6915
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8535 - reconstruction_loss: 0.6680 - kl_loss: 0.6935 - val_total_loss: 0.8753 - val_reconstruction_loss: 0.6035 - val_kl_loss: 1.0067 - lr: 0.0050
# Epoch 30/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8560 - reconstruction_loss: 0.6664 - kl_loss: 0.7030 - val_total_loss: 0.8201 - val_reconstruction_loss: 0.5724 - val_kl_loss: 0.9177 - lr: 0.0025
# Epoch 31/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8432 - reconstruction_loss: 0.6607 - kl_loss: 0.6898 - val_total_loss: 0.9331 - val_reconstruction_loss: 0.6851 - val_kl_loss: 0.9186 - lr: 0.0025
# Epoch 32/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8458 - reconstruction_loss: 0.6593 - kl_loss: 0.7172 - val_total_loss: 0.8528 - val_reconstruction_loss: 0.6054 - val_kl_loss: 0.9163 - lr: 0.0025
# Epoch 33/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8648 - reconstruction_loss: 0.6572 - kl_loss: 0.7294 - val_total_loss: 0.9494 - val_reconstruction_loss: 0.7081 - val_kl_loss: 0.8939 - lr: 0.0025
# Epoch 34/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8476 - reconstruction_loss: 0.6565 - kl_loss: 0.7311 - val_total_loss: 0.8635 - val_reconstruction_loss: 0.6134 - val_kl_loss: 0.9264 - lr: 0.0025
# Epoch 35/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8505 - reconstruction_loss: 0.6584 - kl_loss: 0.7108 - val_total_loss: 0.8409 - val_reconstruction_loss: 0.6052 - val_kl_loss: 0.8730 - lr: 0.0025
# Epoch 36/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8538 - reconstruction_loss: 0.6586 - kl_loss: 0.7210 - val_total_loss: 0.9171 - val_reconstruction_loss: 0.6540 - val_kl_loss: 0.9744 - lr: 0.0025
# Epoch 37/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8499 - reconstruction_loss: 0.6578 - kl_loss: 0.7167 - val_total_loss: 0.8579 - val_reconstruction_loss: 0.6172 - val_kl_loss: 0.8916 - lr: 0.0025
# Epoch 38/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8459 - reconstruction_loss: 0.6617 - kl_loss: 0.7100 - val_total_loss: 1.0351 - val_reconstruction_loss: 0.7965 - val_kl_loss: 0.8837 - lr: 0.0025
# Epoch 39/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8574 - reconstruction_loss: 0.6569 - kl_loss: 0.7083 - val_total_loss: 0.8358 - val_reconstruction_loss: 0.5904 - val_kl_loss: 0.9090 - lr: 0.0025
# Epoch 40/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8507 - reconstruction_loss: 0.6599 - kl_loss: 0.7076 - val_total_loss: 0.6779 - val_reconstruction_loss: 0.4365 - val_kl_loss: 0.8942 - lr: 0.0025
# Epoch 41/100
# 105/105 [==============================] - ETA: 0s - loss: 0.8474 - reconstruction_loss: 0.6618 - kl_loss: 0.7076
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8475 - reconstruction_loss: 0.6618 - kl_loss: 0.7076 - val_total_loss: 0.9138 - val_reconstruction_loss: 0.6839 - val_kl_loss: 0.8512 - lr: 0.0025
# Epoch 42/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8546 - reconstruction_loss: 0.6553 - kl_loss: 0.7226 - val_total_loss: 0.9483 - val_reconstruction_loss: 0.7001 - val_kl_loss: 0.9194 - lr: 0.0012
# Epoch 43/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8440 - reconstruction_loss: 0.6549 - kl_loss: 0.7198 - val_total_loss: 1.1012 - val_reconstruction_loss: 0.8561 - val_kl_loss: 0.9079 - lr: 0.0012
# Epoch 44/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8430 - reconstruction_loss: 0.6511 - kl_loss: 0.7263 - val_total_loss: 0.7971 - val_reconstruction_loss: 0.5563 - val_kl_loss: 0.8918 - lr: 0.0012
# Epoch 45/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8537 - reconstruction_loss: 0.6578 - kl_loss: 0.7093 - val_total_loss: 0.7566 - val_reconstruction_loss: 0.5148 - val_kl_loss: 0.8955 - lr: 0.0012
# Epoch 46/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8504 - reconstruction_loss: 0.6552 - kl_loss: 0.7242 - val_total_loss: 0.8226 - val_reconstruction_loss: 0.5646 - val_kl_loss: 0.9554 - lr: 0.0012
# Epoch 47/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8407 - reconstruction_loss: 0.6589 - kl_loss: 0.6948 - val_total_loss: 0.9655 - val_reconstruction_loss: 0.7254 - val_kl_loss: 0.8890 - lr: 0.0012
# Epoch 48/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8479 - reconstruction_loss: 0.6536 - kl_loss: 0.7042 - val_total_loss: 0.8641 - val_reconstruction_loss: 0.6173 - val_kl_loss: 0.9140 - lr: 0.0012
# Epoch 49/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8607 - reconstruction_loss: 0.6576 - kl_loss: 0.7218 - val_total_loss: 0.7880 - val_reconstruction_loss: 0.5359 - val_kl_loss: 0.9336 - lr: 0.0012
# Epoch 50/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8520 - reconstruction_loss: 0.6562 - kl_loss: 0.7233 - val_total_loss: 0.8637 - val_reconstruction_loss: 0.6163 - val_kl_loss: 0.9165 - lr: 0.0012
# Epoch 51/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8469 - reconstruction_loss: 0.6612 - kl_loss: 0.7161 - val_total_loss: 0.9232 - val_reconstruction_loss: 0.6902 - val_kl_loss: 0.8631 - lr: 0.0012
# Epoch 52/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8418 - reconstruction_loss: 0.6562 - kl_loss: 0.7254 - val_total_loss: 0.8036 - val_reconstruction_loss: 0.5598 - val_kl_loss: 0.9031 - lr: 0.0012
# Epoch 53/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8424 - reconstruction_loss: 0.6516 - kl_loss: 0.7190 - val_total_loss: 0.9754 - val_reconstruction_loss: 0.7178 - val_kl_loss: 0.9540 - lr: 0.0012
# Epoch 54/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8356 - reconstruction_loss: 0.6538 - kl_loss: 0.7015 - val_total_loss: 0.8758 - val_reconstruction_loss: 0.6301 - val_kl_loss: 0.9101 - lr: 0.0012
# Epoch 55/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8461 - reconstruction_loss: 0.6515 - kl_loss: 0.7276 - val_total_loss: 0.7976 - val_reconstruction_loss: 0.5425 - val_kl_loss: 0.9448 - lr: 0.0012
# Epoch 56/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8497 - reconstruction_loss: 0.6515 - kl_loss: 0.7265 - val_total_loss: 0.7315 - val_reconstruction_loss: 0.4769 - val_kl_loss: 0.9432 - lr: 0.0012
# Epoch 57/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8554 - reconstruction_loss: 0.6555 - kl_loss: 0.7318 - val_total_loss: 0.7250 - val_reconstruction_loss: 0.4855 - val_kl_loss: 0.8870 - lr: 0.0012
# Epoch 58/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8474 - reconstruction_loss: 0.6530 - kl_loss: 0.7219 - val_total_loss: 0.8912 - val_reconstruction_loss: 0.6400 - val_kl_loss: 0.9304 - lr: 0.0012
# Epoch 59/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8545 - reconstruction_loss: 0.6561 - kl_loss: 0.7236 - val_total_loss: 0.7773 - val_reconstruction_loss: 0.5315 - val_kl_loss: 0.9105 - lr: 0.0012
# Epoch 60/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8424 - reconstruction_loss: 0.6550 - kl_loss: 0.7180 - val_total_loss: 0.8349 - val_reconstruction_loss: 0.5860 - val_kl_loss: 0.9216 - lr: 0.0012
# Epoch 61/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8578 - reconstruction_loss: 0.6587 - kl_loss: 0.7195 - val_total_loss: 0.8803 - val_reconstruction_loss: 0.6344 - val_kl_loss: 0.9106 - lr: 0.0012
# Epoch 62/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8476 - reconstruction_loss: 0.6574 - kl_loss: 0.7086 - val_total_loss: 0.8767 - val_reconstruction_loss: 0.6424 - val_kl_loss: 0.8676 - lr: 0.0012
# Epoch 63/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8643 - reconstruction_loss: 0.6571 - kl_loss: 0.7259 - val_total_loss: 0.8915 - val_reconstruction_loss: 0.6470 - val_kl_loss: 0.9054 - lr: 0.0012
# Epoch 64/100
# 103/105 [============================>.] - ETA: 0s - loss: 0.8615 - reconstruction_loss: 0.6598 - kl_loss: 0.7159
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8612 - reconstruction_loss: 0.6596 - kl_loss: 0.7149 - val_total_loss: 0.8985 - val_reconstruction_loss: 0.6490 - val_kl_loss: 0.9238 - lr: 0.0012
# Epoch 65/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8585 - reconstruction_loss: 0.6571 - kl_loss: 0.7158 - val_total_loss: 0.8470 - val_reconstruction_loss: 0.5987 - val_kl_loss: 0.9195 - lr: 6.2500e-04
# Epoch 66/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8425 - reconstruction_loss: 0.6552 - kl_loss: 0.7112 - val_total_loss: 0.8092 - val_reconstruction_loss: 0.5680 - val_kl_loss: 0.8930 - lr: 6.2500e-04
# Epoch 67/100
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8390 - reconstruction_loss: 0.6545 - kl_loss: 0.7137 - val_total_loss: 0.9807 - val_reconstruction_loss: 0.7414 - val_kl_loss: 0.8862 - lr: 6.2500e-04
# Epoch 68/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8404 - reconstruction_loss: 0.6549 - kl_loss: 0.7129 - val_total_loss: 0.7638 - val_reconstruction_loss: 0.5154 - val_kl_loss: 0.9201 - lr: 6.2500e-04
# Epoch 69/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8518 - reconstruction_loss: 0.6547 - kl_loss: 0.7333 - val_total_loss: 0.8775 - val_reconstruction_loss: 0.6268 - val_kl_loss: 0.9285 - lr: 6.2500e-04
# Epoch 70/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8464 - reconstruction_loss: 0.6524 - kl_loss: 0.7278 - val_total_loss: 0.9746 - val_reconstruction_loss: 0.7331 - val_kl_loss: 0.8944 - lr: 6.2500e-04
# Epoch 71/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8526 - reconstruction_loss: 0.6566 - kl_loss: 0.7161 - val_total_loss: 0.7801 - val_reconstruction_loss: 0.5356 - val_kl_loss: 0.9058 - lr: 6.2500e-04
# Epoch 72/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8504 - reconstruction_loss: 0.6575 - kl_loss: 0.7140 - val_total_loss: 0.9405 - val_reconstruction_loss: 0.6935 - val_kl_loss: 0.9147 - lr: 6.2500e-04
# Epoch 73/100
# 105/105 [==============================] - 1s 9ms/step - loss: 0.8407 - reconstruction_loss: 0.6535 - kl_loss: 0.7114 - val_total_loss: 0.9551 - val_reconstruction_loss: 0.7051 - val_kl_loss: 0.9262 - lr: 6.2500e-04
# Epoch 74/100
# 103/105 [============================>.] - ETA: 0s - loss: 0.8556 - reconstruction_loss: 0.6570 - kl_loss: 0.7245
# Epoch 74: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# Restoring model weights from the end of the best epoch: 54.
# 105/105 [==============================] - 1s 10ms/step - loss: 0.8555 - reconstruction_loss: 0.6562 - kl_loss: 0.7234 - val_total_loss: 1.0277 - val_reconstruction_loss: 0.7761 - val_kl_loss: 0.9317 - lr: 6.2500e-04
# Epoch 74: early stopping

# %%
#VIZUALIZACIJA GUBITAKA I LEARNING RATES TIJEKOM TRENINGA

#VIzualizacija gubitaka
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Total Loss')
plt.plot(history.history['reconstruction_loss'], label='Reconstruction Loss')
plt.plot(history.history['kl_loss'], label='KL Loss')
plt.xlabel('Epohe treninga')
plt.ylabel('Gubici')
plt.title('Definirani gubici tijekom treninga')
plt.legend()

plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Total Loss')
plt.xlabel('Epohe treninga')
plt.ylabel('Gubici')
plt.title('Ukupni gubici tijekom treninga')
plt.legend()

#Vizualizacija learning rates
plt.figure(figsize=(8, 4))
plt.plot(learning_rates, label='Learning Rate')
plt.xlabel('Epohe treninga')
plt.ylabel('Gubici')
plt.title('Promjene parametra learning_rate tijekom treninga')
plt.legend()

plt.show()

# %%
#Stvaranje enkodiranih i rekonstruiranih podataka za daljnje korištenje
_, _, z_input = encoder.predict(x_train)
reconstructed_z_input = vae.decoder.predict(z_input)
_, _, reconstructed_z_encoded = vae.encoder.predict(reconstructed_z_input)

_, _, z_test_input = encoder.predict(x_test)
reconstructed_z_test_input = vae.decoder.predict(z_test_input)
_, _, reconstructed_z_test_encoded = vae.encoder.predict(reconstructed_z_test_input)
# Out:
# 262/262 [==============================] - 0s 945us/step
# 262/262 [==============================] - 0s 2ms/step
# 262/262 [==============================] - 0s 992us/step
# 66/66 [==============================] - 0s 962us/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 947us/step

# %%
#Funkcija za vizualizaciju ulaznih podataka
def plot_input_data(x_data, y_data):
    z_input = x_data
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=legend_labels[label])

    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

#Vizualizacija podataka za trening i testiranje
plt.figure(figsize=(10, 6))
plt.title("Podaci za trening enkodirani u latentni prostor")
plot_input_data(z_input, y_train)

plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

# %%
#Funkcija za vizualizaciju rekonstruiranih podataka preko ulaznih podataka
def plot_input_and_reconstructed_data(x_input_data, x_reconstructed, y_input_data):
    z_input = x_input_data
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=legend_labels[label])

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Rekonstruirani podaci')
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.title("Podaci za testiranje i rekonstruirani podaci enkodirani u latentni prostor")
    plt.legend()
    plt.show()

plt.figure(figsize=(10, 6))
plot_input_and_reconstructed_data(z_test_input, reconstructed_z_test_encoded, y_test)

# %%
#Funkcija za vizualizaciju rekonstruiranih podataka
def plot_reconstructed_data(x_reconstructed, y_data):
    recon_data_lsp = x_reconstructed
    
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    legend_labels = ['NON AVP', 'AVP', 'NON AMP', 'AMP']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=legend_labels[label])
    
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()
    
#Vizualizacija ulaznih i rekonstruiranih podataka za testiranje
plt.figure(figsize=(10, 6))
plt.title("Podaci za testiranje enkodirani u latentni prostor")
plot_input_data(z_test_input, y_test)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirani podaci enkodirani u latentni prostor")
plot_reconstructed_data(reconstructed_z_test_encoded, y_test)

# %%
#Vizualizacija 10 nasumično izabranih peptida i njihove rekonstrukcije za usporedbu

#Odabir 10 nasumičnih peptida
selected_indices = np.random.choice(len(x_test), 10, replace=False)

selected_peptides = x_test[selected_indices]

#Enkodiranje i rekonstrukcija
_, _, encoded_selected_peptides = vae.encoder.predict(selected_peptides)
reconstructed_peptides = vae.decoder.predict(encoded_selected_peptides)
_, _, encoded_reconstructed_peptides = vae.encoder.predict(reconstructed_peptides)

#Funkcija za vizualizaciju odabranih podataka
def plot_selected_data(x_data):
    z_input = x_data
    num_peptides = z_input.shape[0]
    unique_colors = plt.cm.tab20(np.linspace(0, 1, num_peptides))

    for i in range(num_peptides):
        plt.scatter(z_input[i, 0], z_input[i, 1], color=unique_colors[i], label=f'Peptide {i}')
    
    ax = plt.gca()
    ax.set_xlim([-4,4])
    ax.set_ylim([-4,4]) 
    plt.xlabel("Latentna dimenzija 1")
    plt.ylabel("Latentna dimenzija 2")
    plt.legend()
    plt.show()

#Funkcija za izračun euklidske udaljenosti     
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))

#Vizualizacija odabranih peptida u izvornom i rekonstruiranom obliku
plt.figure(figsize=(10, 6))
plt.title("Slučajno izabrane izvorne točke u latentnom prostoru")
plot_selected_data(encoded_selected_peptides)

plt.figure(figsize=(10, 6))
plt.title("Rekonstruirane točke u latentnom prostoru")
plot_selected_data(encoded_reconstructed_peptides)

#Izračun udaljenosti između izvornih i rekonstruiranih peptida
distances = []

for i in range(10):
    dist = euclidean_distance(encoded_selected_peptides[i], encoded_reconstructed_peptides[i])
        
    distances.append(dist)

print("Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke: \n", distances, "\n")
print("Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka: ", np.sum(distances)/10)
# Out:
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# Relativna udaljenost između svake pojedine točke i njoj pripadajuće rekonstruirane točke:
#  [1.3905905, 1.0082939, 0.63122314, 0.5974758, 1.7985961, 0.47268975, 1.1295648, 1.9990501, 0.15827009, 1.001359]
#
# Prosječna relativna udaljenost između izvornih i rekonstruiranih točaka:  1.0187112808227539

# %%
#NORMALIZIRANA UDALJENOST REKONSTRUKCIJE U LATENTNOM PROSTORU

min_values = np.min(z_test_input, axis=0)
max_values = np.max(z_test_input, axis=0)

latent_space_size = np.linalg.norm(max_values - min_values)

print(latent_space_size)

distances_x_test = []

for i in range(len(x_test)):
    dist = euclidean_distance(z_test_input[i], reconstructed_z_test_encoded[i])
        
    distances_x_test.append(dist)

print("Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka: ", 
      np.sum(distances_x_test)/latent_space_size/len(x_test))
# Out:
# 10.346479
# Normalizirana prosječna udaljenost između izvornih i rekonstruiranih točaka:  0.11041620083110511

# %%
#PEARSONOV KOEFICIJENT KORELACIJE

from scipy.stats import spearmanr, kendalltau, pearsonr

print(pearsonr(x_test.flatten(), reconstructed_z_test_input.flatten()))
# Out:
# PearsonRResult(statistic=0.7915548900904633, pvalue=0.0)

# %%
#RMSE

mse = np.mean(np.square(x_test - reconstructed_z_test_input))
rmse = np.sqrt(mse)

print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.08696027009005573

# %%
#IZRAČUN SLIČNOSTI PEPTIDA PREMA SEKVENCI
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
  
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    alignments = pairwise2.align.globalxx(seq1, seq2)

    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    similarity = (score / max(len(seq1), len(seq2)))

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,101):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.39534884 0.18604651 0.34883721]
#  [0.1025641  0.         0.12820513 ... 0.13157895 0.125      0.05263158]
#  [0.20512821 0.28       0.23076923 ... 0.18421053 0.32       0.23684211]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.34210526 0.32432432 0.34210526]
#  [0.33333333 0.17777778 0.26666667 ... 0.33333333 0.22222222 0.33333333]
#  [0.07692308 0.25       0.15384615 ... 0.18421053 0.16666667 0.23684211]]
# [[0.27272727 0.18604651 0.27906977 ... 0.27906977 0.20930233 0.30232558]
#  [0.36363636 0.25581395 0.27906977 ... 0.3255814  0.1627907  0.18604651]
#  [0.25       0.17241379 0.26666667 ... 0.14285714 0.3        0.2       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.26190476 0.28571429 0.14285714]
#  [0.34090909 0.2972973  0.54054054 ... 0.28571429 0.24324324 0.2972973 ]
#  [0.09090909 0.13793103 0.06666667 ... 0.0952381  0.17647059 0.2       ]]

# %%
#IZRAČUN SLIČNOSTI PEPTIDA PREMA UDALJENOSTI U LATENTNOM PROSTORU
distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,101):
        dist_train = euclidean_distance(z_input[i], z_input[j])
        dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.4319527  0.5993783  0.37290284 ... 0.75246024 0.9243063  0.        ]
#  [0.85479975 0.91644263 0.82905126 ... 0.8546212  0.92088014 0.87076116]
#  [0.37200314 0.05276024 0.5214472  ... 0.5224095  0.4437926  0.4059638 ]
#  ...
#  [0.3571436  0.05971058 0.50462097 ... 0.5141547  0.4487097  0.3908727 ]
#  [0.         0.2763296  0.08974718 ... 0.24977772 0.45808867 0.27494144]
#  [0.2337573  0.453855   0.17679706 ... 0.22835924 0.49252743 0.43404815]]
# [[0.2531352  0.5250423  0.38998842 ... 0.43028328 0.3288722  0.2249237 ]
#  [0.52519184 0.6770717  0.39919156 ... 0.68648255 0.401003   0.11614532]
#  [0.5650837  0.6594287  0.3673203  ... 0.6792588  0.37945384 0.17365652]
#  ...
#  [0.7495868  0.03543192 0.07833587 ... 0.16782665 0.2224972  0.77218634]
#  [0.         0.66295487 0.6798134  ... 0.5817025  0.6484502  0.5189629 ]
#  [0.28497583 0.49714172 0.35130584 ... 0.4012083  0.28670105 0.22944868]]

# %%
#VIZUALIZACIJA OVISNOSTI UDALJENOSTI U LATENTNOM PROSTORU O SLIČNOSTI PREMA SEKVENCAMA

flat_normalized_distances_train = normalized_distances_train.flatten()
flat_similarities_train = similarities_train.flatten()

plt.figure(figsize=(8, 6))
plt.scatter(flat_normalized_distances_train, flat_similarities_train, alpha=0.5)
plt.title("Ovisnost udaljenosti u latentnom prostoru o sličnosti prema sekevencama")
plt.xlabel("Normalizirane udaljenosti")
plt.ylabel("Sličnost prema značajkama")
plt.grid(True)
plt.show()

# %%
#VIZUALIZACIJA DISTRIBUCIJE UDALJENOSTI U LATENTNOM PROSTORU O SLIČNOSTI PREMA ZNAČAJKAMA

plt.figure(figsize=(12, 6))

#Histogram udaljenosti
plt.subplot(1, 2, 1)
plt.hist(flat_normalized_distances_train, bins=20, color='blue', alpha=0.7)
plt.title("Histogram normaliziranih udaljenosti")
plt.xlabel("Normalizirane udaljenosti")
plt.ylabel("Frekvencija")

#Histogram sličnosti prema sekvenci
plt.subplot(1, 2, 2)
plt.hist(flat_similarities_train, bins=20, color='red', alpha=0.7)
plt.title("Histogram sličnosti prema sekvencama")
plt.xlabel("Sličnost prema sekvencama")
plt.ylabel("Frekvencija")

plt.tight_layout()
plt.show()

# %%
#KORELACIJSKA ANALIZA

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test, "\n")
# Out:
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2706352913494616 -0.19891543511792645
# p-value: 4.770171940568368e-44 3.621924297659351e-24

# %%
sum_train = 0
sum_test = 0
pval_train = 0
pval_test = 0

N = 50

for x in range(10):
    
    similarities_train = []
    similarities_test = []

    for i in range(N-50,N):
        row_similarities_train = []
        row_similarities_test = []
        for j in range(N,N+51):
            sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])
            sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])
            row_similarities_train.append(sim_train)
            row_similarities_test.append(sim_test)

        similarities_train.append(row_similarities_train)
        similarities_test.append(row_similarities_test)

    similarities_train = np.array(similarities_train)
    similarities_test = np.array(similarities_test)

    
    distances_train = []
    distances_test = []

    for i in range(N-50,N):
        row_distances_train = []
        row_distances_test = []
        for j in range(N,N+51):
            dist_train = euclidean_distance(z_input[i], z_input[j])
            dist_test = euclidean_distance(z_test_input[i], z_test_input[j])
            row_distances_train.append(dist_train)
            row_distances_test.append(dist_test)

        distances_train.append(row_distances_train)
        distances_test.append(row_distances_test)

    distances_train = np.array(distances_train)
    distances_test = np.array(distances_test)

    normalized_distances_train = scaler.fit_transform(distances_train)
    normalized_distances_test = scaler.fit_transform(distances_test)

    correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
    correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())
    
    print("Rezultati ispitivanja pod rednim brojem ", x+1, ":\n")
    print("Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje: \n", correlation_train, correlation_test)
    print("p-value:", p_value_train, p_value_test, "\n")
    
    sum_train += correlation_train
    sum_test += correlation_test
    pval_train += p_value_train
    pval_test += p_value_test

    N += 50

print("Konačni rezultati ispitivanja:")
print("Usrednjeni koeficijent korelacije za skupove podataka za trening i testiranje: \n", sum_train/10, sum_test/10)
print("p-value:", pval_train/10, pval_test/10, "\n")
# Out:
# Rezultati ispitivanja pod rednim brojem  1 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2706352913494616 -0.19891543511792645
# p-value: 4.770171940568368e-44 3.621924297659351e-24
#
# Rezultati ispitivanja pod rednim brojem  2 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.11971727219764633 -0.23013697415454187
# p-value: 1.325438346920895e-09 5.312417418302212e-32
#
# Rezultati ispitivanja pod rednim brojem  3 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.09911541349429624 -0.1425091586648186
# p-value: 5.303856274386627e-07 4.838504249052396e-13
#
# Rezultati ispitivanja pod rednim brojem  4 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.2119676213598305 -0.25745014117745624
# p-value: 2.714387321338968e-27 6.941020639426752e-40
#
# Rezultati ispitivanja pod rednim brojem  5 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.21561267853142035 -0.2660465679998113
# p-value: 3.3323418667288977e-28 1.4262677967897947e-42
#
# Rezultati ispitivanja pod rednim brojem  6 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.16459952542765457 -0.15359957087105475
# p-value: 6.01623368841089e-17 6.244078968453981e-15
#
# Rezultati ispitivanja pod rednim brojem  7 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.07380241404811785 -0.2319066075025884
# p-value: 0.00019140419577307201 1.7543200475115316e-32
#
# Rezultati ispitivanja pod rednim brojem  8 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.157311375220061 -0.20907773099802432
# p-value: 1.3523068089274289e-15 1.3931114711715272e-26
#
# Rezultati ispitivanja pod rednim brojem  9 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.21427463948221326 -0.22965061418919283
# p-value: 7.229053291345316e-28 7.191675898878329e-32
#
# Rezultati ispitivanja pod rednim brojem  10 :
#
# Pearsonov koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.22089109864429987 -0.27296915410832256
# p-value: 1.4922090880025872e-29 8.258246242289052e-45
#
# Konačni rezultati ispitivanja:
# Usrednjeni koeficijent korelacije za skupove podataka za trening i testiranje:
#  -0.1747927329755002 -0.21922619547837371
# p-value: 1.9193590684027008e-05 4.900945038773295e-14
