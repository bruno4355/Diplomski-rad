# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)  # Crop to the desired output shape
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstruction = self.decoder(z)
        return reconstruction

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    
    def test_step(self, data):
        # Unpack the data
        x, y = data
        # Compute predictions
        y_pred = self(x, training=False)
        # Updates the metrics tracking the loss
        print('ovo je oblik y', y.shape)
        print('ovo je y', y)
        print('ovo je oblik y_pred' ,y_pred.shape)
        print('ovo je y_pred', y_pred)
        self.compute_loss(y=y, y_pred=y_pred)
        # Update the metrics.
        for metric in self.metrics:
            if metric.name != "total_loss":
                metric.update_state(y, y_pred)
        # Return a dict mapping metric names to current value.
        # Note that it will include the loss (tracked in self.metrics).
        return {m.name: m.result() for m in self.metrics}
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 88, 1)]      0           []
#
#  conv1d_65 (Conv1D)             (None, 88, 8)        32          ['input_27[0][0]']
#
#  max_pooling1d_26 (MaxPooling1D  (None, 44, 8)       0           ['conv1d_65[0][0]']
#  )
#
#  conv1d_66 (Conv1D)             (None, 44, 16)       400         ['max_pooling1d_26[0][0]']
#
#  max_pooling1d_27 (MaxPooling1D  (None, 22, 16)      0           ['conv1d_66[0][0]']
#  )
#
#  flatten_13 (Flatten)           (None, 352)          0           ['max_pooling1d_27[0][0]']
#
#  dense_39 (Dense)               (None, 128)          45184       ['flatten_13[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_39[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_39[0][0]']
#
#  sampling_13 (Sampling)         (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_28 (InputLayer)       [(None, 2)]               0
#
#  dense_40 (Dense)            (None, 128)               384
#
#  dense_41 (Dense)            (None, 704)               90816
#
#  reshape_13 (Reshape)        (None, 88, 8)             0
#
#  conv1d_67 (Conv1D)          (None, 88, 16)            400
#
#  up_sampling1d_26 (UpSamplin  (None, 176, 16)          0
#  g1D)
#
#  conv1d_68 (Conv1D)          (None, 176, 8)            392
#
#  up_sampling1d_27 (UpSamplin  (None, 352, 8)           0
#  g1D)
#
#  conv1d_69 (Conv1D)          (None, 352, 1)            25
#
#  cropping1d_13 (Cropping1D)  (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(features, labels, test_size=0.2, random_state=42)

#print(x_train)
#print(x_test)
#print(y_train)
#print(y_test)

# Convert columns to NumPy arrays
x_train_features = x_train.values
x_test_features = x_test.values

# Apply scaling to the features
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

#print(x_train)
#print(x_test)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(x_train, batch_size=128, epochs=5)
#vae.fit(x_train, batch_size=128, epochs=5, validation_data=(x_test, y_test, None))
#vae.fit(x_train, batch_size=128, epochs=5)
# Out:
# Epoch 1/5
# 66/66 [==============================] - 2s 13ms/step - loss: 1.5778 - reconstruction_loss: 1.4054 - kl_loss: 0.0018
# Epoch 2/5
# 66/66 [==============================] - 1s 14ms/step - loss: 1.1363 - reconstruction_loss: 1.1115 - kl_loss: 0.0022
# Epoch 3/5
# 66/66 [==============================] - 1s 13ms/step - loss: 1.0286 - reconstruction_loss: 1.0185 - kl_loss: 0.0012
# Epoch 4/5
# 66/66 [==============================] - 1s 12ms/step - loss: 0.9719 - reconstruction_loss: 0.9774 - kl_loss: 5.7986e-04
# Epoch 5/5
# 66/66 [==============================] - 1s 12ms/step - loss: 0.9620 - reconstruction_loss: 0.9668 - kl_loss: 2.9074e-04

# %%
#print(x_test.shape)
#print(y_test.shape)

validation_loss = vae.evaluate(x_test, y_test)
print("Validation Loss:", validation_loss)
# Out:
# (<tf.Tensor 'IteratorGetNext:0' shape=(None, 88, 1) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 1, 1) dtype=int64>)
# ovo je oblik y (None, 1, 1)
# ovo je y Tensor("IteratorGetNext:1", shape=(None, 1, 1), dtype=int64)
# ovo je oblik y_pred (None, 88, 1)
# ovo je y_pred Tensor("vae_12/decoder/cropping1d_13/strided_slice:0", shape=(None, 88, 1), dtype=float32)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6136\3315526848.py in <cell line: 4>()
#       2 #print(y_test.shape)
#       3
# ----> 4 validation_loss = vae.evaluate(x_test, y_test)
#       5 print("Validation Loss:", validation_loss)
#
# C:\Anaconda\envs\autoencoders\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'broadcast_weights/assert_broadcastable/AssertGuard/Assert' defined at (most recent call last):
#     File "C:\Anaconda\envs\autoencoders\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Anaconda\envs\autoencoders\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#       app.start()
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\kernelapp.py", line 728, in start
#       self.io_loop.start()
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Anaconda\envs\autoencoders\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Anaconda\envs\autoencoders\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Anaconda\envs\autoencoders\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\interactiveshell.py", line 2974, in run_cell
#       result = self._run_cell(
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\interactiveshell.py", line 3029, in _run_cell
#       return runner(coro)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\interactiveshell.py", line 3256, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\interactiveshell.py", line 3472, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\IPython\core\interactiveshell.py", line 3552, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\PC\AppData\Local\Temp\ipykernel_6136\3315526848.py", line 4, in <cell line: 4>
#       validation_loss = vae.evaluate(x_test, y_test)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\engine\training.py", line 1756, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\engine\training.py", line 1557, in test_function
#       return step_function(self, iterator)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\engine\training.py", line 1546, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\engine\training.py", line 1535, in run_step
#       outputs = model.test_step(data)
#     File "C:\Users\PC\AppData\Local\Temp\ipykernel_6136\1253915869.py", line 106, in test_step
#       metric.update_state(y, y_pred)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\utils\metrics_utils.py", line 70, in decorated
#       update_op = update_state_fn(*args, **kwargs)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\metrics\base_metric.py", line 140, in update_state_fn
#       return ag_update_state(*args, **kwargs)
#     File "C:\Anaconda\envs\autoencoders\lib\site-packages\keras\metrics\base_metric.py", line 449, in update_state
#       sample_weight = tf.__internal__.ops.broadcast_weights(
# Node: 'broadcast_weights/assert_broadcastable/AssertGuard/Assert'
# assertion failed: [weights can not be broadcast to values.] [weights.shape=] [vae_12/decoder/cropping1d_13/strided_slice:0] [32 88 1] [values.shape=] [Cast:0] [32 1 1] [is_scalar=] [0]
# 	 [[{{node broadcast_weights/assert_broadcastable/AssertGuard/Assert}}]] [Op:__inference_test_function_98723]

# %%
#VIZUALIZACIJA
import matplotlib.pyplot as plt

img_width = 89
img_height = 1
num_channels = 1

def viz_latent_space(encoder, data, labels):
    input_data, target_data = data
    input_label, target_label = labels
    mu, _, _ = encoder.predict(input_data)
    print(target_label)
    labels = input_label['label']
    print(labels)
    print(labels.shape)
    # Plot points with label 0 in blue
    plt.scatter(mu[labels == 0, 0], mu[labels == 0, 1], c='blue', label='Label 0')
    
    # Plot points with label 1 in red
    plt.scatter(mu[labels == 1, 0], mu[labels == 1, 1], c='red', label='Label 1')
    
    # Plot points with label 2 in green
    plt.scatter(mu[labels == 2, 0], mu[labels == 2, 1], c='green', label='Label 2')
    
    # Plot points with label 3 in yellow
    plt.scatter(mu[labels == 3, 0], mu[labels == 3, 1], c='yellow', label='Label 3')
    
    plt.xlabel('z - dim 1')
    plt.ylabel('z - dim 2')
    plt.colorbar()
    plt.legend()
    plt.show()
    
#label_data = pd.read_csv('tmp.csv')
#labels = label_data['Antiviral'].values
labels = (y_train, y_test)

#print(x_test)
#print(y_test)
    
data = (x_train, x_test)
#print(x_train.shape)
viz_latent_space(encoder, data, labels)

# %%
#VIZUALIZACIJA validacije

def viz_latent_space_val(encoder, data, labels):
    input_data, target_data = data
    input_label, target_label = labels
    mu, _, _ = encoder.predict(target_data)
    labels = target_label['label']
    print(labels)
    print(labels.shape)
    # Plot points with label 0 in blue
    plt.scatter(mu[labels == 0, 0], mu[labels == 0, 1], c='blue', label='Label 0')
    
    # Plot points with label 1 in red
    plt.scatter(mu[labels == 1, 0], mu[labels == 1, 1], c='red', label='Label 1')
    
    # Plot points with label 2 in green
    plt.scatter(mu[labels == 2, 0], mu[labels == 2, 1], c='green', label='Label 2')
    
    # Plot points with label 3 in yellow
    plt.scatter(mu[labels == 3, 0], mu[labels == 3, 1], c='yellow', label='Label 3')
    
    plt.xlabel('z - dim 1')
    plt.ylabel('z - dim 2')
    plt.colorbar()
    plt.legend()
    plt.show()
    
#label_data = pd.read_csv('tmp.csv')
#labels = label_data['Antiviral'].values
labels = (y_train, y_test)
    
data = (x_train, x_test)
print(x_train.shape)
viz_latent_space_val(encoder, data, labels)
