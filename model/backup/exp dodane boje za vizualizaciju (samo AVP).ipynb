# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

encoder_inputs = keras.Input(shape=(17, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(17 * 8)(x)
x = layers.Reshape((17, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 68 - 17))(decoded)  # Crop to the desired output shape
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    (data - reconstruction)**2, axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
(x_train) = pd.read_csv('train_dataset.csv')
(x_test) = pd.read_csv('test_dataset.csv')

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
(x_train) = scaler.fit_transform(x_train)
(x_test) = scaler.fit_transform(x_test)

from sklearn.preprocessing import Normalizer

normalizer = Normalizer()
(x_train) = normalizer.fit_transform(x_train)
(x_test) = normalizer.fit_transform(x_test)

#print(x_train)
#print(x_test)
peptides = np.concatenate([x_train, x_test], axis=0)
#mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255
peptides = np.expand_dims(peptides, -1)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 17, 1)]      0           []
#
#  conv1d_10 (Conv1D)             (None, 17, 8)        32          ['input_5[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 8, 8)        0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 8, 16)        400         ['max_pooling1d_4[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 4, 16)       0           ['conv1d_11[0][0]']
#
#  flatten_2 (Flatten)            (None, 64)           0           ['max_pooling1d_5[0][0]']
#
#  dense_6 (Dense)                (None, 128)          8320        ['flatten_2[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_6[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_6[0][0]']
#
#  sampling_2 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 9,268
# Trainable params: 9,268
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 2)]               0
#
#  dense_7 (Dense)             (None, 128)               384
#
#  dense_8 (Dense)             (None, 136)               17544
#
#  reshape_2 (Reshape)         (None, 17, 8)             0
#
#  conv1d_12 (Conv1D)          (None, 17, 16)            400
#
#  up_sampling1d_4 (UpSampling  (None, 34, 16)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 34, 8)             392
#
#  up_sampling1d_5 (UpSampling  (None, 68, 8)            0
#  1D)
#
#  conv1d_14 (Conv1D)          (None, 68, 1)             25
#
#  cropping1d_2 (Cropping1D)   (None, 17, 1)             0
#
# =================================================================
# Total params: 18,745
# Trainable params: 18,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
#vae.fit(peptides, batch_size=50, epochs=8)
vae.fit(peptides, batch_size=128, epochs=50)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 1s 5ms/step - loss: 1.6475 - reconstruction_loss: 1.5915 - kl_loss: 0.0020
# Epoch 2/50
# 9/9 [==============================] - 0s 5ms/step - loss: 1.3144 - reconstruction_loss: 1.2368 - kl_loss: 0.0059
# Epoch 3/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.8724 - reconstruction_loss: 0.7662 - kl_loss: 0.0181
# Epoch 4/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4777 - reconstruction_loss: 0.4116 - kl_loss: 0.0185
# Epoch 5/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3421 - reconstruction_loss: 0.3415 - kl_loss: 0.0036
# Epoch 6/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3365 - reconstruction_loss: 0.3298 - kl_loss: 3.2444e-04
# Epoch 7/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3116 - reconstruction_loss: 0.3130 - kl_loss: 6.7505e-04
# Epoch 8/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3041 - reconstruction_loss: 0.2999 - kl_loss: 0.0013
# Epoch 9/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2921 - reconstruction_loss: 0.2847 - kl_loss: 0.0010
# Epoch 10/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2797 - reconstruction_loss: 0.2772 - kl_loss: 6.2025e-04
# Epoch 11/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2721 - reconstruction_loss: 0.2713 - kl_loss: 4.2494e-04
# Epoch 12/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2578 - reconstruction_loss: 0.2583 - kl_loss: 3.7896e-04
# Epoch 13/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2529 - reconstruction_loss: 0.2507 - kl_loss: 3.2228e-04
# Epoch 14/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2510 - reconstruction_loss: 0.2461 - kl_loss: 2.9526e-04
# Epoch 15/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2395 - reconstruction_loss: 0.2375 - kl_loss: 2.8143e-04
# Epoch 16/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2337 - reconstruction_loss: 0.2307 - kl_loss: 2.4866e-04
# Epoch 17/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2295 - reconstruction_loss: 0.2257 - kl_loss: 1.7571e-04
# Epoch 18/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2195 - reconstruction_loss: 0.2223 - kl_loss: 1.3619e-04
# Epoch 19/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2150 - reconstruction_loss: 0.2142 - kl_loss: 1.1672e-04
# Epoch 20/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2130 - reconstruction_loss: 0.2166 - kl_loss: 1.0791e-04
# Epoch 21/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2134 - reconstruction_loss: 0.2118 - kl_loss: 8.5211e-05
# Epoch 22/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2123 - reconstruction_loss: 0.2084 - kl_loss: 7.1469e-05
# Epoch 23/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2073 - reconstruction_loss: 0.2076 - kl_loss: 5.3876e-05
# Epoch 24/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2073 - reconstruction_loss: 0.2051 - kl_loss: 3.8993e-05
# Epoch 25/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2068 - reconstruction_loss: 0.2069 - kl_loss: 3.9455e-05
# Epoch 26/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2033 - reconstruction_loss: 0.2025 - kl_loss: 4.5738e-05
# Epoch 27/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2044 - reconstruction_loss: 0.2003 - kl_loss: 4.0016e-05
# Epoch 28/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2021 - reconstruction_loss: 0.2016 - kl_loss: 2.6595e-05
# Epoch 29/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1990 - reconstruction_loss: 0.1998 - kl_loss: 1.7097e-05
# Epoch 30/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2006 - reconstruction_loss: 0.1975 - kl_loss: 1.4592e-05
# Epoch 31/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1989 - reconstruction_loss: 0.1974 - kl_loss: 1.4289e-05
# Epoch 32/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1984 - reconstruction_loss: 0.1974 - kl_loss: 1.2380e-05
# Epoch 33/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1975 - reconstruction_loss: 0.1973 - kl_loss: 1.0089e-05
# Epoch 34/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1979 - reconstruction_loss: 0.1977 - kl_loss: 1.0906e-05
# Epoch 35/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1975 - reconstruction_loss: 0.1979 - kl_loss: 9.7644e-06
# Epoch 36/50
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1955 - reconstruction_loss: 0.1988 - kl_loss: 8.7173e-06
# Epoch 37/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1952 - reconstruction_loss: 0.1967 - kl_loss: 8.4521e-06
# Epoch 38/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1984 - reconstruction_loss: 0.1960 - kl_loss: 8.3204e-06
# Epoch 39/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1961 - reconstruction_loss: 0.1970 - kl_loss: 7.0265e-06
# Epoch 40/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1977 - reconstruction_loss: 0.1972 - kl_loss: 6.5971e-06
# Epoch 41/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1954 - reconstruction_loss: 0.1972 - kl_loss: 6.5657e-06
# Epoch 42/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1959 - reconstruction_loss: 0.1955 - kl_loss: 6.9518e-06
# Epoch 43/50
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1970 - reconstruction_loss: 0.1952 - kl_loss: 6.1040e-06
# Epoch 44/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1934 - reconstruction_loss: 0.1941 - kl_loss: 6.1583e-06
# Epoch 45/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1950 - reconstruction_loss: 0.1970 - kl_loss: 5.8279e-06
# Epoch 46/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1945 - reconstruction_loss: 0.1977 - kl_loss: 5.3773e-06
# Epoch 47/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1963 - reconstruction_loss: 0.1942 - kl_loss: 5.1925e-06
# Epoch 48/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1931 - reconstruction_loss: 0.1955 - kl_loss: 4.7586e-06
# Epoch 49/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1963 - reconstruction_loss: 0.1993 - kl_loss: 4.3471e-06
# Epoch 50/50
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1991 - reconstruction_loss: 0.1968 - kl_loss: 4.3264e-06

# %%
#VIZUALIZACIJA
import matplotlib.pyplot as plt

img_width = 17
img_height = 1
num_channels = 1

def viz_latent_space(encoder, data, labels):
    input_data, target_data = data
    mu, _, _ = encoder.predict(input_data)
    
    plt.figure(figsize=(8, 10))
    # Plot points with label 0 in red
    plt.scatter(mu[labels == 0, 0], mu[labels == 0, 1], c='red', label='Label 0')
    # Plot points with label 1 in green
    plt.scatter(mu[labels == 1, 0], mu[labels == 1, 1], c='green', label='Label 1')
    
    plt.xlabel('z - dim 1')
    plt.ylabel('z - dim 2')
    #plt.colorbar()
    plt.legend()
    plt.show()
    
label_data = pd.read_csv('tmp_avponly.csv')
labels = label_data['Antiviral'].values
    
data = (x_train, x_test)
viz_latent_space(encoder, data, labels)
# Out:
# 27/27 [==============================] - 0s 1ms/step

# %%
def viz_decoded(encoder, decoder, data):
  num_samples = 15
  figure = np.zeros((img_width * num_samples, img_height * num_samples, num_channels))
  grid_x = np.linspace(-4, 4, num_samples)
  grid_y = np.linspace(-4, 4, num_samples)[::-1]
  for i, yi in enumerate(grid_y):
      for j, xi in enumerate(grid_x):
          z_sample = np.array([[xi, yi]])
          x_decoded = decoder.predict(z_sample)
          digit = x_decoded[0].reshape(img_width, img_height, num_channels)
          figure[i * img_width: (i + 1) * img_width,
                  j * img_height: (j + 1) * img_height] = digit
  plt.figure(figsize=(10, 10))
  start_range = img_width // 2
  end_range = num_samples * img_width + start_range + 1
  pixel_range = np.arange(start_range, end_range, img_width)[:num_samples]
  sample_range_x = np.round(grid_x, 1)
  sample_range_y = np.round(grid_y, 1)
  plt.xticks(pixel_range, sample_range_x)
  plt.yticks(pixel_range, sample_range_y)
  plt.xlabel('z - dim 1')
  plt.ylabel('z - dim 2')
  # matplotlib.pyplot.imshow() needs a 2D array, or a 3D array with the third dimension being of shape 3 or 4!
  # So reshape if necessary
  fig_shape = np.shape(figure)
  if fig_shape[2] == 1:
    figure = figure.reshape((fig_shape[0], fig_shape[1]))
  # Show image
  plt.imshow(figure)
  plt.show()

# Plot results
data = (x_train, x_test)
viz_decoded(encoder, decoder, data)
