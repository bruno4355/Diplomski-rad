# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

encoder_inputs = keras.Input(shape=(88, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(88 * 8)(x)
x = layers.Reshape((88, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 264))(decoded)  # Crop to the desired output shape
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum((data - reconstruction) ** 2, axis=(1, 2))
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }


    def test_step(self, data):
        x, y = data

        z_mean, z_log_var, z = self.encoder(x, training=False)
        reconstructed_x = self.decoder(z, training=False)

        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum((x - reconstructed_x) ** 2, axis=(1, 2))
        )

        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))

        total_loss = reconstruction_loss + kl_loss

        self.compiled_metrics.update_state(y, reconstructed_x)

        results = {m.name: m.result() for m in self.metrics}
        results["reconstruction_loss"] = reconstruction_loss
        results["kl_loss"] = kl_loss
        results["total_loss"] = total_loss
        return results
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 88, 1)]      0           []
#
#  conv1d_5 (Conv1D)              (None, 88, 8)        32          ['input_3[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 44, 8)       0           ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d_2[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_6[0][0]']
#
#  flatten_1 (Flatten)            (None, 352)          0           ['max_pooling1d_3[0][0]']
#
#  dense_3 (Dense)                (None, 128)          45184       ['flatten_1[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense_3[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense_3[0][0]']
#
#  sampling_1 (Sampling)          (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 128)               384
#
#  dense_5 (Dense)             (None, 704)               90816
#
#  reshape_1 (Reshape)         (None, 88, 8)             0
#
#  conv1d_7 (Conv1D)           (None, 88, 16)            400
#
#  up_sampling1d_2 (UpSampling  (None, 176, 16)          0
#  1D)
#
#  conv1d_8 (Conv1D)           (None, 176, 8)            392
#
#  up_sampling1d_3 (UpSampling  (None, 352, 8)           0
#  1D)
#
#  conv1d_9 (Conv1D)           (None, 352, 1)            25
#
#  cropping1d_1 (Cropping1D)   (None, 88, 1)             0
#
# =================================================================
# Total params: 92,017
# Trainable params: 92,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv('features.csv')
labels = pd.read_csv('labels.csv')
(x_train, x_test, y_train, y_test) = train_test_split(features, labels, test_size=0.2, random_state=42)

x_train_seq = x_train.values[:, 0]
x_test_seq = x_test.values[:, 0]
y_train_labels = y_train
y_test_labels = y_test

#print(x_train)
#print(x_test)
#print(y_train)
#print(y_test)

# Convert columns to NumPy arrays
x_train_features = x_train.values[:, 1:]
x_test_features = x_test.values[:, 1:]

# Apply scaling to the features
scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train_features)
x_test = scaler.transform(x_test_features)

#print(x_train)
#print(x_test)

x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
y_train = np.expand_dims(y_train, -1)
y_test = np.expand_dims(y_test, -1)

# %%
learn_rate = [0.005, 0.01, 0.05, 0.1]
batch_size = [32, 64, 128, 256]
#learn_rate = [0.005, 0.01]
#batch_size = [32, 64]
param_grid = dict(learn_rate=learn_rate, batch_size=batch_size)

best_score = None
best_params = {}

for lr in learn_rate:
    for bs in batch_size:
        # Create the VAE model with the current hyperparameters
        vae = VAE(encoder, decoder)
        vae.compile(optimizer=keras.optimizers.Adam(learning_rate=lr))

        # Train the model
        vae.fit(x_train, batch_size=bs, epochs=5, validation_data=(x_test, y_test))

        # Evaluate the model on the validation set
        score = vae.evaluate(x_test, y_test)

        # Update the best score and parameters if needed
        if best_score is None or score < best_score:
            best_score = score
            best_params = {'learn_rate': lr, 'batch_size': bs}

print("Best Hyperparameters:", best_params)
print("Best Score:", best_score)

lr = best_params['learn_rate']
bs = best_params['batch_size']
# Out:
# Epoch 1/5
# 262/262 [==============================] - 4s 8ms/step - loss: 1.1828 - reconstruction_loss: 1.0411 - kl_loss: 8.0708e-04 - val_total_loss: 0.9130 - val_reconstruction_loss: 0.9128 - val_kl_loss: 1.4650e-04
# Epoch 2/5
# 262/262 [==============================] - 2s 7ms/step - loss: 0.9746 - reconstruction_loss: 0.9663 - kl_loss: 1.1991e-05 - val_total_loss: 0.9407 - val_reconstruction_loss: 0.9407 - val_kl_loss: 3.0796e-07
# Epoch 3/5
# 262/262 [==============================] - 2s 7ms/step - loss: 0.9691 - reconstruction_loss: 0.9669 - kl_loss: 9.3518e-06 - val_total_loss: 0.9070 - val_reconstruction_loss: 0.9070 - val_kl_loss: 3.8743e-06
# Epoch 4/5
# 262/262 [==============================] - 2s 7ms/step - loss: 0.9661 - reconstruction_loss: 0.9645 - kl_loss: 7.9213e-06 - val_total_loss: 0.9096 - val_reconstruction_loss: 0.9096 - val_kl_loss: 8.6725e-06
# Epoch 5/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9569 - reconstruction_loss: 0.9618 - kl_loss: 3.6879e-06 - val_total_loss: 0.9342 - val_reconstruction_loss: 0.9342 - val_kl_loss: 1.0610e-05
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9336 - reconstruction_loss: 0.9336 - kl_loss: 1.0610e-05
# Epoch 1/5
# 131/131 [==============================] - 3s 11ms/step - loss: 0.9751 - reconstruction_loss: 0.9599 - kl_loss: 4.5230e-06 - val_total_loss: 0.8549 - val_reconstruction_loss: 0.8549 - val_kl_loss: 2.8610e-06
# Epoch 2/5
# 131/131 [==============================] - 1s 9ms/step - loss: 0.9617 - reconstruction_loss: 0.9581 - kl_loss: 6.1816e-06 - val_total_loss: 0.8916 - val_reconstruction_loss: 0.8916 - val_kl_loss: 1.0937e-05
# Epoch 3/5
# 131/131 [==============================] - 1s 9ms/step - loss: 0.9553 - reconstruction_loss: 0.9595 - kl_loss: 1.2588e-05 - val_total_loss: 0.8740 - val_reconstruction_loss: 0.8740 - val_kl_loss: 1.8775e-06
# Epoch 4/5
# 131/131 [==============================] - 1s 9ms/step - loss: 0.9561 - reconstruction_loss: 0.9579 - kl_loss: 5.2543e-06 - val_total_loss: 0.8806 - val_reconstruction_loss: 0.8806 - val_kl_loss: 2.0862e-07
# Epoch 5/5
# 131/131 [==============================] - 1s 8ms/step - loss: 0.9815 - reconstruction_loss: 0.9577 - kl_loss: 2.0459e-06 - val_total_loss: 0.8747 - val_reconstruction_loss: 0.8747 - val_kl_loss: 1.4305e-06
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9089 - reconstruction_loss: 0.9089 - kl_loss: 1.4305e-06
# Epoch 1/5
# 66/66 [==============================] - 3s 22ms/step - loss: 0.9681 - reconstruction_loss: 0.9583 - kl_loss: 3.5121e-06 - val_total_loss: 0.8722 - val_reconstruction_loss: 0.8722 - val_kl_loss: 6.2585e-07
# Epoch 2/5
# 66/66 [==============================] - 1s 15ms/step - loss: 0.9435 - reconstruction_loss: 0.9561 - kl_loss: 1.0792e-06 - val_total_loss: 0.8765 - val_reconstruction_loss: 0.8765 - val_kl_loss: 5.9605e-07
# Epoch 3/5
# 66/66 [==============================] - 1s 16ms/step - loss: 0.9584 - reconstruction_loss: 0.9546 - kl_loss: 1.2824e-06 - val_total_loss: 0.8831 - val_reconstruction_loss: 0.8830 - val_kl_loss: 6.2585e-07
# Epoch 4/5
# 66/66 [==============================] - 1s 15ms/step - loss: 0.9550 - reconstruction_loss: 0.9536 - kl_loss: 2.0198e-06 - val_total_loss: 0.8697 - val_reconstruction_loss: 0.8697 - val_kl_loss: 1.3709e-06
# Epoch 5/5
# 66/66 [==============================] - 1s 15ms/step - loss: 0.9585 - reconstruction_loss: 0.9558 - kl_loss: 3.2223e-06 - val_total_loss: 0.8683 - val_reconstruction_loss: 0.8683 - val_kl_loss: 1.2815e-06
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9050 - reconstruction_loss: 0.9050 - kl_loss: 1.2815e-06
# Epoch 1/5
# 33/33 [==============================] - 3s 33ms/step - loss: 0.9642 - reconstruction_loss: 0.9598 - kl_loss: 4.9896e-06 - val_total_loss: 0.8784 - val_reconstruction_loss: 0.8784 - val_kl_loss: 2.5928e-06
# Epoch 2/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9722 - reconstruction_loss: 0.9527 - kl_loss: 8.9408e-07 - val_total_loss: 0.8641 - val_reconstruction_loss: 0.8641 - val_kl_loss: 1.4901e-07
# Epoch 3/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9675 - reconstruction_loss: 0.9539 - kl_loss: 5.3011e-07 - val_total_loss: 0.8660 - val_reconstruction_loss: 0.8660 - val_kl_loss: 5.9605e-08
# Epoch 4/5
# 33/33 [==============================] - 1s 28ms/step - loss: 0.9459 - reconstruction_loss: 0.9540 - kl_loss: 7.3512e-07 - val_total_loss: 0.8680 - val_reconstruction_loss: 0.8680 - val_kl_loss: 1.6093e-06
# Epoch 5/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9499 - reconstruction_loss: 0.9547 - kl_loss: 1.3194e-06 - val_total_loss: 0.8693 - val_reconstruction_loss: 0.8693 - val_kl_loss: 3.5763e-07
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9097 - reconstruction_loss: 0.9097 - kl_loss: 3.5763e-07
# Epoch 1/5
# 262/262 [==============================] - 4s 7ms/step - loss: 0.9687 - reconstruction_loss: 0.9646 - kl_loss: 1.3279e-05 - val_total_loss: 0.9313 - val_reconstruction_loss: 0.9313 - val_kl_loss: 1.0133e-06
# Epoch 2/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9499 - reconstruction_loss: 0.9618 - kl_loss: 4.6216e-06 - val_total_loss: 0.9254 - val_reconstruction_loss: 0.9254 - val_kl_loss: 2.4438e-06
# Epoch 3/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9593 - reconstruction_loss: 0.9605 - kl_loss: 7.5461e-07 - val_total_loss: 0.9167 - val_reconstruction_loss: 0.9167 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9775 - reconstruction_loss: 0.9597 - kl_loss: 0.0000e+00 - val_total_loss: 0.9251 - val_reconstruction_loss: 0.9251 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 262/262 [==============================] - 2s 7ms/step - loss: 0.9614 - reconstruction_loss: 0.9597 - kl_loss: 0.0000e+00 - val_total_loss: 0.9077 - val_reconstruction_loss: 0.9077 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9077 - reconstruction_loss: 0.9077 - kl_loss: 0.0000e+00
# Epoch 1/5
# 131/131 [==============================] - 3s 14ms/step - loss: 0.9673 - reconstruction_loss: 0.9606 - kl_loss: 1.5204e-06 - val_total_loss: 0.8732 - val_reconstruction_loss: 0.8732 - val_kl_loss: 0.0000e+00
# Epoch 2/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9604 - reconstruction_loss: 0.9575 - kl_loss: 0.0000e+00 - val_total_loss: 0.8714 - val_reconstruction_loss: 0.8714 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9460 - reconstruction_loss: 0.9567 - kl_loss: 0.0000e+00 - val_total_loss: 0.8632 - val_reconstruction_loss: 0.8632 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9694 - reconstruction_loss: 0.9586 - kl_loss: 7.6405e-06 - val_total_loss: 0.8696 - val_reconstruction_loss: 0.8696 - val_kl_loss: 3.9339e-06
# Epoch 5/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9517 - reconstruction_loss: 0.9588 - kl_loss: 1.0856e-06 - val_total_loss: 0.8712 - val_reconstruction_loss: 0.8712 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9074 - reconstruction_loss: 0.9074 - kl_loss: 0.0000e+00
# Epoch 1/5
# 66/66 [==============================] - 3s 19ms/step - loss: 0.9593 - reconstruction_loss: 0.9644 - kl_loss: 6.5692e-06 - val_total_loss: 0.8708 - val_reconstruction_loss: 0.8708 - val_kl_loss: 0.0000e+00
# Epoch 2/5
# 66/66 [==============================] - 1s 14ms/step - loss: 0.9502 - reconstruction_loss: 0.9550 - kl_loss: 2.0004e-07 - val_total_loss: 0.8762 - val_reconstruction_loss: 0.8762 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 66/66 [==============================] - 1s 14ms/step - loss: 0.9433 - reconstruction_loss: 0.9539 - kl_loss: 0.0000e+00 - val_total_loss: 0.8725 - val_reconstruction_loss: 0.8725 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 66/66 [==============================] - 1s 15ms/step - loss: 0.9625 - reconstruction_loss: 0.9526 - kl_loss: 0.0000e+00 - val_total_loss: 0.8735 - val_reconstruction_loss: 0.8735 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 66/66 [==============================] - 1s 14ms/step - loss: 0.9328 - reconstruction_loss: 0.9570 - kl_loss: 0.0000e+00 - val_total_loss: 0.8773 - val_reconstruction_loss: 0.8773 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9225 - reconstruction_loss: 0.9225 - kl_loss: 0.0000e+00
# Epoch 1/5
# 33/33 [==============================] - 3s 34ms/step - loss: 0.9778 - reconstruction_loss: 0.9676 - kl_loss: 7.5915e-06 - val_total_loss: 0.8717 - val_reconstruction_loss: 0.8717 - val_kl_loss: 9.5367e-07
# Epoch 2/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9468 - reconstruction_loss: 0.9530 - kl_loss: 2.8808e-07 - val_total_loss: 0.8723 - val_reconstruction_loss: 0.8723 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 33/33 [==============================] - 1s 26ms/step - loss: 0.9453 - reconstruction_loss: 0.9539 - kl_loss: 5.4005e-07 - val_total_loss: 0.8647 - val_reconstruction_loss: 0.8647 - val_kl_loss: 5.6624e-07
# Epoch 4/5
# 33/33 [==============================] - 1s 26ms/step - loss: 0.9382 - reconstruction_loss: 0.9521 - kl_loss: 1.2192e-07 - val_total_loss: 0.8675 - val_reconstruction_loss: 0.8675 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9661 - reconstruction_loss: 0.9534 - kl_loss: 6.3217e-09 - val_total_loss: 0.8739 - val_reconstruction_loss: 0.8739 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9162 - reconstruction_loss: 0.9162 - kl_loss: 0.0000e+00
# Epoch 1/5
# 262/262 [==============================] - 3s 7ms/step - loss: 1.2946 - reconstruction_loss: 1.1344 - kl_loss: 6.0870e-05 - val_total_loss: 1.0083 - val_reconstruction_loss: 1.0083 - val_kl_loss: 1.1921e-07
# Epoch 2/5
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0322 - reconstruction_loss: 1.0233 - kl_loss: 1.7887e-06 - val_total_loss: 0.9913 - val_reconstruction_loss: 0.9913 - val_kl_loss: 1.1146e-05
# Epoch 3/5
# 262/262 [==============================] - 2s 6ms/step - loss: 1.0002 - reconstruction_loss: 1.0085 - kl_loss: 3.7913e-07 - val_total_loss: 0.9601 - val_reconstruction_loss: 0.9601 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9850 - reconstruction_loss: 0.9954 - kl_loss: 9.2532e-05 - val_total_loss: 0.9280 - val_reconstruction_loss: 0.9280 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 262/262 [==============================] - 2s 6ms/step - loss: 0.9822 - reconstruction_loss: 0.9872 - kl_loss: 0.0000e+00 - val_total_loss: 0.9541 - val_reconstruction_loss: 0.9541 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9541 - reconstruction_loss: 0.9541 - kl_loss: 0.0000e+00
# Epoch 1/5
# 131/131 [==============================] - 3s 11ms/step - loss: 1.0720 - reconstruction_loss: 1.0076 - kl_loss: 6.1492e-05 - val_total_loss: 0.9245 - val_reconstruction_loss: 0.9245 - val_kl_loss: 0.0000e+00
# Epoch 2/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9841 - reconstruction_loss: 0.9817 - kl_loss: 0.0000e+00 - val_total_loss: 0.8986 - val_reconstruction_loss: 0.8986 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 131/131 [==============================] - 1s 10ms/step - loss: 0.9722 - reconstruction_loss: 0.9763 - kl_loss: 0.0000e+00 - val_total_loss: 0.9099 - val_reconstruction_loss: 0.9099 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 131/131 [==============================] - 1s 9ms/step - loss: 0.9581 - reconstruction_loss: 0.9736 - kl_loss: 0.0000e+00 - val_total_loss: 0.9139 - val_reconstruction_loss: 0.9139 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 131/131 [==============================] - 1s 9ms/step - loss: 0.9670 - reconstruction_loss: 0.9763 - kl_loss: 0.0000e+00 - val_total_loss: 0.8859 - val_reconstruction_loss: 0.8859 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9290 - reconstruction_loss: 0.9290 - kl_loss: 0.0000e+00
# Epoch 1/5
# 66/66 [==============================] - 3s 18ms/step - loss: 1.0990 - reconstruction_loss: 1.0158 - kl_loss: 1.0769e-04 - val_total_loss: 0.8899 - val_reconstruction_loss: 0.8899 - val_kl_loss: 1.1027e-06
# Epoch 2/5
# 66/66 [==============================] - 1s 14ms/step - loss: 0.9667 - reconstruction_loss: 0.9660 - kl_loss: 1.5759e-07 - val_total_loss: 0.8812 - val_reconstruction_loss: 0.8812 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 66/66 [==============================] - 1s 15ms/step - loss: 0.9794 - reconstruction_loss: 0.9647 - kl_loss: 5.8412e-06 - val_total_loss: 0.8887 - val_reconstruction_loss: 0.8887 - val_kl_loss: 1.2606e-05
# Epoch 4/5
# 66/66 [==============================] - 1s 14ms/step - loss: 0.9649 - reconstruction_loss: 0.9658 - kl_loss: 1.2472e-06 - val_total_loss: 0.8902 - val_reconstruction_loss: 0.8902 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 66/66 [==============================] - 1s 18ms/step - loss: 0.9877 - reconstruction_loss: 0.9701 - kl_loss: 1.9828e-05 - val_total_loss: 0.8797 - val_reconstruction_loss: 0.8797 - val_kl_loss: 2.1756e-06
# 66/66 [==============================] - 0s 2ms/step - total_loss: 0.9202 - reconstruction_loss: 0.9202 - kl_loss: 2.1756e-06
# Epoch 1/5
# 33/33 [==============================] - 3s 35ms/step - loss: 1.0799 - reconstruction_loss: 1.0247 - kl_loss: 4.3051e-04 - val_total_loss: 0.8952 - val_reconstruction_loss: 0.8951 - val_kl_loss: 7.2956e-05
# Epoch 2/5
# 33/33 [==============================] - 1s 27ms/step - loss: 0.9625 - reconstruction_loss: 0.9647 - kl_loss: 1.3985e-05 - val_total_loss: 0.8790 - val_reconstruction_loss: 0.8790 - val_kl_loss: 5.9605e-07
# Epoch 3/5
# 33/33 [==============================] - 1s 28ms/step - loss: 0.9587 - reconstruction_loss: 0.9621 - kl_loss: 4.9309e-07 - val_total_loss: 0.8818 - val_reconstruction_loss: 0.8818 - val_kl_loss: 8.9407e-08
# Epoch 4/5
# 33/33 [==============================] - 1s 28ms/step - loss: 0.9509 - reconstruction_loss: 0.9611 - kl_loss: 6.3217e-09 - val_total_loss: 0.8845 - val_reconstruction_loss: 0.8845 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 33/33 [==============================] - 1s 30ms/step - loss: 0.9499 - reconstruction_loss: 0.9624 - kl_loss: 4.3349e-08 - val_total_loss: 0.8893 - val_reconstruction_loss: 0.8893 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 3ms/step - total_loss: 0.9297 - reconstruction_loss: 0.9297 - kl_loss: 0.0000e+00
# Epoch 1/5
# 262/262 [==============================] - 5s 9ms/step - loss: 1.3059 - reconstruction_loss: 1.1588 - kl_loss: 0.0010 - val_total_loss: 1.0445 - val_reconstruction_loss: 1.0310 - val_kl_loss: 0.0135
# Epoch 2/5
# 262/262 [==============================] - 2s 8ms/step - loss: 1.0713 - reconstruction_loss: 1.0752 - kl_loss: 6.4504e-04 - val_total_loss: 1.0136 - val_reconstruction_loss: 1.0136 - val_kl_loss: 4.1425e-06
# Epoch 3/5
# 262/262 [==============================] - 2s 6ms/step - loss: 1.1748 - reconstruction_loss: 1.3240 - kl_loss: 4.1517e-06 - val_total_loss: 1.4814 - val_reconstruction_loss: 1.4814 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 262/262 [==============================] - 2s 6ms/step - loss: 1.5041 - reconstruction_loss: 1.4927 - kl_loss: 0.0000e+00 - val_total_loss: 1.4945 - val_reconstruction_loss: 1.4945 - val_kl_loss: 0.0000e+00
# Epoch 5/5
# 262/262 [==============================] - 2s 6ms/step - loss: 1.4897 - reconstruction_loss: 1.4872 - kl_loss: 0.0000e+00 - val_total_loss: 1.4809 - val_reconstruction_loss: 1.4809 - val_kl_loss: 0.0000e+00
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.4809 - reconstruction_loss: 1.4809 - kl_loss: 0.0000e+00
# Epoch 1/5
# 131/131 [==============================] - 3s 13ms/step - loss: 1.6195 - reconstruction_loss: 1.5931 - kl_loss: 1.6667e-04 - val_total_loss: 1.5697 - val_reconstruction_loss: 1.5697 - val_kl_loss: 0.0000e+00
# Epoch 2/5
# 131/131 [==============================] - 1s 9ms/step - loss: 1.5527 - reconstruction_loss: 1.5701 - kl_loss: 0.0000e+00 - val_total_loss: 1.5739 - val_reconstruction_loss: 1.5739 - val_kl_loss: 0.0000e+00
# Epoch 3/5
# 131/131 [==============================] - 1s 9ms/step - loss: 1.5705 - reconstruction_loss: 1.5713 - kl_loss: 1.7976e-04 - val_total_loss: 1.5704 - val_reconstruction_loss: 1.5704 - val_kl_loss: 0.0000e+00
# Epoch 4/5
# 131/131 [==============================] - 1s 9ms/step - loss: 1.5812 - reconstruction_loss: 1.6442 - kl_loss: 0.0018 - val_total_loss: 1.8062 - val_reconstruction_loss: 1.8020 - val_kl_loss: 0.0042
# Epoch 5/5
# 131/131 [==============================] - 1s 11ms/step - loss: 1.7510 - reconstruction_loss: 1.7628 - kl_loss: 0.0133 - val_total_loss: 1.8174 - val_reconstruction_loss: 1.8168 - val_kl_loss: 5.1421e-04
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.8139 - reconstruction_loss: 1.8134 - kl_loss: 5.1421e-04
# Epoch 1/5
# 66/66 [==============================] - 3s 19ms/step - loss: 1.7732 - reconstruction_loss: 1.7706 - kl_loss: 0.0049 - val_total_loss: 1.8101 - val_reconstruction_loss: 1.8099 - val_kl_loss: 2.6131e-04
# Epoch 2/5
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7729 - reconstruction_loss: 1.7598 - kl_loss: 0.0018 - val_total_loss: 1.8095 - val_reconstruction_loss: 1.8095 - val_kl_loss: 9.3877e-06
# Epoch 3/5
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7627 - reconstruction_loss: 1.7595 - kl_loss: 0.0015 - val_total_loss: 1.8047 - val_reconstruction_loss: 1.8022 - val_kl_loss: 0.0025
# Epoch 4/5
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7773 - reconstruction_loss: 1.7517 - kl_loss: 0.0124 - val_total_loss: 1.7916 - val_reconstruction_loss: 1.7914 - val_kl_loss: 1.6072e-04
# Epoch 5/5
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7416 - reconstruction_loss: 1.7489 - kl_loss: 2.6787e-04 - val_total_loss: 1.7972 - val_reconstruction_loss: 1.7972 - val_kl_loss: 1.1235e-05
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.7963 - reconstruction_loss: 1.7963 - kl_loss: 1.1235e-05
# Epoch 1/5
# 33/33 [==============================] - 3s 34ms/step - loss: 1.7766 - reconstruction_loss: 1.7605 - kl_loss: 0.0020 - val_total_loss: 1.8072 - val_reconstruction_loss: 1.8067 - val_kl_loss: 4.3052e-04
# Epoch 2/5
# 33/33 [==============================] - 1s 26ms/step - loss: 1.7604 - reconstruction_loss: 1.7573 - kl_loss: 7.8872e-05 - val_total_loss: 1.8062 - val_reconstruction_loss: 1.8062 - val_kl_loss: 8.1360e-06
# Epoch 3/5
# 33/33 [==============================] - 1s 25ms/step - loss: 1.7566 - reconstruction_loss: 1.7545 - kl_loss: 0.0107 - val_total_loss: 1.8111 - val_reconstruction_loss: 1.8053 - val_kl_loss: 0.0058
# Epoch 4/5
# 33/33 [==============================] - 1s 26ms/step - loss: 1.7587 - reconstruction_loss: 1.7514 - kl_loss: 0.0017 - val_total_loss: 1.7993 - val_reconstruction_loss: 1.7992 - val_kl_loss: 1.0878e-04
# Epoch 5/5
# 33/33 [==============================] - 1s 26ms/step - loss: 1.7532 - reconstruction_loss: 1.7514 - kl_loss: 4.6691e-04 - val_total_loss: 1.8017 - val_reconstruction_loss: 1.8016 - val_kl_loss: 9.8407e-05
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.7887 - reconstruction_loss: 1.7886 - kl_loss: 9.8407e-05
# Best Hyperparameters: {'learn_rate': 0.005, 'batch_size': 128}
# Best Score: [0.9049680233001709, 0.9049667716026306, 1.2814998626708984e-06]

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = lr))

reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)
early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1, restore_best_weights=True)

vae.fit(x_train, batch_size=bs, epochs=50, validation_data=(x_test, y_test), callbacks=[reduce_lr, early_stop])
#vae.fit(x_train, batch_size=128, epochs=5, validation_data=(x_test, y_test, None))
#vae.fit(x_train, batch_size=128, epochs=5)
# Out:
# Epoch 1/50
# 66/66 [==============================] - 3s 17ms/step - loss: 1.7542 - reconstruction_loss: 1.7521 - kl_loss: 5.2768e-06 - val_total_loss: 1.7972 - val_reconstruction_loss: 1.7972 - val_kl_loss: 0.0000e+00 - lr: 0.0050
# Epoch 2/50
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7360 - reconstruction_loss: 1.7544 - kl_loss: 1.8062e-09 - val_total_loss: 1.7962 - val_reconstruction_loss: 1.7962 - val_kl_loss: 0.0000e+00 - lr: 0.0050
# Epoch 3/50
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7599 - reconstruction_loss: 1.7527 - kl_loss: 0.0000e+00 - val_total_loss: 1.7962 - val_reconstruction_loss: 1.7962 - val_kl_loss: 0.0000e+00 - lr: 0.0050
# Epoch 4/50
# 63/66 [===========================>..] - ETA: 0s - loss: 1.7493 - reconstruction_loss: 1.7527 - kl_loss: 0.0000e+00
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7495 - reconstruction_loss: 1.7527 - kl_loss: 0.0000e+00 - val_total_loss: 1.8102 - val_reconstruction_loss: 1.8102 - val_kl_loss: 0.0000e+00 - lr: 0.0050
# Epoch 5/50
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7467 - reconstruction_loss: 1.7523 - kl_loss: 4.1023e-06 - val_total_loss: 1.7977 - val_reconstruction_loss: 1.7977 - val_kl_loss: 0.0000e+00 - lr: 0.0025
# Epoch 6/50
# 61/66 [==========================>...] - ETA: 0s - loss: 1.7422 - reconstruction_loss: 1.7486 - kl_loss: 0.0000e+00Restoring model weights from the end of the best epoch: 1.
# 66/66 [==============================] - 1s 14ms/step - loss: 1.7430 - reconstruction_loss: 1.7535 - kl_loss: 0.0000e+00 - val_total_loss: 1.7942 - val_reconstruction_loss: 1.7942 - val_kl_loss: 0.0000e+00 - lr: 0.0025
# Epoch 6: early stopping

# %%
#print(x_test.shape)
#print(y_test.shape)

validation_loss = vae.evaluate(x_test, y_test)
print("Validation Loss:", validation_loss)
# Out:
# 66/66 [==============================] - 0s 2ms/step - total_loss: 1.8015 - reconstruction_loss: 1.8015 - kl_loss: 0.0000e+00
# Validation Loss: [1.8015245199203491, 1.8015245199203491, 0.0]

# %%
import matplotlib.pyplot as plt

# encode data into the latent space
_, _, encoded_x_train = vae.encoder.predict(x_train)
_, _, encoded_x_test = vae.encoder.predict(x_test)

label_colors = {0: 'blue', 1: 'red', 2: 'green', 3: 'orange'}

# input data
plt.figure(figsize=(10, 6))
for label in range(4):
    indices_train = np.where(y_train == label)[0]
    plt.scatter(encoded_x_train[indices_train, 0], encoded_x_train[indices_train, 1], c=label_colors[label],
                label='Label {}'.format(label))
plt.title('Latent Space Visualization - Input Data')
plt.xlabel('Latent Dimension 1')
plt.ylabel('Latent Dimension 2')
plt.legend()
plt.show()

# validation data
plt.figure(figsize=(10, 6))
for label in range(4):
    indices_test = np.where(y_test == label)[0]
    plt.scatter(encoded_x_test[indices_test, 0], encoded_x_test[indices_test, 1], c=label_colors[label],
                label='Label {}'.format(label))
plt.title('Latent Space Visualization - Validation Data')
plt.xlabel('Latent Dimension 1')
plt.ylabel('Latent Dimension 2')
plt.legend()
plt.show()
# Out:
# 262/262 [==============================] - 0s 973us/step
# 66/66 [==============================] - 0s 1ms/step

# %%
def plot_input_and_reconstructed_data(x_input_data, y_input_data):
    _, _, z_input = encoder.predict(x_input_data)
    reconstructed_data = vae.decoder.predict(z_input)
    _, _, recon_data_lsp = vae.encoder.predict(reconstructed_data)
    
    unique_labels = np.unique(y_input_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_input_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.scatter(recon_data_lsp[:, 0], recon_data_lsp[:, 1], c='black', alpha=0.5, label='Reconstructed Data')

    plt.xlabel("Latent Dimension 1")
    plt.ylabel("Latent Dimension 2")
    plt.title("Input Data and Reconstructed Data in Latent Space")
    plt.legend()
    plt.show()

# Assuming `x_test` and `y_test` are the original input data
# and `reconstructed_x_test` is the reconstructed data obtained from the decoder
plot_input_and_reconstructed_data(x_test, y_test)
# Out:
# 66/66 [==============================] - 0s 758us/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 821us/step

# %%
import matplotlib.pyplot as plt

def plot_input_data(encoder, x_data, y_data):
    _, _, z_input = encoder.predict(x_data)
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(z_input[indices, 0], z_input[indices, 1], c=label_colors[label], label=f'Label {label}')

    plt.xlabel("Latent Dimension 1")
    plt.ylabel("Latent Dimension 2")
    plt.title("Input Data")
    plt.legend()
    plt.show()

def plot_reconstructed_data(encoder, decoder, x_data, y_data):
    _, _, z = encoder.predict(x_data)
    reconstructed_data = decoder.predict(z)
    _, _, recon_data_lsp = encoder.predict(reconstructed_data)
    unique_labels = np.unique(y_data)
    label_colors = ['blue', 'red', 'green', 'orange']
    
    for label in unique_labels:
        indices = np.where(y_data == label)[0]
        plt.scatter(recon_data_lsp[indices, 0], recon_data_lsp[indices, 1], 
                    c=label_colors[label], label=f'Label {label}')

    plt.xlabel("Latent Dimension 1")
    plt.ylabel("Latent Dimension 2")
    plt.title("Reconstructed Data")
    plt.legend()
    plt.show()
    
plt.figure(figsize=(10, 6))
plot_input_data(encoder, x_train, y_train) 

plt.figure(figsize=(10, 6))
plot_reconstructed_data(encoder, decoder, x_test, y_test)
# Out:
# 262/262 [==============================] - 0s 948us/step
# 66/66 [==============================] - 0s 1ms/step
# 66/66 [==============================] - 0s 2ms/step
# 66/66 [==============================] - 0s 1ms/step

# %%
from Bio import pairwise2
from Bio.Seq import Seq

def calculate_sequence_similarity(seq1, seq2):
    # Convert the sequences to Seq objects
    seq1 = Seq(seq1)
    seq2 = Seq(seq2)

    # Perform global sequence alignment
    alignments = pairwise2.align.globalxx(seq1, seq2)

    # Get the alignment with the best score (the first one in the list)
    best_alignment = alignments[0]
    seq1_aligned, seq2_aligned, score, begin, end = best_alignment

    # Calculate similarity as a percentage
    similarity = (score / max(len(seq1), len(seq2))) * 100

    return similarity

similarities_train = []
similarities_test = []

for i in range(50):
    row_similarities_train = []
    row_similarities_test = []
    for j in range(50,100):
        sim_train = calculate_sequence_similarity(x_train_seq[i], x_train_seq[j])/100
        sim_test = calculate_sequence_similarity(x_test_seq[i], x_test_seq[j])/100
        row_similarities_train.append(sim_train)
        row_similarities_test.append(sim_test)
        
    similarities_train.append(row_similarities_train)
    similarities_test.append(row_similarities_test)
    
similarities_train = np.array(similarities_train)
similarities_test = np.array(similarities_test)

print(similarities_train)
print(similarities_test)
# Out:
# [[0.25581395 0.13953488 0.39534884 ... 0.23255814 0.39534884 0.18604651]
#  [0.1025641  0.         0.12820513 ... 0.04347826 0.13157895 0.125     ]
#  [0.20512821 0.28       0.23076923 ... 0.24       0.18421053 0.32      ]
#  ...
#  [0.33333333 0.21621622 0.35897436 ... 0.24324324 0.34210526 0.32432432]
#  [0.33333333 0.17777778 0.26666667 ... 0.2        0.33333333 0.22222222]
#  [0.07692308 0.25       0.15384615 ... 0.2173913  0.18421053 0.16666667]]
# [[0.27272727 0.18604651 0.27906977 ... 0.13953488 0.27906977 0.20930233]
#  [0.36363636 0.25581395 0.27906977 ... 0.09302326 0.3255814  0.1627907 ]
#  [0.25       0.17241379 0.26666667 ... 0.2        0.14285714 0.3       ]
#  ...
#  [0.15909091 0.31034483 0.33333333 ... 0.17857143 0.26190476 0.28571429]
#  [0.34090909 0.2972973  0.54054054 ... 0.13513514 0.28571429 0.24324324]
#  [0.09090909 0.13793103 0.06666667 ... 0.33333333 0.0952381  0.17647059]]

# %%
_, _, encoded_x_train_dist = vae.encoder.predict(x_train)
_, _, encoded_x_test_dist = vae.encoder.predict(x_test)
# Out:
# 262/262 [==============================] - 0s 970us/step
# 66/66 [==============================] - 0s 985us/step

# %%
def euclidean_distance(x, y):
    return np.sqrt(np.sum((x - y)**2))

def calculate_distance(latent_representations):
    num_peptides = len(latent_representations)
    distance_matrix = np.zeros((num_peptides, num_peptides))
    
    for i in range(num_peptides):
        for j in range(num_peptides):
            distance_matrix[i, j] = euclidean_distance(latent_representations[i], latent_representations[j])
    
    return distance_matrix

distances_train = []
distances_test = []

for i in range(50):
    row_distances_train = []
    row_distances_test = []
    for j in range(50,100):
        dist_train = euclidean_distance(encoded_x_train_dist[i], encoded_x_train_dist[j])
        dist_test = euclidean_distance(encoded_x_train_dist[i], encoded_x_test_dist[j])
        row_distances_train.append(dist_train)
        row_distances_test.append(dist_test)
        
    distances_train.append(row_distances_train)
    distances_test.append(row_distances_test)
        
distances_train = np.array(distances_train)
distances_test = np.array(distances_test)

normalized_distances_train = scaler.fit_transform(distances_train)
normalized_distances_test = scaler.fit_transform(distances_test)

print(normalized_distances_train)
print(normalized_distances_test)
# Out:
# [[0.708267   0.26070946 0.         ... 0.6259526  0.10844216 0.5561065 ]
#  [0.6431471  0.14843914 0.4465599  ... 0.6429196  0.42565688 0.18386468]
#  [0.47079378 0.35806122 0.5879358  ... 0.51281923 0.55626327 0.044031  ]
#  ...
#  [0.5199027  1.         0.860826   ... 0.36564076 0.94869524 1.        ]
#  [0.2815094  0.6834684  0.5426031  ... 0.14174876 0.57183623 0.6684885 ]
#  [0.10562276 0.8725574  0.86755073 ... 0.07286511 0.8941462  0.7073661 ]]
# [[0.21743572 0.2836216  0.3912293  ... 0.51207733 0.5305189  0.464159  ]
#  [0.17444494 0.07982609 0.01810396 ... 0.18516101 0.53505486 0.2781045 ]
#  [0.3900247  0.2982483  0.15610886 ... 0.04197311 0.41357452 0.22808656]
#  ...
#  [1.         1.         0.99999994 ... 1.         0.623579   0.99999994]
#  [0.6932901  0.6744162  0.6484885  ... 0.6186739  0.2029247  0.5726463 ]
#  [0.8957761  0.8489131  0.780231   ... 0.7064676  0.362886   0.73588806]]

# %%
from scipy.stats import spearmanr, kendalltau, pearsonr

correlation_train, p_value_train = spearmanr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = spearmanr(similarities_test.flatten(), distances_test.flatten())

print("Spearman's Correlation:", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)

correlation_train, p_value_train = pearsonr(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = pearsonr(similarities_test.flatten(), distances_test.flatten())

print("Pearson's Correlation:", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)

correlation_train, p_value_train = kendalltau(similarities_train.flatten(), distances_train.flatten())
correlation_test, p_value_test = kendalltau(similarities_test.flatten(), distances_test.flatten())

print("Kendall's tau Correlation:", correlation_train, correlation_test)
print("p-value:", p_value_train, p_value_test)
# Out:
# Spearman's Correlation: -0.022151710238326443 -0.039027511956139606
# p-value: 0.2682215433653331 0.05104003610727663
# Pearson's Correlation: -0.005764714620615829 -0.039515358097046975
# p-value: 0.7732748055417407 0.04820561232985058
# Kendall's tau Correlation: -0.015142965356602206 -0.026418052516195303
# p-value: 0.25829267596732985 0.04874495771737554
