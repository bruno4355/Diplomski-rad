# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
from sklearn.model_selection import train_test_split

class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
latent_dim = 2

encoder_inputs = keras.Input(shape=(89, 1))
x = layers.Conv1D(8, 3, activation='relu', padding='same', dilation_rate=2)(encoder_inputs)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same', dilation_rate=2)(x)
x = layers.MaxPooling1D(2)(x)
x = layers.Flatten()(x)
encoder = layers.Dense(128, activation='relu')(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(encoder)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(encoder)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(128, activation='relu')(latent_inputs)
x = layers.Dense(89 * 8)(x)
x = layers.Reshape((89, 8))(x)
x = layers.Conv1D(16, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
x = layers.Conv1D(8, 3, activation='relu', padding='same')(x)
x = layers.UpSampling1D(2)(x)
decoded = layers.Conv1D(1, 3, activation='sigmoid', padding='same')(x)
decoded = layers.Cropping1D(cropping=(0, 267))(decoded)  # Crop to the desired output shape
decoder = keras.Model(latent_inputs, decoded, name="decoder")
decoder.summary()

class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    (data - reconstruction)**2, axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 89, 8)        32          ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 44, 8)        0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 44, 16)       400         ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 22, 16)      0           ['conv1d_1[0][0]']
#
#  flatten (Flatten)              (None, 352)          0           ['max_pooling1d_1[0][0]']
#
#  dense (Dense)                  (None, 128)          45184       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            258         ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            258         ['dense[0][0]']
#
#  sampling (Sampling)            (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 46,132
# Trainable params: 46,132
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 128)               384
#
#  dense_2 (Dense)             (None, 712)               91848
#
#  reshape (Reshape)           (None, 89, 8)             0
#
#  conv1d_2 (Conv1D)           (None, 89, 16)            400
#
#  up_sampling1d (UpSampling1D  (None, 178, 16)          0
#  )
#
#  conv1d_3 (Conv1D)           (None, 178, 8)            392
#
#  up_sampling1d_1 (UpSampling  (None, 356, 8)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 356, 1)            25
#
#  cropping1d (Cropping1D)     (None, 89, 1)             0
#
# =================================================================
# Total params: 93,049
# Trainable params: 93,049
# Non-trainable params: 0
# _________________________________________________________________

# %%
#(x_train) = pd.read_csv('train_dataset.csv')
#(x_test) = pd.read_csv('test_dataset.csv')
df = pd.read_csv('amp+avp_features.csv')
(x_train, x_test) = train_test_split(df, test_size=0.2, random_state=42)

from sklearn.preprocessing import MinMaxScaler, Normalizer

# Separate the last column from x_train and x_test
x_train_last_col = x_train['label']
x_test_last_col = x_test['label']

# Convert the remaining columns to NumPy arrays
x_train_features = x_train.drop('label', axis=1).values
x_test_features = x_test.drop('label', axis=1).values

# Apply scaling and normalization to the features
scaler = MinMaxScaler()
normalizer = Normalizer()

x_train_scaled = scaler.fit_transform(x_train_features)
x_train_scaled_normalized = normalizer.fit_transform(x_train_scaled)

x_test_scaled = scaler.transform(x_test_features)
x_test_scaled_normalized = normalizer.transform(x_test_scaled)

# Concatenate the normalized features with the last column
x_train_processed = np.hstack((x_train_scaled_normalized, x_train_last_col.values[:, np.newaxis]))
x_test_processed = np.hstack((x_test_scaled_normalized, x_test_last_col.values[:, np.newaxis]))

#print(x_train.shape)
#print(x_test.shape)
peptides = np.concatenate([x_train, x_test], axis=0)
#print(peptides.shape)
peptides = np.expand_dims(peptides, -1)
#print(peptides.shape)

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
#vae.fit(peptides, batch_size=50, epochs=8)
vae.fit(peptides, batch_size=128, epochs=5, validation_data=(validation_data, None))
# Out:
# Epoch 1/50
# 82/82 [==============================] - 3s 13ms/step - loss: 70.8982 - reconstruction_loss: 59.9805 - kl_loss: 1.0058
# Epoch 2/50
# 82/82 [==============================] - 1s 13ms/step - loss: 50.1095 - reconstruction_loss: 49.8206 - kl_loss: 0.0408
# Epoch 3/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.7640 - reconstruction_loss: 49.6730 - kl_loss: 0.0065
# Epoch 4/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.2595 - reconstruction_loss: 49.5455 - kl_loss: 0.0045
# Epoch 5/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1832 - reconstruction_loss: 49.3619 - kl_loss: 0.0069
# Epoch 6/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.8128 - reconstruction_loss: 49.2649 - kl_loss: 0.0056
# Epoch 7/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1559 - reconstruction_loss: 49.2547 - kl_loss: 0.0048
# Epoch 8/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.4382 - reconstruction_loss: 49.2156 - kl_loss: 0.0039
# Epoch 9/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1196 - reconstruction_loss: 49.2037 - kl_loss: 0.0037
# Epoch 10/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3297 - reconstruction_loss: 49.1973 - kl_loss: 0.0035
# Epoch 11/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3396 - reconstruction_loss: 49.2134 - kl_loss: 0.0032
# Epoch 12/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1355 - reconstruction_loss: 49.2135 - kl_loss: 0.0033
# Epoch 13/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.0610 - reconstruction_loss: 49.2071 - kl_loss: 0.0030
# Epoch 14/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9534 - reconstruction_loss: 49.1845 - kl_loss: 0.0032
# Epoch 15/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.6065 - reconstruction_loss: 49.1923 - kl_loss: 0.0028
# Epoch 16/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.4050 - reconstruction_loss: 49.1993 - kl_loss: 0.0029
# Epoch 17/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.4052 - reconstruction_loss: 49.1982 - kl_loss: 0.0028
# Epoch 18/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.5607 - reconstruction_loss: 49.1842 - kl_loss: 0.0038
# Epoch 19/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3009 - reconstruction_loss: 49.1829 - kl_loss: 0.0037
# Epoch 20/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.8188 - reconstruction_loss: 49.1805 - kl_loss: 0.0031
# Epoch 21/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.2493 - reconstruction_loss: 49.1594 - kl_loss: 0.0029
# Epoch 22/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9273 - reconstruction_loss: 49.1473 - kl_loss: 0.0022
# Epoch 23/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.1495 - reconstruction_loss: 49.1583 - kl_loss: 0.0019
# Epoch 24/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.1857 - reconstruction_loss: 49.1575 - kl_loss: 0.0020
# Epoch 25/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.0287 - reconstruction_loss: 49.1736 - kl_loss: 0.0023
# Epoch 26/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.0361 - reconstruction_loss: 49.1702 - kl_loss: 0.0019
# Epoch 27/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1292 - reconstruction_loss: 49.1469 - kl_loss: 0.0014
# Epoch 28/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.8809 - reconstruction_loss: 49.1748 - kl_loss: 0.0018
# Epoch 29/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3133 - reconstruction_loss: 49.1553 - kl_loss: 0.0023
# Epoch 30/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3421 - reconstruction_loss: 49.1282 - kl_loss: 0.0021
# Epoch 31/50
# 82/82 [==============================] - 1s 14ms/step - loss: 48.8644 - reconstruction_loss: 49.1311 - kl_loss: 0.0017
# Epoch 32/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.0547 - reconstruction_loss: 49.1216 - kl_loss: 0.0012
# Epoch 33/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.3644 - reconstruction_loss: 49.1317 - kl_loss: 8.2056e-04
# Epoch 34/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1495 - reconstruction_loss: 49.1224 - kl_loss: 8.9839e-04
# Epoch 35/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9654 - reconstruction_loss: 49.1370 - kl_loss: 0.0013
# Epoch 36/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1565 - reconstruction_loss: 49.1474 - kl_loss: 0.0016
# Epoch 37/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1766 - reconstruction_loss: 49.1119 - kl_loss: 0.0013
# Epoch 38/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.2913 - reconstruction_loss: 49.1242 - kl_loss: 0.0013
# Epoch 39/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.4720 - reconstruction_loss: 49.1361 - kl_loss: 0.0014
# Epoch 40/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9558 - reconstruction_loss: 49.1232 - kl_loss: 0.0015
# Epoch 41/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1178 - reconstruction_loss: 49.1191 - kl_loss: 0.0018
# Epoch 42/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1435 - reconstruction_loss: 49.1246 - kl_loss: 0.0011
# Epoch 43/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.1759 - reconstruction_loss: 49.1297 - kl_loss: 8.6168e-04
# Epoch 44/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.0775 - reconstruction_loss: 49.1131 - kl_loss: 7.9904e-04
# Epoch 45/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.2258 - reconstruction_loss: 49.1265 - kl_loss: 0.0010
# Epoch 46/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9928 - reconstruction_loss: 49.1144 - kl_loss: 9.5823e-04
# Epoch 47/50
# 82/82 [==============================] - 1s 13ms/step - loss: 49.3243 - reconstruction_loss: 49.1306 - kl_loss: 0.0010
# Epoch 48/50
# 82/82 [==============================] - 1s 13ms/step - loss: 48.9203 - reconstruction_loss: 49.1439 - kl_loss: 0.0015
# Epoch 49/50
# 82/82 [==============================] - 1s 14ms/step - loss: 49.2781 - reconstruction_loss: 49.1132 - kl_loss: 0.0013
# Epoch 50/50
# 82/82 [==============================] - 1s 14ms/step - loss: 48.8204 - reconstruction_loss: 49.1232 - kl_loss: 9.3149e-04

# %%
#VIZUALIZACIJA
import matplotlib.pyplot as plt

img_width = 89
img_height = 1
num_channels = 1

def viz_latent_space(encoder, data, labels):
    input_data, target_data = data
    mu, _, _ = encoder.predict(input_data)
    labels = input_data['label']
    print(labels)
    print(labels.shape)
    # Plot points with label 0 in blue
    plt.scatter(mu[labels == 0, 0], mu[labels == 0, 1], c='blue', label='Label 0')
    
    # Plot points with label 1 in red
    plt.scatter(mu[labels == 1, 0], mu[labels == 1, 1], c='red', label='Label 1')
    
    # Plot points with label 2 in green
    plt.scatter(mu[labels == 2, 0], mu[labels == 2, 1], c='green', label='Label 2')
    
    # Plot points with label 3 in yellow
    plt.scatter(mu[labels == 3, 0], mu[labels == 3, 1], c='yellow', label='Label 3')
    
    plt.xlabel('z - dim 1')
    plt.ylabel('z - dim 2')
    plt.colorbar()
    plt.legend()
    plt.show()
    
label_data = pd.read_csv('tmp.csv')
labels = label_data['Antiviral'].values
    
data = (x_train, x_test)
print(x_train.shape)
viz_latent_space(encoder, data, labels)
# Out:
# (8367, 89)
# 262/262 [==============================] - 0s 962us/step
# 7364    2
# 611     3
# 3333    3
# 9483    1
# 511     2
#        ..
# 5734    2
# 5191    2
# 5390    2
# 860     2
# 7270    3
# Name: label, Length: 8367, dtype: int64
# (8367,)
